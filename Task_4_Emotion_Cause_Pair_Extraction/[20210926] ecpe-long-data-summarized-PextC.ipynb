# %%
# connect to google colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# base path
DATA_PATH = './drive/MyDrive/fyp-code/codes/data/ecpe/'
MODEL_PATH = './drive/MyDrive/fyp-code/codes/model/ecpe/CE/long_summarized/'

# %%
############################################ IMPORT ##########################################################
import sys, os
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# call the zip folder with all the self defined modules
base_folder = '/content/drive/MyDrive/fyp-code/codes'

training_path = os.path.join(base_folder, "utils_ecpe.zip") 
# !unzip $training_path

from funcs import *
from prepare_data import *
# Out:
# Archive:  /content/drive/MyDrive/fyp-code/codes/utils_ecpe.zip
#   inflating: funcs.py
#   inflating: prepare_data.py

# %%
############################################ FLAGS ############################################################
# file names of the data files
LOOKUP = 'ecpe_long_summarized_max_5_clauses_annotated.csv'
DATA = 'long_summarized'
TRAIN_DATA = 'ecpe_long_summarized_max_5_clauses_annotated_train'
VAL_DATA = 'ecpe_long_summarized_max_5_clauses_annotated_val'

# fixed parameters
train_file_path = DATA_PATH + LOOKUP                                # clause keyword file
w2v_file = DATA_PATH+'w2v_200.txt'                                  # embedding file
embedding_dim = 200                                                 # dimension of word embedding
embedding_dim_pos = 30                                              # dimension of position embedding
max_sen_len = 30                                                    # max number of tokens per sentence
max_doc_len = 41                                                    # max number of tokens per document
n_class = 2                                                         # number of distinct class
training_epochs = 20                                                # number of train epochs
keep_prob1 = 0.8                                                    # word embedding training dropout keep prob
keep_prob2 = 1.0                                                    # softmax layer dropout keep prob
keep_prob3 = 1.0                                                    # softmax layer dropout keep prob
l2_reg = 0.00010                                                    # l2 regularization
cause = 1.0                                                         # lambda1
pos = 1.0                                                           # lambda2
pair = 2.5                                                          # lambda3

# hyperparameters considered for tuning (will be tuned later when the class is called)
n_hidden = None                                                     # number of hidden unit
batch_size = None                                                   # number of example per batch
learning_rate = None                                                # learning rate
diminish_factor = None                                              # give less weight to -ve examples

# %%
############################################ MODEL ############################################################
class E2E_PextC(nn.Module):
    def __init__(self, embedding_dim, embedding_dim_pos, sen_len, doc_len, keep_prob1, keep_prob2, \
                 keep_prob3, n_hidden, n_class):
        super(E2E_PextC, self).__init__()
        self.embedding_dim = embedding_dim; self.embedding_dim_pos = embedding_dim_pos 
        self.sen_len = sen_len; self.doc_len = doc_len
        self.keep_prob1 = keep_prob1; self.keep_prob2 = keep_prob2
        self.n_hidden = n_hidden; self.n_class = n_class

        self.dropout1 = nn.Dropout(p = 1 - keep_prob1)
        self.dropout2 = nn.Dropout(p = 1 - keep_prob2)
        self.dropout3 = nn.Dropout(p = 1 - keep_prob3)
        self.relu = nn.ReLU()
        self.pos_linear = nn.Linear(2*n_hidden, n_class)
        self.cause_linear = nn.Linear(2*n_hidden, n_class)
        self.pair_linear1 = nn.Linear(4*n_hidden + embedding_dim_pos, n_hidden//2)
        self.pair_linear2 = nn.Linear(n_hidden//2, n_class)
        self.word_bilstm = nn.LSTM(embedding_dim, n_hidden, batch_first = True, bidirectional = True)
        self.cause_bilstm = nn.LSTM(2*n_hidden, n_hidden, batch_first = True, bidirectional = True)
        self.pos_bilstm = nn.LSTM(2*n_hidden + n_class, n_hidden, batch_first = True, bidirectional = True)
        self.attention = Attention(n_hidden, sen_len)

    def get_clause_embedding(self, x):
        '''
        input shape: [batch_size, doc_len, sen_len, embedding_dim]
        output shape: [batch_size, doc_len, 2 * n_hidden]
        '''
        x = x.reshape(-1, self.sen_len, self.embedding_dim)
        x = self.dropout1(x)
        # x is of shape (batch_size * max_doc_len, max_sen_len, embedding_dim)
        x, hidden_states = self.word_bilstm(x.float())
        # x is of shape (batch_size * max_doc_len, max_sen_len, 2 * n_hidden)
        s = self.attention(x).reshape(-1, self.doc_len, 2 * self.n_hidden)
        # s is of shape (batch_size, max_doc_len, 2 * n_hidden)
        return s

    def get_emotion_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden + n_class]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.pos_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_pos = F.softmax(self.pos_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_pos = pred_pos.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_pos

    def get_cause_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.cause_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_cause = F.softmax(self.cause_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_cause = pred_cause.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_cause

    def get_pair_prediction(self, x1, x2, distance):
        '''
        input(s) shape: [batch_size * doc_len, 2 * n_hidden], [batch_size * doc_len, 2 * n_hidden], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos] 
        output shape: [batch_size, doc_len * doc_len, n_class]
        '''        
        x = create_pairs(x1, x2)
        # x is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden)
        x_distance = torch.cat([x, distance.float()], -1)
        # x_distance is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        x_distance = x_distance.reshape(-1, 4 * self.n_hidden + self.embedding_dim_pos)
        x_distance = self.dropout3(x_distance)
        # x is of shape (batch_size * max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        pred_pair = F.softmax(self.pair_linear2(self.relu(self.pair_linear1(x_distance))), dim = -1)
        # pred_pair is of shape (batch_size * max_doc_len * max_doc_len, n_class)
        pred_pair = pred_pair.reshape(-1, self.doc_len * self.doc_len, self.n_class)
        # pred_pair is of shape (batch_size, max_doc_len * max_doc_len, n_class)
        return pred_pair

    def forward(self, x, distance):
        '''
        input(s) shape: [batch_size, doc_len, sen_len, embedding_dim], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos]
        output(s) shape: [batch_size, doc_len, n_class], [batch_size, doc_len, n_class], 
                         [batch_size, doc_len * doc_len, n_class]
        '''
        s = self.get_clause_embedding(x)
        x_cause, pred_cause = self.get_cause_prediction(s)
        s_pred_cause = torch.cat([s, pred_cause], 2)
        x_pos, pred_pos = self.get_emotion_prediction(s_pred_cause)
        pred_pair = self.get_pair_prediction(x_pos, x_cause, distance)
        return pred_pos, pred_cause, pred_pair

# %%
## PextE Tryout
############################################ MODEL ############################################################
class E2E_PextE(nn.Module):
    def __init__(self, embedding_dim, embedding_dim_pos, sen_len, doc_len, keep_prob1, keep_prob2, \
                 keep_prob3, n_hidden, n_class):
        super(E2E_PextE, self).__init__()
        self.embedding_dim = embedding_dim; self.embedding_dim_pos = embedding_dim_pos 
        self.sen_len = sen_len; self.doc_len = doc_len
        self.keep_prob1 = keep_prob1; self.keep_prob2 = keep_prob2
        self.n_hidden = n_hidden; self.n_class = n_class

        self.dropout1 = nn.Dropout(p = 1 - keep_prob1)
        self.dropout2 = nn.Dropout(p = 1 - keep_prob2)
        self.dropout3 = nn.Dropout(p = 1 - keep_prob3)
        self.relu = nn.ReLU()
        self.pos_linear = nn.Linear(2*n_hidden, n_class)
        self.cause_linear = nn.Linear(2*n_hidden, n_class)
        self.pair_linear1 = nn.Linear(4*n_hidden + embedding_dim_pos, n_hidden//2)
        self.pair_linear2 = nn.Linear(n_hidden//2, n_class)
        self.word_bilstm = nn.LSTM(embedding_dim, n_hidden, batch_first = True, bidirectional = True)
        self.cause_bilstm = nn.LSTM(2*n_hidden + n_class, n_hidden, batch_first = True, bidirectional = True)
        self.pos_bilstm = nn.LSTM(2*n_hidden, n_hidden, batch_first = True, bidirectional = True)
        self.attention = Attention(n_hidden, sen_len)

    def get_clause_embedding(self, x):
        '''
        input shape: [batch_size, doc_len, sen_len, embedding_dim]
        output shape: [batch_size, doc_len, 2 * n_hidden]
        '''
        x = x.reshape(-1, self.sen_len, self.embedding_dim)
        x = self.dropout1(x)
        # x is of shape (batch_size * max_doc_len, max_sen_len, embedding_dim)
        x, hidden_states = self.word_bilstm(x.float())
        # x is of shape (batch_size * max_doc_len, max_sen_len, 2 * n_hidden)
        s = self.attention(x).reshape(-1, self.doc_len, 2 * self.n_hidden)
        # s is of shape (batch_size, max_doc_len, 2 * n_hidden)
        return s

    def get_emotion_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.pos_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_pos = F.softmax(self.pos_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_pos = pred_pos.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_pos

    def get_cause_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden + n_class]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.cause_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_cause = F.softmax(self.cause_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_cause = pred_cause.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_cause

    def get_pair_prediction(self, x1, x2, distance):
        '''
        input(s) shape: [batch_size * doc_len, 2 * n_hidden], [batch_size * doc_len, 2 * n_hidden], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos] 
        output shape: [batch_size, doc_len * doc_len, n_class]
        '''        
        x = create_pairs(x1, x2)
        # x is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden)
        x_distance = torch.cat([x, distance.float()], -1)
        # x_distance is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        x_distance = x_distance.reshape(-1, 4 * self.n_hidden + self.embedding_dim_pos)
        x_distance = self.dropout3(x_distance)
        # x is of shape (batch_size * max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        pred_pair = F.softmax(self.pair_linear2(self.relu(self.pair_linear1(x_distance))), dim = -1)
        # pred_pair is of shape (batch_size * max_doc_len * max_doc_len, n_class)
        pred_pair = pred_pair.reshape(-1, self.doc_len * self.doc_len, self.n_class)
        # pred_pair is of shape (batch_size, max_doc_len * max_doc_len, n_class)
        return pred_pair

    def forward(self, x, distance):
        '''
        input(s) shape: [batch_size, doc_len, sen_len, embedding_dim], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos]
        output(s) shape: [batch_size, doc_len, n_class], [batch_size, doc_len, n_class], 
                         [batch_size, doc_len * doc_len, n_class]
        '''
        s = self.get_clause_embedding(x)
        x_pos, pred_pos = self.get_emotion_prediction(s)
        s_pred_pos = torch.cat([s, pred_pos], 2)
        x_cause, pred_cause = self.get_cause_prediction(s_pred_pos)
        pred_pair = self.get_pair_prediction(x_pos, x_cause, distance)
        return pred_pos, pred_cause, pred_pair

# %%
def load_data_pair(input_file, word_idx, max_doc_len = 75, max_sen_len = 45):
    print('load data_file: {}'.format(input_file))
    pair_id_all, y_position, y_cause, y_pair, x, sen_len, doc_len, distance = [], [], [], [], [], [], [], []
    n_cut = 0
    inputFile = open(input_file, 'r')
    while True:
        line = inputFile.readline()
        if line == '': break
        line = line.strip().split()
        doc_id = int(line[0])
        d_len = int(line[1])
        ######################################## doc_len_condition ########################################
        if d_len >= max_doc_len :
            for i in range(d_len+1) :
                line = inputFile.readline().strip().split(',')
            continue
        ######################################## doc_len_condition ########################################

        pairs = eval('[' + inputFile.readline().strip() + ']')
        pos_list, cause_list = zip(*pairs)
        pairs = [[pos_list[i], cause_list[i]] for i in range(len(pos_list))]
        pair_id_all.extend([doc_id*10000+p[0]*100+p[1] for p in pairs])
        y_position_tmp, y_cause_tmp, y_pair_tmp, sen_len_tmp, x_tmp, distance_tmp = \
        np.zeros((max_doc_len, 2)), np.zeros((max_doc_len, 2)), np.zeros((max_doc_len * max_doc_len, 2)), \
        np.zeros((max_doc_len, )), np.zeros((max_doc_len, max_sen_len)), np.zeros((max_doc_len * max_doc_len, ))

        for i in range(d_len):
            line = inputFile.readline().strip().split(',')
            words = line[-1]
            sen_len_tmp[i] = min(len(words.split()), max_sen_len)
            for j, word in enumerate(words.split()):
                word = word.lower()
                if j >= max_sen_len:
                    n_cut += 1
                    break
                elif word not in word_idx : x_tmp[i][j] = 24166
                else : x_tmp[i][j] = int(word_idx[word])

        for i in range(d_len):
            for j in range(d_len):
                # Check whether i is an emotion clause
                if i+1 in pos_list :
                    y_position_tmp[i][0] = 0; y_position_tmp[i][1] = 1
                else :
                    y_position_tmp[i][0] = 1; y_position_tmp[i][1] = 0
                # Check whether j is a cause clause
                if j+1 in cause_list :
                    y_cause_tmp[j][0] = 0; y_cause_tmp[j][1] = 1
                else :
                    y_cause_tmp[j][0] = 1; y_cause_tmp[j][1] = 0
                # Check whether i, j clauses are emotion cause pairs
                pair_id_curr = doc_id*10000+(i+1)*100+(j+1)
                if pair_id_curr in pair_id_all :
                    y_pair_tmp[i*max_doc_len+j][0] = 0; y_pair_tmp[i*max_doc_len+j][1] = 1
                else :
                    y_pair_tmp[i*max_doc_len+j][0] = 1; y_pair_tmp[i*max_doc_len+j][1] = 0
                # Find the distance between the clauses, and use the same embedding beyond 10 clauses
                distance_tmp[i*max_doc_len+j] = min(max(j-i+100, 90), 110)

        y_position.append(y_position_tmp)
        y_cause.append(y_cause_tmp)
        y_pair.append(y_pair_tmp)
        x.append(x_tmp)
        sen_len.append(sen_len_tmp)
        doc_len.append(d_len)
        distance.append(distance_tmp)

    y_position, y_cause, y_pair, x, sen_len, doc_len, distance = map(torch.tensor, \
    [y_position, y_cause, y_pair, x, sen_len, doc_len, distance])

    for var in ['y_position', 'y_cause', 'y_pair', 'x', 'sen_len', 'doc_len', 'distance']:
        print('{}.shape {}'.format( var, eval(var).shape ))
    print('n_cut {}'.format(n_cut))
    print('load data done!\n')
    return y_position, y_cause, y_pair, x, sen_len, doc_len, distance

# %%
############################################ TRAIN #####################################################
def train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, n_hidden, batch_size, learning_rate, diminish_factor):
    word_idx_rev, word_id_mapping, word_embedding, pos_embedding = load_w2v(
        embedding_dim, embedding_dim_pos, train_file_path, w2v_file)
    word_embedding = torch.from_numpy(word_embedding)
    # Train distance embeddings
    pos_embedding = torch.autograd.Variable(torch.from_numpy(pos_embedding))
    pos_embedding.requires_grad_(True)
    #torch.save(word_embedding, MODEL_PATH+DATA+'_'+'word_embedding'+'.pth')
    torch.save(word_embedding, f'{MODEL_PATH}{DATA}_word_embedding_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    #torch.save(word_id_mapping, MODEL_PATH+DATA+'_'+'word_id_mapping'+'.pth')
    torch.save(word_id_mapping, f'{MODEL_PATH}{DATA}_word_id_mapping_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    acc_cause_list, p_cause_list, r_cause_list, f1_cause_list = [], [], [], []
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list = [], [], [], []
    acc_pair_list, p_pair_list, r_pair_list, f1_pair_list = [], [], [], []
    #################################### LOOP OVER FOLDS ####################################
    # do 5 fold cross validation
    for fold in range(1, 2):
        print('############# fold {} begin ###############'.format(fold))
        ############################# RE-INITIALIZE MODEL PARAMETERS #############################
        for layer in Model.parameters():
            nn.init.uniform_(layer.data, -0.10, 0.10)
        #################################### TRAIN/TEST DATA ####################################
        train_file_name = '{}_{}.txt'.format(TRAIN_DATA,fold)
        val_file_name = '{}_{}.txt'.format(VAL_DATA,fold)
        tr_y_position, tr_y_cause, tr_y_pair, tr_x, tr_sen_len, tr_doc_len, tr_distance = load_data_pair(
                        DATA_PATH+train_file_name, word_id_mapping, max_doc_len, max_sen_len)
        val_y_position, val_y_cause, val_y_pair, val_x, val_sen_len, val_doc_len, val_distance = \
            load_data_pair(DATA_PATH+val_file_name, word_id_mapping, max_doc_len, max_sen_len)
        max_f1_cause, max_f1_pos, max_f1_pair, max_f1_avg = [-1.] * 4
        #################################### LOOP OVER EPOCHS ####################################
        for epoch in range(1, training_epochs + 1):
            step = 1
            #################################### GET BATCH DATA ####################################
            for train, _ in get_batch_data_pair(
                tr_x, tr_sen_len, tr_doc_len, tr_y_position, tr_y_cause, tr_y_pair, tr_distance, batch_size):
                tr_x_batch, tr_sen_len_batch, tr_doc_len_batch, tr_true_y_pos, tr_true_y_cause, \
                tr_true_y_pair, tr_distance_batch = train
                Model.train()
                tr_pred_y_pos, tr_pred_y_cause, tr_pred_y_pair = Model(embedding_lookup(word_embedding, \
                tr_x_batch), embedding_lookup(pos_embedding, tr_distance_batch))
                ############################## LOSS FUNCTION AND OPTIMIZATION ##############################
                loss = pos_cause_criterion(tr_true_y_pos, tr_pred_y_pos, tr_doc_len_batch)*pos + \
                pos_cause_criterion(tr_true_y_cause, tr_pred_y_cause, tr_doc_len_batch)*cause + \
                pair_criterion(tr_true_y_pair, tr_pred_y_pair, tr_doc_len_batch)*pair
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                #################################### PRINT AFTER EPOCHS ####################################
                if step % 25 == 0:
                    # print(Model.pair_linear.weight.shape); print(Model.pair_linear.weight.grad)
                    print('Fold {}, Epoch {}, step {}: train loss {:.4f} '.format(fold, epoch, step, loss))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_pos, tr_true_y_pos, tr_doc_len_batch)
                    print('emotion_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_cause, tr_true_y_cause, tr_doc_len_batch)
                    print('cause_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_pair(tr_pred_y_pair, tr_true_y_pair, tr_doc_len_batch)
                    print('pair_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1)) 
                step += 1
            #################################### TEST ON 1 FOLD ####################################
            with torch.no_grad():
                Model.eval()
                val_pred_y_pos, val_pred_y_cause, val_pred_y_pair = Model(embedding_lookup(word_embedding, \
                val_x), embedding_lookup(pos_embedding, val_distance))

                loss = pos_cause_criterion(val_y_position, val_pred_y_pos, val_doc_len)*pos + \
                pos_cause_criterion(val_y_cause, val_pred_y_cause, val_doc_len)*cause + \
                pair_criterion(val_y_pair, val_pred_y_pair, val_doc_len)*pair
                print('Fold {} Epoch {} val loss {:.4f}'.format(fold, epoch, loss))
                acc, p, r, f1 = acc_prf_aux(val_pred_y_pos, val_y_position, val_doc_len)
                result_avg_pos = [acc, p, r, f1]
                if f1 > max_f1_pos:
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos = acc, p, r, f1
                print('emotion_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos))

                acc, p, r, f1 = acc_prf_aux(val_pred_y_cause, val_y_cause, val_doc_len)
                result_avg_cause = [acc, p, r, f1]
                if f1 > max_f1_cause:
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause = acc, p, r, f1
                print('cause_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause))

                acc, p, r, f1 = acc_prf_pair(val_pred_y_pair, val_y_pair, val_doc_len)
                result_avg_pair = [acc, p, r, f1]
                if f1 > max_f1_pair:
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair = acc, p, r, f1
                print('pair_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair))

            #################################### STORE BETTER PAIR F1 ####################################
            if result_avg_pair[-1] > max_f1_avg:
                #torch.save(pos_embedding, MODEL_PATH+DATA+"_"+"pos_embedding_fold_{}.pth".format(fold))
                torch.save(pos_embedding, f'{MODEL_PATH}{DATA}_pos_embedding_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                #torch.save(Model.state_dict(), MODEL_PATH+DATA+"_"+"E2E-EC_fold_{}.pth".format(fold))
                torch.save(Model.state_dict(), f'{MODEL_PATH}{DATA}_E2E-EC_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                
                max_f1_avg = result_avg_pair[-1]
                result_avg_cause_max = result_avg_cause
                result_avg_pos_max = result_avg_pos
                result_avg_pair_max = result_avg_pair

            print('avg max cause: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_cause_max[0], result_avg_cause_max[1], result_avg_cause_max[2], result_avg_cause_max[3]))
            print('avg max pos: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_pos_max[0], result_avg_pos_max[1], result_avg_pos_max[2], result_avg_pos_max[3]))
            print('avg max pair: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                result_avg_pair_max[0], result_avg_pair_max[1], result_avg_pair_max[2], result_avg_pair_max[3]))

        print('############# fold {} end ###############'.format(fold))
        acc_cause_list.append(result_avg_cause_max[0])
        p_cause_list.append(result_avg_cause_max[1])
        r_cause_list.append(result_avg_cause_max[2])
        f1_cause_list.append(result_avg_cause_max[3])
        acc_pos_list.append(result_avg_pos_max[0])
        p_pos_list.append(result_avg_pos_max[1])
        r_pos_list.append(result_avg_pos_max[2])
        f1_pos_list.append(result_avg_pos_max[3])
        acc_pair_list.append(result_avg_pair_max[0])
        p_pair_list.append(result_avg_pair_max[1])
        r_pair_list.append(result_avg_pair_max[2])
        f1_pair_list.append(result_avg_pair_max[3])

    #################################### FINAL TEST RESULTS ON 10 FOLDS ####################################
    all_results = [acc_cause_list, p_cause_list, r_cause_list, f1_cause_list, \
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list, acc_pair_list, p_pair_list, r_pair_list, f1_pair_list,]
    acc_cause, p_cause, r_cause, f1_cause, acc_pos, p_pos, r_pos, f1_pos, acc_pair, p_pair, r_pair, f1_pair = \
        map(lambda x: np.array(x).mean(), all_results)
    print('\ncause_predict: val f1 in 1 fold: {}'.format(np.array(f1_cause_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_cause, p_cause, r_cause, f1_cause))
    print('emotion_predict: val f1 in 1 fold: {}'.format(np.array(f1_pos_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pos, p_pos, r_pos, f1_pos))
    print('pair_predict: val f1 in 1 fold: {}'.format(np.array(f1_pair_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pair, p_pair, r_pair, f1_pair))

# %% [markdown]
# ## Calling the class for the varying hyperparameters

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.2377
# emotion_predict: val acc 0.6749 p 0.5000 r 0.0909 f1 0.1538
# max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
#
# cause_predict: val acc 0.7241 p 0.7500 r 0.2273 f1 0.3488
# max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0260
# emotion_predict: val acc 0.6847 p 0.5833 r 0.1061 f1 0.1795
# max_acc 0.6847 max_p 0.5833 max_r 0.1061 max_f1 0.1795
#
# cause_predict: val acc 0.7291 p 0.8235 r 0.2121 f1 0.3373
# max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.9729
# emotion_predict: val acc 0.6700 p 0.4839 r 0.2273 f1 0.3093
# max_acc 0.6700 max_p 0.4839 max_r 0.2273 max_f1 0.3093
#
# cause_predict: val acc 0.7340 p 0.6875 r 0.3333 f1 0.4490
# max_acc 0.7340 max_p 0.6875 max_r 0.3333 max_f1 0.4490
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7677
# emotion_predict: val acc 0.7389 p 0.5890 r 0.6515 f1 0.6187
# max_acc 0.7389 max_p 0.5890 max_r 0.6515 max_f1 0.6187
#
# cause_predict: val acc 0.7241 p 0.5781 r 0.5606 f1 0.5692
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.5031
# emotion_predict: val acc 0.8227 p 0.8409 r 0.5606 f1 0.6727
# max_acc 0.8227 max_p 0.8409 max_r 0.5606 max_f1 0.6727
#
# cause_predict: val acc 0.7438 p 0.6522 r 0.4545 f1 0.5357
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.0909 max_f1 0.1538
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.4599
# emotion_predict: val acc 0.8424 p 0.7833 r 0.7121 f1 0.7460
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7537 p 0.6667 r 0.4848 f1 0.5614
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.9246 p 0.7083 r 0.2576 f1 0.3778
# max_acc 0.9246 max_p 0.7083 max_r 0.2576 max_f1 0.3778
#
# avg max cause: max_acc 0.7537 max_p 0.6667 max_r 0.4848 max_f1 0.5614
# avg max pos: max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
# avg max pair: max_acc 0.9246 max_p 0.7083 max_r 0.2576 max_f1 0.3778
#
# Fold 1 Epoch 7 val loss 2.5536
# emotion_predict: val acc 0.8030 p 0.7321 r 0.6212 f1 0.6721
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7291 p 0.6078 r 0.4697 f1 0.5299
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8991 p 0.4308 r 0.4242 f1 0.4275
# max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# avg max cause: max_acc 0.7291 max_p 0.6078 max_r 0.4697 max_f1 0.5299
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# Fold 1 Epoch 8 val loss 2.4848
# emotion_predict: val acc 0.8374 p 0.7705 r 0.7121 f1 0.7402
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7143 p 0.5571 r 0.5909 f1 0.5735
# max_acc 0.7143 max_p 0.5571 max_r 0.5909 max_f1 0.5735
#
# pair_predict: val acc 0.8533 p 0.3162 r 0.5606 f1 0.4044
# max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# avg max cause: max_acc 0.7291 max_p 0.6078 max_r 0.4697 max_f1 0.5299
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# Fold 1 Epoch 9 val loss 2.4784
# emotion_predict: val acc 0.8079 p 0.7015 r 0.7121 f1 0.7068
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8668 p 0.3458 r 0.5606 f1 0.4277
# max_acc 0.8668 max_p 0.3458 max_r 0.5606 max_f1 0.4277
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8079 max_p 0.7015 max_r 0.7121 max_f1 0.7068
# avg max pair: max_acc 0.8668 max_p 0.3458 max_r 0.5606 max_f1 0.4277
#
# Fold 1 Epoch 10 val loss 2.5420
# emotion_predict: val acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7438 p 0.6522 r 0.4545 f1 0.5357
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8910 p 0.4051 r 0.4848 f1 0.4414
# max_acc 0.8910 max_p 0.4051 max_r 0.4848 max_f1 0.4414
#
# avg max cause: max_acc 0.7438 max_p 0.6522 max_r 0.4545 max_f1 0.5357
# avg max pos: max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
# avg max pair: max_acc 0.8910 max_p 0.4051 max_r 0.4848 max_f1 0.4414
#
# Fold 1 Epoch 11 val loss 2.4664
# emotion_predict: val acc 0.8374 p 0.7705 r 0.7121 f1 0.7402
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7488 p 0.6415 r 0.5152 f1 0.5714
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9044 p 0.4590 r 0.4242 f1 0.4409
# max_acc 0.8910 max_p 0.4051 max_r 0.4848 max_f1 0.4414
#
# avg max cause: max_acc 0.7438 max_p 0.6522 max_r 0.4545 max_f1 0.5357
# avg max pos: max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
# avg max pair: max_acc 0.8910 max_p 0.4051 max_r 0.4848 max_f1 0.4414
#
# Fold 1 Epoch 12 val loss 2.6449
# emotion_predict: val acc 0.8177 p 0.7302 r 0.6970 f1 0.7132
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7241 p 0.5926 r 0.4848 f1 0.5333
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8883 p 0.4045 r 0.5455 f1 0.4645
# max_acc 0.8883 max_p 0.4045 max_r 0.5455 max_f1 0.4645
#
# avg max cause: max_acc 0.7241 max_p 0.5926 max_r 0.4848 max_f1 0.5333
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.8883 max_p 0.4045 max_r 0.5455 max_f1 0.4645
#
# Fold 1 Epoch 13 val loss 2.8903
# emotion_predict: val acc 0.8424 p 0.7931 r 0.6970 f1 0.7419
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7094 p 0.5593 r 0.5000 f1 0.5280
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9004 p 0.4394 r 0.4394 f1 0.4394
# max_acc 0.8883 max_p 0.4045 max_r 0.5455 max_f1 0.4645
#
# avg max cause: max_acc 0.7241 max_p 0.5926 max_r 0.4848 max_f1 0.5333
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.8883 max_p 0.4045 max_r 0.5455 max_f1 0.4645
#
# Fold 1 Epoch 14 val loss 2.9919
# emotion_predict: val acc 0.8227 p 0.7419 r 0.6970 f1 0.7187
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7291 p 0.6078 r 0.4697 f1 0.5299
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9058 p 0.4714 r 0.5000 f1 0.4853
# max_acc 0.9058 max_p 0.4714 max_r 0.5000 max_f1 0.4853
#
# avg max cause: max_acc 0.7291 max_p 0.6078 max_r 0.4697 max_f1 0.5299
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.9058 max_p 0.4714 max_r 0.5000 max_f1 0.4853
#
# Fold 1 Epoch 15 val loss 3.4500
# emotion_predict: val acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7192 p 0.5714 r 0.5455 f1 0.5581
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9125 p 0.5070 r 0.5455 f1 0.5255
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# Fold 1 Epoch 16 val loss 3.1848
# emotion_predict: val acc 0.7931 p 0.6765 r 0.6970 f1 0.6866
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7340 p 0.6250 r 0.4545 f1 0.5263
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9004 p 0.4394 r 0.4394 f1 0.4394
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# Fold 1 Epoch 17 val loss 3.8754
# emotion_predict: val acc 0.8079 p 0.7547 r 0.6061 f1 0.6723
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.6601 p 0.4789 r 0.5152 f1 0.4964
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.4697 f1 0.4844
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# Fold 1 Epoch 18 val loss 3.7017
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9098 p 0.4923 r 0.4848 f1 0.4885
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# Fold 1 Epoch 19 val loss 4.4871
# emotion_predict: val acc 0.7586 p 0.6308 r 0.6212 f1 0.6260
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.6897 p 0.5217 r 0.5455 f1 0.5333
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8775 p 0.3563 r 0.4697 f1 0.4052
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# Fold 1 Epoch 20 val loss 5.2907
# emotion_predict: val acc 0.7882 p 0.6716 r 0.6818 f1 0.6767
# max_acc 0.8424 max_p 0.7833 max_r 0.7121 max_f1 0.7460
#
# cause_predict: val acc 0.7192 p 0.5672 r 0.5758 f1 0.5714
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9071 p 0.4746 r 0.4242 f1 0.4480
# max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
# avg max pair: max_acc 0.9125 max_p 0.5070 max_r 0.5455 max_f1 0.5255
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.55813953]]
# average : acc 0.7192 p 0.5714 r 0.5455 f1 0.5581
#
# emotion_predict: val f1 in 5 fold: [[0.71544715]]
# average : acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
#
# pair_predict: val f1 in 5 fold: [[0.52554744]]
# average : acc 0.9125 p 0.5070 r 0.5455 f1 0.5255

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.6229
# emotion_predict: val acc 0.6946 p 1.0000 r 0.0606 f1 0.1143
# max_acc 0.6946 max_p 1.0000 max_r 0.0606 max_f1 0.1143
#
# cause_predict: val acc 0.7044 p 1.0000 r 0.0909 f1 0.1667
# max_acc 0.7044 max_p 1.0000 max_r 0.0909 max_f1 0.1667
#
# pair_predict: val acc 0.9192 p 1.0000 r 0.0909 f1 0.1667
# max_acc 0.9192 max_p 1.0000 max_r 0.0909 max_f1 0.1667
#
# avg max cause: max_acc 0.7044 max_p 1.0000 max_r 0.0909 max_f1 0.1667
# avg max pos: max_acc 0.6946 max_p 1.0000 max_r 0.0606 max_f1 0.1143
# avg max pair: max_acc 0.9192 max_p 1.0000 max_r 0.0909 max_f1 0.1667
#
# Fold 1 Epoch 2 val loss 2.4663
# emotion_predict: val acc 0.7094 p 0.5686 r 0.4394 f1 0.4957
# max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
#
# cause_predict: val acc 0.6995 p 0.5352 r 0.5758 f1 0.5547
# max_acc 0.6995 max_p 0.5352 max_r 0.5758 max_f1 0.5547
#
# pair_predict: val acc 0.8291 p 0.2636 r 0.5152 f1 0.3487
# max_acc 0.8291 max_p 0.2636 max_r 0.5152 max_f1 0.3487
#
# avg max cause: max_acc 0.6995 max_p 0.5352 max_r 0.5758 max_f1 0.5547
# avg max pos: max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
# avg max pair: max_acc 0.8291 max_p 0.2636 max_r 0.5152 max_f1 0.3487
#
# Fold 1 Epoch 3 val loss 2.1888
# emotion_predict: val acc 0.7586 p 0.7073 r 0.4394 f1 0.5421
# max_acc 0.7586 max_p 0.7073 max_r 0.4394 max_f1 0.5421
#
# cause_predict: val acc 0.7635 p 0.7250 r 0.4394 f1 0.5472
# max_acc 0.6995 max_p 0.5352 max_r 0.5758 max_f1 0.5547
#
# pair_predict: val acc 0.8600 p 0.3304 r 0.5606 f1 0.4157
# max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# avg max cause: max_acc 0.7635 max_p 0.7250 max_r 0.4394 max_f1 0.5472
# avg max pos: max_acc 0.7586 max_p 0.7073 max_r 0.4394 max_f1 0.5421
# avg max pair: max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# Fold 1 Epoch 4 val loss 2.1003
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
#
# cause_predict: val acc 0.7389 p 0.6032 r 0.5758 f1 0.5891
# max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
#
# pair_predict: val acc 0.8385 p 0.3015 r 0.6212 f1 0.4059
# max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# avg max cause: max_acc 0.7635 max_p 0.7250 max_r 0.4394 max_f1 0.5472
# avg max pos: max_acc 0.7586 max_p 0.7073 max_r 0.4394 max_f1 0.5421
# avg max pair: max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# Fold 1 Epoch 5 val loss 2.0926
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
#
# cause_predict: val acc 0.7340 p 0.6111 r 0.5000 f1 0.5500
# max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
#
# pair_predict: val acc 0.8318 p 0.2993 r 0.6667 f1 0.4131
# max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# avg max cause: max_acc 0.7635 max_p 0.7250 max_r 0.4394 max_f1 0.5472
# avg max pos: max_acc 0.7586 max_p 0.7073 max_r 0.4394 max_f1 0.5421
# avg max pair: max_acc 0.8600 max_p 0.3304 max_r 0.5606 max_f1 0.4157
#
# Fold 1 Epoch 6 val loss 2.0534
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
#
# cause_predict: val acc 0.7291 p 0.5873 r 0.5606 f1 0.5736
# max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
#
# pair_predict: val acc 0.8533 p 0.3333 r 0.6515 f1 0.4410
# max_acc 0.8533 max_p 0.3333 max_r 0.6515 max_f1 0.4410
#
# avg max cause: max_acc 0.7291 max_p 0.5873 max_r 0.5606 max_f1 0.5736
# avg max pos: max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
# avg max pair: max_acc 0.8533 max_p 0.3333 max_r 0.6515 max_f1 0.4410
#
# Fold 1 Epoch 7 val loss 2.1824
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
#
# cause_predict: val acc 0.7340 p 0.6111 r 0.5000 f1 0.5500
# max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
#
# pair_predict: val acc 0.8816 p 0.3900 r 0.5909 f1 0.4699
# max_acc 0.8816 max_p 0.3900 max_r 0.5909 max_f1 0.4699
#
# avg max cause: max_acc 0.7340 max_p 0.6111 max_r 0.5000 max_f1 0.5500
# avg max pos: max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
# avg max pair: max_acc 0.8816 max_p 0.3900 max_r 0.5909 max_f1 0.4699
#
# Fold 1 Epoch 8 val loss 2.0834
# emotion_predict: val acc 0.8325 p 0.7759 r 0.6818 f1 0.7258
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7635 p 0.6607 r 0.5606 f1 0.6066
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8694 p 0.3628 r 0.6212 f1 0.4581
# max_acc 0.8816 max_p 0.3900 max_r 0.5909 max_f1 0.4699
#
# avg max cause: max_acc 0.7340 max_p 0.6111 max_r 0.5000 max_f1 0.5500
# avg max pos: max_acc 0.8128 max_p 0.7258 max_r 0.6818 max_f1 0.7031
# avg max pair: max_acc 0.8816 max_p 0.3900 max_r 0.5909 max_f1 0.4699
#
# Fold 1 Epoch 9 val loss 2.2288
# emotion_predict: val acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7389 p 0.6032 r 0.5758 f1 0.5891
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8694 p 0.3675 r 0.6515 f1 0.4699
# max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# avg max cause: max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# Fold 1 Epoch 10 val loss 2.2825
# emotion_predict: val acc 0.8177 p 0.7164 r 0.7273 f1 0.7218
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7241 p 0.5714 r 0.6061 f1 0.5882
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8560 p 0.3411 r 0.6667 f1 0.4513
# max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# avg max cause: max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# Fold 1 Epoch 11 val loss 2.7308
# emotion_predict: val acc 0.7734 p 0.6515 r 0.6515 f1 0.6515
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8762 p 0.3700 r 0.5606 f1 0.4458
# max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# avg max cause: max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# Fold 1 Epoch 12 val loss 2.4940
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7291 p 0.5775 r 0.6212 f1 0.5985
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8614 p 0.3471 r 0.6364 f1 0.4492
# max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# avg max cause: max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# Fold 1 Epoch 13 val loss 2.9292
# emotion_predict: val acc 0.8177 p 0.7231 r 0.7121 f1 0.7176
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7094 p 0.5556 r 0.5303 f1 0.5426
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8789 p 0.3750 r 0.5455 f1 0.4444
# max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# avg max cause: max_acc 0.7389 max_p 0.6032 max_r 0.5758 max_f1 0.5891
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.8694 max_p 0.3675 max_r 0.6515 max_f1 0.4699
#
# Fold 1 Epoch 14 val loss 3.2304
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8937 p 0.4270 r 0.5758 f1 0.4903
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 15 val loss 3.4731
# emotion_predict: val acc 0.8030 p 0.7031 r 0.6818 f1 0.6923
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.6946 p 0.5286 r 0.5606 f1 0.5441
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8883 p 0.4066 r 0.5606 f1 0.4713
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 16 val loss 4.2545
# emotion_predict: val acc 0.8128 p 0.7500 r 0.6364 f1 0.6885
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.6946 p 0.5345 r 0.4697 f1 0.5000
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8991 p 0.4444 r 0.5455 f1 0.4898
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 17 val loss 4.0557
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7241 p 0.5833 r 0.5303 f1 0.5556
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.9058 p 0.4714 r 0.5000 f1 0.4853
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 18 val loss 3.9888
# emotion_predict: val acc 0.7882 p 0.6716 r 0.6818 f1 0.6767
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.6946 p 0.5278 r 0.5758 f1 0.5507
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# pair_predict: val acc 0.8573 p 0.3214 r 0.5455 f1 0.4045
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 19 val loss 3.8642
# emotion_predict: val acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7537 p 0.6290 r 0.5909 f1 0.6094
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.9017 p 0.4533 r 0.5152 f1 0.4823
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# Fold 1 Epoch 20 val loss 3.9728
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.6995 p 0.5352 r 0.5758 f1 0.5547
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8802 p 0.3647 r 0.4697 f1 0.4106
# max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8937 max_p 0.4270 max_r 0.5758 max_f1 0.4903
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.578125]]
# average : acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
#
# emotion_predict: val f1 in 5 fold: [[0.70866142]]
# average : acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
#
# pair_predict: val f1 in 5 fold: [[0.49032258]]
# average : acc 0.8937 p 0.4270 r 0.5758 f1 0.4903

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3340
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2190
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.1915
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.0895
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.0366
# emotion_predict: val acc 0.6897 p 0.5294 r 0.4091 f1 0.4615
# max_acc 0.6897 max_p 0.5294 max_r 0.4091 max_f1 0.4615
#
# cause_predict: val acc 0.7192 p 0.6154 r 0.3636 f1 0.4571
# max_acc 0.7192 max_p 0.6154 max_r 0.3636 max_f1 0.4571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.9521
# emotion_predict: val acc 0.7143 p 0.6053 r 0.3485 f1 0.4423
# max_acc 0.6897 max_p 0.5294 max_r 0.4091 max_f1 0.4615
#
# cause_predict: val acc 0.7143 p 0.6667 r 0.2424 f1 0.3556
# max_acc 0.7192 max_p 0.6154 max_r 0.3636 max_f1 0.4571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.8675
# emotion_predict: val acc 0.7389 p 0.8421 r 0.2424 f1 0.3765
# max_acc 0.6897 max_p 0.5294 max_r 0.4091 max_f1 0.4615
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
#
# pair_predict: val acc 0.9192 p 0.8750 r 0.1061 f1 0.1892
# max_acc 0.9192 max_p 0.8750 max_r 0.1061 max_f1 0.1892
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.7389 max_p 0.8421 max_r 0.2424 max_f1 0.3765
# avg max pair: max_acc 0.9192 max_p 0.8750 max_r 0.1061 max_f1 0.1892
#
# Fold 1 Epoch 8 val loss 2.7907
# emotion_predict: val acc 0.7192 p 0.5918 r 0.4394 f1 0.5043
# max_acc 0.7192 max_p 0.5918 max_r 0.4394 max_f1 0.5043
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
#
# pair_predict: val acc 0.9260 p 0.9231 r 0.1818 f1 0.3038
# max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.7192 max_p 0.5918 max_r 0.4394 max_f1 0.5043
# avg max pair: max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# Fold 1 Epoch 9 val loss 2.7136
# emotion_predict: val acc 0.7389 p 0.7241 r 0.3182 f1 0.4421
# max_acc 0.7192 max_p 0.5918 max_r 0.4394 max_f1 0.5043
#
# cause_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
#
# pair_predict: val acc 0.9098 p 0.4884 r 0.3182 f1 0.3853
# max_acc 0.9098 max_p 0.4884 max_r 0.3182 max_f1 0.3853
#
# avg max cause: max_acc 0.7143 max_p 0.5667 max_r 0.5152 max_f1 0.5397
# avg max pos: max_acc 0.7389 max_p 0.7241 max_r 0.3182 max_f1 0.4421
# avg max pair: max_acc 0.9098 max_p 0.4884 max_r 0.3182 max_f1 0.3853
#
# Fold 1 Epoch 10 val loss 2.7240
# emotion_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7340 max_p 0.6154 max_r 0.4848 max_f1 0.5424
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9031 p 0.4423 r 0.3485 f1 0.3898
# max_acc 0.9031 max_p 0.4423 max_r 0.3485 max_f1 0.3898
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7340 max_p 0.6154 max_r 0.4848 max_f1 0.5424
# avg max pair: max_acc 0.9031 max_p 0.4423 max_r 0.3485 max_f1 0.3898
#
# Fold 1 Epoch 11 val loss 2.7372
# emotion_predict: val acc 0.7537 p 0.6739 r 0.4697 f1 0.5536
# max_acc 0.7537 max_p 0.6739 max_r 0.4697 max_f1 0.5536
#
# cause_predict: val acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9125 p 0.5128 r 0.3030 f1 0.3810
# max_acc 0.9031 max_p 0.4423 max_r 0.3485 max_f1 0.3898
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7340 max_p 0.6154 max_r 0.4848 max_f1 0.5424
# avg max pair: max_acc 0.9031 max_p 0.4423 max_r 0.3485 max_f1 0.3898
#
# Fold 1 Epoch 12 val loss 2.6849
# emotion_predict: val acc 0.7586 p 0.6491 r 0.5606 f1 0.6016
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# cause_predict: val acc 0.7044 p 0.5484 r 0.5152 f1 0.5312
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.8991 p 0.4328 r 0.4394 f1 0.4361
# max_acc 0.8991 max_p 0.4328 max_r 0.4394 max_f1 0.4361
#
# avg max cause: max_acc 0.7044 max_p 0.5484 max_r 0.5152 max_f1 0.5312
# avg max pos: max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
# avg max pair: max_acc 0.8991 max_p 0.4328 max_r 0.4394 max_f1 0.4361
#
# Fold 1 Epoch 13 val loss 2.6045
# emotion_predict: val acc 0.7980 p 0.7660 r 0.5455 f1 0.6372
# max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
#
# cause_predict: val acc 0.7340 p 0.6034 r 0.5303 f1 0.5645
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9166 p 0.5400 r 0.4091 f1 0.4655
# max_acc 0.9166 max_p 0.5400 max_r 0.4091 max_f1 0.4655
#
# avg max cause: max_acc 0.7340 max_p 0.6034 max_r 0.5303 max_f1 0.5645
# avg max pos: max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
# avg max pair: max_acc 0.9166 max_p 0.5400 max_r 0.4091 max_f1 0.4655
#
# Fold 1 Epoch 14 val loss 2.5415
# emotion_predict: val acc 0.7931 p 0.6935 r 0.6515 f1 0.6719
# max_acc 0.7931 max_p 0.6935 max_r 0.6515 max_f1 0.6719
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9098 p 0.4915 r 0.4394 f1 0.4640
# max_acc 0.9166 max_p 0.5400 max_r 0.4091 max_f1 0.4655
#
# avg max cause: max_acc 0.7340 max_p 0.6034 max_r 0.5303 max_f1 0.5645
# avg max pos: max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
# avg max pair: max_acc 0.9166 max_p 0.5400 max_r 0.4091 max_f1 0.4655
#
# Fold 1 Epoch 15 val loss 2.5455
# emotion_predict: val acc 0.8128 p 0.7692 r 0.6061 f1 0.6780
# max_acc 0.8128 max_p 0.7692 max_r 0.6061 max_f1 0.6780
#
# cause_predict: val acc 0.7143 p 0.5645 r 0.5303 f1 0.5469
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9085 p 0.4844 r 0.4697 f1 0.4769
# max_acc 0.9085 max_p 0.4844 max_r 0.4697 max_f1 0.4769
#
# avg max cause: max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
# avg max pos: max_acc 0.8128 max_p 0.7692 max_r 0.6061 max_f1 0.6780
# avg max pair: max_acc 0.9085 max_p 0.4844 max_r 0.4697 max_f1 0.4769
#
# Fold 1 Epoch 16 val loss 2.5370
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8030 max_p 0.7097 max_r 0.6667 max_f1 0.6875
#
# cause_predict: val acc 0.7143 p 0.5645 r 0.5303 f1 0.5469
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9031 p 0.4583 r 0.5000 f1 0.4783
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
# avg max pos: max_acc 0.8030 max_p 0.7097 max_r 0.6667 max_f1 0.6875
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 17 val loss 2.3703
# emotion_predict: val acc 0.8276 p 0.7541 r 0.6970 f1 0.7244
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7537 p 0.6212 r 0.6212 f1 0.6212
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.9044 p 0.4684 r 0.5606 f1 0.5103
# max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# avg max cause: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pos: max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
# avg max pair: max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# Fold 1 Epoch 18 val loss 2.6002
# emotion_predict: val acc 0.8030 p 0.6970 r 0.6970 f1 0.6970
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7192 p 0.5738 r 0.5303 f1 0.5512
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8991 p 0.4400 r 0.5000 f1 0.4681
# max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# avg max cause: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pos: max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
# avg max pair: max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# Fold 1 Epoch 19 val loss 2.5663
# emotion_predict: val acc 0.8325 p 0.7963 r 0.6515 f1 0.7167
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7143 p 0.5556 r 0.6061 f1 0.5797
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.9071 p 0.4769 r 0.4697 f1 0.4733
# max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# avg max cause: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pos: max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
# avg max pair: max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# Fold 1 Epoch 20 val loss 2.5297
# emotion_predict: val acc 0.7931 p 0.6765 r 0.6970 f1 0.6866
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.6995 p 0.5373 r 0.5455 f1 0.5414
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8843 p 0.3958 r 0.5758 f1 0.4691
# max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# avg max cause: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pos: max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
# avg max pair: max_acc 0.9044 max_p 0.4684 max_r 0.5606 max_f1 0.5103
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.62121212]]
# average : acc 0.7537 p 0.6212 r 0.6212 f1 0.6212
#
# emotion_predict: val f1 in 5 fold: [[0.72440945]]
# average : acc 0.8276 p 0.7541 r 0.6970 f1 0.7244
#
# pair_predict: val f1 in 5 fold: [[0.51034483]]
# average : acc 0.9044 p 0.4684 r 0.5606 f1 0.5103

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7751
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7179
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.6011
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.5208
# emotion_predict: val acc 0.7291 p 0.6486 r 0.3636 f1 0.4660
# max_acc 0.7291 max_p 0.6486 max_r 0.3636 max_f1 0.4660
#
# cause_predict: val acc 0.7389 p 0.6970 r 0.3485 f1 0.4646
# max_acc 0.7389 max_p 0.6970 max_r 0.3485 max_f1 0.4646
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.2727 f1 0.3529
# max_acc 0.9112 max_p 0.5000 max_r 0.2727 max_f1 0.3529
#
# avg max cause: max_acc 0.7389 max_p 0.6970 max_r 0.3485 max_f1 0.4646
# avg max pos: max_acc 0.7291 max_p 0.6486 max_r 0.3636 max_f1 0.4660
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.2727 max_f1 0.3529
#
# Fold 1 Epoch 5 val loss 2.3906
# emotion_predict: val acc 0.7389 p 0.6970 r 0.3485 f1 0.4646
# max_acc 0.7291 max_p 0.6486 max_r 0.3636 max_f1 0.4660
#
# cause_predict: val acc 0.7192 p 0.6047 r 0.3939 f1 0.4771
# max_acc 0.7192 max_p 0.6047 max_r 0.3939 max_f1 0.4771
#
# pair_predict: val acc 0.8479 p 0.2991 r 0.5303 f1 0.3825
# max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# avg max cause: max_acc 0.7192 max_p 0.6047 max_r 0.3939 max_f1 0.4771
# avg max pos: max_acc 0.7389 max_p 0.6970 max_r 0.3485 max_f1 0.4646
# avg max pair: max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# Fold 1 Epoch 6 val loss 2.3580
# emotion_predict: val acc 0.7192 p 0.5882 r 0.4545 f1 0.5128
# max_acc 0.7192 max_p 0.5882 max_r 0.4545 max_f1 0.5128
#
# cause_predict: val acc 0.7143 p 0.5588 r 0.5758 f1 0.5672
# max_acc 0.7143 max_p 0.5588 max_r 0.5758 max_f1 0.5672
#
# pair_predict: val acc 0.8291 p 0.2741 r 0.5606 f1 0.3682
# max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# avg max cause: max_acc 0.7192 max_p 0.6047 max_r 0.3939 max_f1 0.4771
# avg max pos: max_acc 0.7389 max_p 0.6970 max_r 0.3485 max_f1 0.4646
# avg max pair: max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# Fold 1 Epoch 7 val loss 2.3013
# emotion_predict: val acc 0.7586 p 0.7073 r 0.4394 f1 0.5421
# max_acc 0.7586 max_p 0.7073 max_r 0.4394 max_f1 0.5421
#
# cause_predict: val acc 0.7291 p 0.6038 r 0.4848 f1 0.5378
# max_acc 0.7143 max_p 0.5588 max_r 0.5758 max_f1 0.5672
#
# pair_predict: val acc 0.8223 p 0.2643 r 0.5606 f1 0.3592
# max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# avg max cause: max_acc 0.7192 max_p 0.6047 max_r 0.3939 max_f1 0.4771
# avg max pos: max_acc 0.7389 max_p 0.6970 max_r 0.3485 max_f1 0.4646
# avg max pair: max_acc 0.8479 max_p 0.2991 max_r 0.5303 max_f1 0.3825
#
# Fold 1 Epoch 8 val loss 2.2514
# emotion_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8641 p 0.3267 r 0.5000 f1 0.3952
# max_acc 0.8641 max_p 0.3267 max_r 0.5000 max_f1 0.3952
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pair: max_acc 0.8641 max_p 0.3267 max_r 0.5000 max_f1 0.3952
#
# Fold 1 Epoch 9 val loss 2.2216
# emotion_predict: val acc 0.8030 p 0.7826 r 0.5455 f1 0.6429
# max_acc 0.8030 max_p 0.7826 max_r 0.5455 max_f1 0.6429
#
# cause_predict: val acc 0.7438 p 0.6346 r 0.5000 f1 0.5593
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8641 p 0.3364 r 0.5455 f1 0.4162
# max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# avg max cause: max_acc 0.7438 max_p 0.6346 max_r 0.5000 max_f1 0.5593
# avg max pos: max_acc 0.8030 max_p 0.7826 max_r 0.5455 max_f1 0.6429
# avg max pair: max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# Fold 1 Epoch 10 val loss 2.2330
# emotion_predict: val acc 0.7833 p 0.6964 r 0.5909 f1 0.6393
# max_acc 0.8030 max_p 0.7826 max_r 0.5455 max_f1 0.6429
#
# cause_predict: val acc 0.7094 p 0.5574 r 0.5152 f1 0.5354
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8627 p 0.3421 r 0.5909 f1 0.4333
# max_acc 0.8627 max_p 0.3421 max_r 0.5909 max_f1 0.4333
#
# avg max cause: max_acc 0.7094 max_p 0.5574 max_r 0.5152 max_f1 0.5354
# avg max pos: max_acc 0.7833 max_p 0.6964 max_r 0.5909 max_f1 0.6393
# avg max pair: max_acc 0.8627 max_p 0.3421 max_r 0.5909 max_f1 0.4333
#
# Fold 1 Epoch 11 val loss 2.0722
# emotion_predict: val acc 0.8177 p 0.7544 r 0.6515 f1 0.6992
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7537 p 0.6429 r 0.5455 f1 0.5902
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8600 p 0.3516 r 0.6818 f1 0.4639
# max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
# avg max pair: max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# Fold 1 Epoch 12 val loss 2.0975
# emotion_predict: val acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8331 p 0.3014 r 0.6667 f1 0.4151
# max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
# avg max pair: max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# Fold 1 Epoch 13 val loss 2.1215
# emotion_predict: val acc 0.8276 p 0.7541 r 0.6970 f1 0.7244
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7537 p 0.6333 r 0.5758 f1 0.6032
# max_acc 0.7537 max_p 0.6333 max_r 0.5758 max_f1 0.6032
#
# pair_predict: val acc 0.8681 p 0.3621 r 0.6364 f1 0.4615
# max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
# avg max pair: max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# Fold 1 Epoch 14 val loss 2.4166
# emotion_predict: val acc 0.7685 p 0.6508 r 0.6212 f1 0.6357
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7537 max_p 0.6333 max_r 0.5758 max_f1 0.6032
#
# pair_predict: val acc 0.8425 p 0.3083 r 0.6212 f1 0.4121
# max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
# avg max pair: max_acc 0.8600 max_p 0.3516 max_r 0.6818 max_f1 0.4639
#
# Fold 1 Epoch 15 val loss 2.1529
# emotion_predict: val acc 0.8030 p 0.7031 r 0.6818 f1 0.6923
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7537 p 0.6250 r 0.6061 f1 0.6154
# max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
#
# pair_predict: val acc 0.8748 p 0.3826 r 0.6667 f1 0.4862
# max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# avg max cause: max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
# avg max pos: max_acc 0.8030 max_p 0.7031 max_r 0.6818 max_f1 0.6923
# avg max pair: max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# Fold 1 Epoch 16 val loss 2.2934
# emotion_predict: val acc 0.7980 p 0.6923 r 0.6818 f1 0.6870
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7192 p 0.5634 r 0.6061 f1 0.5839
# max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
#
# pair_predict: val acc 0.8291 p 0.3007 r 0.6970 f1 0.4201
# max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# avg max cause: max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
# avg max pos: max_acc 0.8030 max_p 0.7031 max_r 0.6818 max_f1 0.6923
# avg max pair: max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# Fold 1 Epoch 17 val loss 2.3646
# emotion_predict: val acc 0.8079 p 0.7143 r 0.6818 f1 0.6977
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7438 p 0.6061 r 0.6061 f1 0.6061
# max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
#
# pair_predict: val acc 0.8614 p 0.3588 r 0.7121 f1 0.4772
# max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# avg max cause: max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
# avg max pos: max_acc 0.8030 max_p 0.7031 max_r 0.6818 max_f1 0.6923
# avg max pair: max_acc 0.8748 max_p 0.3826 max_r 0.6667 max_f1 0.4862
#
# Fold 1 Epoch 18 val loss 2.4376
# emotion_predict: val acc 0.8079 p 0.7368 r 0.6364 f1 0.6829
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7488 p 0.6087 r 0.6364 f1 0.6222
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.8775 p 0.3894 r 0.6667 f1 0.4916
# max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# avg max cause: max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
# avg max pos: max_acc 0.8079 max_p 0.7368 max_r 0.6364 max_f1 0.6829
# avg max pair: max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# Fold 1 Epoch 19 val loss 2.6644
# emotion_predict: val acc 0.7833 p 0.6719 r 0.6515 f1 0.6615
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.8829 p 0.4037 r 0.6667 f1 0.5029
# max_acc 0.8829 max_p 0.4037 max_r 0.6667 max_f1 0.5029
#
# avg max cause: max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
# avg max pos: max_acc 0.7833 max_p 0.6719 max_r 0.6515 max_f1 0.6615
# avg max pair: max_acc 0.8829 max_p 0.4037 max_r 0.6667 max_f1 0.5029
#
# Fold 1 Epoch 20 val loss 2.6421
# emotion_predict: val acc 0.7980 p 0.6866 r 0.6970 f1 0.6917
# max_acc 0.8276 max_p 0.7541 max_r 0.6970 max_f1 0.7244
#
# cause_predict: val acc 0.7438 p 0.6029 r 0.6212 f1 0.6119
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.8627 p 0.3571 r 0.6818 f1 0.4687
# max_acc 0.8829 max_p 0.4037 max_r 0.6667 max_f1 0.5029
#
# avg max cause: max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
# avg max pos: max_acc 0.7833 max_p 0.6719 max_r 0.6515 max_f1 0.6615
# avg max pair: max_acc 0.8829 max_p 0.4037 max_r 0.6667 max_f1 0.5029
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.59701492]]
# average : acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
#
# emotion_predict: val f1 in 5 fold: [[0.66153846]]
# average : acc 0.7833 p 0.6719 r 0.6515 f1 0.6615
#
# pair_predict: val f1 in 5 fold: [[0.50285714]]
# average : acc 0.8829 p 0.4037 r 0.6667 f1 0.5029

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 4.2054
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.4731
# emotion_predict: val acc 0.6749 p 0.5000 r 0.1667 f1 0.2500
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.7241 p 0.9167 r 0.1667 f1 0.2821
# max_acc 0.7241 max_p 0.9167 max_r 0.1667 max_f1 0.2821
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3854
# emotion_predict: val acc 0.6897 p 0.6667 r 0.0909 f1 0.1600
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.7291 p 1.0000 r 0.1667 f1 0.2857
# max_acc 0.7291 max_p 1.0000 max_r 0.1667 max_f1 0.2857
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1407
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.6995 p 1.0000 r 0.0758 f1 0.1408
# max_acc 0.7291 max_p 1.0000 max_r 0.1667 max_f1 0.2857
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.1629
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.6946 p 1.0000 r 0.0606 f1 0.1143
# max_acc 0.7291 max_p 1.0000 max_r 0.1667 max_f1 0.2857
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.0800
# emotion_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.7291 max_p 1.0000 max_r 0.1667 max_f1 0.2857
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.0310
# emotion_predict: val acc 0.6946 p 0.7500 r 0.0909 f1 0.1622
# max_acc 0.6749 max_p 0.5000 max_r 0.1667 max_f1 0.2500
#
# cause_predict: val acc 0.7241 p 0.7273 r 0.2424 f1 0.3636
# max_acc 0.7241 max_p 0.7273 max_r 0.2424 max_f1 0.3636
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.0532
# emotion_predict: val acc 0.6847 p 0.5312 r 0.2576 f1 0.3469
# max_acc 0.6847 max_p 0.5312 max_r 0.2576 max_f1 0.3469
#
# cause_predict: val acc 0.6946 p 0.5385 r 0.4242 f1 0.4746
# max_acc 0.6946 max_p 0.5385 max_r 0.4242 max_f1 0.4746
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.9476
# emotion_predict: val acc 0.6700 p 0.4848 r 0.2424 f1 0.3232
# max_acc 0.6847 max_p 0.5312 max_r 0.2576 max_f1 0.3469
#
# cause_predict: val acc 0.7094 p 0.5814 r 0.3788 f1 0.4587
# max_acc 0.6946 max_p 0.5385 max_r 0.4242 max_f1 0.4746
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.9081
# emotion_predict: val acc 0.7044 p 0.5682 r 0.3788 f1 0.4545
# max_acc 0.7044 max_p 0.5682 max_r 0.3788 max_f1 0.4545
#
# cause_predict: val acc 0.7044 p 0.5652 r 0.3939 f1 0.4643
# max_acc 0.6946 max_p 0.5385 max_r 0.4242 max_f1 0.4746
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.8544
# emotion_predict: val acc 0.7586 p 0.6308 r 0.6212 f1 0.6260
# max_acc 0.7586 max_p 0.6308 max_r 0.6212 max_f1 0.6260
#
# cause_predict: val acc 0.7094 p 0.5522 r 0.5606 f1 0.5564
# max_acc 0.7094 max_p 0.5522 max_r 0.5606 max_f1 0.5564
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.7539
# emotion_predict: val acc 0.7438 p 0.6094 r 0.5909 f1 0.6000
# max_acc 0.7586 max_p 0.6308 max_r 0.6212 max_f1 0.6260
#
# cause_predict: val acc 0.7044 p 0.5455 r 0.5455 f1 0.5455
# max_acc 0.7094 max_p 0.5522 max_r 0.5606 max_f1 0.5564
#
# pair_predict: val acc 0.9125 p 0.6667 r 0.0303 f1 0.0580
# max_acc 0.9125 max_p 0.6667 max_r 0.0303 max_f1 0.0580
#
# avg max cause: max_acc 0.7044 max_p 0.5455 max_r 0.5455 max_f1 0.5455
# avg max pos: max_acc 0.7438 max_p 0.6094 max_r 0.5909 max_f1 0.6000
# avg max pair: max_acc 0.9125 max_p 0.6667 max_r 0.0303 max_f1 0.0580
#
# Fold 1 Epoch 13 val loss 2.6209
# emotion_predict: val acc 0.7882 p 0.7255 r 0.5606 f1 0.6325
# max_acc 0.7882 max_p 0.7255 max_r 0.5606 max_f1 0.6325
#
# cause_predict: val acc 0.7389 p 0.6667 r 0.3939 f1 0.4952
# max_acc 0.7094 max_p 0.5522 max_r 0.5606 max_f1 0.5564
#
# pair_predict: val acc 0.9179 p 0.5676 r 0.3182 f1 0.4078
# max_acc 0.9179 max_p 0.5676 max_r 0.3182 max_f1 0.4078
#
# avg max cause: max_acc 0.7389 max_p 0.6667 max_r 0.3939 max_f1 0.4952
# avg max pos: max_acc 0.7882 max_p 0.7255 max_r 0.5606 max_f1 0.6325
# avg max pair: max_acc 0.9179 max_p 0.5676 max_r 0.3182 max_f1 0.4078
#
# Fold 1 Epoch 14 val loss 2.5026
# emotion_predict: val acc 0.8177 p 0.7736 r 0.6212 f1 0.6891
# max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
#
# cause_predict: val acc 0.7488 p 0.7027 r 0.3939 f1 0.5049
# max_acc 0.7094 max_p 0.5522 max_r 0.5606 max_f1 0.5564
#
# pair_predict: val acc 0.9179 p 0.5510 r 0.4091 f1 0.4696
# max_acc 0.9179 max_p 0.5510 max_r 0.4091 max_f1 0.4696
#
# avg max cause: max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.9179 max_p 0.5510 max_r 0.4091 max_f1 0.4696
#
# Fold 1 Epoch 15 val loss 2.4487
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.9031 p 0.4583 r 0.5000 f1 0.4783
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 16 val loss 2.5189
# emotion_predict: val acc 0.7931 p 0.7069 r 0.6212 f1 0.6613
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7241 p 0.5926 r 0.4848 f1 0.5333
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8789 p 0.3667 r 0.5000 f1 0.4231
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 17 val loss 2.5668
# emotion_predict: val acc 0.7833 p 0.7115 r 0.5606 f1 0.6271
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7586 p 0.7073 r 0.4394 f1 0.5421
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8991 p 0.4286 r 0.4091 f1 0.4186
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 18 val loss 2.5183
# emotion_predict: val acc 0.7833 p 0.6618 r 0.6818 f1 0.6716
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7389 p 0.6102 r 0.5455 f1 0.5760
# max_acc 0.7389 max_p 0.6102 max_r 0.5455 max_f1 0.5760
#
# pair_predict: val acc 0.8735 p 0.3571 r 0.5303 f1 0.4268
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 19 val loss 2.5293
# emotion_predict: val acc 0.7734 p 0.6786 r 0.5758 f1 0.6230
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7291 p 0.6222 r 0.4242 f1 0.5045
# max_acc 0.7389 max_p 0.6102 max_r 0.5455 max_f1 0.5760
#
# pair_predict: val acc 0.9152 p 0.5333 r 0.3636 f1 0.4324
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# Fold 1 Epoch 20 val loss 2.4802
# emotion_predict: val acc 0.7931 p 0.7143 r 0.6061 f1 0.6557
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7586 p 0.6393 r 0.5909 f1 0.6142
# max_acc 0.7586 max_p 0.6393 max_r 0.5909 max_f1 0.6142
#
# pair_predict: val acc 0.8762 p 0.3523 r 0.4697 f1 0.4026
# max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.9031 max_p 0.4583 max_r 0.5000 max_f1 0.4783
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.56198347]]
# average : acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
#
# emotion_predict: val f1 in 5 fold: [[0.70866142]]
# average : acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
#
# pair_predict: val f1 in 5 fold: [[0.47826087]]
# average : acc 0.9031 p 0.4583 r 0.5000 f1 0.4783

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.8013
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6946 p 0.7500 r 0.0909 f1 0.1622
# max_acc 0.6946 max_p 0.7500 max_r 0.0909 max_f1 0.1622
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6946 max_p 0.7500 max_r 0.0909 max_f1 0.1622
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.6774
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.7044 p 1.0000 r 0.0909 f1 0.1667
# max_acc 0.7044 max_p 1.0000 max_r 0.0909 max_f1 0.1667
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6946 max_p 0.7500 max_r 0.0909 max_f1 0.1622
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.6581
# emotion_predict: val acc 0.6995 p 0.7778 r 0.1061 f1 0.1867
# max_acc 0.6995 max_p 0.7778 max_r 0.1061 max_f1 0.1867
#
# cause_predict: val acc 0.6995 p 0.5610 r 0.3485 f1 0.4299
# max_acc 0.6995 max_p 0.5610 max_r 0.3485 max_f1 0.4299
#
# pair_predict: val acc 0.8600 p 0.2935 r 0.4091 f1 0.3418
# max_acc 0.8600 max_p 0.2935 max_r 0.4091 max_f1 0.3418
#
# avg max cause: max_acc 0.6995 max_p 0.5610 max_r 0.3485 max_f1 0.4299
# avg max pos: max_acc 0.6995 max_p 0.7778 max_r 0.1061 max_f1 0.1867
# avg max pair: max_acc 0.8600 max_p 0.2935 max_r 0.4091 max_f1 0.3418
#
# Fold 1 Epoch 4 val loss 2.5358
# emotion_predict: val acc 0.6995 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.6995 max_p 0.7778 max_r 0.1061 max_f1 0.1867
#
# cause_predict: val acc 0.7389 p 0.7600 r 0.2879 f1 0.4176
# max_acc 0.6995 max_p 0.5610 max_r 0.3485 max_f1 0.4299
#
# pair_predict: val acc 0.9044 p 0.4468 r 0.3182 f1 0.3717
# max_acc 0.9044 max_p 0.4468 max_r 0.3182 max_f1 0.3717
#
# avg max cause: max_acc 0.7389 max_p 0.7600 max_r 0.2879 max_f1 0.4176
# avg max pos: max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
# avg max pair: max_acc 0.9044 max_p 0.4468 max_r 0.3182 max_f1 0.3717
#
# Fold 1 Epoch 5 val loss 2.4553
# emotion_predict: val acc 0.7192 p 0.5634 r 0.6061 f1 0.5839
# max_acc 0.7192 max_p 0.5634 max_r 0.6061 max_f1 0.5839
#
# cause_predict: val acc 0.7143 p 0.5571 r 0.5909 f1 0.5735
# max_acc 0.7143 max_p 0.5571 max_r 0.5909 max_f1 0.5735
#
# pair_predict: val acc 0.8493 p 0.2946 r 0.5000 f1 0.3708
# max_acc 0.9044 max_p 0.4468 max_r 0.3182 max_f1 0.3717
#
# avg max cause: max_acc 0.7389 max_p 0.7600 max_r 0.2879 max_f1 0.4176
# avg max pos: max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
# avg max pair: max_acc 0.9044 max_p 0.4468 max_r 0.3182 max_f1 0.3717
#
# Fold 1 Epoch 6 val loss 2.3162
# emotion_predict: val acc 0.7537 p 0.6538 r 0.5152 f1 0.5763
# max_acc 0.7192 max_p 0.5634 max_r 0.6061 max_f1 0.5839
#
# cause_predict: val acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
# max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
#
# pair_predict: val acc 0.8869 p 0.3875 r 0.4697 f1 0.4247
# max_acc 0.8869 max_p 0.3875 max_r 0.4697 max_f1 0.4247
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7537 max_p 0.6538 max_r 0.5152 max_f1 0.5763
# avg max pair: max_acc 0.8869 max_p 0.3875 max_r 0.4697 max_f1 0.4247
#
# Fold 1 Epoch 7 val loss 2.2184
# emotion_predict: val acc 0.7783 p 0.8621 r 0.3788 f1 0.5263
# max_acc 0.7192 max_p 0.5634 max_r 0.6061 max_f1 0.5839
#
# cause_predict: val acc 0.7586 p 0.6667 r 0.5152 f1 0.5812
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# pair_predict: val acc 0.8452 p 0.3008 r 0.5606 f1 0.3915
# max_acc 0.8869 max_p 0.3875 max_r 0.4697 max_f1 0.4247
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7537 max_p 0.6538 max_r 0.5152 max_f1 0.5763
# avg max pair: max_acc 0.8869 max_p 0.3875 max_r 0.4697 max_f1 0.4247
#
# Fold 1 Epoch 8 val loss 2.1108
# emotion_predict: val acc 0.8030 p 0.7708 r 0.5606 f1 0.6491
# max_acc 0.8030 max_p 0.7708 max_r 0.5606 max_f1 0.6491
#
# cause_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# pair_predict: val acc 0.8627 p 0.3421 r 0.5909 f1 0.4333
# max_acc 0.8627 max_p 0.3421 max_r 0.5909 max_f1 0.4333
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.8030 max_p 0.7708 max_r 0.5606 max_f1 0.6491
# avg max pair: max_acc 0.8627 max_p 0.3421 max_r 0.5909 max_f1 0.4333
#
# Fold 1 Epoch 9 val loss 2.0328
# emotion_predict: val acc 0.8227 p 0.7419 r 0.6970 f1 0.7187
# max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
#
# cause_predict: val acc 0.7438 p 0.6129 r 0.5758 f1 0.5937
# max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
#
# pair_predict: val acc 0.8748 p 0.3738 r 0.6061 f1 0.4624
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 10 val loss 2.0686
# emotion_predict: val acc 0.8128 p 0.7187 r 0.6970 f1 0.7077
# max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
#
# cause_predict: val acc 0.7241 p 0.5694 r 0.6212 f1 0.5942
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8493 p 0.3231 r 0.6364 f1 0.4286
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 11 val loss 2.0574
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
#
# cause_predict: val acc 0.7291 p 0.5965 r 0.5152 f1 0.5528
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8425 p 0.3111 r 0.6364 f1 0.4179
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 12 val loss 2.0266
# emotion_predict: val acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
# max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
#
# cause_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8708 p 0.3585 r 0.5758 f1 0.4419
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 13 val loss 2.0342
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7241 p 0.5714 r 0.6061 f1 0.5882
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8210 p 0.2945 r 0.7273 f1 0.4192
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 14 val loss 2.1543
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7438 p 0.6667 r 0.4242 f1 0.5185
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8910 p 0.4051 r 0.4848 f1 0.4414
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 15 val loss 2.0983
# emotion_predict: val acc 0.8079 p 0.7077 r 0.6970 f1 0.7023
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7241 p 0.5735 r 0.5909 f1 0.5821
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8358 p 0.3108 r 0.6970 f1 0.4299
# max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8227 max_p 0.7419 max_r 0.6970 max_f1 0.7187
# avg max pair: max_acc 0.8748 max_p 0.3738 max_r 0.6061 max_f1 0.4624
#
# Fold 1 Epoch 16 val loss 2.1686
# emotion_predict: val acc 0.8177 p 0.7959 r 0.5909 f1 0.6783
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7438 p 0.6061 r 0.6061 f1 0.6061
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8748 p 0.3805 r 0.6515 f1 0.4804
# max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# avg max cause: max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
# avg max pos: max_acc 0.8177 max_p 0.7959 max_r 0.5909 max_f1 0.6783
# avg max pair: max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# Fold 1 Epoch 17 val loss 2.2300
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7094 p 0.5574 r 0.5152 f1 0.5354
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8681 p 0.3689 r 0.6818 f1 0.4787
# max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# avg max cause: max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
# avg max pos: max_acc 0.8177 max_p 0.7959 max_r 0.5909 max_f1 0.6783
# avg max pair: max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# Fold 1 Epoch 18 val loss 2.2918
# emotion_predict: val acc 0.8374 p 0.7619 r 0.7273 f1 0.7442
# max_acc 0.8374 max_p 0.7619 max_r 0.7273 max_f1 0.7442
#
# cause_predict: val acc 0.7094 p 0.5538 r 0.5455 f1 0.5496
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8600 p 0.3538 r 0.6970 f1 0.4694
# max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# avg max cause: max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
# avg max pos: max_acc 0.8177 max_p 0.7959 max_r 0.5909 max_f1 0.6783
# avg max pair: max_acc 0.8748 max_p 0.3805 max_r 0.6515 max_f1 0.4804
#
# Fold 1 Epoch 19 val loss 2.4181
# emotion_predict: val acc 0.8424 p 0.7656 r 0.7424 f1 0.7538
# max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
#
# cause_predict: val acc 0.7537 p 0.6250 r 0.6061 f1 0.6154
# max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
#
# pair_predict: val acc 0.8775 p 0.3894 r 0.6667 f1 0.4916
# max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# avg max cause: max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
# avg max pos: max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
# avg max pair: max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# Fold 1 Epoch 20 val loss 2.4748
# emotion_predict: val acc 0.8571 p 0.7937 r 0.7576 f1 0.7752
# max_acc 0.8571 max_p 0.7937 max_r 0.7576 max_f1 0.7752
#
# cause_predict: val acc 0.7192 p 0.5763 r 0.5152 f1 0.5440
# max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
#
# pair_predict: val acc 0.8856 p 0.4040 r 0.6061 f1 0.4848
# max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# avg max cause: max_acc 0.7537 max_p 0.6250 max_r 0.6061 max_f1 0.6154
# avg max pos: max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
# avg max pair: max_acc 0.8775 max_p 0.3894 max_r 0.6667 max_f1 0.4916
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.61538461]]
# average : acc 0.7537 p 0.6250 r 0.6061 f1 0.6154
#
# emotion_predict: val f1 in 5 fold: [[0.75384615]]
# average : acc 0.8424 p 0.7656 r 0.7424 f1 0.7538
#
# pair_predict: val f1 in 5 fold: [[0.49162011]]
# average : acc 0.8775 p 0.3894 r 0.6667 f1 0.4916

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 4.0185
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.5275
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.2535
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.3406
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.2145
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.1881
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.1902
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.1535
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.1078
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0932
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 3.0679
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 3.0451
# emotion_predict: val acc 0.6995 p 0.5490 r 0.4242 f1 0.4786
# max_acc 0.6995 max_p 0.5490 max_r 0.4242 max_f1 0.4786
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.0517
# emotion_predict: val acc 0.6995 p 0.5410 r 0.5000 f1 0.5197
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7241 p 0.7500 r 0.2273 f1 0.3488
# max_acc 0.7241 max_p 0.7500 max_r 0.2273 max_f1 0.3488
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 3.0308
# emotion_predict: val acc 0.7094 p 0.5745 r 0.4091 f1 0.4779
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7241 p 0.6471 r 0.3333 f1 0.4400
# max_acc 0.7241 max_p 0.6471 max_r 0.3333 max_f1 0.4400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 2.9865
# emotion_predict: val acc 0.7389 p 0.8824 r 0.2273 f1 0.3614
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7192 p 0.7647 r 0.1970 f1 0.3133
# max_acc 0.7241 max_p 0.6471 max_r 0.3333 max_f1 0.4400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 16 val loss 2.9647
# emotion_predict: val acc 0.7192 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7291 p 0.9231 r 0.1818 f1 0.3038
# max_acc 0.7241 max_p 0.6471 max_r 0.3333 max_f1 0.4400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 17 val loss 2.9315
# emotion_predict: val acc 0.7389 p 0.8824 r 0.2273 f1 0.3614
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7340 p 0.9286 r 0.1970 f1 0.3250
# max_acc 0.7241 max_p 0.6471 max_r 0.3333 max_f1 0.4400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 18 val loss 2.8995
# emotion_predict: val acc 0.7241 p 0.6471 r 0.3333 f1 0.4400
# max_acc 0.6995 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# cause_predict: val acc 0.7241 p 0.6786 r 0.2879 f1 0.4043
# max_acc 0.7241 max_p 0.6471 max_r 0.3333 max_f1 0.4400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 19 val loss 2.8718
# emotion_predict: val acc 0.7340 p 0.6200 r 0.4697 f1 0.5345
# max_acc 0.7340 max_p 0.6200 max_r 0.4697 max_f1 0.5345
#
# cause_predict: val acc 0.7537 p 0.6818 r 0.4545 f1 0.5455
# max_acc 0.7537 max_p 0.6818 max_r 0.4545 max_f1 0.5455
#
# pair_predict: val acc 0.9206 p 1.0000 r 0.1061 f1 0.1918
# max_acc 0.9206 max_p 1.0000 max_r 0.1061 max_f1 0.1918
#
# avg max cause: max_acc 0.7537 max_p 0.6818 max_r 0.4545 max_f1 0.5455
# avg max pos: max_acc 0.7340 max_p 0.6200 max_r 0.4697 max_f1 0.5345
# avg max pair: max_acc 0.9206 max_p 1.0000 max_r 0.1061 max_f1 0.1918
#
# Fold 1 Epoch 20 val loss 2.8284
# emotion_predict: val acc 0.7537 p 0.6905 r 0.4394 f1 0.5370
# max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
#
# cause_predict: val acc 0.7488 p 0.6364 r 0.5303 f1 0.5785
# max_acc 0.7488 max_p 0.6364 max_r 0.5303 max_f1 0.5785
#
# pair_predict: val acc 0.9233 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.9233 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# avg max cause: max_acc 0.7488 max_p 0.6364 max_r 0.5303 max_f1 0.5785
# avg max pos: max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
# avg max pair: max_acc 0.9233 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.5785124]]
# average : acc 0.7488 p 0.6364 r 0.5303 f1 0.5785
#
# emotion_predict: val f1 in 5 fold: [[0.53703704]]
# average : acc 0.7537 p 0.6905 r 0.4394 f1 0.5370
#
# pair_predict: val f1 in 5 fold: [[0.25974026]]
# average : acc 0.9233 p 0.9091 r 0.1515 f1 0.2597

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9146
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7913
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7740
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7353
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.7317
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.6866
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.6453
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.6231
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.5884
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.7143 p 0.9000 r 0.1364 f1 0.2368
# max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
#
# pair_predict: val acc 0.9125 p 0.5152 r 0.2576 f1 0.3434
# max_acc 0.9125 max_p 0.5152 max_r 0.2576 max_f1 0.3434
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9125 max_p 0.5152 max_r 0.2576 max_f1 0.3434
#
# Fold 1 Epoch 10 val loss 2.5788
# emotion_predict: val acc 0.6995 p 0.5581 r 0.3636 f1 0.4404
# max_acc 0.6995 max_p 0.5581 max_r 0.3636 max_f1 0.4404
#
# cause_predict: val acc 0.7340 p 0.6500 r 0.3939 f1 0.4906
# max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
#
# pair_predict: val acc 0.8721 p 0.3165 r 0.3788 f1 0.3448
# max_acc 0.8721 max_p 0.3165 max_r 0.3788 max_f1 0.3448
#
# avg max cause: max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
# avg max pos: max_acc 0.6995 max_p 0.5581 max_r 0.3636 max_f1 0.4404
# avg max pair: max_acc 0.8721 max_p 0.3165 max_r 0.3788 max_f1 0.3448
#
# Fold 1 Epoch 11 val loss 2.5335
# emotion_predict: val acc 0.6995 p 0.5510 r 0.4091 f1 0.4696
# max_acc 0.6995 max_p 0.5510 max_r 0.4091 max_f1 0.4696
#
# cause_predict: val acc 0.7192 p 0.6552 r 0.2879 f1 0.4000
# max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
#
# pair_predict: val acc 0.8896 p 0.3788 r 0.3788 f1 0.3788
# max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# avg max cause: max_acc 0.7192 max_p 0.6552 max_r 0.2879 max_f1 0.4000
# avg max pos: max_acc 0.6995 max_p 0.5510 max_r 0.4091 max_f1 0.4696
# avg max pair: max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# Fold 1 Epoch 12 val loss 2.4879
# emotion_predict: val acc 0.7143 p 0.5769 r 0.4545 f1 0.5085
# max_acc 0.7143 max_p 0.5769 max_r 0.4545 max_f1 0.5085
#
# cause_predict: val acc 0.7291 p 0.6486 r 0.3636 f1 0.4660
# max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
#
# pair_predict: val acc 0.8654 p 0.3111 r 0.4242 f1 0.3590
# max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# avg max cause: max_acc 0.7192 max_p 0.6552 max_r 0.2879 max_f1 0.4000
# avg max pos: max_acc 0.6995 max_p 0.5510 max_r 0.4091 max_f1 0.4696
# avg max pair: max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# Fold 1 Epoch 13 val loss 2.4414
# emotion_predict: val acc 0.7389 p 0.6512 r 0.4242 f1 0.5138
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7143 p 0.5645 r 0.5303 f1 0.5469
# max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
#
# pair_predict: val acc 0.8318 p 0.2677 r 0.5152 f1 0.3523
# max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# avg max cause: max_acc 0.7192 max_p 0.6552 max_r 0.2879 max_f1 0.4000
# avg max pos: max_acc 0.6995 max_p 0.5510 max_r 0.4091 max_f1 0.4696
# avg max pair: max_acc 0.8896 max_p 0.3788 max_r 0.3788 max_f1 0.3788
#
# Fold 1 Epoch 14 val loss 2.3832
# emotion_predict: val acc 0.7438 p 0.7692 r 0.3030 f1 0.4348
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7143 p 0.5741 r 0.4697 f1 0.5167
# max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
#
# pair_predict: val acc 0.8843 p 0.3750 r 0.4545 f1 0.4110
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 15 val loss 2.3534
# emotion_predict: val acc 0.7291 p 0.6774 r 0.3182 f1 0.4330
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
#
# pair_predict: val acc 0.8694 p 0.3297 r 0.4545 f1 0.3822
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 16 val loss 2.3396
# emotion_predict: val acc 0.7241 p 0.6136 r 0.4091 f1 0.4909
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7291 p 0.5821 r 0.5909 f1 0.5865
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.8533 p 0.3063 r 0.5152 f1 0.3842
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 17 val loss 2.3237
# emotion_predict: val acc 0.7340 p 0.6579 r 0.3788 f1 0.4808
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8614 p 0.3131 r 0.4697 f1 0.3758
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 18 val loss 2.3089
# emotion_predict: val acc 0.7635 p 0.7368 r 0.4242 f1 0.5385
# max_acc 0.7635 max_p 0.7368 max_r 0.4242 max_f1 0.5385
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8304 p 0.2761 r 0.5606 f1 0.3700
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 19 val loss 2.2888
# emotion_predict: val acc 0.7488 p 0.6829 r 0.4242 f1 0.5234
# max_acc 0.7635 max_p 0.7368 max_r 0.4242 max_f1 0.5385
#
# cause_predict: val acc 0.7586 p 0.6441 r 0.5758 f1 0.6080
# max_acc 0.7586 max_p 0.6441 max_r 0.5758 max_f1 0.6080
#
# pair_predict: val acc 0.8250 p 0.2576 r 0.5152 f1 0.3434
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# Fold 1 Epoch 20 val loss 2.2730
# emotion_predict: val acc 0.7537 p 0.6667 r 0.4848 f1 0.5614
# max_acc 0.7537 max_p 0.6667 max_r 0.4848 max_f1 0.5614
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7586 max_p 0.6441 max_r 0.5758 max_f1 0.6080
#
# pair_predict: val acc 0.8546 p 0.3019 r 0.4848 f1 0.3721
# max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# avg max cause: max_acc 0.7143 max_p 0.5741 max_r 0.4697 max_f1 0.5167
# avg max pos: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pair: max_acc 0.8843 max_p 0.3750 max_r 0.4545 max_f1 0.4110
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.51666667]]
# average : acc 0.7143 p 0.5741 r 0.4697 f1 0.5167
#
# emotion_predict: val f1 in 5 fold: [[0.43478261]]
# average : acc 0.7438 p 0.7692 r 0.3030 f1 0.4348
#
# pair_predict: val f1 in 5 fold: [[0.4109589]]
# average : acc 0.8843 p 0.3750 r 0.4545 f1 0.4110

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.2140
# emotion_predict: val acc 0.6995 p 1.0000 r 0.0758 f1 0.1408
# max_acc 0.6995 max_p 1.0000 max_r 0.0758 max_f1 0.1408
#
# cause_predict: val acc 0.7241 p 1.0000 r 0.1515 f1 0.2632
# max_acc 0.7241 max_p 1.0000 max_r 0.1515 max_f1 0.2632
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 1.0000 max_r 0.1515 max_f1 0.2632
# avg max pos: max_acc 0.6995 max_p 1.0000 max_r 0.0758 max_f1 0.1408
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0435
# emotion_predict: val acc 0.6946 p 0.7500 r 0.0909 f1 0.1622
# max_acc 0.6946 max_p 0.7500 max_r 0.0909 max_f1 0.1622
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.7241 max_p 1.0000 max_r 0.1515 max_f1 0.2632
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7241 max_p 1.0000 max_r 0.1515 max_f1 0.2632
# avg max pos: max_acc 0.6995 max_p 1.0000 max_r 0.0758 max_f1 0.1408
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.8833
# emotion_predict: val acc 0.6798 p 0.5333 r 0.1212 f1 0.1975
# max_acc 0.6798 max_p 0.5333 max_r 0.1212 max_f1 0.1975
#
# cause_predict: val acc 0.7340 p 0.8750 r 0.2121 f1 0.3415
# max_acc 0.7340 max_p 0.8750 max_r 0.2121 max_f1 0.3415
#
# pair_predict: val acc 0.9058 p 0.4091 r 0.1364 f1 0.2045
# max_acc 0.9058 max_p 0.4091 max_r 0.1364 max_f1 0.2045
#
# avg max cause: max_acc 0.7340 max_p 0.8750 max_r 0.2121 max_f1 0.3415
# avg max pos: max_acc 0.6798 max_p 0.5333 max_r 0.1212 max_f1 0.1975
# avg max pair: max_acc 0.9058 max_p 0.4091 max_r 0.1364 max_f1 0.2045
#
# Fold 1 Epoch 4 val loss 2.8114
# emotion_predict: val acc 0.7340 p 0.6667 r 0.3636 f1 0.4706
# max_acc 0.7340 max_p 0.6667 max_r 0.3636 max_f1 0.4706
#
# cause_predict: val acc 0.7340 p 0.6579 r 0.3788 f1 0.4808
# max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
#
# pair_predict: val acc 0.9219 p 0.6818 r 0.2273 f1 0.3409
# max_acc 0.9219 max_p 0.6818 max_r 0.2273 max_f1 0.3409
#
# avg max cause: max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
# avg max pos: max_acc 0.7340 max_p 0.6667 max_r 0.3636 max_f1 0.4706
# avg max pair: max_acc 0.9219 max_p 0.6818 max_r 0.2273 max_f1 0.3409
#
# Fold 1 Epoch 5 val loss 2.7676
# emotion_predict: val acc 0.7192 p 0.6800 r 0.2576 f1 0.3736
# max_acc 0.7340 max_p 0.6667 max_r 0.3636 max_f1 0.4706
#
# cause_predict: val acc 0.7389 p 0.7241 r 0.3182 f1 0.4421
# max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
#
# pair_predict: val acc 0.9166 p 0.5714 r 0.2424 f1 0.3404
# max_acc 0.9219 max_p 0.6818 max_r 0.2273 max_f1 0.3409
#
# avg max cause: max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
# avg max pos: max_acc 0.7340 max_p 0.6667 max_r 0.3636 max_f1 0.4706
# avg max pair: max_acc 0.9219 max_p 0.6818 max_r 0.2273 max_f1 0.3409
#
# Fold 1 Epoch 6 val loss 2.6985
# emotion_predict: val acc 0.7241 p 0.6087 r 0.4242 f1 0.5000
# max_acc 0.7241 max_p 0.6087 max_r 0.4242 max_f1 0.5000
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# pair_predict: val acc 0.9192 p 0.5789 r 0.3333 f1 0.4231
# max_acc 0.9192 max_p 0.5789 max_r 0.3333 max_f1 0.4231
#
# avg max cause: max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
# avg max pos: max_acc 0.7241 max_p 0.6087 max_r 0.4242 max_f1 0.5000
# avg max pair: max_acc 0.9192 max_p 0.5789 max_r 0.3333 max_f1 0.4231
#
# Fold 1 Epoch 7 val loss 2.6454
# emotion_predict: val acc 0.7635 p 0.8000 r 0.3636 f1 0.5000
# max_acc 0.7635 max_p 0.8000 max_r 0.3636 max_f1 0.5000
#
# cause_predict: val acc 0.7537 p 0.6739 r 0.4697 f1 0.5536
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# pair_predict: val acc 0.9260 p 0.6774 r 0.3182 f1 0.4330
# max_acc 0.9260 max_p 0.6774 max_r 0.3182 max_f1 0.4330
#
# avg max cause: max_acc 0.7537 max_p 0.6739 max_r 0.4697 max_f1 0.5536
# avg max pos: max_acc 0.7635 max_p 0.8000 max_r 0.3636 max_f1 0.5000
# avg max pair: max_acc 0.9260 max_p 0.6774 max_r 0.3182 max_f1 0.4330
#
# Fold 1 Epoch 8 val loss 2.6615
# emotion_predict: val acc 0.7586 p 0.6667 r 0.5152 f1 0.5812
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# cause_predict: val acc 0.7241 p 0.5862 r 0.5152 f1 0.5484
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# pair_predict: val acc 0.9017 p 0.4386 r 0.3788 f1 0.4065
# max_acc 0.9260 max_p 0.6774 max_r 0.3182 max_f1 0.4330
#
# avg max cause: max_acc 0.7537 max_p 0.6739 max_r 0.4697 max_f1 0.5536
# avg max pos: max_acc 0.7635 max_p 0.8000 max_r 0.3636 max_f1 0.5000
# avg max pair: max_acc 0.9260 max_p 0.6774 max_r 0.3182 max_f1 0.4330
#
# Fold 1 Epoch 9 val loss 2.6360
# emotion_predict: val acc 0.7291 p 0.5902 r 0.5455 f1 0.5669
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# cause_predict: val acc 0.7537 p 0.6429 r 0.5455 f1 0.5902
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9098 p 0.4912 r 0.4242 f1 0.4553
# max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# Fold 1 Epoch 10 val loss 2.5521
# emotion_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# cause_predict: val acc 0.7438 p 0.6346 r 0.5000 f1 0.5593
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.4091 f1 0.4500
# max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# Fold 1 Epoch 11 val loss 2.5758
# emotion_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7586 max_p 0.6667 max_r 0.5152 max_f1 0.5812
#
# cause_predict: val acc 0.7438 p 0.6400 r 0.4848 f1 0.5517
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9071 p 0.4706 r 0.3636 f1 0.4103
# max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# Fold 1 Epoch 12 val loss 2.9447
# emotion_predict: val acc 0.6995 p 0.5309 r 0.6515 f1 0.5850
# max_acc 0.6995 max_p 0.5309 max_r 0.6515 max_f1 0.5850
#
# cause_predict: val acc 0.7241 p 0.5893 r 0.5000 f1 0.5410
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.8762 p 0.3587 r 0.5000 f1 0.4177
# max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# Fold 1 Epoch 13 val loss 2.6213
# emotion_predict: val acc 0.7833 p 0.7292 r 0.5303 f1 0.6140
# max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9058 p 0.4615 r 0.3636 f1 0.4068
# max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# avg max cause: max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9098 max_p 0.4912 max_r 0.4242 max_f1 0.4553
#
# Fold 1 Epoch 14 val loss 2.6619
# emotion_predict: val acc 0.7438 p 0.6250 r 0.5303 f1 0.5738
# max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
#
# cause_predict: val acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9206 p 0.5660 r 0.4545 f1 0.5042
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 15 val loss 2.4937
# emotion_predict: val acc 0.7586 p 0.6667 r 0.5152 f1 0.5812
# max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
#
# cause_predict: val acc 0.7389 p 0.6585 r 0.4091 f1 0.5047
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9071 p 0.4746 r 0.4242 f1 0.4480
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 16 val loss 2.6658
# emotion_predict: val acc 0.7537 p 0.6481 r 0.5303 f1 0.5833
# max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
#
# cause_predict: val acc 0.7488 p 0.6316 r 0.5455 f1 0.5854
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9004 p 0.4394 r 0.4394 f1 0.4394
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 17 val loss 2.9039
# emotion_predict: val acc 0.7931 p 0.6579 r 0.7576 f1 0.7042
# max_acc 0.7931 max_p 0.6579 max_r 0.7576 max_f1 0.7042
#
# cause_predict: val acc 0.6897 p 0.5181 r 0.6515 f1 0.5772
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9058 p 0.4687 r 0.4545 f1 0.4615
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 18 val loss 2.4951
# emotion_predict: val acc 0.7833 p 0.6774 r 0.6364 f1 0.6562
# max_acc 0.7931 max_p 0.6579 max_r 0.7576 max_f1 0.7042
#
# cause_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7537 max_p 0.6429 max_r 0.5455 max_f1 0.5902
#
# pair_predict: val acc 0.9004 p 0.4474 r 0.5152 f1 0.4789
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 19 val loss 2.7672
# emotion_predict: val acc 0.7980 p 0.6866 r 0.6970 f1 0.6917
# max_acc 0.7931 max_p 0.6579 max_r 0.7576 max_f1 0.7042
#
# cause_predict: val acc 0.7340 p 0.5811 r 0.6515 f1 0.6143
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8829 p 0.3820 r 0.5152 f1 0.4387
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7340 max_p 0.5968 max_r 0.5606 max_f1 0.5781
# avg max pos: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 20 val loss 2.4865
# emotion_predict: val acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
# max_acc 0.7931 max_p 0.6579 max_r 0.7576 max_f1 0.7042
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.9125 p 0.5075 r 0.5152 f1 0.5113
# max_acc 0.9125 max_p 0.5075 max_r 0.5152 max_f1 0.5113
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7980 max_p 0.7049 max_r 0.6515 max_f1 0.6772
# avg max pair: max_acc 0.9125 max_p 0.5075 max_r 0.5152 max_f1 0.5113
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.59677419]]
# average : acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
#
# emotion_predict: val f1 in 5 fold: [[0.67716535]]
# average : acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
#
# pair_predict: val f1 in 5 fold: [[0.51127819]]
# average : acc 0.9125 p 0.5075 r 0.5152 f1 0.5113

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.6855
# emotion_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.6798 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# cause_predict: val acc 0.7192 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.7192 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# pair_predict: val acc 0.9125 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.9125 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# avg max cause: max_acc 0.7192 max_p 0.9091 max_r 0.1515 max_f1 0.2597
# avg max pos: max_acc 0.6798 max_p 1.0000 max_r 0.0152 max_f1 0.0299
# avg max pair: max_acc 0.9125 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# Fold 1 Epoch 2 val loss 2.5082
# emotion_predict: val acc 0.6995 p 0.5641 r 0.3333 f1 0.4190
# max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
#
# cause_predict: val acc 0.6897 p 0.5224 r 0.5303 f1 0.5263
# max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
#
# pair_predict: val acc 0.9166 p 0.5476 r 0.3485 f1 0.4259
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 3 val loss 2.3434
# emotion_predict: val acc 0.7291 p 0.7037 r 0.2879 f1 0.4086
# max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
#
# cause_predict: val acc 0.7685 p 0.8065 r 0.3788 f1 0.5155
# max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
#
# pair_predict: val acc 0.8533 p 0.3130 r 0.5455 f1 0.3978
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 4 val loss 2.3831
# emotion_predict: val acc 0.7389 p 0.7241 r 0.3182 f1 0.4421
# max_acc 0.7389 max_p 0.7241 max_r 0.3182 max_f1 0.4421
#
# cause_predict: val acc 0.7537 p 0.6481 r 0.5303 f1 0.5833
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.9017 p 0.4340 r 0.3485 f1 0.3866
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 5 val loss 2.3842
# emotion_predict: val acc 0.6946 p 0.5370 r 0.4394 f1 0.4833
# max_acc 0.6946 max_p 0.5370 max_r 0.4394 max_f1 0.4833
#
# cause_predict: val acc 0.7389 p 0.6585 r 0.4091 f1 0.5047
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.8668 p 0.3103 r 0.4091 f1 0.3529
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 6 val loss 2.3895
# emotion_predict: val acc 0.7882 p 0.8108 r 0.4545 f1 0.5825
# max_acc 0.7882 max_p 0.8108 max_r 0.4545 max_f1 0.5825
#
# cause_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.8533 p 0.2991 r 0.4848 f1 0.3699
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 7 val loss 2.4097
# emotion_predict: val acc 0.7586 p 0.7179 r 0.4242 f1 0.5333
# max_acc 0.7882 max_p 0.8108 max_r 0.4545 max_f1 0.5825
#
# cause_predict: val acc 0.6897 p 0.5429 r 0.2879 f1 0.3762
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.8735 p 0.3409 r 0.4545 f1 0.3896
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 8 val loss 2.2810
# emotion_predict: val acc 0.7783 p 0.7143 r 0.5303 f1 0.6087
# max_acc 0.7783 max_p 0.7143 max_r 0.5303 max_f1 0.6087
#
# cause_predict: val acc 0.7291 p 0.5873 r 0.5606 f1 0.5736
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.8520 p 0.3070 r 0.5303 f1 0.3889
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 9 val loss 2.4011
# emotion_predict: val acc 0.7143 p 0.5556 r 0.6061 f1 0.5797
# max_acc 0.7783 max_p 0.7143 max_r 0.5303 max_f1 0.6087
#
# cause_predict: val acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
# max_acc 0.7537 max_p 0.6481 max_r 0.5303 max_f1 0.5833
#
# pair_predict: val acc 0.8331 p 0.2899 r 0.6061 f1 0.3922
# max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# avg max cause: max_acc 0.6897 max_p 0.5224 max_r 0.5303 max_f1 0.5263
# avg max pos: max_acc 0.6995 max_p 0.5641 max_r 0.3333 max_f1 0.4190
# avg max pair: max_acc 0.9166 max_p 0.5476 max_r 0.3485 max_f1 0.4259
#
# Fold 1 Epoch 10 val loss 2.2355
# emotion_predict: val acc 0.7980 p 0.7660 r 0.5455 f1 0.6372
# max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
#
# cause_predict: val acc 0.7783 p 0.6981 r 0.5606 f1 0.6218
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.9004 p 0.4412 r 0.4545 f1 0.4478
# max_acc 0.9004 max_p 0.4412 max_r 0.4545 max_f1 0.4478
#
# avg max cause: max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
# avg max pos: max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
# avg max pair: max_acc 0.9004 max_p 0.4412 max_r 0.4545 max_f1 0.4478
#
# Fold 1 Epoch 11 val loss 2.1893
# emotion_predict: val acc 0.7635 p 0.6957 r 0.4848 f1 0.5714
# max_acc 0.7980 max_p 0.7660 max_r 0.5455 max_f1 0.6372
#
# cause_predict: val acc 0.7635 p 0.7368 r 0.4242 f1 0.5385
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8923 p 0.4167 r 0.5303 f1 0.4667
# max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# avg max cause: max_acc 0.7635 max_p 0.7368 max_r 0.4242 max_f1 0.5385
# avg max pos: max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
# avg max pair: max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# Fold 1 Epoch 12 val loss 2.2205
# emotion_predict: val acc 0.7882 p 0.6575 r 0.7273 f1 0.6906
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7389 p 0.5942 r 0.6212 f1 0.6074
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8398 p 0.3172 r 0.6970 f1 0.4360
# max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# avg max cause: max_acc 0.7635 max_p 0.7368 max_r 0.4242 max_f1 0.5385
# avg max pos: max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
# avg max pair: max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# Fold 1 Epoch 13 val loss 2.2535
# emotion_predict: val acc 0.7980 p 0.6984 r 0.6667 f1 0.6822
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7241 p 0.5862 r 0.5152 f1 0.5484
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8304 p 0.3101 r 0.7424 f1 0.4375
# max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# avg max cause: max_acc 0.7635 max_p 0.7368 max_r 0.4242 max_f1 0.5385
# avg max pos: max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
# avg max pair: max_acc 0.8923 max_p 0.4167 max_r 0.5303 max_f1 0.4667
#
# Fold 1 Epoch 14 val loss 2.3107
# emotion_predict: val acc 0.7931 p 0.6875 r 0.6667 f1 0.6769
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8991 p 0.4430 r 0.5303 f1 0.4828
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 15 val loss 2.6902
# emotion_predict: val acc 0.7438 p 0.6029 r 0.6212 f1 0.6119
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7438 p 0.6061 r 0.6061 f1 0.6061
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8452 p 0.3158 r 0.6364 f1 0.4221
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 16 val loss 2.4648
# emotion_predict: val acc 0.7882 p 0.6885 r 0.6364 f1 0.6614
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7192 p 0.5789 r 0.5000 f1 0.5366
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8533 p 0.3383 r 0.6818 f1 0.4523
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 17 val loss 2.6151
# emotion_predict: val acc 0.7833 p 0.6667 r 0.6667 f1 0.6667
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7389 p 0.5942 r 0.6212 f1 0.6074
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8775 p 0.3737 r 0.5606 f1 0.4485
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 18 val loss 3.0410
# emotion_predict: val acc 0.7980 p 0.7193 r 0.6212 f1 0.6667
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8681 p 0.3462 r 0.5455 f1 0.4235
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 19 val loss 2.8817
# emotion_predict: val acc 0.7734 p 0.6667 r 0.6061 f1 0.6349
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7291 p 0.6078 r 0.4697 f1 0.5299
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8735 p 0.3511 r 0.5000 f1 0.4125
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# Fold 1 Epoch 20 val loss 2.8175
# emotion_predict: val acc 0.7389 p 0.5867 r 0.6667 f1 0.6241
# max_acc 0.7882 max_p 0.6575 max_r 0.7273 max_f1 0.6906
#
# cause_predict: val acc 0.7488 p 0.6271 r 0.5606 f1 0.5920
# max_acc 0.7783 max_p 0.6981 max_r 0.5606 max_f1 0.6218
#
# pair_predict: val acc 0.8573 p 0.3413 r 0.6515 f1 0.4479
# max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# avg max cause: max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
# avg max pos: max_acc 0.7931 max_p 0.6875 max_r 0.6667 max_f1 0.6769
# avg max pair: max_acc 0.8991 max_p 0.4430 max_r 0.5303 max_f1 0.4828
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.59677419]]
# average : acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
#
# emotion_predict: val f1 in 5 fold: [[0.67692308]]
# average : acc 0.7931 p 0.6875 r 0.6667 f1 0.6769
#
# pair_predict: val f1 in 5 fold: [[0.48275862]]
# average : acc 0.8991 p 0.4430 r 0.5303 f1 0.4828

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.1741
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0460
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.9540
# emotion_predict: val acc 0.6798 p 0.5075 r 0.5152 f1 0.5113
# max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
#
# cause_predict: val acc 0.7389 p 0.6327 r 0.4697 f1 0.5391
# max_acc 0.7389 max_p 0.6327 max_r 0.4697 max_f1 0.5391
#
# pair_predict: val acc 0.9219 p 1.0000 r 0.1212 f1 0.2162
# max_acc 0.9219 max_p 1.0000 max_r 0.1212 max_f1 0.2162
#
# avg max cause: max_acc 0.7389 max_p 0.6327 max_r 0.4697 max_f1 0.5391
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9219 max_p 1.0000 max_r 0.1212 max_f1 0.2162
#
# Fold 1 Epoch 4 val loss 2.8089
# emotion_predict: val acc 0.7438 p 0.6458 r 0.4697 f1 0.5439
# max_acc 0.7438 max_p 0.6458 max_r 0.4697 max_f1 0.5439
#
# cause_predict: val acc 0.6995 p 0.5342 r 0.5909 f1 0.5612
# max_acc 0.6995 max_p 0.5342 max_r 0.5909 max_f1 0.5612
#
# pair_predict: val acc 0.9058 p 0.4583 r 0.3333 f1 0.3860
# max_acc 0.9058 max_p 0.4583 max_r 0.3333 max_f1 0.3860
#
# avg max cause: max_acc 0.6995 max_p 0.5342 max_r 0.5909 max_f1 0.5612
# avg max pos: max_acc 0.7438 max_p 0.6458 max_r 0.4697 max_f1 0.5439
# avg max pair: max_acc 0.9058 max_p 0.4583 max_r 0.3333 max_f1 0.3860
#
# Fold 1 Epoch 5 val loss 2.7221
# emotion_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7241 max_p 0.5806 max_r 0.5455 max_f1 0.5625
#
# cause_predict: val acc 0.7241 p 0.5714 r 0.6061 f1 0.5882
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.8937 p 0.3968 r 0.3788 f1 0.3876
# max_acc 0.8937 max_p 0.3968 max_r 0.3788 max_f1 0.3876
#
# avg max cause: max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
# avg max pos: max_acc 0.7241 max_p 0.5806 max_r 0.5455 max_f1 0.5625
# avg max pair: max_acc 0.8937 max_p 0.3968 max_r 0.3788 max_f1 0.3876
#
# Fold 1 Epoch 6 val loss 2.5977
# emotion_predict: val acc 0.7537 p 0.6212 r 0.6212 f1 0.6212
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.8977 p 0.4242 r 0.4242 f1 0.4242
# max_acc 0.8977 max_p 0.4242 max_r 0.4242 max_f1 0.4242
#
# avg max cause: max_acc 0.7291 max_p 0.5846 max_r 0.5758 max_f1 0.5802
# avg max pos: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pair: max_acc 0.8977 max_p 0.4242 max_r 0.4242 max_f1 0.4242
#
# Fold 1 Epoch 7 val loss 2.5864
# emotion_predict: val acc 0.8030 p 0.7321 r 0.6212 f1 0.6721
# max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
#
# cause_predict: val acc 0.7143 p 0.5645 r 0.5303 f1 0.5469
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.9017 p 0.4444 r 0.4242 f1 0.4341
# max_acc 0.9017 max_p 0.4444 max_r 0.4242 max_f1 0.4341
#
# avg max cause: max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9017 max_p 0.4444 max_r 0.4242 max_f1 0.4341
#
# Fold 1 Epoch 8 val loss 2.4732
# emotion_predict: val acc 0.8030 p 0.7167 r 0.6515 f1 0.6825
# max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
#
# cause_predict: val acc 0.7241 p 0.5893 r 0.5000 f1 0.5410
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.9179 p 0.5455 r 0.4545 f1 0.4959
# max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# avg max cause: max_acc 0.7241 max_p 0.5893 max_r 0.5000 max_f1 0.5410
# avg max pos: max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
# avg max pair: max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# Fold 1 Epoch 9 val loss 2.4832
# emotion_predict: val acc 0.8177 p 0.7636 r 0.6364 f1 0.6942
# max_acc 0.8177 max_p 0.7636 max_r 0.6364 max_f1 0.6942
#
# cause_predict: val acc 0.6995 p 0.5352 r 0.5758 f1 0.5547
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.8937 p 0.4177 r 0.5000 f1 0.4552
# max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# avg max cause: max_acc 0.7241 max_p 0.5893 max_r 0.5000 max_f1 0.5410
# avg max pos: max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
# avg max pair: max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# Fold 1 Epoch 10 val loss 2.3485
# emotion_predict: val acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
# max_acc 0.8177 max_p 0.7636 max_r 0.6364 max_f1 0.6942
#
# cause_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7241 max_p 0.5714 max_r 0.6061 max_f1 0.5882
#
# pair_predict: val acc 0.9004 p 0.4487 r 0.5303 f1 0.4861
# max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# avg max cause: max_acc 0.7241 max_p 0.5893 max_r 0.5000 max_f1 0.5410
# avg max pos: max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
# avg max pair: max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# Fold 1 Epoch 11 val loss 2.5694
# emotion_predict: val acc 0.7783 p 0.6522 r 0.6818 f1 0.6667
# max_acc 0.8177 max_p 0.7636 max_r 0.6364 max_f1 0.6942
#
# cause_predict: val acc 0.7241 p 0.5676 r 0.6364 f1 0.6000
# max_acc 0.7241 max_p 0.5676 max_r 0.6364 max_f1 0.6000
#
# pair_predict: val acc 0.8910 p 0.4026 r 0.4697 f1 0.4336
# max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# avg max cause: max_acc 0.7241 max_p 0.5893 max_r 0.5000 max_f1 0.5410
# avg max pos: max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
# avg max pair: max_acc 0.9179 max_p 0.5455 max_r 0.4545 max_f1 0.4959
#
# Fold 1 Epoch 12 val loss 2.4514
# emotion_predict: val acc 0.8177 p 0.7302 r 0.6970 f1 0.7132
# max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
#
# cause_predict: val acc 0.7438 p 0.6129 r 0.5758 f1 0.5937
# max_acc 0.7241 max_p 0.5676 max_r 0.6364 max_f1 0.6000
#
# pair_predict: val acc 0.9058 p 0.4762 r 0.6061 f1 0.5333
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 13 val loss 2.7787
# emotion_predict: val acc 0.8079 p 0.7213 r 0.6667 f1 0.6929
# max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
#
# cause_predict: val acc 0.6897 p 0.5176 r 0.6667 f1 0.5828
# max_acc 0.7241 max_p 0.5676 max_r 0.6364 max_f1 0.6000
#
# pair_predict: val acc 0.8964 p 0.4321 r 0.5303 f1 0.4762
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 14 val loss 2.5965
# emotion_predict: val acc 0.8325 p 0.7759 r 0.6818 f1 0.7258
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7241 p 0.5781 r 0.5606 f1 0.5692
# max_acc 0.7241 max_p 0.5676 max_r 0.6364 max_f1 0.6000
#
# pair_predict: val acc 0.8802 p 0.3964 r 0.6667 f1 0.4972
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 15 val loss 2.6893
# emotion_predict: val acc 0.8030 p 0.6757 r 0.7576 f1 0.7143
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.6995 p 0.5275 r 0.7273 f1 0.6115
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.8869 p 0.4100 r 0.6212 f1 0.4940
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 16 val loss 2.8599
# emotion_predict: val acc 0.8473 p 0.8182 r 0.6818 f1 0.7438
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7241 p 0.5714 r 0.6061 f1 0.5882
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.8775 p 0.3853 r 0.6364 f1 0.4800
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 17 val loss 2.9502
# emotion_predict: val acc 0.8079 p 0.7015 r 0.7121 f1 0.7068
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.6798 p 0.5070 r 0.5455 f1 0.5255
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.9098 p 0.4933 r 0.5606 f1 0.5248
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 18 val loss 3.1061
# emotion_predict: val acc 0.8128 p 0.7121 r 0.7121 f1 0.7121
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7389 p 0.5970 r 0.6061 f1 0.6015
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.9152 p 0.5231 r 0.5152 f1 0.5191
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 19 val loss 3.5349
# emotion_predict: val acc 0.8177 p 0.7302 r 0.6970 f1 0.7132
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.9058 p 0.4706 r 0.4848 f1 0.4776
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# Fold 1 Epoch 20 val loss 3.9987
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7192 p 0.5692 r 0.5606 f1 0.5649
# max_acc 0.6995 max_p 0.5275 max_r 0.7273 max_f1 0.6115
#
# pair_predict: val acc 0.9098 p 0.4923 r 0.4848 f1 0.4885
# max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# avg max cause: max_acc 0.7438 max_p 0.6129 max_r 0.5758 max_f1 0.5937
# avg max pos: max_acc 0.8177 max_p 0.7302 max_r 0.6970 max_f1 0.7132
# avg max pair: max_acc 0.9058 max_p 0.4762 max_r 0.6061 max_f1 0.5333
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.59375]]
# average : acc 0.7438 p 0.6129 r 0.5758 f1 0.5937
#
# emotion_predict: val f1 in 5 fold: [[0.71317829]]
# average : acc 0.8177 p 0.7302 r 0.6970 f1 0.7132
#
# pair_predict: val f1 in 5 fold: [[0.53333333]]
# average : acc 0.9058 p 0.4762 r 0.6061 f1 0.5333

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7105
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.5858
# emotion_predict: val acc 0.6798 p 0.5385 r 0.1061 f1 0.1772
# max_acc 0.6798 max_p 0.5385 max_r 0.1061 max_f1 0.1772
#
# cause_predict: val acc 0.7241 p 0.8571 r 0.1818 f1 0.3000
# max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
#
# pair_predict: val acc 0.9139 p 0.6000 r 0.0909 f1 0.1579
# max_acc 0.9139 max_p 0.6000 max_r 0.0909 max_f1 0.1579
#
# avg max cause: max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
# avg max pos: max_acc 0.6798 max_p 0.5385 max_r 0.1061 max_f1 0.1772
# avg max pair: max_acc 0.9139 max_p 0.6000 max_r 0.0909 max_f1 0.1579
#
# Fold 1 Epoch 3 val loss 2.4878
# emotion_predict: val acc 0.6995 p 0.5472 r 0.4394 f1 0.4874
# max_acc 0.6995 max_p 0.5472 max_r 0.4394 max_f1 0.4874
#
# cause_predict: val acc 0.6995 p 0.5532 r 0.3939 f1 0.4602
# max_acc 0.6995 max_p 0.5532 max_r 0.3939 max_f1 0.4602
#
# pair_predict: val acc 0.8304 p 0.2541 r 0.4697 f1 0.3298
# max_acc 0.8304 max_p 0.2541 max_r 0.4697 max_f1 0.3298
#
# avg max cause: max_acc 0.6995 max_p 0.5532 max_r 0.3939 max_f1 0.4602
# avg max pos: max_acc 0.6995 max_p 0.5472 max_r 0.4394 max_f1 0.4874
# avg max pair: max_acc 0.8304 max_p 0.2541 max_r 0.4697 max_f1 0.3298
#
# Fold 1 Epoch 4 val loss 2.3271
# emotion_predict: val acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
# max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
#
# cause_predict: val acc 0.7094 p 0.5432 r 0.6667 f1 0.5986
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8089 p 0.2625 r 0.6364 f1 0.3717
# max_acc 0.8089 max_p 0.2625 max_r 0.6364 max_f1 0.3717
#
# avg max cause: max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
# avg max pos: max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
# avg max pair: max_acc 0.8089 max_p 0.2625 max_r 0.6364 max_f1 0.3717
#
# Fold 1 Epoch 5 val loss 2.0752
# emotion_predict: val acc 0.8079 p 0.8140 r 0.5303 f1 0.6422
# max_acc 0.8079 max_p 0.8140 max_r 0.5303 max_f1 0.6422
#
# cause_predict: val acc 0.7537 p 0.6905 r 0.4394 f1 0.5370
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8506 p 0.3228 r 0.6212 f1 0.4249
# max_acc 0.8506 max_p 0.3228 max_r 0.6212 max_f1 0.4249
#
# avg max cause: max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
# avg max pos: max_acc 0.8079 max_p 0.8140 max_r 0.5303 max_f1 0.6422
# avg max pair: max_acc 0.8506 max_p 0.3228 max_r 0.6212 max_f1 0.4249
#
# Fold 1 Epoch 6 val loss 2.0212
# emotion_predict: val acc 0.8128 p 0.7800 r 0.5909 f1 0.6724
# max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
#
# cause_predict: val acc 0.7438 p 0.6207 r 0.5455 f1 0.5806
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.9017 p 0.4507 r 0.4848 f1 0.4672
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 7 val loss 1.9937
# emotion_predict: val acc 0.8325 p 0.7759 r 0.6818 f1 0.7258
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7586 p 0.6889 r 0.4697 f1 0.5586
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8452 p 0.3185 r 0.6515 f1 0.4279
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 8 val loss 2.0787
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7389 p 0.6102 r 0.5455 f1 0.5760
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8573 p 0.3246 r 0.5606 f1 0.4111
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 9 val loss 1.9954
# emotion_predict: val acc 0.8177 p 0.7544 r 0.6515 f1 0.6992
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7537 p 0.6481 r 0.5303 f1 0.5833
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8627 p 0.3475 r 0.6212 f1 0.4457
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 10 val loss 2.0759
# emotion_predict: val acc 0.8177 p 0.7231 r 0.7121 f1 0.7176
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7586 p 0.6545 r 0.5455 f1 0.5950
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8748 p 0.3689 r 0.5758 f1 0.4497
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 11 val loss 2.1835
# emotion_predict: val acc 0.8128 p 0.7414 r 0.6515 f1 0.6935
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7340 p 0.6200 r 0.4697 f1 0.5345
# max_acc 0.7094 max_p 0.5432 max_r 0.6667 max_f1 0.5986
#
# pair_predict: val acc 0.8681 p 0.3596 r 0.6212 f1 0.4556
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 12 val loss 2.1540
# emotion_predict: val acc 0.8276 p 0.7541 r 0.6970 f1 0.7244
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7438 p 0.6061 r 0.6061 f1 0.6061
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8641 p 0.3423 r 0.5758 f1 0.4294
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 13 val loss 2.2386
# emotion_predict: val acc 0.8227 p 0.7344 r 0.7121 f1 0.7231
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7389 p 0.6102 r 0.5455 f1 0.5760
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8614 p 0.3543 r 0.6818 f1 0.4663
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 14 val loss 2.4978
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8681 p 0.3545 r 0.5909 f1 0.4432
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 15 val loss 2.3606
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7537 p 0.6290 r 0.5909 f1 0.6094
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8748 p 0.3738 r 0.6061 f1 0.4624
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 16 val loss 2.5884
# emotion_predict: val acc 0.8128 p 0.7187 r 0.6970 f1 0.7077
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8721 p 0.3645 r 0.5909 f1 0.4509
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 17 val loss 2.8002
# emotion_predict: val acc 0.7931 p 0.6818 r 0.6818 f1 0.6818
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8856 p 0.3956 r 0.5455 f1 0.4586
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 18 val loss 3.1161
# emotion_predict: val acc 0.7635 p 0.6364 r 0.6364 f1 0.6364
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8789 p 0.3667 r 0.5000 f1 0.4231
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 19 val loss 3.2443
# emotion_predict: val acc 0.8276 p 0.7246 r 0.7576 f1 0.7407
# max_acc 0.8276 max_p 0.7246 max_r 0.7576 max_f1 0.7407
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8735 p 0.3654 r 0.5758 f1 0.4471
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# Fold 1 Epoch 20 val loss 3.4776
# emotion_predict: val acc 0.7980 p 0.6923 r 0.6818 f1 0.6870
# max_acc 0.8276 max_p 0.7246 max_r 0.7576 max_f1 0.7407
#
# cause_predict: val acc 0.7340 p 0.5968 r 0.5606 f1 0.5781
# max_acc 0.7537 max_p 0.6290 max_r 0.5909 max_f1 0.6094
#
# pair_predict: val acc 0.8896 p 0.3974 r 0.4697 f1 0.4306
# max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# avg max cause: max_acc 0.7438 max_p 0.6207 max_r 0.5455 max_f1 0.5806
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9017 max_p 0.4507 max_r 0.4848 max_f1 0.4672
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.58064516]]
# average : acc 0.7438 p 0.6207 r 0.5455 f1 0.5806
#
# emotion_predict: val f1 in 5 fold: [[0.67241379]]
# average : acc 0.8128 p 0.7800 r 0.5909 f1 0.6724
#
# pair_predict: val f1 in 5 fold: [[0.46715328]]
# average : acc 0.9017 p 0.4507 r 0.4848 f1 0.4672

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 4.4025
# emotion_predict: val acc 0.3350 p 0.3284 r 1.0000 f1 0.4944
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.3251 p 0.3251 r 1.0000 f1 0.4907
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.5410 p 0.1037 r 0.5455 f1 0.1743
# max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# avg max cause: max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
# avg max pos: max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
# avg max pair: max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# Fold 1 Epoch 2 val loss 3.3565
# emotion_predict: val acc 0.6897 p 1.0000 r 0.0455 f1 0.0870
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# avg max cause: max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
# avg max pos: max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
# avg max pair: max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# Fold 1 Epoch 3 val loss 3.2052
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# avg max cause: max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
# avg max pos: max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
# avg max pair: max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# Fold 1 Epoch 4 val loss 3.0942
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# avg max cause: max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
# avg max pos: max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
# avg max pair: max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# Fold 1 Epoch 5 val loss 3.0094
# emotion_predict: val acc 0.6798 p 0.5333 r 0.1212 f1 0.1975
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7291 p 0.7895 r 0.2273 f1 0.3529
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9125 p 0.5455 r 0.0909 f1 0.1558
# max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# avg max cause: max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
# avg max pos: max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
# avg max pair: max_acc 0.5410 max_p 0.1037 max_r 0.5455 max_f1 0.1743
#
# Fold 1 Epoch 6 val loss 2.9780
# emotion_predict: val acc 0.6798 p 0.5094 r 0.4091 f1 0.4538
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.6946 p 0.5400 r 0.4091 f1 0.4655
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9085 p 0.4687 r 0.2273 f1 0.3061
# max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# avg max cause: max_acc 0.6946 max_p 0.5400 max_r 0.4091 max_f1 0.4655
# avg max pos: max_acc 0.6798 max_p 0.5094 max_r 0.4091 max_f1 0.4538
# avg max pair: max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# Fold 1 Epoch 7 val loss 2.9498
# emotion_predict: val acc 0.6897 p 0.5366 r 0.3333 f1 0.4112
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7094 p 0.6061 r 0.3030 f1 0.4040
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9152 p 0.6364 r 0.1061 f1 0.1818
# max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# avg max cause: max_acc 0.6946 max_p 0.5400 max_r 0.4091 max_f1 0.4655
# avg max pos: max_acc 0.6798 max_p 0.5094 max_r 0.4091 max_f1 0.4538
# avg max pair: max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# Fold 1 Epoch 8 val loss 2.9692
# emotion_predict: val acc 0.6946 p 0.7000 r 0.1061 f1 0.1842
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7291 p 1.0000 r 0.1667 f1 0.2857
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# avg max cause: max_acc 0.6946 max_p 0.5400 max_r 0.4091 max_f1 0.4655
# avg max pos: max_acc 0.6798 max_p 0.5094 max_r 0.4091 max_f1 0.4538
# avg max pair: max_acc 0.9085 max_p 0.4687 max_r 0.2273 max_f1 0.3061
#
# Fold 1 Epoch 9 val loss 2.9466
# emotion_predict: val acc 0.6946 p 0.7000 r 0.1061 f1 0.1842
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7241 p 0.8571 r 0.1818 f1 0.3000
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9152 p 0.5385 r 0.3182 f1 0.4000
# max_acc 0.9152 max_p 0.5385 max_r 0.3182 max_f1 0.4000
#
# avg max cause: max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
# avg max pos: max_acc 0.6946 max_p 0.7000 max_r 0.1061 max_f1 0.1842
# avg max pair: max_acc 0.9152 max_p 0.5385 max_r 0.3182 max_f1 0.4000
#
# Fold 1 Epoch 10 val loss 2.8500
# emotion_predict: val acc 0.7241 p 0.7083 r 0.2576 f1 0.3778
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7537 p 0.7500 r 0.3636 f1 0.4898
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9166 p 0.6000 r 0.1818 f1 0.2791
# max_acc 0.9152 max_p 0.5385 max_r 0.3182 max_f1 0.4000
#
# avg max cause: max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
# avg max pos: max_acc 0.6946 max_p 0.7000 max_r 0.1061 max_f1 0.1842
# avg max pair: max_acc 0.9152 max_p 0.5385 max_r 0.3182 max_f1 0.4000
#
# Fold 1 Epoch 11 val loss 2.7704
# emotion_predict: val acc 0.7241 p 0.6786 r 0.2879 f1 0.4043
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7537 p 0.7500 r 0.3636 f1 0.4898
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9206 p 0.6000 r 0.3182 f1 0.4158
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 12 val loss 2.7943
# emotion_predict: val acc 0.7044 p 0.7143 r 0.1515 f1 0.2500
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7537 p 0.8077 r 0.3182 f1 0.4565
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9260 p 0.7895 r 0.2273 f1 0.3529
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 13 val loss 2.8015
# emotion_predict: val acc 0.7241 p 0.8125 r 0.1970 f1 0.3171
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7438 p 0.7917 r 0.2879 f1 0.4222
# max_acc 0.3251 max_p 0.3251 max_r 1.0000 max_f1 0.4907
#
# pair_predict: val acc 0.9273 p 0.8750 r 0.2121 f1 0.3415
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 14 val loss 2.7402
# emotion_predict: val acc 0.7291 p 0.6410 r 0.3788 f1 0.4762
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7635 p 0.7143 r 0.4545 f1 0.5556
# max_acc 0.7635 max_p 0.7143 max_r 0.4545 max_f1 0.5556
#
# pair_predict: val acc 0.9179 p 0.5714 r 0.3030 f1 0.3960
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 15 val loss 2.6919
# emotion_predict: val acc 0.7241 p 0.6316 r 0.3636 f1 0.4615
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7635 p 0.6957 r 0.4848 f1 0.5714
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9152 p 0.5429 r 0.2879 f1 0.3762
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 16 val loss 2.7213
# emotion_predict: val acc 0.7389 p 0.6757 r 0.3788 f1 0.4854
# max_acc 0.3350 max_p 0.3284 max_r 1.0000 max_f1 0.4944
#
# cause_predict: val acc 0.7438 p 0.6458 r 0.4697 f1 0.5439
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9192 p 0.5882 r 0.3030 f1 0.4000
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 17 val loss 2.7473
# emotion_predict: val acc 0.7389 p 0.6512 r 0.4242 f1 0.5138
# max_acc 0.7389 max_p 0.6512 max_r 0.4242 max_f1 0.5138
#
# cause_predict: val acc 0.7094 p 0.5660 r 0.4545 f1 0.5042
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9139 p 0.5250 r 0.3182 f1 0.3962
# max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# avg max cause: max_acc 0.7537 max_p 0.7500 max_r 0.3636 max_f1 0.4898
# avg max pos: max_acc 0.7241 max_p 0.6786 max_r 0.2879 max_f1 0.4043
# avg max pair: max_acc 0.9206 max_p 0.6000 max_r 0.3182 max_f1 0.4158
#
# Fold 1 Epoch 18 val loss 2.7365
# emotion_predict: val acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
# max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
#
# cause_predict: val acc 0.7094 p 0.5538 r 0.5455 f1 0.5496
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9152 p 0.5333 r 0.3636 f1 0.4324
# max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# avg max cause: max_acc 0.7094 max_p 0.5538 max_r 0.5455 max_f1 0.5496
# avg max pos: max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
# avg max pair: max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# Fold 1 Epoch 19 val loss 2.7477
# emotion_predict: val acc 0.7143 p 0.5690 r 0.5000 f1 0.5323
# max_acc 0.7143 max_p 0.5690 max_r 0.5000 max_f1 0.5323
#
# cause_predict: val acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9139 p 0.5278 r 0.2879 f1 0.3725
# max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# avg max cause: max_acc 0.7094 max_p 0.5538 max_r 0.5455 max_f1 0.5496
# avg max pos: max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
# avg max pair: max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# Fold 1 Epoch 20 val loss 2.7027
# emotion_predict: val acc 0.7143 p 0.5800 r 0.4394 f1 0.5000
# max_acc 0.7143 max_p 0.5690 max_r 0.5000 max_f1 0.5323
#
# cause_predict: val acc 0.7143 p 0.5690 r 0.5000 f1 0.5323
# max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
#
# pair_predict: val acc 0.9139 p 0.5263 r 0.3030 f1 0.3846
# max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# avg max cause: max_acc 0.7094 max_p 0.5538 max_r 0.5455 max_f1 0.5496
# avg max pos: max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
# avg max pair: max_acc 0.9152 max_p 0.5333 max_r 0.3636 max_f1 0.4324
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.54961832]]
# average : acc 0.7094 p 0.5538 r 0.5455 f1 0.5496
#
# emotion_predict: val f1 in 5 fold: [[0.52892562]]
# average : acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
#
# pair_predict: val f1 in 5 fold: [[0.43243243]]
# average : acc 0.9152 p 0.5333 r 0.3636 f1 0.4324

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.4250
# emotion_predict: val acc 0.3547 p 0.3298 r 0.9545 f1 0.4903
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.3448 p 0.3299 r 0.9848 f1 0.4943
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.1265 p 0.0889 r 0.9545 f1 0.1626
# max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# avg max cause: max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
# avg max pos: max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
# avg max pair: max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# Fold 1 Epoch 2 val loss 2.8505
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# avg max cause: max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
# avg max pos: max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
# avg max pair: max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# Fold 1 Epoch 3 val loss 2.7924
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# avg max cause: max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
# avg max pos: max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
# avg max pair: max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# Fold 1 Epoch 4 val loss 2.6957
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.9125 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# avg max cause: max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
# avg max pos: max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
# avg max pair: max_acc 0.1265 max_p 0.0889 max_r 0.9545 max_f1 0.1626
#
# Fold 1 Epoch 5 val loss 2.5849
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.6897 p 0.8000 r 0.0606 f1 0.1127
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.9152 p 0.5789 r 0.1667 f1 0.2588
# max_acc 0.9152 max_p 0.5789 max_r 0.1667 max_f1 0.2588
#
# avg max cause: max_acc 0.6897 max_p 0.8000 max_r 0.0606 max_f1 0.1127
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9152 max_p 0.5789 max_r 0.1667 max_f1 0.2588
#
# Fold 1 Epoch 6 val loss 2.6255
# emotion_predict: val acc 0.6798 p 0.6000 r 0.0455 f1 0.0845
# max_acc 0.3547 max_p 0.3298 max_r 0.9545 max_f1 0.4903
#
# cause_predict: val acc 0.7192 p 0.8000 r 0.1818 f1 0.2963
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.6608 p 0.1725 r 0.7424 f1 0.2800
# max_acc 0.6608 max_p 0.1725 max_r 0.7424 max_f1 0.2800
#
# avg max cause: max_acc 0.7192 max_p 0.8000 max_r 0.1818 max_f1 0.2963
# avg max pos: max_acc 0.6798 max_p 0.6000 max_r 0.0455 max_f1 0.0845
# avg max pair: max_acc 0.6608 max_p 0.1725 max_r 0.7424 max_f1 0.2800
#
# Fold 1 Epoch 7 val loss 2.5112
# emotion_predict: val acc 0.7291 p 0.6222 r 0.4242 f1 0.5045
# max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
#
# cause_predict: val acc 0.7291 p 0.6571 r 0.3485 f1 0.4554
# max_acc 0.3448 max_p 0.3299 max_r 0.9848 max_f1 0.4943
#
# pair_predict: val acc 0.8977 p 0.4167 r 0.3788 f1 0.3968
# max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# avg max cause: max_acc 0.7291 max_p 0.6571 max_r 0.3485 max_f1 0.4554
# avg max pos: max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
# avg max pair: max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# Fold 1 Epoch 8 val loss 2.4253
# emotion_predict: val acc 0.7340 p 0.6364 r 0.4242 f1 0.5091
# max_acc 0.7340 max_p 0.6364 max_r 0.4242 max_f1 0.5091
#
# cause_predict: val acc 0.7340 p 0.5769 r 0.6818 f1 0.6250
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.7968 p 0.2543 r 0.6667 f1 0.3682
# max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# avg max cause: max_acc 0.7291 max_p 0.6571 max_r 0.3485 max_f1 0.4554
# avg max pos: max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
# avg max pair: max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# Fold 1 Epoch 9 val loss 2.3529
# emotion_predict: val acc 0.7488 p 0.8261 r 0.2879 f1 0.4270
# max_acc 0.7340 max_p 0.6364 max_r 0.4242 max_f1 0.5091
#
# cause_predict: val acc 0.7291 p 0.7037 r 0.2879 f1 0.4086
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8762 p 0.3617 r 0.5152 f1 0.4250
# max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# avg max cause: max_acc 0.7291 max_p 0.7037 max_r 0.2879 max_f1 0.4086
# avg max pos: max_acc 0.7488 max_p 0.8261 max_r 0.2879 max_f1 0.4270
# avg max pair: max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# Fold 1 Epoch 10 val loss 2.2926
# emotion_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# cause_predict: val acc 0.7340 p 0.6034 r 0.5303 f1 0.5645
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8425 p 0.2960 r 0.5606 f1 0.3874
# max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# avg max cause: max_acc 0.7291 max_p 0.7037 max_r 0.2879 max_f1 0.4086
# avg max pos: max_acc 0.7488 max_p 0.8261 max_r 0.2879 max_f1 0.4270
# avg max pair: max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# Fold 1 Epoch 11 val loss 2.2627
# emotion_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# cause_predict: val acc 0.7488 p 0.6230 r 0.5758 f1 0.5984
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8371 p 0.2932 r 0.5909 f1 0.3920
# max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# avg max cause: max_acc 0.7291 max_p 0.7037 max_r 0.2879 max_f1 0.4086
# avg max pos: max_acc 0.7488 max_p 0.8261 max_r 0.2879 max_f1 0.4270
# avg max pair: max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# Fold 1 Epoch 12 val loss 2.1610
# emotion_predict: val acc 0.7685 p 0.6863 r 0.5303 f1 0.5983
# max_acc 0.7685 max_p 0.6863 max_r 0.5303 max_f1 0.5983
#
# cause_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8614 p 0.3238 r 0.5152 f1 0.3977
# max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# avg max cause: max_acc 0.7291 max_p 0.7037 max_r 0.2879 max_f1 0.4086
# avg max pos: max_acc 0.7488 max_p 0.8261 max_r 0.2879 max_f1 0.4270
# avg max pair: max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# Fold 1 Epoch 13 val loss 2.1343
# emotion_predict: val acc 0.7882 p 0.6716 r 0.6818 f1 0.6767
# max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8385 p 0.3043 r 0.6364 f1 0.4118
# max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# avg max cause: max_acc 0.7291 max_p 0.7037 max_r 0.2879 max_f1 0.4086
# avg max pos: max_acc 0.7488 max_p 0.8261 max_r 0.2879 max_f1 0.4270
# avg max pair: max_acc 0.8762 max_p 0.3617 max_r 0.5152 max_f1 0.4250
#
# Fold 1 Epoch 14 val loss 2.1158
# emotion_predict: val acc 0.7980 p 0.7119 r 0.6364 f1 0.6720
# max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
#
# cause_predict: val acc 0.7340 p 0.6034 r 0.5303 f1 0.5645
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8654 p 0.3455 r 0.5758 f1 0.4318
# max_acc 0.8654 max_p 0.3455 max_r 0.5758 max_f1 0.4318
#
# avg max cause: max_acc 0.7340 max_p 0.6034 max_r 0.5303 max_f1 0.5645
# avg max pos: max_acc 0.7980 max_p 0.7119 max_r 0.6364 max_f1 0.6720
# avg max pair: max_acc 0.8654 max_p 0.3455 max_r 0.5758 max_f1 0.4318
#
# Fold 1 Epoch 15 val loss 2.1247
# emotion_predict: val acc 0.7833 p 0.6667 r 0.6667 f1 0.6667
# max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
#
# cause_predict: val acc 0.7488 p 0.6190 r 0.5909 f1 0.6047
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8277 p 0.2847 r 0.6212 f1 0.3905
# max_acc 0.8654 max_p 0.3455 max_r 0.5758 max_f1 0.4318
#
# avg max cause: max_acc 0.7340 max_p 0.6034 max_r 0.5303 max_f1 0.5645
# avg max pos: max_acc 0.7980 max_p 0.7119 max_r 0.6364 max_f1 0.6720
# avg max pair: max_acc 0.8654 max_p 0.3455 max_r 0.5758 max_f1 0.4318
#
# Fold 1 Epoch 16 val loss 2.1842
# emotion_predict: val acc 0.7734 p 0.6515 r 0.6515 f1 0.6515
# max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
#
# cause_predict: val acc 0.7488 p 0.6415 r 0.5152 f1 0.5714
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8856 p 0.3933 r 0.5303 f1 0.4516
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
# avg max pos: max_acc 0.7734 max_p 0.6515 max_r 0.6515 max_f1 0.6515
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 17 val loss 2.1509
# emotion_predict: val acc 0.8079 p 0.7077 r 0.6970 f1 0.7023
# max_acc 0.8079 max_p 0.7077 max_r 0.6970 max_f1 0.7023
#
# cause_predict: val acc 0.7192 p 0.5672 r 0.5758 f1 0.5714
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8170 p 0.2812 r 0.6818 f1 0.3982
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
# avg max pos: max_acc 0.7734 max_p 0.6515 max_r 0.6515 max_f1 0.6515
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 18 val loss 2.1681
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8079 max_p 0.7077 max_r 0.6970 max_f1 0.7023
#
# cause_predict: val acc 0.7438 p 0.6094 r 0.5909 f1 0.6000
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8843 p 0.3889 r 0.5303 f1 0.4487
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
# avg max pos: max_acc 0.7734 max_p 0.6515 max_r 0.6515 max_f1 0.6515
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 19 val loss 2.2118
# emotion_predict: val acc 0.7783 p 0.6667 r 0.6364 f1 0.6512
# max_acc 0.8079 max_p 0.7077 max_r 0.6970 max_f1 0.7023
#
# cause_predict: val acc 0.7192 p 0.5672 r 0.5758 f1 0.5714
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8573 p 0.3305 r 0.5909 f1 0.4239
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
# avg max pos: max_acc 0.7734 max_p 0.6515 max_r 0.6515 max_f1 0.6515
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 20 val loss 2.2590
# emotion_predict: val acc 0.7980 p 0.7273 r 0.6061 f1 0.6612
# max_acc 0.8079 max_p 0.7077 max_r 0.6970 max_f1 0.7023
#
# cause_predict: val acc 0.7438 p 0.6591 r 0.4394 f1 0.5273
# max_acc 0.7340 max_p 0.5769 max_r 0.6818 max_f1 0.6250
#
# pair_predict: val acc 0.8843 p 0.3980 r 0.5909 f1 0.4756
# max_acc 0.8843 max_p 0.3980 max_r 0.5909 max_f1 0.4756
#
# avg max cause: max_acc 0.7438 max_p 0.6591 max_r 0.4394 max_f1 0.5273
# avg max pos: max_acc 0.7980 max_p 0.7273 max_r 0.6061 max_f1 0.6612
# avg max pair: max_acc 0.8843 max_p 0.3980 max_r 0.5909 max_f1 0.4756
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.52727273]]
# average : acc 0.7438 p 0.6591 r 0.4394 f1 0.5273
#
# emotion_predict: val f1 in 5 fold: [[0.66115702]]
# average : acc 0.7980 p 0.7273 r 0.6061 f1 0.6612
#
# pair_predict: val f1 in 5 fold: [[0.47560976]]
# average : acc 0.8843 p 0.3980 r 0.5909 f1 0.4756

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.2832
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2474
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.2439
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1619
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.0759
# emotion_predict: val acc 0.6847 p 0.7500 r 0.0455 f1 0.0857
# max_acc 0.6847 max_p 0.7500 max_r 0.0455 max_f1 0.0857
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.0392
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6847 max_p 0.7500 max_r 0.0455 max_f1 0.0857
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.9614
# emotion_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.6847 max_p 0.7500 max_r 0.0455 max_f1 0.0857
#
# cause_predict: val acc 0.7241 p 0.8571 r 0.1818 f1 0.3000
# max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.9554
# emotion_predict: val acc 0.7488 p 0.8947 r 0.2576 f1 0.4000
# max_acc 0.7488 max_p 0.8947 max_r 0.2576 max_f1 0.4000
#
# cause_predict: val acc 0.7291 p 0.6571 r 0.3485 f1 0.4554
# max_acc 0.7291 max_p 0.6571 max_r 0.3485 max_f1 0.4554
#
# pair_predict: val acc 0.9206 p 1.0000 r 0.1061 f1 0.1918
# max_acc 0.9206 max_p 1.0000 max_r 0.1061 max_f1 0.1918
#
# avg max cause: max_acc 0.7291 max_p 0.6571 max_r 0.3485 max_f1 0.4554
# avg max pos: max_acc 0.7488 max_p 0.8947 max_r 0.2576 max_f1 0.4000
# avg max pair: max_acc 0.9206 max_p 1.0000 max_r 0.1061 max_f1 0.1918
#
# Fold 1 Epoch 9 val loss 2.8631
# emotion_predict: val acc 0.7340 p 0.6579 r 0.3788 f1 0.4808
# max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
#
# cause_predict: val acc 0.7340 p 0.6364 r 0.4242 f1 0.5091
# max_acc 0.7340 max_p 0.6364 max_r 0.4242 max_f1 0.5091
#
# pair_predict: val acc 0.9260 p 0.9231 r 0.1818 f1 0.3038
# max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# avg max cause: max_acc 0.7340 max_p 0.6364 max_r 0.4242 max_f1 0.5091
# avg max pos: max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
# avg max pair: max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# Fold 1 Epoch 10 val loss 2.8096
# emotion_predict: val acc 0.7044 p 0.5556 r 0.4545 f1 0.5000
# max_acc 0.7044 max_p 0.5556 max_r 0.4545 max_f1 0.5000
#
# cause_predict: val acc 0.7537 p 0.6600 r 0.5000 f1 0.5690
# max_acc 0.7537 max_p 0.6600 max_r 0.5000 max_f1 0.5690
#
# pair_predict: val acc 0.9260 p 0.9231 r 0.1818 f1 0.3038
# max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# avg max cause: max_acc 0.7340 max_p 0.6364 max_r 0.4242 max_f1 0.5091
# avg max pos: max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
# avg max pair: max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# Fold 1 Epoch 11 val loss 2.7413
# emotion_predict: val acc 0.7094 p 0.5593 r 0.5000 f1 0.5280
# max_acc 0.7094 max_p 0.5593 max_r 0.5000 max_f1 0.5280
#
# cause_predict: val acc 0.7291 p 0.5821 r 0.5909 f1 0.5865
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.9206 p 0.6296 r 0.2576 f1 0.3656
# max_acc 0.9206 max_p 0.6296 max_r 0.2576 max_f1 0.3656
#
# avg max cause: max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
# avg max pos: max_acc 0.7094 max_p 0.5593 max_r 0.5000 max_f1 0.5280
# avg max pair: max_acc 0.9206 max_p 0.6296 max_r 0.2576 max_f1 0.3656
#
# Fold 1 Epoch 12 val loss 2.6903
# emotion_predict: val acc 0.7291 p 0.5902 r 0.5455 f1 0.5669
# max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
#
# cause_predict: val acc 0.7291 p 0.5797 r 0.6061 f1 0.5926
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.9031 p 0.4464 r 0.3788 f1 0.4098
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 13 val loss 2.6463
# emotion_predict: val acc 0.7635 p 0.7250 r 0.4394 f1 0.5472
# max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
#
# cause_predict: val acc 0.7389 p 0.6512 r 0.4242 f1 0.5138
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.9004 p 0.4310 r 0.3788 f1 0.4032
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
# avg max pos: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 14 val loss 2.5559
# emotion_predict: val acc 0.7833 p 0.7619 r 0.4848 f1 0.5926
# max_acc 0.7833 max_p 0.7619 max_r 0.4848 max_f1 0.5926
#
# cause_predict: val acc 0.7586 p 0.6491 r 0.5606 f1 0.6016
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9058 p 0.4677 r 0.4394 f1 0.4531
# max_acc 0.9058 max_p 0.4677 max_r 0.4394 max_f1 0.4531
#
# avg max cause: max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
# avg max pos: max_acc 0.7833 max_p 0.7619 max_r 0.4848 max_f1 0.5926
# avg max pair: max_acc 0.9058 max_p 0.4677 max_r 0.4394 max_f1 0.4531
#
# Fold 1 Epoch 15 val loss 2.5095
# emotion_predict: val acc 0.8079 p 0.7647 r 0.5909 f1 0.6667
# max_acc 0.8079 max_p 0.7647 max_r 0.5909 max_f1 0.6667
#
# cause_predict: val acc 0.7291 p 0.5821 r 0.5909 f1 0.5865
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.4394 f1 0.4677
# max_acc 0.9112 max_p 0.5000 max_r 0.4394 max_f1 0.4677
#
# avg max cause: max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
# avg max pos: max_acc 0.8079 max_p 0.7647 max_r 0.5909 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4394 max_f1 0.4677
#
# Fold 1 Epoch 16 val loss 2.4346
# emotion_predict: val acc 0.8177 p 0.7736 r 0.6212 f1 0.6891
# max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
#
# cause_predict: val acc 0.7488 p 0.6364 r 0.5303 f1 0.5785
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9246 p 0.6087 r 0.4242 f1 0.5000
# max_acc 0.9246 max_p 0.6087 max_r 0.4242 max_f1 0.5000
#
# avg max cause: max_acc 0.7488 max_p 0.6364 max_r 0.5303 max_f1 0.5785
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.9246 max_p 0.6087 max_r 0.4242 max_f1 0.5000
#
# Fold 1 Epoch 17 val loss 2.3845
# emotion_predict: val acc 0.8325 p 0.7667 r 0.6970 f1 0.7302
# max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
#
# cause_predict: val acc 0.7438 p 0.6167 r 0.5606 f1 0.5873
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9206 p 0.5660 r 0.4545 f1 0.5042
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7438 max_p 0.6167 max_r 0.5606 max_f1 0.5873
# avg max pos: max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 18 val loss 2.4069
# emotion_predict: val acc 0.8079 p 0.7455 r 0.6212 f1 0.6777
# max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9031 p 0.4571 r 0.4848 f1 0.4706
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7438 max_p 0.6167 max_r 0.5606 max_f1 0.5873
# avg max pos: max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 19 val loss 2.3961
# emotion_predict: val acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
# max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
#
# cause_predict: val acc 0.7537 p 0.6481 r 0.5303 f1 0.5833
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.8923 p 0.4103 r 0.4848 f1 0.4444
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7438 max_p 0.6167 max_r 0.5606 max_f1 0.5873
# avg max pos: max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# Fold 1 Epoch 20 val loss 2.4651
# emotion_predict: val acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
# max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
#
# cause_predict: val acc 0.7340 p 0.6071 r 0.5152 f1 0.5574
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9085 p 0.4848 r 0.4848 f1 0.4848
# max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# avg max cause: max_acc 0.7438 max_p 0.6167 max_r 0.5606 max_f1 0.5873
# avg max pos: max_acc 0.8325 max_p 0.7667 max_r 0.6970 max_f1 0.7302
# avg max pair: max_acc 0.9206 max_p 0.5660 max_r 0.4545 max_f1 0.5042
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.58730159]]
# average : acc 0.7438 p 0.6167 r 0.5606 f1 0.5873
#
# emotion_predict: val f1 in 5 fold: [[0.73015873]]
# average : acc 0.8325 p 0.7667 r 0.6970 f1 0.7302
#
# pair_predict: val f1 in 5 fold: [[0.50420168]]
# average : acc 0.9206 p 0.5660 r 0.4545 f1 0.5042

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.8364
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7286
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7045
# emotion_predict: val acc 0.6700 p 0.3333 r 0.0152 f1 0.0290
# max_acc 0.6700 max_p 0.3333 max_r 0.0152 max_f1 0.0290
#
# cause_predict: val acc 0.7192 p 0.6552 r 0.2879 f1 0.4000
# max_acc 0.7192 max_p 0.6552 max_r 0.2879 max_f1 0.4000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.5865
# emotion_predict: val acc 0.6847 p 1.0000 r 0.0303 f1 0.0588
# max_acc 0.6847 max_p 1.0000 max_r 0.0303 max_f1 0.0588
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.7192 max_p 0.6552 max_r 0.2879 max_f1 0.4000
#
# pair_predict: val acc 0.9125 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.9125 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# avg max cause: max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
# avg max pos: max_acc 0.6847 max_p 1.0000 max_r 0.0303 max_f1 0.0588
# avg max pair: max_acc 0.9125 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# Fold 1 Epoch 5 val loss 2.4931
# emotion_predict: val acc 0.7143 p 0.8333 r 0.1515 f1 0.2564
# max_acc 0.7143 max_p 0.8333 max_r 0.1515 max_f1 0.2564
#
# cause_predict: val acc 0.7291 p 0.6897 r 0.3030 f1 0.4211
# max_acc 0.7291 max_p 0.6897 max_r 0.3030 max_f1 0.4211
#
# pair_predict: val acc 0.9179 p 0.5758 r 0.2879 f1 0.3838
# max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# avg max cause: max_acc 0.7291 max_p 0.6897 max_r 0.3030 max_f1 0.4211
# avg max pos: max_acc 0.7143 max_p 0.8333 max_r 0.1515 max_f1 0.2564
# avg max pair: max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# Fold 1 Epoch 6 val loss 2.4533
# emotion_predict: val acc 0.6995 p 0.5439 r 0.4697 f1 0.5041
# max_acc 0.6995 max_p 0.5439 max_r 0.4697 max_f1 0.5041
#
# cause_predict: val acc 0.7044 p 0.5484 r 0.5152 f1 0.5312
# max_acc 0.7044 max_p 0.5484 max_r 0.5152 max_f1 0.5312
#
# pair_predict: val acc 0.8143 p 0.2500 r 0.5455 f1 0.3429
# max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# avg max cause: max_acc 0.7291 max_p 0.6897 max_r 0.3030 max_f1 0.4211
# avg max pos: max_acc 0.7143 max_p 0.8333 max_r 0.1515 max_f1 0.2564
# avg max pair: max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# Fold 1 Epoch 7 val loss 2.4049
# emotion_predict: val acc 0.7044 p 0.5556 r 0.4545 f1 0.5000
# max_acc 0.6995 max_p 0.5439 max_r 0.4697 max_f1 0.5041
#
# cause_predict: val acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
# max_acc 0.7044 max_p 0.5484 max_r 0.5152 max_f1 0.5312
#
# pair_predict: val acc 0.8398 p 0.2846 r 0.5303 f1 0.3704
# max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# avg max cause: max_acc 0.7291 max_p 0.6897 max_r 0.3030 max_f1 0.4211
# avg max pos: max_acc 0.7143 max_p 0.8333 max_r 0.1515 max_f1 0.2564
# avg max pair: max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# Fold 1 Epoch 8 val loss 2.3220
# emotion_predict: val acc 0.7291 p 0.6222 r 0.4242 f1 0.5045
# max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
#
# cause_predict: val acc 0.7143 p 0.5645 r 0.5303 f1 0.5469
# max_acc 0.7143 max_p 0.5645 max_r 0.5303 max_f1 0.5469
#
# pair_predict: val acc 0.8237 p 0.2695 r 0.5758 f1 0.3671
# max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# avg max cause: max_acc 0.7291 max_p 0.6897 max_r 0.3030 max_f1 0.4211
# avg max pos: max_acc 0.7143 max_p 0.8333 max_r 0.1515 max_f1 0.2564
# avg max pair: max_acc 0.9179 max_p 0.5758 max_r 0.2879 max_f1 0.3838
#
# Fold 1 Epoch 9 val loss 2.2550
# emotion_predict: val acc 0.7685 p 0.7714 r 0.4091 f1 0.5347
# max_acc 0.7685 max_p 0.7714 max_r 0.4091 max_f1 0.5347
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.8775 p 0.3596 r 0.4848 f1 0.4129
# max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7685 max_p 0.7714 max_r 0.4091 max_f1 0.5347
# avg max pair: max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# Fold 1 Epoch 10 val loss 2.2047
# emotion_predict: val acc 0.7586 p 0.6545 r 0.5455 f1 0.5950
# max_acc 0.7586 max_p 0.6545 max_r 0.5455 max_f1 0.5950
#
# cause_predict: val acc 0.7438 p 0.6167 r 0.5606 f1 0.5873
# max_acc 0.7438 max_p 0.6167 max_r 0.5606 max_f1 0.5873
#
# pair_predict: val acc 0.8210 p 0.2752 r 0.6212 f1 0.3814
# max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7685 max_p 0.7714 max_r 0.4091 max_f1 0.5347
# avg max pair: max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# Fold 1 Epoch 11 val loss 2.1081
# emotion_predict: val acc 0.7931 p 0.7857 r 0.5000 f1 0.6111
# max_acc 0.7931 max_p 0.7857 max_r 0.5000 max_f1 0.6111
#
# cause_predict: val acc 0.7833 p 0.7500 r 0.5000 f1 0.6000
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8681 p 0.3333 r 0.4848 f1 0.3951
# max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7685 max_p 0.7714 max_r 0.4091 max_f1 0.5347
# avg max pair: max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# Fold 1 Epoch 12 val loss 2.0760
# emotion_predict: val acc 0.8079 p 0.8000 r 0.5455 f1 0.6486
# max_acc 0.8079 max_p 0.8000 max_r 0.5455 max_f1 0.6486
#
# cause_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8506 p 0.3009 r 0.5152 f1 0.3799
# max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.7685 max_p 0.7714 max_r 0.4091 max_f1 0.5347
# avg max pair: max_acc 0.8775 max_p 0.3596 max_r 0.4848 max_f1 0.4129
#
# Fold 1 Epoch 13 val loss 2.0812
# emotion_predict: val acc 0.8030 p 0.7321 r 0.6212 f1 0.6721
# max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
#
# cause_predict: val acc 0.7143 p 0.5606 r 0.5606 f1 0.5606
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8560 p 0.3248 r 0.5758 f1 0.4153
# max_acc 0.8560 max_p 0.3248 max_r 0.5758 max_f1 0.4153
#
# avg max cause: max_acc 0.7143 max_p 0.5606 max_r 0.5606 max_f1 0.5606
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.8560 max_p 0.3248 max_r 0.5758 max_f1 0.4153
#
# Fold 1 Epoch 14 val loss 2.0951
# emotion_predict: val acc 0.8079 p 0.7455 r 0.6212 f1 0.6777
# max_acc 0.8079 max_p 0.7455 max_r 0.6212 max_f1 0.6777
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8762 p 0.3646 r 0.5303 f1 0.4321
# max_acc 0.8762 max_p 0.3646 max_r 0.5303 max_f1 0.4321
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.8079 max_p 0.7455 max_r 0.6212 max_f1 0.6777
# avg max pair: max_acc 0.8762 max_p 0.3646 max_r 0.5303 max_f1 0.4321
#
# Fold 1 Epoch 15 val loss 2.0518
# emotion_predict: val acc 0.8128 p 0.7500 r 0.6364 f1 0.6885
# max_acc 0.8128 max_p 0.7500 max_r 0.6364 max_f1 0.6885
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8614 p 0.3419 r 0.6061 f1 0.4372
# max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# avg max cause: max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
# avg max pos: max_acc 0.8128 max_p 0.7500 max_r 0.6364 max_f1 0.6885
# avg max pair: max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# Fold 1 Epoch 16 val loss 2.0470
# emotion_predict: val acc 0.8325 p 0.7857 r 0.6667 f1 0.7213
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8654 p 0.3509 r 0.6061 f1 0.4444
# max_acc 0.8654 max_p 0.3509 max_r 0.6061 max_f1 0.4444
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8654 max_p 0.3509 max_r 0.6061 max_f1 0.4444
#
# Fold 1 Epoch 17 val loss 2.0243
# emotion_predict: val acc 0.8079 p 0.7213 r 0.6667 f1 0.6929
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8694 p 0.3604 r 0.6061 f1 0.4520
# max_acc 0.8694 max_p 0.3604 max_r 0.6061 max_f1 0.4520
#
# avg max cause: max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
# avg max pos: max_acc 0.8079 max_p 0.7213 max_r 0.6667 max_f1 0.6929
# avg max pair: max_acc 0.8694 max_p 0.3604 max_r 0.6061 max_f1 0.4520
#
# Fold 1 Epoch 18 val loss 2.0358
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8762 p 0.3700 r 0.5606 f1 0.4458
# max_acc 0.8694 max_p 0.3604 max_r 0.6061 max_f1 0.4520
#
# avg max cause: max_acc 0.7340 max_p 0.5882 max_r 0.6061 max_f1 0.5970
# avg max pos: max_acc 0.8079 max_p 0.7213 max_r 0.6667 max_f1 0.6929
# avg max pair: max_acc 0.8694 max_p 0.3604 max_r 0.6061 max_f1 0.4520
#
# Fold 1 Epoch 19 val loss 2.0733
# emotion_predict: val acc 0.8227 p 0.7679 r 0.6515 f1 0.7049
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7291 p 0.5965 r 0.5152 f1 0.5528
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8668 p 0.3565 r 0.6212 f1 0.4530
# max_acc 0.8668 max_p 0.3565 max_r 0.6212 max_f1 0.4530
#
# avg max cause: max_acc 0.7291 max_p 0.5965 max_r 0.5152 max_f1 0.5528
# avg max pos: max_acc 0.8227 max_p 0.7679 max_r 0.6515 max_f1 0.7049
# avg max pair: max_acc 0.8668 max_p 0.3565 max_r 0.6212 max_f1 0.4530
#
# Fold 1 Epoch 20 val loss 2.1049
# emotion_predict: val acc 0.7980 p 0.6984 r 0.6667 f1 0.6822
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7537 p 0.6481 r 0.5303 f1 0.5833
# max_acc 0.7833 max_p 0.7500 max_r 0.5000 max_f1 0.6000
#
# pair_predict: val acc 0.8506 p 0.3171 r 0.5909 f1 0.4127
# max_acc 0.8668 max_p 0.3565 max_r 0.6212 max_f1 0.4530
#
# avg max cause: max_acc 0.7291 max_p 0.5965 max_r 0.5152 max_f1 0.5528
# avg max pos: max_acc 0.8227 max_p 0.7679 max_r 0.6515 max_f1 0.7049
# avg max pair: max_acc 0.8668 max_p 0.3565 max_r 0.6212 max_f1 0.4530
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 5 fold: [[0.55284553]]
# average : acc 0.7291 p 0.5965 r 0.5152 f1 0.5528
#
# emotion_predict: val f1 in 5 fold: [[0.70491803]]
# average : acc 0.8227 p 0.7679 r 0.6515 f1 0.7049
#
# pair_predict: val f1 in 5 fold: [[0.45303867]]
# average : acc 0.8668 p 0.3565 r 0.6212 f1 0.4530
