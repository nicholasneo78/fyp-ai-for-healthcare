# %%
# connect to google colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# base path
DATA_PATH = './drive/MyDrive/fyp-code/codes/data/ecpe/'
MODEL_PATH = './drive/MyDrive/fyp-code/codes/model/ecpe/EC/short/'

# %%
############################################ IMPORT ##########################################################
import sys, os
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# call the zip folder with all the self defined modules
base_folder = '/content/drive/MyDrive/fyp-code/codes'

training_path = os.path.join(base_folder, "utils_ecpe.zip") 
# !unzip $training_path

from funcs import *
from prepare_data import *
# Out:
# Archive:  /content/drive/MyDrive/fyp-code/codes/utils_ecpe.zip
#   inflating: funcs.py
#   inflating: prepare_data.py

# %%
############################################ FLAGS ############################################################
# file names of the data files
LOOKUP = 'ecpe_short_annotated.csv'
DATA = 'short'
TRAIN_DATA = 'ecpe_short_annotated_train'
VAL_DATA = 'ecpe_short_annotated_val'

# fixed parameters
train_file_path = DATA_PATH + LOOKUP                                # clause keyword file
w2v_file = DATA_PATH+'w2v_200.txt'                                  # embedding file
embedding_dim = 200                                                 # dimension of word embedding
embedding_dim_pos = 30                                              # dimension of position embedding
max_sen_len = 30                                                    # max number of tokens per sentence
max_doc_len = 41                                                    # max number of tokens per document
n_class = 2                                                         # number of distinct class
training_epochs = 15                                                # number of train epochs
keep_prob1 = 0.8                                                    # word embedding training dropout keep prob
keep_prob2 = 1.0                                                    # softmax layer dropout keep prob
keep_prob3 = 1.0                                                    # softmax layer dropout keep prob
l2_reg = 0.00010                                                    # l2 regularization
cause = 1.0                                                         # lambda1
pos = 1.0                                                           # lambda2
pair = 2.5                                                          # lambda3

# hyperparameters considered for tuning (will be tuned later when the class is called)
n_hidden = None                                                     # number of hidden unit
batch_size = None                                                   # number of example per batch
learning_rate = None                                                # learning rate
diminish_factor = None                                              # give less weight to -ve examples

# %%
############################################ MODEL ############################################################
class E2E_PextE(nn.Module):
    def __init__(self, embedding_dim, embedding_dim_pos, sen_len, doc_len, keep_prob1, keep_prob2, \
                 keep_prob3, n_hidden, n_class):
        super(E2E_PextE, self).__init__()
        self.embedding_dim = embedding_dim; self.embedding_dim_pos = embedding_dim_pos 
        self.sen_len = sen_len; self.doc_len = doc_len
        self.keep_prob1 = keep_prob1; self.keep_prob2 = keep_prob2
        self.n_hidden = n_hidden; self.n_class = n_class

        self.dropout1 = nn.Dropout(p = 1 - keep_prob1)
        self.dropout2 = nn.Dropout(p = 1 - keep_prob2)
        self.dropout3 = nn.Dropout(p = 1 - keep_prob3)
        self.relu = nn.ReLU()
        self.pos_linear = nn.Linear(2*n_hidden, n_class)
        self.cause_linear = nn.Linear(2*n_hidden, n_class)
        self.pair_linear1 = nn.Linear(4*n_hidden + embedding_dim_pos, n_hidden//2)
        self.pair_linear2 = nn.Linear(n_hidden//2, n_class)
        self.word_bilstm = nn.LSTM(embedding_dim, n_hidden, batch_first = True, bidirectional = True)
        self.cause_bilstm = nn.LSTM(2*n_hidden + n_class, n_hidden, batch_first = True, bidirectional = True)
        self.pos_bilstm = nn.LSTM(2*n_hidden, n_hidden, batch_first = True, bidirectional = True)
        self.attention = Attention(n_hidden, sen_len)

    def get_clause_embedding(self, x):
        '''
        input shape: [batch_size, doc_len, sen_len, embedding_dim]
        output shape: [batch_size, doc_len, 2 * n_hidden]
        '''
        x = x.reshape(-1, self.sen_len, self.embedding_dim)
        x = self.dropout1(x)
        # x is of shape (batch_size * max_doc_len, max_sen_len, embedding_dim)
        x, hidden_states = self.word_bilstm(x.float())
        # x is of shape (batch_size * max_doc_len, max_sen_len, 2 * n_hidden)
        s = self.attention(x).reshape(-1, self.doc_len, 2 * self.n_hidden)
        # s is of shape (batch_size, max_doc_len, 2 * n_hidden)
        return s

    def get_emotion_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.pos_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_pos = F.softmax(self.pos_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_pos = pred_pos.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_pos

    def get_cause_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden + n_class]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.cause_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_cause = F.softmax(self.cause_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_cause = pred_cause.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_cause

    def get_pair_prediction(self, x1, x2, distance):
        '''
        input(s) shape: [batch_size * doc_len, 2 * n_hidden], [batch_size * doc_len, 2 * n_hidden], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos] 
        output shape: [batch_size, doc_len * doc_len, n_class]
        '''        
        x = create_pairs(x1, x2)
        # x is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden)
        x_distance = torch.cat([x, distance.float()], -1)
        # x_distance is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        x_distance = x_distance.reshape(-1, 4 * self.n_hidden + self.embedding_dim_pos)
        x_distance = self.dropout3(x_distance)
        # x is of shape (batch_size * max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        pred_pair = F.softmax(self.pair_linear2(self.relu(self.pair_linear1(x_distance))), dim = -1)
        # pred_pair is of shape (batch_size * max_doc_len * max_doc_len, n_class)
        pred_pair = pred_pair.reshape(-1, self.doc_len * self.doc_len, self.n_class)
        # pred_pair is of shape (batch_size, max_doc_len * max_doc_len, n_class)
        return pred_pair

    def forward(self, x, distance):
        '''
        input(s) shape: [batch_size, doc_len, sen_len, embedding_dim], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos]
        output(s) shape: [batch_size, doc_len, n_class], [batch_size, doc_len, n_class], 
                         [batch_size, doc_len * doc_len, n_class]
        '''
        s = self.get_clause_embedding(x)
        x_pos, pred_pos = self.get_emotion_prediction(s)
        s_pred_pos = torch.cat([s, pred_pos], 2)
        x_cause, pred_cause = self.get_cause_prediction(s_pred_pos)
        pred_pair = self.get_pair_prediction(x_pos, x_cause, distance)
        return pred_pos, pred_cause, pred_pair

# %%
def load_data_pair(input_file, word_idx, max_doc_len = 75, max_sen_len = 45):
    print('load data_file: {}'.format(input_file))
    pair_id_all, y_position, y_cause, y_pair, x, sen_len, doc_len, distance = [], [], [], [], [], [], [], []
    n_cut = 0
    inputFile = open(input_file, 'r')
    while True:
        line = inputFile.readline()
        if line == '': break
        line = line.strip().split()
        doc_id = int(line[0])
        d_len = int(line[1])
        ######################################## doc_len_condition ########################################
        if d_len >= max_doc_len :
            for i in range(d_len+1) :
                line = inputFile.readline().strip().split(',')
            continue
        ######################################## doc_len_condition ########################################

        pairs = eval('[' + inputFile.readline().strip() + ']')
        pos_list, cause_list = zip(*pairs)
        pairs = [[pos_list[i], cause_list[i]] for i in range(len(pos_list))]
        pair_id_all.extend([doc_id*10000+p[0]*100+p[1] for p in pairs])
        y_position_tmp, y_cause_tmp, y_pair_tmp, sen_len_tmp, x_tmp, distance_tmp = \
        np.zeros((max_doc_len, 2)), np.zeros((max_doc_len, 2)), np.zeros((max_doc_len * max_doc_len, 2)), \
        np.zeros((max_doc_len, )), np.zeros((max_doc_len, max_sen_len)), np.zeros((max_doc_len * max_doc_len, ))

        for i in range(d_len):
            line = inputFile.readline().strip().split(',')
            words = line[-1]
            sen_len_tmp[i] = min(len(words.split()), max_sen_len)
            for j, word in enumerate(words.split()):
                word = word.lower()
                if j >= max_sen_len:
                    n_cut += 1
                    break
                elif word not in word_idx : x_tmp[i][j] = 24166
                else : x_tmp[i][j] = int(word_idx[word])

        for i in range(d_len):
            for j in range(d_len):
                # Check whether i is an emotion clause
                if i+1 in pos_list :
                    y_position_tmp[i][0] = 0; y_position_tmp[i][1] = 1
                else :
                    y_position_tmp[i][0] = 1; y_position_tmp[i][1] = 0
                # Check whether j is a cause clause
                if j+1 in cause_list :
                    y_cause_tmp[j][0] = 0; y_cause_tmp[j][1] = 1
                else :
                    y_cause_tmp[j][0] = 1; y_cause_tmp[j][1] = 0
                # Check whether i, j clauses are emotion cause pairs
                pair_id_curr = doc_id*10000+(i+1)*100+(j+1)
                if pair_id_curr in pair_id_all :
                    y_pair_tmp[i*max_doc_len+j][0] = 0; y_pair_tmp[i*max_doc_len+j][1] = 1
                else :
                    y_pair_tmp[i*max_doc_len+j][0] = 1; y_pair_tmp[i*max_doc_len+j][1] = 0
                # Find the distance between the clauses, and use the same embedding beyond 10 clauses
                distance_tmp[i*max_doc_len+j] = min(max(j-i+100, 90), 110)

        y_position.append(y_position_tmp)
        y_cause.append(y_cause_tmp)
        y_pair.append(y_pair_tmp)
        x.append(x_tmp)
        sen_len.append(sen_len_tmp)
        doc_len.append(d_len)
        distance.append(distance_tmp)

    y_position, y_cause, y_pair, x, sen_len, doc_len, distance = map(torch.tensor, \
    [y_position, y_cause, y_pair, x, sen_len, doc_len, distance])

    for var in ['y_position', 'y_cause', 'y_pair', 'x', 'sen_len', 'doc_len', 'distance']:
        print('{}.shape {}'.format( var, eval(var).shape ))
    print('n_cut {}'.format(n_cut))
    print('load data done!\n')
    return y_position, y_cause, y_pair, x, sen_len, doc_len, distance

# %%
############################################ TRAIN #####################################################
def train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, n_hidden, batch_size, learning_rate, diminish_factor):
    word_idx_rev, word_id_mapping, word_embedding, pos_embedding = load_w2v(
        embedding_dim, embedding_dim_pos, train_file_path, w2v_file)
    word_embedding = torch.from_numpy(word_embedding)
    # Train distance embeddings
    pos_embedding = torch.autograd.Variable(torch.from_numpy(pos_embedding))
    pos_embedding.requires_grad_(True)
    #torch.save(word_embedding, MODEL_PATH+DATA+'_'+'word_embedding'+'.pth')
    torch.save(word_embedding, f'{MODEL_PATH}{DATA}_word_embedding_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    #torch.save(word_id_mapping, MODEL_PATH+DATA+'_'+'word_id_mapping'+'.pth')
    torch.save(word_id_mapping, f'{MODEL_PATH}{DATA}_word_id_mapping_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    acc_cause_list, p_cause_list, r_cause_list, f1_cause_list = [], [], [], []
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list = [], [], [], []
    acc_pair_list, p_pair_list, r_pair_list, f1_pair_list = [], [], [], []
    #################################### LOOP OVER FOLDS ####################################
    # do 5 fold cross validation
    for fold in range(1, 2):
        print('############# fold {} begin ###############'.format(fold))
        ############################# RE-INITIALIZE MODEL PARAMETERS #############################
        for layer in Model.parameters():
            nn.init.uniform_(layer.data, -0.10, 0.10)
        #################################### TRAIN/TEST DATA ####################################
        train_file_name = '{}_{}.txt'.format(TRAIN_DATA,fold)
        val_file_name = '{}_{}.txt'.format(VAL_DATA,fold)
        tr_y_position, tr_y_cause, tr_y_pair, tr_x, tr_sen_len, tr_doc_len, tr_distance = load_data_pair(
                        DATA_PATH+train_file_name, word_id_mapping, max_doc_len, max_sen_len)
        val_y_position, val_y_cause, val_y_pair, val_x, val_sen_len, val_doc_len, val_distance = \
            load_data_pair(DATA_PATH+val_file_name, word_id_mapping, max_doc_len, max_sen_len)
        max_f1_cause, max_f1_pos, max_f1_pair, max_f1_avg = [-1.] * 4
        #################################### LOOP OVER EPOCHS ####################################
        for epoch in range(1, training_epochs + 1):
            step = 1
            #################################### GET BATCH DATA ####################################
            for train, _ in get_batch_data_pair(
                tr_x, tr_sen_len, tr_doc_len, tr_y_position, tr_y_cause, tr_y_pair, tr_distance, batch_size):
                tr_x_batch, tr_sen_len_batch, tr_doc_len_batch, tr_true_y_pos, tr_true_y_cause, \
                tr_true_y_pair, tr_distance_batch = train
                Model.train()
                tr_pred_y_pos, tr_pred_y_cause, tr_pred_y_pair = Model(embedding_lookup(word_embedding, \
                tr_x_batch), embedding_lookup(pos_embedding, tr_distance_batch))
                ############################## LOSS FUNCTION AND OPTIMIZATION ##############################
                loss = pos_cause_criterion(tr_true_y_pos, tr_pred_y_pos, tr_doc_len_batch)*pos + \
                pos_cause_criterion(tr_true_y_cause, tr_pred_y_cause, tr_doc_len_batch)*cause + \
                pair_criterion(tr_true_y_pair, tr_pred_y_pair, tr_doc_len_batch)*pair
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                #################################### PRINT AFTER EPOCHS ####################################
                if step % 25 == 0:
                    # print(Model.pair_linear.weight.shape); print(Model.pair_linear.weight.grad)
                    print('Fold {}, Epoch {}, step {}: train loss {:.4f} '.format(fold, epoch, step, loss))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_pos, tr_true_y_pos, tr_doc_len_batch)
                    print('emotion_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_cause, tr_true_y_cause, tr_doc_len_batch)
                    print('cause_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_pair(tr_pred_y_pair, tr_true_y_pair, tr_doc_len_batch)
                    print('pair_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1)) 
                step += 1
            #################################### TEST ON 1 FOLD ####################################
            with torch.no_grad():
                Model.eval()
                val_pred_y_pos, val_pred_y_cause, val_pred_y_pair = Model(embedding_lookup(word_embedding, \
                val_x), embedding_lookup(pos_embedding, val_distance))

                loss = pos_cause_criterion(val_y_position, val_pred_y_pos, val_doc_len)*pos + \
                pos_cause_criterion(val_y_cause, val_pred_y_cause, val_doc_len)*cause + \
                pair_criterion(val_y_pair, val_pred_y_pair, val_doc_len)*pair
                print('Fold {} Epoch {} val loss {:.4f}'.format(fold, epoch, loss))
                acc, p, r, f1 = acc_prf_aux(val_pred_y_pos, val_y_position, val_doc_len)
                result_avg_pos = [acc, p, r, f1]
                if f1 > max_f1_pos:
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos = acc, p, r, f1
                print('emotion_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos))

                acc, p, r, f1 = acc_prf_aux(val_pred_y_cause, val_y_cause, val_doc_len)
                result_avg_cause = [acc, p, r, f1]
                if f1 > max_f1_cause:
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause = acc, p, r, f1
                print('cause_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause))

                acc, p, r, f1 = acc_prf_pair(val_pred_y_pair, val_y_pair, val_doc_len)
                result_avg_pair = [acc, p, r, f1]
                if f1 > max_f1_pair:
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair = acc, p, r, f1
                print('pair_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair))

            #################################### STORE BETTER PAIR F1 ####################################
            if result_avg_pair[-1] > max_f1_avg:
                #torch.save(pos_embedding, MODEL_PATH+DATA+"_"+"pos_embedding_fold_{}.pth".format(fold))
                torch.save(pos_embedding, f'{MODEL_PATH}{DATA}_pos_embedding_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                #torch.save(Model.state_dict(), MODEL_PATH+DATA+"_"+"E2E-EC_fold_{}.pth".format(fold))
                torch.save(Model.state_dict(), f'{MODEL_PATH}{DATA}_E2E-EC_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                
                max_f1_avg = result_avg_pair[-1]
                result_avg_cause_max = result_avg_cause
                result_avg_pos_max = result_avg_pos
                result_avg_pair_max = result_avg_pair

            print('avg max cause: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_cause_max[0], result_avg_cause_max[1], result_avg_cause_max[2], result_avg_cause_max[3]))
            print('avg max pos: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_pos_max[0], result_avg_pos_max[1], result_avg_pos_max[2], result_avg_pos_max[3]))
            print('avg max pair: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                result_avg_pair_max[0], result_avg_pair_max[1], result_avg_pair_max[2], result_avg_pair_max[3]))

        print('############# fold {} end ###############'.format(fold))
        acc_cause_list.append(result_avg_cause_max[0])
        p_cause_list.append(result_avg_cause_max[1])
        r_cause_list.append(result_avg_cause_max[2])
        f1_cause_list.append(result_avg_cause_max[3])
        acc_pos_list.append(result_avg_pos_max[0])
        p_pos_list.append(result_avg_pos_max[1])
        r_pos_list.append(result_avg_pos_max[2])
        f1_pos_list.append(result_avg_pos_max[3])
        acc_pair_list.append(result_avg_pair_max[0])
        p_pair_list.append(result_avg_pair_max[1])
        r_pair_list.append(result_avg_pair_max[2])
        f1_pair_list.append(result_avg_pair_max[3])

    #################################### FINAL TEST RESULTS ON 10 FOLDS ####################################
    all_results = [acc_cause_list, p_cause_list, r_cause_list, f1_cause_list, \
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list, acc_pair_list, p_pair_list, r_pair_list, f1_pair_list,]
    acc_cause, p_cause, r_cause, f1_cause, acc_pos, p_pos, r_pos, f1_pos, acc_pair, p_pair, r_pair, f1_pair = \
        map(lambda x: np.array(x).mean(), all_results)
    print('\ncause_predict: val f1 in 1 fold: {}'.format(np.array(f1_cause_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_cause, p_cause, r_cause, f1_cause))
    print('emotion_predict: val f1 in 1 fold: {}'.format(np.array(f1_pos_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pos, p_pos, r_pos, f1_pos))
    print('pair_predict: val f1 in 1 fold: {}'.format(np.array(f1_pair_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pair, p_pair, r_pair, f1_pair))

# %% [markdown]
# ## Calling the class for the varying hyperparamters

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3501
# emotion_predict: val acc 0.6765 p 0.5833 r 0.0778 f1 0.1373
# max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
#
# cause_predict: val acc 0.6654 p 0.4865 r 0.2000 f1 0.2835
# max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
# avg max pos: max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2760
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
# avg max pos: max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0687
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
# avg max pos: max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.9264
# emotion_predict: val acc 0.7426 p 0.7174 r 0.3667 f1 0.4853
# max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
#
# cause_predict: val acc 0.7279 p 0.5889 r 0.5889 f1 0.5889
# max_acc 0.7279 max_p 0.5889 max_r 0.5889 max_f1 0.5889
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6654 max_p 0.4865 max_r 0.2000 max_f1 0.2835
# avg max pos: max_acc 0.6765 max_p 0.5833 max_r 0.0778 max_f1 0.1373
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.8302
# emotion_predict: val acc 0.7463 p 0.7333 r 0.3667 f1 0.4889
# max_acc 0.7463 max_p 0.7333 max_r 0.3667 max_f1 0.4889
#
# cause_predict: val acc 0.7647 p 0.7241 r 0.4667 f1 0.5676
# max_acc 0.7279 max_p 0.5889 max_r 0.5889 max_f1 0.5889
#
# pair_predict: val acc 0.9385 p 0.8800 r 0.2444 f1 0.3826
# max_acc 0.9385 max_p 0.8800 max_r 0.2444 max_f1 0.3826
#
# avg max cause: max_acc 0.7647 max_p 0.7241 max_r 0.4667 max_f1 0.5676
# avg max pos: max_acc 0.7463 max_p 0.7333 max_r 0.3667 max_f1 0.4889
# avg max pair: max_acc 0.9385 max_p 0.8800 max_r 0.2444 max_f1 0.3826
#
# Fold 1 Epoch 6 val loss 2.7527
# emotion_predict: val acc 0.7279 p 0.6176 r 0.4667 f1 0.5316
# max_acc 0.7279 max_p 0.6176 max_r 0.4667 max_f1 0.5316
#
# cause_predict: val acc 0.7684 p 0.7077 r 0.5111 f1 0.5935
# max_acc 0.7684 max_p 0.7077 max_r 0.5111 max_f1 0.5935
#
# pair_predict: val acc 0.9272 p 0.5577 r 0.3222 f1 0.4085
# max_acc 0.9272 max_p 0.5577 max_r 0.3222 max_f1 0.4085
#
# avg max cause: max_acc 0.7684 max_p 0.7077 max_r 0.5111 max_f1 0.5935
# avg max pos: max_acc 0.7279 max_p 0.6176 max_r 0.4667 max_f1 0.5316
# avg max pair: max_acc 0.9272 max_p 0.5577 max_r 0.3222 max_f1 0.4085
#
# Fold 1 Epoch 7 val loss 2.6716
# emotion_predict: val acc 0.7463 p 0.6154 r 0.6222 f1 0.6188
# max_acc 0.7463 max_p 0.6154 max_r 0.6222 max_f1 0.6188
#
# cause_predict: val acc 0.7684 p 0.6627 r 0.6111 f1 0.6358
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9168 p 0.4615 r 0.4000 f1 0.4286
# max_acc 0.9168 max_p 0.4615 max_r 0.4000 max_f1 0.4286
#
# avg max cause: max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
# avg max pos: max_acc 0.7463 max_p 0.6154 max_r 0.6222 max_f1 0.6188
# avg max pair: max_acc 0.9168 max_p 0.4615 max_r 0.4000 max_f1 0.4286
#
# Fold 1 Epoch 8 val loss 2.5250
# emotion_predict: val acc 0.7831 p 0.8163 r 0.4444 f1 0.5755
# max_acc 0.7463 max_p 0.6154 max_r 0.6222 max_f1 0.6188
#
# cause_predict: val acc 0.7757 p 0.7636 r 0.4667 f1 0.5793
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9350 p 0.6531 r 0.3556 f1 0.4604
# max_acc 0.9350 max_p 0.6531 max_r 0.3556 max_f1 0.4604
#
# avg max cause: max_acc 0.7757 max_p 0.7636 max_r 0.4667 max_f1 0.5793
# avg max pos: max_acc 0.7831 max_p 0.8163 max_r 0.4444 max_f1 0.5755
# avg max pair: max_acc 0.9350 max_p 0.6531 max_r 0.3556 max_f1 0.4604
#
# Fold 1 Epoch 9 val loss 2.4676
# emotion_predict: val acc 0.8051 p 0.7284 r 0.6556 f1 0.6901
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7500 p 0.6279 r 0.6000 f1 0.6136
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9263 p 0.5309 r 0.4778 f1 0.5029
# max_acc 0.9263 max_p 0.5309 max_r 0.4778 max_f1 0.5029
#
# avg max cause: max_acc 0.7500 max_p 0.6279 max_r 0.6000 max_f1 0.6136
# avg max pos: max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
# avg max pair: max_acc 0.9263 max_p 0.5309 max_r 0.4778 max_f1 0.5029
#
# Fold 1 Epoch 10 val loss 2.5503
# emotion_predict: val acc 0.7757 p 0.6706 r 0.6333 f1 0.6514
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7794 p 0.7778 r 0.4667 f1 0.5833
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9298 p 0.5584 r 0.4778 f1 0.5150
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# Fold 1 Epoch 11 val loss 2.5703
# emotion_predict: val acc 0.8051 p 0.7403 r 0.6333 f1 0.6826
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7684 p 0.7077 r 0.5111 f1 0.5935
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9272 p 0.5385 r 0.4667 f1 0.5000
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# Fold 1 Epoch 12 val loss 2.5734
# emotion_predict: val acc 0.7941 p 0.7179 r 0.6222 f1 0.6667
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7500 p 0.6410 r 0.5556 f1 0.5952
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9324 p 0.5882 r 0.4444 f1 0.5063
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# Fold 1 Epoch 13 val loss 2.7665
# emotion_predict: val acc 0.7721 p 0.6842 r 0.5778 f1 0.6265
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9159 p 0.4568 r 0.4111 f1 0.4327
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# Fold 1 Epoch 14 val loss 2.7555
# emotion_predict: val acc 0.7904 p 0.7089 r 0.6222 f1 0.6627
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7610 p 0.7119 r 0.4667 f1 0.5638
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9185 p 0.4767 r 0.4556 f1 0.4659
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# Fold 1 Epoch 15 val loss 2.9381
# emotion_predict: val acc 0.7537 p 0.6322 r 0.6111 f1 0.6215
# max_acc 0.8051 max_p 0.7284 max_r 0.6556 max_f1 0.6901
#
# cause_predict: val acc 0.7169 p 0.5730 r 0.5667 f1 0.5698
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.8977 p 0.3772 r 0.4778 f1 0.4216
# max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# avg max cause: max_acc 0.7794 max_p 0.7778 max_r 0.4667 max_f1 0.5833
# avg max pos: max_acc 0.7757 max_p 0.6706 max_r 0.6333 max_f1 0.6514
# avg max pair: max_acc 0.9298 max_p 0.5584 max_r 0.4778 max_f1 0.5150
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58333333]]
# average : acc 0.7794 p 0.7778 r 0.4667 f1 0.5833
#
# emotion_predict: val f1 in 1 fold: [[0.65142857]]
# average : acc 0.7757 p 0.6706 r 0.6333 f1 0.6514
#
# pair_predict: val f1 in 1 fold: [[0.51497006]]
# average : acc 0.9298 p 0.5584 r 0.4778 f1 0.5150

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.8927
# emotion_predict: val acc 0.6691 p 0.5000 r 0.0111 f1 0.0217
# max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
#
# cause_predict: val acc 0.6985 p 0.5606 r 0.4111 f1 0.4744
# max_acc 0.6985 max_p 0.5606 max_r 0.4111 max_f1 0.4744
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6985 max_p 0.5606 max_r 0.4111 max_f1 0.4744
# avg max pos: max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8760
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6985 max_p 0.5606 max_r 0.4111 max_f1 0.4744
#
# pair_predict: val acc 0.9246 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
# avg max pair: max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# Fold 1 Epoch 3 val loss 2.6576
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6985 max_p 0.5606 max_r 0.4111 max_f1 0.4744
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
# avg max pair: max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# Fold 1 Epoch 4 val loss 2.5578
# emotion_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
#
# cause_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.6985 max_p 0.5606 max_r 0.4111 max_f1 0.4744
#
# pair_predict: val acc 0.9289 p 0.7857 r 0.1222 f1 0.2115
# max_acc 0.9289 max_p 0.7857 max_r 0.1222 max_f1 0.2115
#
# avg max cause: max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
# avg max pos: max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
# avg max pair: max_acc 0.9289 max_p 0.7857 max_r 0.1222 max_f1 0.2115
#
# Fold 1 Epoch 5 val loss 2.5495
# emotion_predict: val acc 0.7279 p 0.6143 r 0.4778 f1 0.5375
# max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
#
# cause_predict: val acc 0.7500 p 0.6447 r 0.5444 f1 0.5904
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8995 p 0.3673 r 0.4000 f1 0.3830
# max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# avg max cause: max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# Fold 1 Epoch 6 val loss 2.4642
# emotion_predict: val acc 0.7426 p 0.7083 r 0.3778 f1 0.4928
# max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
#
# cause_predict: val acc 0.7684 p 0.7455 r 0.4556 f1 0.5655
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.9055 p 0.3882 r 0.3667 f1 0.3771
# max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# avg max cause: max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# Fold 1 Epoch 7 val loss 2.3695
# emotion_predict: val acc 0.7059 p 0.5658 r 0.4778 f1 0.5181
# max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
#
# cause_predict: val acc 0.7610 p 0.6506 r 0.6000 f1 0.6243
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.8562 p 0.2738 r 0.5111 f1 0.3566
# max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# avg max cause: max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.8995 max_p 0.3673 max_r 0.4000 max_f1 0.3830
#
# Fold 1 Epoch 8 val loss 2.3123
# emotion_predict: val acc 0.7463 p 0.7143 r 0.3889 f1 0.5036
# max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
#
# cause_predict: val acc 0.7721 p 0.7500 r 0.4667 f1 0.5753
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.9003 p 0.3786 r 0.4333 f1 0.4041
# max_acc 0.9003 max_p 0.3786 max_r 0.4333 max_f1 0.4041
#
# avg max cause: max_acc 0.7721 max_p 0.7500 max_r 0.4667 max_f1 0.5753
# avg max pos: max_acc 0.7463 max_p 0.7143 max_r 0.3889 max_f1 0.5036
# avg max pair: max_acc 0.9003 max_p 0.3786 max_r 0.4333 max_f1 0.4041
#
# Fold 1 Epoch 9 val loss 2.2548
# emotion_predict: val acc 0.7353 p 0.6125 r 0.5444 f1 0.5765
# max_acc 0.7353 max_p 0.6125 max_r 0.5444 max_f1 0.5765
#
# cause_predict: val acc 0.7647 p 0.6757 r 0.5556 f1 0.6098
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.9003 p 0.3932 r 0.5111 f1 0.4444
# max_acc 0.9003 max_p 0.3932 max_r 0.5111 max_f1 0.4444
#
# avg max cause: max_acc 0.7647 max_p 0.6757 max_r 0.5556 max_f1 0.6098
# avg max pos: max_acc 0.7353 max_p 0.6125 max_r 0.5444 max_f1 0.5765
# avg max pair: max_acc 0.9003 max_p 0.3932 max_r 0.5111 max_f1 0.4444
#
# Fold 1 Epoch 10 val loss 2.1770
# emotion_predict: val acc 0.8015 p 0.7571 r 0.5889 f1 0.6625
# max_acc 0.8015 max_p 0.7571 max_r 0.5889 max_f1 0.6625
#
# cause_predict: val acc 0.7610 p 0.6984 r 0.4889 f1 0.5752
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.8769 p 0.3395 r 0.6111 f1 0.4365
# max_acc 0.9003 max_p 0.3932 max_r 0.5111 max_f1 0.4444
#
# avg max cause: max_acc 0.7647 max_p 0.6757 max_r 0.5556 max_f1 0.6098
# avg max pos: max_acc 0.7353 max_p 0.6125 max_r 0.5444 max_f1 0.5765
# avg max pair: max_acc 0.9003 max_p 0.3932 max_r 0.5111 max_f1 0.4444
#
# Fold 1 Epoch 11 val loss 2.1254
# emotion_predict: val acc 0.8162 p 0.7941 r 0.6000 f1 0.6835
# max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
#
# cause_predict: val acc 0.7831 p 0.7541 r 0.5111 f1 0.6093
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.9177 p 0.4731 r 0.4889 f1 0.4809
# max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# avg max cause: max_acc 0.7831 max_p 0.7541 max_r 0.5111 max_f1 0.6093
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# Fold 1 Epoch 12 val loss 2.1155
# emotion_predict: val acc 0.8088 p 0.7436 r 0.6444 f1 0.6905
# max_acc 0.8088 max_p 0.7436 max_r 0.6444 max_f1 0.6905
#
# cause_predict: val acc 0.7574 p 0.6667 r 0.5333 f1 0.5926
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.8778 p 0.3396 r 0.6000 f1 0.4337
# max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# avg max cause: max_acc 0.7831 max_p 0.7541 max_r 0.5111 max_f1 0.6093
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# Fold 1 Epoch 13 val loss 2.1505
# emotion_predict: val acc 0.8015 p 0.7727 r 0.5667 f1 0.6538
# max_acc 0.8088 max_p 0.7436 max_r 0.6444 max_f1 0.6905
#
# cause_predict: val acc 0.7647 p 0.7097 r 0.4889 f1 0.5789
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.9055 p 0.4128 r 0.5000 f1 0.4523
# max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# avg max cause: max_acc 0.7831 max_p 0.7541 max_r 0.5111 max_f1 0.6093
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# Fold 1 Epoch 14 val loss 2.1537
# emotion_predict: val acc 0.7941 p 0.6977 r 0.6667 f1 0.6818
# max_acc 0.8088 max_p 0.7436 max_r 0.6444 max_f1 0.6905
#
# cause_predict: val acc 0.7574 p 0.6538 r 0.5667 f1 0.6071
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.9038 p 0.4103 r 0.5333 f1 0.4638
# max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# avg max cause: max_acc 0.7831 max_p 0.7541 max_r 0.5111 max_f1 0.6093
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# Fold 1 Epoch 15 val loss 2.2358
# emotion_predict: val acc 0.8199 p 0.7733 r 0.6444 f1 0.7030
# max_acc 0.8199 max_p 0.7733 max_r 0.6444 max_f1 0.7030
#
# cause_predict: val acc 0.7500 p 0.6618 r 0.5000 f1 0.5696
# max_acc 0.7610 max_p 0.6506 max_r 0.6000 max_f1 0.6243
#
# pair_predict: val acc 0.8917 p 0.3741 r 0.5778 f1 0.4541
# max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# avg max cause: max_acc 0.7831 max_p 0.7541 max_r 0.5111 max_f1 0.6093
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9177 max_p 0.4731 max_r 0.4889 max_f1 0.4809
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.60927152]]
# average : acc 0.7831 p 0.7541 r 0.5111 f1 0.6093
#
# emotion_predict: val f1 in 1 fold: [[0.6835443]]
# average : acc 0.8162 p 0.7941 r 0.6000 f1 0.6835
#
# pair_predict: val f1 in 1 fold: [[0.48087432]]
# average : acc 0.9177 p 0.4731 r 0.4889 f1 0.4809

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 4.2763
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.4046
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3409
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.2223
# emotion_predict: val acc 0.6728 p 0.5556 r 0.0556 f1 0.1010
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.1880
# emotion_predict: val acc 0.6765 p 0.6000 r 0.0667 f1 0.1200
# max_acc 0.6765 max_p 0.6000 max_r 0.0667 max_f1 0.1200
#
# cause_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.0137
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6765 max_p 0.6000 max_r 0.0667 max_f1 0.1200
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.9816
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6765 max_p 0.6000 max_r 0.0667 max_f1 0.1200
#
# cause_predict: val acc 0.7132 p 0.7143 r 0.2222 f1 0.3390
# max_acc 0.7132 max_p 0.7143 max_r 0.2222 max_f1 0.3390
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.9379
# emotion_predict: val acc 0.7059 p 0.5658 r 0.4778 f1 0.5181
# max_acc 0.7059 max_p 0.5658 max_r 0.4778 max_f1 0.5181
#
# cause_predict: val acc 0.7096 p 0.5618 r 0.5556 f1 0.5587
# max_acc 0.7096 max_p 0.5618 max_r 0.5556 max_f1 0.5587
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.9241
# emotion_predict: val acc 0.7059 p 0.5568 r 0.5444 f1 0.5506
# max_acc 0.7059 max_p 0.5568 max_r 0.5444 max_f1 0.5506
#
# cause_predict: val acc 0.7169 p 0.5657 r 0.6222 f1 0.5926
# max_acc 0.7169 max_p 0.5657 max_r 0.6222 max_f1 0.5926
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.8670
# emotion_predict: val acc 0.7574 p 0.8333 r 0.3333 f1 0.4762
# max_acc 0.7059 max_p 0.5568 max_r 0.5444 max_f1 0.5506
#
# cause_predict: val acc 0.7610 p 0.6866 r 0.5111 f1 0.5860
# max_acc 0.7169 max_p 0.5657 max_r 0.6222 max_f1 0.5926
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.7989
# emotion_predict: val acc 0.7500 p 0.7895 r 0.3333 f1 0.4687
# max_acc 0.7059 max_p 0.5568 max_r 0.5444 max_f1 0.5506
#
# cause_predict: val acc 0.7684 p 0.7077 r 0.5111 f1 0.5935
# max_acc 0.7684 max_p 0.7077 max_r 0.5111 max_f1 0.5935
#
# pair_predict: val acc 0.9367 p 0.9048 r 0.2111 f1 0.3423
# max_acc 0.9367 max_p 0.9048 max_r 0.2111 max_f1 0.3423
#
# avg max cause: max_acc 0.7684 max_p 0.7077 max_r 0.5111 max_f1 0.5935
# avg max pos: max_acc 0.7500 max_p 0.7895 max_r 0.3333 max_f1 0.4687
# avg max pair: max_acc 0.9367 max_p 0.9048 max_r 0.2111 max_f1 0.3423
#
# Fold 1 Epoch 12 val loss 2.7449
# emotion_predict: val acc 0.7426 p 0.6562 r 0.4667 f1 0.5455
# max_acc 0.7059 max_p 0.5568 max_r 0.5444 max_f1 0.5506
#
# cause_predict: val acc 0.7684 p 0.6627 r 0.6111 f1 0.6358
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9359 p 0.7000 r 0.3111 f1 0.4308
# max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# avg max cause: max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
# avg max pos: max_acc 0.7426 max_p 0.6562 max_r 0.4667 max_f1 0.5455
# avg max pair: max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# Fold 1 Epoch 13 val loss 2.6747
# emotion_predict: val acc 0.7463 p 0.6667 r 0.4667 f1 0.5490
# max_acc 0.7059 max_p 0.5568 max_r 0.5444 max_f1 0.5506
#
# cause_predict: val acc 0.7647 p 0.6857 r 0.5333 f1 0.6000
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9376 p 0.8000 r 0.2667 f1 0.4000
# max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# avg max cause: max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
# avg max pos: max_acc 0.7426 max_p 0.6562 max_r 0.4667 max_f1 0.5455
# avg max pair: max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# Fold 1 Epoch 14 val loss 2.6396
# emotion_predict: val acc 0.7500 p 0.6618 r 0.5000 f1 0.5696
# max_acc 0.7500 max_p 0.6618 max_r 0.5000 max_f1 0.5696
#
# cause_predict: val acc 0.7721 p 0.7121 r 0.5222 f1 0.6026
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9376 p 0.8214 r 0.2556 f1 0.3898
# max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# avg max cause: max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
# avg max pos: max_acc 0.7426 max_p 0.6562 max_r 0.4667 max_f1 0.5455
# avg max pair: max_acc 0.9359 max_p 0.7000 max_r 0.3111 max_f1 0.4308
#
# Fold 1 Epoch 15 val loss 2.5958
# emotion_predict: val acc 0.7500 p 0.6310 r 0.5889 f1 0.6092
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# cause_predict: val acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
# max_acc 0.7684 max_p 0.6627 max_r 0.6111 max_f1 0.6358
#
# pair_predict: val acc 0.9324 p 0.6250 r 0.3333 f1 0.4348
# max_acc 0.9324 max_p 0.6250 max_r 0.3333 max_f1 0.4348
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
# avg max pair: max_acc 0.9324 max_p 0.6250 max_r 0.3333 max_f1 0.4348
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.62576687]]
# average : acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
#
# emotion_predict: val f1 in 1 fold: [[0.6091954]]
# average : acc 0.7500 p 0.6310 r 0.5889 f1 0.6092
#
# pair_predict: val f1 in 1 fold: [[0.43478261]]
# average : acc 0.9324 p 0.6250 r 0.3333 f1 0.4348

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9841
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8405
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7788
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6801 p 0.6000 r 0.1000 f1 0.1714
# max_acc 0.6801 max_p 0.6000 max_r 0.1000 max_f1 0.1714
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.5987
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6801 p 0.6667 r 0.0667 f1 0.1212
# max_acc 0.6801 max_p 0.6000 max_r 0.1000 max_f1 0.1714
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.4509
# emotion_predict: val acc 0.7316 p 0.7297 r 0.3000 f1 0.4252
# max_acc 0.7316 max_p 0.7297 max_r 0.3000 max_f1 0.4252
#
# cause_predict: val acc 0.7684 p 0.7647 r 0.4333 f1 0.5532
# max_acc 0.7684 max_p 0.7647 max_r 0.4333 max_f1 0.5532
#
# pair_predict: val acc 0.9237 p 0.5167 r 0.3444 f1 0.4133
# max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# avg max cause: max_acc 0.7684 max_p 0.7647 max_r 0.4333 max_f1 0.5532
# avg max pos: max_acc 0.7316 max_p 0.7297 max_r 0.3000 max_f1 0.4252
# avg max pair: max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# Fold 1 Epoch 6 val loss 2.3751
# emotion_predict: val acc 0.7353 p 0.6216 r 0.5111 f1 0.5610
# max_acc 0.7353 max_p 0.6216 max_r 0.5111 max_f1 0.5610
#
# cause_predict: val acc 0.7537 p 0.6322 r 0.6111 f1 0.6215
# max_acc 0.7537 max_p 0.6322 max_r 0.6111 max_f1 0.6215
#
# pair_predict: val acc 0.8631 p 0.2875 r 0.5111 f1 0.3680
# max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# avg max cause: max_acc 0.7684 max_p 0.7647 max_r 0.4333 max_f1 0.5532
# avg max pos: max_acc 0.7316 max_p 0.7297 max_r 0.3000 max_f1 0.4252
# avg max pair: max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# Fold 1 Epoch 7 val loss 2.2935
# emotion_predict: val acc 0.7426 p 0.6667 r 0.4444 f1 0.5333
# max_acc 0.7353 max_p 0.6216 max_r 0.5111 max_f1 0.5610
#
# cause_predict: val acc 0.7721 p 0.6892 r 0.5667 f1 0.6220
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8908 p 0.3594 r 0.5111 f1 0.4220
# max_acc 0.8908 max_p 0.3594 max_r 0.5111 max_f1 0.4220
#
# avg max cause: max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
# avg max pos: max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
# avg max pair: max_acc 0.8908 max_p 0.3594 max_r 0.5111 max_f1 0.4220
#
# Fold 1 Epoch 8 val loss 2.2147
# emotion_predict: val acc 0.7316 p 0.6604 r 0.3889 f1 0.4895
# max_acc 0.7353 max_p 0.6216 max_r 0.5111 max_f1 0.5610
#
# cause_predict: val acc 0.7647 p 0.6970 r 0.5111 f1 0.5897
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8821 p 0.3380 r 0.5333 f1 0.4138
# max_acc 0.8908 max_p 0.3594 max_r 0.5111 max_f1 0.4220
#
# avg max cause: max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
# avg max pos: max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
# avg max pair: max_acc 0.8908 max_p 0.3594 max_r 0.5111 max_f1 0.4220
#
# Fold 1 Epoch 9 val loss 2.1754
# emotion_predict: val acc 0.7426 p 0.6613 r 0.4556 f1 0.5395
# max_acc 0.7353 max_p 0.6216 max_r 0.5111 max_f1 0.5610
#
# cause_predict: val acc 0.7868 p 0.7424 r 0.5444 f1 0.6282
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8951 p 0.3760 r 0.5222 f1 0.4372
# max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# avg max cause: max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
# avg max pos: max_acc 0.7426 max_p 0.6613 max_r 0.4556 max_f1 0.5395
# avg max pair: max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# Fold 1 Epoch 10 val loss 2.1503
# emotion_predict: val acc 0.7537 p 0.7018 r 0.4444 f1 0.5442
# max_acc 0.7353 max_p 0.6216 max_r 0.5111 max_f1 0.5610
#
# cause_predict: val acc 0.7647 p 0.6912 r 0.5222 f1 0.5949
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8934 p 0.3701 r 0.5222 f1 0.4332
# max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# avg max cause: max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
# avg max pos: max_acc 0.7426 max_p 0.6613 max_r 0.4556 max_f1 0.5395
# avg max pair: max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# Fold 1 Epoch 11 val loss 2.1375
# emotion_predict: val acc 0.7647 p 0.6912 r 0.5222 f1 0.5949
# max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
#
# cause_predict: val acc 0.7831 p 0.7385 r 0.5333 f1 0.6194
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8761 p 0.3268 r 0.5556 f1 0.4115
# max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# avg max cause: max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
# avg max pos: max_acc 0.7426 max_p 0.6613 max_r 0.4556 max_f1 0.5395
# avg max pair: max_acc 0.8951 max_p 0.3760 max_r 0.5222 max_f1 0.4372
#
# Fold 1 Epoch 12 val loss 2.1105
# emotion_predict: val acc 0.7684 p 0.6901 r 0.5444 f1 0.6087
# max_acc 0.7684 max_p 0.6901 max_r 0.5444 max_f1 0.6087
#
# cause_predict: val acc 0.7647 p 0.6912 r 0.5222 f1 0.5949
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8899 p 0.3650 r 0.5556 f1 0.4405
# max_acc 0.8899 max_p 0.3650 max_r 0.5556 max_f1 0.4405
#
# avg max cause: max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
# avg max pos: max_acc 0.7684 max_p 0.6901 max_r 0.5444 max_f1 0.6087
# avg max pair: max_acc 0.8899 max_p 0.3650 max_r 0.5556 max_f1 0.4405
#
# Fold 1 Epoch 13 val loss 2.1354
# emotion_predict: val acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
# max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
#
# cause_predict: val acc 0.7574 p 0.6622 r 0.5444 f1 0.5976
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9116 p 0.4444 r 0.5333 f1 0.4848
# max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# avg max cause: max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
# avg max pos: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pair: max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# Fold 1 Epoch 14 val loss 2.1229
# emotion_predict: val acc 0.7610 p 0.6582 r 0.5778 f1 0.6154
# max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
#
# cause_predict: val acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8735 p 0.3272 r 0.5889 f1 0.4206
# max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# avg max cause: max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
# avg max pos: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pair: max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# Fold 1 Epoch 15 val loss 2.1787
# emotion_predict: val acc 0.7831 p 0.7123 r 0.5778 f1 0.6380
# max_acc 0.7831 max_p 0.7123 max_r 0.5778 max_f1 0.6380
#
# cause_predict: val acc 0.7868 p 0.7424 r 0.5444 f1 0.6282
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.8951 p 0.3835 r 0.5667 f1 0.4574
# max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# avg max cause: max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
# avg max pos: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pair: max_acc 0.9116 max_p 0.4444 max_r 0.5333 max_f1 0.4848
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.59756098]]
# average : acc 0.7574 p 0.6622 r 0.5444 f1 0.5976
#
# emotion_predict: val f1 in 1 fold: [[0.62576687]]
# average : acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
#
# pair_predict: val f1 in 1 fold: [[0.48484848]]
# average : acc 0.9116 p 0.4444 r 0.5333 f1 0.4848

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.6194
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.4929
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3110
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6728 p 0.5714 r 0.0444 f1 0.0825
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.7624
# emotion_predict: val acc 0.6728 p 0.5556 r 0.0556 f1 0.1010
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.6040
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.3426
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.1452
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.1414
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0999
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5714 max_r 0.0444 max_f1 0.0825
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0247
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.7574 p 0.7400 r 0.4111 f1 0.5286
# max_acc 0.7574 max_p 0.7400 max_r 0.4111 max_f1 0.5286
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.9865
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.7390 p 0.6301 r 0.5111 f1 0.5644
# max_acc 0.7390 max_p 0.6301 max_r 0.5111 max_f1 0.5644
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.9798
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6728 max_p 0.5556 max_r 0.0556 max_f1 0.1010
#
# cause_predict: val acc 0.7206 p 0.5833 r 0.5444 f1 0.5632
# max_acc 0.7390 max_p 0.6301 max_r 0.5111 max_f1 0.5644
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 2.9648
# emotion_predict: val acc 0.7500 p 0.8667 r 0.2889 f1 0.4333
# max_acc 0.7500 max_p 0.8667 max_r 0.2889 max_f1 0.4333
#
# cause_predict: val acc 0.7279 p 0.5909 r 0.5778 f1 0.5843
# max_acc 0.7279 max_p 0.5909 max_r 0.5778 max_f1 0.5843
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 2.9309
# emotion_predict: val acc 0.7463 p 0.7442 r 0.3556 f1 0.4812
# max_acc 0.7463 max_p 0.7442 max_r 0.3556 max_f1 0.4812
#
# cause_predict: val acc 0.7316 p 0.6024 r 0.5556 f1 0.5780
# max_acc 0.7279 max_p 0.5909 max_r 0.5778 max_f1 0.5843
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 2.8930
# emotion_predict: val acc 0.7463 p 0.7059 r 0.4000 f1 0.5106
# max_acc 0.7463 max_p 0.7059 max_r 0.4000 max_f1 0.5106
#
# cause_predict: val acc 0.7390 p 0.6301 r 0.5111 f1 0.5644
# max_acc 0.7279 max_p 0.5909 max_r 0.5778 max_f1 0.5843
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# emotion_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# pair_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.9220 p 0.0000 r 0.0000 f1 0.0000

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9304
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7817
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.1706
# emotion_predict: val acc 0.5331 p 0.3879 r 0.7111 f1 0.5020
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.5625 p 0.4216 r 0.8667 f1 0.5673
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.6282 p 0.1386 r 0.7222 f1 0.2326
# max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# avg max cause: max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
# avg max pos: max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
# avg max pair: max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# Fold 1 Epoch 4 val loss 2.5922
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# avg max cause: max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
# avg max pos: max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
# avg max pair: max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# Fold 1 Epoch 5 val loss 2.7435
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# avg max cause: max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
# avg max pos: max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
# avg max pair: max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# Fold 1 Epoch 6 val loss 2.6172
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# avg max cause: max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
# avg max pos: max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
# avg max pair: max_acc 0.6282 max_p 0.1386 max_r 0.7222 max_f1 0.2326
#
# Fold 1 Epoch 7 val loss 2.6450
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9012 p 0.3605 r 0.3444 f1 0.3523
# max_acc 0.9012 max_p 0.3605 max_r 0.3444 max_f1 0.3523
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9012 max_p 0.3605 max_r 0.3444 max_f1 0.3523
#
# Fold 1 Epoch 8 val loss 2.6636
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.8995 p 0.3556 r 0.3556 f1 0.3556
# max_acc 0.8995 max_p 0.3556 max_r 0.3556 max_f1 0.3556
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8995 max_p 0.3556 max_r 0.3556 max_f1 0.3556
#
# Fold 1 Epoch 9 val loss 2.6088
# emotion_predict: val acc 0.6838 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.8986 p 0.3483 r 0.3444 f1 0.3464
# max_acc 0.8995 max_p 0.3556 max_r 0.3556 max_f1 0.3556
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8995 max_p 0.3556 max_r 0.3556 max_f1 0.3556
#
# Fold 1 Epoch 10 val loss 2.5628
# emotion_predict: val acc 0.7243 p 0.9412 r 0.1778 f1 0.2991
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.6875 p 0.8571 r 0.0667 f1 0.1237
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9090 p 0.4000 r 0.3333 f1 0.3636
# max_acc 0.9090 max_p 0.4000 max_r 0.3333 max_f1 0.3636
#
# avg max cause: max_acc 0.6875 max_p 0.8571 max_r 0.0667 max_f1 0.1237
# avg max pos: max_acc 0.7243 max_p 0.9412 max_r 0.1778 max_f1 0.2991
# avg max pair: max_acc 0.9090 max_p 0.4000 max_r 0.3333 max_f1 0.3636
#
# Fold 1 Epoch 11 val loss 2.5472
# emotion_predict: val acc 0.7316 p 0.8400 r 0.2333 f1 0.3652
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.7500 p 0.9231 r 0.2667 f1 0.4138
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9159 p 0.4462 r 0.3222 f1 0.3742
# max_acc 0.9159 max_p 0.4462 max_r 0.3222 max_f1 0.3742
#
# avg max cause: max_acc 0.7500 max_p 0.9231 max_r 0.2667 max_f1 0.4138
# avg max pos: max_acc 0.7316 max_p 0.8400 max_r 0.2333 max_f1 0.3652
# avg max pair: max_acc 0.9159 max_p 0.4462 max_r 0.3222 max_f1 0.3742
#
# Fold 1 Epoch 12 val loss 2.5283
# emotion_predict: val acc 0.7426 p 0.8571 r 0.2667 f1 0.4068
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.7647 p 0.8250 r 0.3667 f1 0.5077
# max_acc 0.5625 max_p 0.4216 max_r 0.8667 max_f1 0.5673
#
# pair_predict: val acc 0.9099 p 0.4103 r 0.3556 f1 0.3810
# max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# avg max cause: max_acc 0.7647 max_p 0.8250 max_r 0.3667 max_f1 0.5077
# avg max pos: max_acc 0.7426 max_p 0.8571 max_r 0.2667 max_f1 0.4068
# avg max pair: max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# Fold 1 Epoch 13 val loss 2.4861
# emotion_predict: val acc 0.7353 p 0.7500 r 0.3000 f1 0.4286
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.7647 p 0.7241 r 0.4667 f1 0.5676
# max_acc 0.7647 max_p 0.7241 max_r 0.4667 max_f1 0.5676
#
# pair_predict: val acc 0.8969 p 0.3441 r 0.3556 f1 0.3497
# max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# avg max cause: max_acc 0.7647 max_p 0.8250 max_r 0.3667 max_f1 0.5077
# avg max pos: max_acc 0.7426 max_p 0.8571 max_r 0.2667 max_f1 0.4068
# avg max pair: max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# Fold 1 Epoch 14 val loss 2.4458
# emotion_predict: val acc 0.7390 p 0.7111 r 0.3556 f1 0.4741
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.7610 p 0.6582 r 0.5778 f1 0.6154
# max_acc 0.7610 max_p 0.6582 max_r 0.5778 max_f1 0.6154
#
# pair_predict: val acc 0.8622 p 0.2857 r 0.5111 f1 0.3665
# max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# avg max cause: max_acc 0.7647 max_p 0.8250 max_r 0.3667 max_f1 0.5077
# avg max pos: max_acc 0.7426 max_p 0.8571 max_r 0.2667 max_f1 0.4068
# avg max pair: max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# Fold 1 Epoch 15 val loss 2.4266
# emotion_predict: val acc 0.7169 p 0.6102 r 0.4000 f1 0.4832
# max_acc 0.5331 max_p 0.3879 max_r 0.7111 max_f1 0.5020
#
# cause_predict: val acc 0.7279 p 0.5870 r 0.6000 f1 0.5934
# max_acc 0.7610 max_p 0.6582 max_r 0.5778 max_f1 0.6154
#
# pair_predict: val acc 0.8180 p 0.2458 r 0.6444 f1 0.3558
# max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# avg max cause: max_acc 0.7647 max_p 0.8250 max_r 0.3667 max_f1 0.5077
# avg max pos: max_acc 0.7426 max_p 0.8571 max_r 0.2667 max_f1 0.4068
# avg max pair: max_acc 0.9099 max_p 0.4103 max_r 0.3556 max_f1 0.3810
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.50769231]]
# average : acc 0.7647 p 0.8250 r 0.3667 f1 0.5077
#
# emotion_predict: val f1 in 1 fold: [[0.40677966]]
# average : acc 0.7426 p 0.8571 r 0.2667 f1 0.4068
#
# pair_predict: val f1 in 1 fold: [[0.38095238]]
# average : acc 0.9099 p 0.4103 r 0.3556 f1 0.3810

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 4.4847
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.3050
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 4.1156
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.9052
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.6722
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.4513
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.3580
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.3541
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.3050
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.2514
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 3.2296
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6912 p 0.7500 r 0.1000 f1 0.1765
# max_acc 0.6912 max_p 0.7500 max_r 0.1000 max_f1 0.1765
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 3.2239
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.7463 p 0.7333 r 0.3667 f1 0.4889
# max_acc 0.7463 max_p 0.7333 max_r 0.3667 max_f1 0.4889
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.2072
# emotion_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.6728 max_p 0.6667 max_r 0.0222 max_f1 0.0430
#
# cause_predict: val acc 0.7279 p 0.6429 r 0.4000 f1 0.4932
# max_acc 0.7279 max_p 0.6429 max_r 0.4000 max_f1 0.4932
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 3.1650
# emotion_predict: val acc 0.6838 p 0.7500 r 0.0667 f1 0.1224
# max_acc 0.6838 max_p 0.7500 max_r 0.0667 max_f1 0.1224
#
# cause_predict: val acc 0.7390 p 0.7021 r 0.3667 f1 0.4818
# max_acc 0.7279 max_p 0.6429 max_r 0.4000 max_f1 0.4932
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 3.1060
# emotion_predict: val acc 0.6912 p 0.8000 r 0.0889 f1 0.1600
# max_acc 0.6912 max_p 0.8000 max_r 0.0889 max_f1 0.1600
#
# cause_predict: val acc 0.7500 p 0.7750 r 0.3444 f1 0.4769
# max_acc 0.7279 max_p 0.6429 max_r 0.4000 max_f1 0.4932
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# emotion_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# pair_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.9220 p 0.0000 r 0.0000 f1 0.0000

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.1522
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0792
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0180
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.9607
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.9083
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.8607
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.8188
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.7892
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6618 p 0.3333 r 0.0222 f1 0.0417
# max_acc 0.6618 max_p 0.3333 max_r 0.0222 max_f1 0.0417
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.7561
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6875 p 0.5676 r 0.2333 f1 0.3307
# max_acc 0.6875 max_p 0.5676 max_r 0.2333 max_f1 0.3307
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.6997
# emotion_predict: val acc 0.6728 p 0.6000 r 0.0333 f1 0.0632
# max_acc 0.6728 max_p 0.6000 max_r 0.0333 max_f1 0.0632
#
# cause_predict: val acc 0.7169 p 0.6327 r 0.3444 f1 0.4460
# max_acc 0.7169 max_p 0.6327 max_r 0.3444 max_f1 0.4460
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.6273
# emotion_predict: val acc 0.6875 p 0.6471 r 0.1222 f1 0.2056
# max_acc 0.6875 max_p 0.6471 max_r 0.1222 max_f1 0.2056
#
# cause_predict: val acc 0.7279 p 0.6818 r 0.3333 f1 0.4478
# max_acc 0.7279 max_p 0.6818 max_r 0.3333 max_f1 0.4478
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.5588
# emotion_predict: val acc 0.7279 p 0.7667 r 0.2556 f1 0.3833
# max_acc 0.7279 max_p 0.7667 max_r 0.2556 max_f1 0.3833
#
# cause_predict: val acc 0.7316 p 0.6977 r 0.3333 f1 0.4511
# max_acc 0.7316 max_p 0.6977 max_r 0.3333 max_f1 0.4511
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.7316 max_p 0.6977 max_r 0.3333 max_f1 0.4511
# avg max pos: max_acc 0.7279 max_p 0.7667 max_r 0.2556 max_f1 0.3833
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 13 val loss 2.5009
# emotion_predict: val acc 0.7279 p 0.6818 r 0.3333 f1 0.4478
# max_acc 0.7279 max_p 0.6818 max_r 0.3333 max_f1 0.4478
#
# cause_predict: val acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
# max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
#
# pair_predict: val acc 0.9255 p 0.5385 r 0.3111 f1 0.3944
# max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# avg max cause: max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
# avg max pos: max_acc 0.7279 max_p 0.6818 max_r 0.3333 max_f1 0.4478
# avg max pair: max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# Fold 1 Epoch 14 val loss 2.4635
# emotion_predict: val acc 0.7426 p 0.6667 r 0.4444 f1 0.5333
# max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
#
# cause_predict: val acc 0.7390 p 0.6301 r 0.5111 f1 0.5644
# max_acc 0.7390 max_p 0.6301 max_r 0.5111 max_f1 0.5644
#
# pair_predict: val acc 0.8951 p 0.3524 r 0.4111 f1 0.3795
# max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# avg max cause: max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
# avg max pos: max_acc 0.7279 max_p 0.6818 max_r 0.3333 max_f1 0.4478
# avg max pair: max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# Fold 1 Epoch 15 val loss 2.4188
# emotion_predict: val acc 0.7426 p 0.6613 r 0.4556 f1 0.5395
# max_acc 0.7426 max_p 0.6613 max_r 0.4556 max_f1 0.5395
#
# cause_predict: val acc 0.7500 p 0.6486 r 0.5333 f1 0.5854
# max_acc 0.7500 max_p 0.6486 max_r 0.5333 max_f1 0.5854
#
# pair_predict: val acc 0.8761 p 0.3066 r 0.4667 f1 0.3700
# max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# avg max cause: max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
# avg max pos: max_acc 0.7279 max_p 0.6818 max_r 0.3333 max_f1 0.4478
# avg max pair: max_acc 0.9255 max_p 0.5385 max_r 0.3111 max_f1 0.3944
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.51034483]]
# average : acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
#
# emotion_predict: val f1 in 1 fold: [[0.44776119]]
# average : acc 0.7279 p 0.6818 r 0.3333 f1 0.4478
#
# pair_predict: val f1 in 1 fold: [[0.3943662]]
# average : acc 0.9255 p 0.5385 r 0.3111 f1 0.3944

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.9828
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0787
# emotion_predict: val acc 0.7463 p 0.8000 r 0.3111 f1 0.4480
# max_acc 0.7463 max_p 0.8000 max_r 0.3111 max_f1 0.4480
#
# cause_predict: val acc 0.7316 p 0.6049 r 0.5444 f1 0.5731
# max_acc 0.7316 max_p 0.6049 max_r 0.5444 max_f1 0.5731
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7927
# emotion_predict: val acc 0.7353 p 0.6286 r 0.4889 f1 0.5500
# max_acc 0.7353 max_p 0.6286 max_r 0.4889 max_f1 0.5500
#
# cause_predict: val acc 0.7316 p 0.6024 r 0.5556 f1 0.5780
# max_acc 0.7316 max_p 0.6024 max_r 0.5556 max_f1 0.5780
#
# pair_predict: val acc 0.9289 p 0.5714 r 0.3556 f1 0.4384
# max_acc 0.9289 max_p 0.5714 max_r 0.3556 max_f1 0.4384
#
# avg max cause: max_acc 0.7316 max_p 0.6024 max_r 0.5556 max_f1 0.5780
# avg max pos: max_acc 0.7353 max_p 0.6286 max_r 0.4889 max_f1 0.5500
# avg max pair: max_acc 0.9289 max_p 0.5714 max_r 0.3556 max_f1 0.4384
#
# Fold 1 Epoch 4 val loss 2.7323
# emotion_predict: val acc 0.7463 p 0.6842 r 0.4333 f1 0.5306
# max_acc 0.7353 max_p 0.6286 max_r 0.4889 max_f1 0.5500
#
# cause_predict: val acc 0.7684 p 0.7547 r 0.4444 f1 0.5594
# max_acc 0.7316 max_p 0.6024 max_r 0.5556 max_f1 0.5780
#
# pair_predict: val acc 0.8960 p 0.3790 r 0.5222 f1 0.4393
# max_acc 0.8960 max_p 0.3790 max_r 0.5222 max_f1 0.4393
#
# avg max cause: max_acc 0.7684 max_p 0.7547 max_r 0.4444 max_f1 0.5594
# avg max pos: max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
# avg max pair: max_acc 0.8960 max_p 0.3790 max_r 0.5222 max_f1 0.4393
#
# Fold 1 Epoch 5 val loss 2.6694
# emotion_predict: val acc 0.7132 p 0.5698 r 0.5444 f1 0.5568
# max_acc 0.7132 max_p 0.5698 max_r 0.5444 max_f1 0.5568
#
# cause_predict: val acc 0.7243 p 0.5806 r 0.6000 f1 0.5902
# max_acc 0.7243 max_p 0.5806 max_r 0.6000 max_f1 0.5902
#
# pair_predict: val acc 0.9177 p 0.4699 r 0.4333 f1 0.4509
# max_acc 0.9177 max_p 0.4699 max_r 0.4333 max_f1 0.4509
#
# avg max cause: max_acc 0.7243 max_p 0.5806 max_r 0.6000 max_f1 0.5902
# avg max pos: max_acc 0.7132 max_p 0.5698 max_r 0.5444 max_f1 0.5568
# avg max pair: max_acc 0.9177 max_p 0.4699 max_r 0.4333 max_f1 0.4509
#
# Fold 1 Epoch 6 val loss 2.7026
# emotion_predict: val acc 0.7316 p 0.5934 r 0.6000 f1 0.5967
# max_acc 0.7316 max_p 0.5934 max_r 0.6000 max_f1 0.5967
#
# cause_predict: val acc 0.7610 p 0.6712 r 0.5444 f1 0.6012
# max_acc 0.7610 max_p 0.6712 max_r 0.5444 max_f1 0.6012
#
# pair_predict: val acc 0.8899 p 0.3520 r 0.4889 f1 0.4093
# max_acc 0.9177 max_p 0.4699 max_r 0.4333 max_f1 0.4509
#
# avg max cause: max_acc 0.7243 max_p 0.5806 max_r 0.6000 max_f1 0.5902
# avg max pos: max_acc 0.7132 max_p 0.5698 max_r 0.5444 max_f1 0.5568
# avg max pair: max_acc 0.9177 max_p 0.4699 max_r 0.4333 max_f1 0.4509
#
# Fold 1 Epoch 7 val loss 2.4772
# emotion_predict: val acc 0.7647 p 0.6585 r 0.6000 f1 0.6279
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# cause_predict: val acc 0.7537 p 0.6456 r 0.5667 f1 0.6036
# max_acc 0.7537 max_p 0.6456 max_r 0.5667 max_f1 0.6036
#
# pair_predict: val acc 0.9281 p 0.5556 r 0.3889 f1 0.4575
# max_acc 0.9281 max_p 0.5556 max_r 0.3889 max_f1 0.4575
#
# avg max cause: max_acc 0.7537 max_p 0.6456 max_r 0.5667 max_f1 0.6036
# avg max pos: max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
# avg max pair: max_acc 0.9281 max_p 0.5556 max_r 0.3889 max_f1 0.4575
#
# Fold 1 Epoch 8 val loss 2.5720
# emotion_predict: val acc 0.7941 p 0.9048 r 0.4222 f1 0.5758
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# cause_predict: val acc 0.7647 p 0.7955 r 0.3889 f1 0.5224
# max_acc 0.7537 max_p 0.6456 max_r 0.5667 max_f1 0.6036
#
# pair_predict: val acc 0.9411 p 0.8056 r 0.3222 f1 0.4603
# max_acc 0.9411 max_p 0.8056 max_r 0.3222 max_f1 0.4603
#
# avg max cause: max_acc 0.7647 max_p 0.7955 max_r 0.3889 max_f1 0.5224
# avg max pos: max_acc 0.7941 max_p 0.9048 max_r 0.4222 max_f1 0.5758
# avg max pair: max_acc 0.9411 max_p 0.8056 max_r 0.3222 max_f1 0.4603
#
# Fold 1 Epoch 9 val loss 2.4051
# emotion_predict: val acc 0.7721 p 0.6429 r 0.7000 f1 0.6702
# max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
#
# cause_predict: val acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
# max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
#
# pair_predict: val acc 0.9289 p 0.5526 r 0.4667 f1 0.5060
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 10 val loss 2.3621
# emotion_predict: val acc 0.7794 p 0.7273 r 0.5333 f1 0.6154
# max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
#
# cause_predict: val acc 0.7868 p 0.7424 r 0.5444 f1 0.6282
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9281 p 0.5493 r 0.4333 f1 0.4845
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 11 val loss 2.4727
# emotion_predict: val acc 0.7904 p 0.7143 r 0.6111 f1 0.6587
# max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
#
# cause_predict: val acc 0.7721 p 0.6842 r 0.5778 f1 0.6265
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9281 p 0.5479 r 0.4444 f1 0.4908
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 12 val loss 2.6762
# emotion_predict: val acc 0.7831 p 0.6566 r 0.7222 f1 0.6878
# max_acc 0.7831 max_p 0.6566 max_r 0.7222 max_f1 0.6878
#
# cause_predict: val acc 0.7684 p 0.6901 r 0.5444 f1 0.6087
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9194 p 0.4845 r 0.5222 f1 0.5027
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 13 val loss 3.1664
# emotion_predict: val acc 0.7721 p 0.6750 r 0.6000 f1 0.6353
# max_acc 0.7831 max_p 0.6566 max_r 0.7222 max_f1 0.6878
#
# cause_predict: val acc 0.7647 p 0.6667 r 0.5778 f1 0.6190
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9298 p 0.5652 r 0.4333 f1 0.4906
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 14 val loss 2.9216
# emotion_predict: val acc 0.7941 p 0.7237 r 0.6111 f1 0.6627
# max_acc 0.7831 max_p 0.6566 max_r 0.7222 max_f1 0.6878
#
# cause_predict: val acc 0.7243 p 0.6027 r 0.4889 f1 0.5399
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9168 p 0.4706 r 0.5333 f1 0.5000
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# Fold 1 Epoch 15 val loss 2.9184
# emotion_predict: val acc 0.8125 p 0.7191 r 0.7111 f1 0.7151
# max_acc 0.8125 max_p 0.7191 max_r 0.7111 max_f1 0.7151
#
# cause_predict: val acc 0.7647 p 0.6667 r 0.5778 f1 0.6190
# max_acc 0.7868 max_p 0.7424 max_r 0.5444 max_f1 0.6282
#
# pair_predict: val acc 0.9177 p 0.4737 r 0.5000 f1 0.4865
# max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# avg max cause: max_acc 0.7757 max_p 0.6986 max_r 0.5667 max_f1 0.6258
# avg max pos: max_acc 0.7721 max_p 0.6429 max_r 0.7000 max_f1 0.6702
# avg max pair: max_acc 0.9289 max_p 0.5526 max_r 0.4667 max_f1 0.5060
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.62576687]]
# average : acc 0.7757 p 0.6986 r 0.5667 f1 0.6258
#
# emotion_predict: val f1 in 1 fold: [[0.67021277]]
# average : acc 0.7721 p 0.6429 r 0.7000 f1 0.6702
#
# pair_predict: val f1 in 1 fold: [[0.5060241]]
# average : acc 0.9289 p 0.5526 r 0.4667 f1 0.5060

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.0488
# emotion_predict: val acc 0.7206 p 0.5673 r 0.6556 f1 0.6082
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.7574 p 0.7308 r 0.4222 f1 0.5352
# max_acc 0.7574 max_p 0.7308 max_r 0.4222 max_f1 0.5352
#
# pair_predict: val acc 0.9211 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7574 max_p 0.7308 max_r 0.4222 max_f1 0.5352
# avg max pos: max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
# avg max pair: max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8373
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.7574 max_p 0.7308 max_r 0.4222 max_f1 0.5352
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7574 max_p 0.7308 max_r 0.4222 max_f1 0.5352
# avg max pos: max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
# avg max pair: max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.5254
# emotion_predict: val acc 0.6801 p 1.0000 r 0.0333 f1 0.0645
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.7757 p 0.8222 r 0.4111 f1 0.5481
# max_acc 0.7757 max_p 0.8222 max_r 0.4111 max_f1 0.5481
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7574 max_p 0.7308 max_r 0.4222 max_f1 0.5352
# avg max pos: max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
# avg max pair: max_acc 0.9211 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.4678
# emotion_predict: val acc 0.7610 p 0.6866 r 0.5111 f1 0.5860
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.7647 p 0.6806 r 0.5444 f1 0.6049
# max_acc 0.7647 max_p 0.6806 max_r 0.5444 max_f1 0.6049
#
# pair_predict: val acc 0.8068 p 0.2452 r 0.7111 f1 0.3647
# max_acc 0.8068 max_p 0.2452 max_r 0.7111 max_f1 0.3647
#
# avg max cause: max_acc 0.7647 max_p 0.6806 max_r 0.5444 max_f1 0.6049
# avg max pos: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pair: max_acc 0.8068 max_p 0.2452 max_r 0.7111 max_f1 0.3647
#
# Fold 1 Epoch 5 val loss 2.3000
# emotion_predict: val acc 0.7537 p 0.7018 r 0.4444 f1 0.5442
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.7610 p 0.6812 r 0.5222 f1 0.5912
# max_acc 0.7647 max_p 0.6806 max_r 0.5444 max_f1 0.6049
#
# pair_predict: val acc 0.8787 p 0.3333 r 0.5556 f1 0.4167
# max_acc 0.8787 max_p 0.3333 max_r 0.5556 max_f1 0.4167
#
# avg max cause: max_acc 0.7610 max_p 0.6812 max_r 0.5222 max_f1 0.5912
# avg max pos: max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
# avg max pair: max_acc 0.8787 max_p 0.3333 max_r 0.5556 max_f1 0.4167
#
# Fold 1 Epoch 6 val loss 2.2465
# emotion_predict: val acc 0.7647 p 0.6857 r 0.5333 f1 0.6000
# max_acc 0.7206 max_p 0.5673 max_r 0.6556 max_f1 0.6082
#
# cause_predict: val acc 0.7610 p 0.7358 r 0.4333 f1 0.5455
# max_acc 0.7647 max_p 0.6806 max_r 0.5444 max_f1 0.6049
#
# pair_predict: val acc 0.9012 p 0.3947 r 0.5000 f1 0.4412
# max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# avg max cause: max_acc 0.7610 max_p 0.7358 max_r 0.4333 max_f1 0.5455
# avg max pos: max_acc 0.7647 max_p 0.6857 max_r 0.5333 max_f1 0.6000
# avg max pair: max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# Fold 1 Epoch 7 val loss 2.1206
# emotion_predict: val acc 0.7721 p 0.6944 r 0.5556 f1 0.6173
# max_acc 0.7721 max_p 0.6944 max_r 0.5556 max_f1 0.6173
#
# cause_predict: val acc 0.7574 p 0.6667 r 0.5333 f1 0.5926
# max_acc 0.7647 max_p 0.6806 max_r 0.5444 max_f1 0.6049
#
# pair_predict: val acc 0.8821 p 0.3487 r 0.5889 f1 0.4380
# max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# avg max cause: max_acc 0.7610 max_p 0.7358 max_r 0.4333 max_f1 0.5455
# avg max pos: max_acc 0.7647 max_p 0.6857 max_r 0.5333 max_f1 0.6000
# avg max pair: max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# Fold 1 Epoch 8 val loss 2.1539
# emotion_predict: val acc 0.7647 p 0.6477 r 0.6333 f1 0.6404
# max_acc 0.7647 max_p 0.6477 max_r 0.6333 max_f1 0.6404
#
# cause_predict: val acc 0.7684 p 0.6588 r 0.6222 f1 0.6400
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.8622 p 0.3155 r 0.6556 f1 0.4260
# max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# avg max cause: max_acc 0.7610 max_p 0.7358 max_r 0.4333 max_f1 0.5455
# avg max pos: max_acc 0.7647 max_p 0.6857 max_r 0.5333 max_f1 0.6000
# avg max pair: max_acc 0.9012 max_p 0.3947 max_r 0.5000 max_f1 0.4412
#
# Fold 1 Epoch 9 val loss 2.0868
# emotion_predict: val acc 0.8199 p 0.7971 r 0.6111 f1 0.6918
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7684 p 0.7213 r 0.4889 f1 0.5828
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.8977 p 0.3871 r 0.5333 f1 0.4486
# max_acc 0.8977 max_p 0.3871 max_r 0.5333 max_f1 0.4486
#
# avg max cause: max_acc 0.7684 max_p 0.7213 max_r 0.4889 max_f1 0.5828
# avg max pos: max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
# avg max pair: max_acc 0.8977 max_p 0.3871 max_r 0.5333 max_f1 0.4486
#
# Fold 1 Epoch 10 val loss 2.1756
# emotion_predict: val acc 0.8088 p 0.7568 r 0.6222 f1 0.6829
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.5000 f1 0.5000
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# Fold 1 Epoch 11 val loss 2.1777
# emotion_predict: val acc 0.7647 p 0.6585 r 0.6000 f1 0.6279
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7721 p 0.7187 r 0.5111 f1 0.5974
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.8761 p 0.3333 r 0.5889 f1 0.4257
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# Fold 1 Epoch 12 val loss 2.4071
# emotion_predict: val acc 0.7941 p 0.6977 r 0.6667 f1 0.6818
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7610 p 0.6761 r 0.5333 f1 0.5963
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.9142 p 0.4579 r 0.5444 f1 0.4975
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# Fold 1 Epoch 13 val loss 2.6729
# emotion_predict: val acc 0.7574 p 0.6500 r 0.5778 f1 0.6118
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7684 p 0.6849 r 0.5556 f1 0.6135
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.8865 p 0.3566 r 0.5667 f1 0.4378
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# Fold 1 Epoch 14 val loss 2.8365
# emotion_predict: val acc 0.7610 p 0.6506 r 0.6000 f1 0.6243
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7537 p 0.6533 r 0.5444 f1 0.5939
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.8769 p 0.3289 r 0.5556 f1 0.4132
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# Fold 1 Epoch 15 val loss 3.1848
# emotion_predict: val acc 0.7574 p 0.6429 r 0.6000 f1 0.6207
# max_acc 0.8199 max_p 0.7971 max_r 0.6111 max_f1 0.6918
#
# cause_predict: val acc 0.7463 p 0.6329 r 0.5556 f1 0.5917
# max_acc 0.7684 max_p 0.6588 max_r 0.6222 max_f1 0.6400
#
# pair_predict: val acc 0.9081 p 0.4245 r 0.5000 f1 0.4592
# max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.5000 max_f1 0.5000
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.5875]]
# average : acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
#
# emotion_predict: val f1 in 1 fold: [[0.68292683]]
# average : acc 0.8088 p 0.7568 r 0.6222 f1 0.6829
#
# pair_predict: val f1 in 1 fold: [[0.5]]
# average : acc 0.9220 p 0.5000 r 0.5000 f1 0.5000

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3531
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2229
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0732
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# cause_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.9182
# emotion_predict: val acc 0.7426 p 0.7632 r 0.3222 f1 0.4531
# max_acc 0.7426 max_p 0.7632 max_r 0.3222 max_f1 0.4531
#
# cause_predict: val acc 0.7574 p 0.7500 r 0.4000 f1 0.5217
# max_acc 0.7574 max_p 0.7500 max_r 0.4000 max_f1 0.5217
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.7574 max_p 0.7500 max_r 0.4000 max_f1 0.5217
# avg max pos: max_acc 0.7426 max_p 0.7632 max_r 0.3222 max_f1 0.4531
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 5 val loss 2.8942
# emotion_predict: val acc 0.7500 p 0.7292 r 0.3889 f1 0.5072
# max_acc 0.7500 max_p 0.7292 max_r 0.3889 max_f1 0.5072
#
# cause_predict: val acc 0.7574 p 0.7069 r 0.4556 f1 0.5541
# max_acc 0.7574 max_p 0.7069 max_r 0.4556 max_f1 0.5541
#
# pair_predict: val acc 0.9341 p 0.8182 r 0.2000 f1 0.3214
# max_acc 0.9341 max_p 0.8182 max_r 0.2000 max_f1 0.3214
#
# avg max cause: max_acc 0.7574 max_p 0.7069 max_r 0.4556 max_f1 0.5541
# avg max pos: max_acc 0.7500 max_p 0.7292 max_r 0.3889 max_f1 0.5072
# avg max pair: max_acc 0.9341 max_p 0.8182 max_r 0.2000 max_f1 0.3214
#
# Fold 1 Epoch 6 val loss 2.8425
# emotion_predict: val acc 0.7500 p 0.6833 r 0.4556 f1 0.5467
# max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
#
# cause_predict: val acc 0.7537 p 0.6667 r 0.5111 f1 0.5786
# max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
#
# pair_predict: val acc 0.9263 p 0.5455 r 0.3333 f1 0.4138
# max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# avg max cause: max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
# avg max pos: max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
# avg max pair: max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# Fold 1 Epoch 7 val loss 2.8572
# emotion_predict: val acc 0.7279 p 0.8077 r 0.2333 f1 0.3621
# max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
#
# cause_predict: val acc 0.7537 p 0.8485 r 0.3111 f1 0.4553
# max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
#
# pair_predict: val acc 0.9350 p 0.8571 r 0.2000 f1 0.3243
# max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# avg max cause: max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
# avg max pos: max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
# avg max pair: max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# Fold 1 Epoch 8 val loss 2.7595
# emotion_predict: val acc 0.7022 p 0.5570 r 0.4889 f1 0.5207
# max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
#
# cause_predict: val acc 0.7537 p 0.6386 r 0.5889 f1 0.6127
# max_acc 0.7537 max_p 0.6386 max_r 0.5889 max_f1 0.6127
#
# pair_predict: val acc 0.9185 p 0.4697 r 0.3444 f1 0.3974
# max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# avg max cause: max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
# avg max pos: max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
# avg max pair: max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# Fold 1 Epoch 9 val loss 2.6661
# emotion_predict: val acc 0.7169 p 0.5714 r 0.5778 f1 0.5746
# max_acc 0.7169 max_p 0.5714 max_r 0.5778 max_f1 0.5746
#
# cause_predict: val acc 0.7610 p 0.6404 r 0.6333 f1 0.6369
# max_acc 0.7610 max_p 0.6404 max_r 0.6333 max_f1 0.6369
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.3333 f1 0.4000
# max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# avg max cause: max_acc 0.7537 max_p 0.6667 max_r 0.5111 max_f1 0.5786
# avg max pos: max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
# avg max pair: max_acc 0.9263 max_p 0.5455 max_r 0.3333 max_f1 0.4138
#
# Fold 1 Epoch 10 val loss 2.5590
# emotion_predict: val acc 0.7610 p 0.7049 r 0.4778 f1 0.5695
# max_acc 0.7169 max_p 0.5714 max_r 0.5778 max_f1 0.5746
#
# cause_predict: val acc 0.7831 p 0.7460 r 0.5222 f1 0.6144
# max_acc 0.7610 max_p 0.6404 max_r 0.6333 max_f1 0.6369
#
# pair_predict: val acc 0.9307 p 0.5962 r 0.3444 f1 0.4366
# max_acc 0.9307 max_p 0.5962 max_r 0.3444 max_f1 0.4366
#
# avg max cause: max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
# avg max pos: max_acc 0.7610 max_p 0.7049 max_r 0.4778 max_f1 0.5695
# avg max pair: max_acc 0.9307 max_p 0.5962 max_r 0.3444 max_f1 0.4366
#
# Fold 1 Epoch 11 val loss 2.5165
# emotion_predict: val acc 0.7463 p 0.6265 r 0.5778 f1 0.6012
# max_acc 0.7463 max_p 0.6265 max_r 0.5778 max_f1 0.6012
#
# cause_predict: val acc 0.7721 p 0.6795 r 0.5889 f1 0.6310
# max_acc 0.7610 max_p 0.6404 max_r 0.6333 max_f1 0.6369
#
# pair_predict: val acc 0.9038 p 0.4103 r 0.5333 f1 0.4638
# max_acc 0.9038 max_p 0.4103 max_r 0.5333 max_f1 0.4638
#
# avg max cause: max_acc 0.7721 max_p 0.6795 max_r 0.5889 max_f1 0.6310
# avg max pos: max_acc 0.7463 max_p 0.6265 max_r 0.5778 max_f1 0.6012
# avg max pair: max_acc 0.9038 max_p 0.4103 max_r 0.5333 max_f1 0.4638
#
# Fold 1 Epoch 12 val loss 2.4464
# emotion_predict: val acc 0.8162 p 0.7941 r 0.6000 f1 0.6835
# max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
#
# cause_predict: val acc 0.7610 p 0.6923 r 0.5000 f1 0.5806
# max_acc 0.7610 max_p 0.6404 max_r 0.6333 max_f1 0.6369
#
# pair_predict: val acc 0.9341 p 0.6250 r 0.3889 f1 0.4795
# max_acc 0.9341 max_p 0.6250 max_r 0.3889 max_f1 0.4795
#
# avg max cause: max_acc 0.7610 max_p 0.6923 max_r 0.5000 max_f1 0.5806
# avg max pos: max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
# avg max pair: max_acc 0.9341 max_p 0.6250 max_r 0.3889 max_f1 0.4795
#
# Fold 1 Epoch 13 val loss 2.4841
# emotion_predict: val acc 0.7757 p 0.6593 r 0.6667 f1 0.6630
# max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
#
# cause_predict: val acc 0.7647 p 0.6477 r 0.6333 f1 0.6404
# max_acc 0.7647 max_p 0.6477 max_r 0.6333 max_f1 0.6404
#
# pair_predict: val acc 0.9090 p 0.4359 r 0.5667 f1 0.4928
# max_acc 0.9090 max_p 0.4359 max_r 0.5667 max_f1 0.4928
#
# avg max cause: max_acc 0.7647 max_p 0.6477 max_r 0.6333 max_f1 0.6404
# avg max pos: max_acc 0.7757 max_p 0.6593 max_r 0.6667 max_f1 0.6630
# avg max pair: max_acc 0.9090 max_p 0.4359 max_r 0.5667 max_f1 0.4928
#
# Fold 1 Epoch 14 val loss 2.4537
# emotion_predict: val acc 0.7978 p 0.7612 r 0.5667 f1 0.6497
# max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
#
# cause_predict: val acc 0.7794 p 0.7586 r 0.4889 f1 0.5946
# max_acc 0.7647 max_p 0.6477 max_r 0.6333 max_f1 0.6404
#
# pair_predict: val acc 0.9298 p 0.5634 r 0.4444 f1 0.4969
# max_acc 0.9298 max_p 0.5634 max_r 0.4444 max_f1 0.4969
#
# avg max cause: max_acc 0.7794 max_p 0.7586 max_r 0.4889 max_f1 0.5946
# avg max pos: max_acc 0.7978 max_p 0.7612 max_r 0.5667 max_f1 0.6497
# avg max pair: max_acc 0.9298 max_p 0.5634 max_r 0.4444 max_f1 0.4969
#
# Fold 1 Epoch 15 val loss 2.5036
# emotion_predict: val acc 0.7904 p 0.6988 r 0.6444 f1 0.6705
# max_acc 0.8162 max_p 0.7941 max_r 0.6000 max_f1 0.6835
#
# cause_predict: val acc 0.7647 p 0.6757 r 0.5556 f1 0.6098
# max_acc 0.7647 max_p 0.6477 max_r 0.6333 max_f1 0.6404
#
# pair_predict: val acc 0.9064 p 0.4211 r 0.5333 f1 0.4706
# max_acc 0.9298 max_p 0.5634 max_r 0.4444 max_f1 0.4969
#
# avg max cause: max_acc 0.7794 max_p 0.7586 max_r 0.4889 max_f1 0.5946
# avg max pos: max_acc 0.7978 max_p 0.7612 max_r 0.5667 max_f1 0.6497
# avg max pair: max_acc 0.9298 max_p 0.5634 max_r 0.4444 max_f1 0.4969
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.59459459]]
# average : acc 0.7794 p 0.7586 r 0.4889 f1 0.5946
#
# emotion_predict: val f1 in 1 fold: [[0.64968153]]
# average : acc 0.7978 p 0.7612 r 0.5667 f1 0.6497
#
# pair_predict: val f1 in 1 fold: [[0.49689441]]
# average : acc 0.9298 p 0.5634 r 0.4444 f1 0.4969

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7663
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.5260
# emotion_predict: val acc 0.7279 p 0.6379 r 0.4111 f1 0.5000
# max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
#
# cause_predict: val acc 0.7206 p 0.6094 r 0.4333 f1 0.5065
# max_acc 0.7206 max_p 0.6094 max_r 0.4333 max_f1 0.5065
#
# pair_predict: val acc 0.9038 p 0.3820 r 0.3778 f1 0.3799
# max_acc 0.9038 max_p 0.3820 max_r 0.3778 max_f1 0.3799
#
# avg max cause: max_acc 0.7206 max_p 0.6094 max_r 0.4333 max_f1 0.5065
# avg max pos: max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
# avg max pair: max_acc 0.9038 max_p 0.3820 max_r 0.3778 max_f1 0.3799
#
# Fold 1 Epoch 3 val loss 2.5224
# emotion_predict: val acc 0.6434 p 0.4660 r 0.5333 f1 0.4974
# max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
#
# cause_predict: val acc 0.7426 p 0.6000 r 0.6667 f1 0.6316
# max_acc 0.7426 max_p 0.6000 max_r 0.6667 max_f1 0.6316
#
# pair_predict: val acc 0.7712 p 0.2138 r 0.7222 f1 0.3299
# max_acc 0.9038 max_p 0.3820 max_r 0.3778 max_f1 0.3799
#
# avg max cause: max_acc 0.7206 max_p 0.6094 max_r 0.4333 max_f1 0.5065
# avg max pos: max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
# avg max pair: max_acc 0.9038 max_p 0.3820 max_r 0.3778 max_f1 0.3799
#
# Fold 1 Epoch 4 val loss 2.3337
# emotion_predict: val acc 0.7353 p 0.7647 r 0.2889 f1 0.4194
# max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
#
# cause_predict: val acc 0.7721 p 0.7917 r 0.4222 f1 0.5507
# max_acc 0.7426 max_p 0.6000 max_r 0.6667 max_f1 0.6316
#
# pair_predict: val acc 0.9047 p 0.3889 r 0.3889 f1 0.3889
# max_acc 0.9047 max_p 0.3889 max_r 0.3889 max_f1 0.3889
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7353 max_p 0.7647 max_r 0.2889 max_f1 0.4194
# avg max pair: max_acc 0.9047 max_p 0.3889 max_r 0.3889 max_f1 0.3889
#
# Fold 1 Epoch 5 val loss 2.2394
# emotion_predict: val acc 0.7096 p 0.5632 r 0.5444 f1 0.5537
# max_acc 0.7096 max_p 0.5632 max_r 0.5444 max_f1 0.5537
#
# cause_predict: val acc 0.7610 p 0.6374 r 0.6444 f1 0.6409
# max_acc 0.7610 max_p 0.6374 max_r 0.6444 max_f1 0.6409
#
# pair_predict: val acc 0.8666 p 0.3140 r 0.6000 f1 0.4122
# max_acc 0.8666 max_p 0.3140 max_r 0.6000 max_f1 0.4122
#
# avg max cause: max_acc 0.7610 max_p 0.6374 max_r 0.6444 max_f1 0.6409
# avg max pos: max_acc 0.7096 max_p 0.5632 max_r 0.5444 max_f1 0.5537
# avg max pair: max_acc 0.8666 max_p 0.3140 max_r 0.6000 max_f1 0.4122
#
# Fold 1 Epoch 6 val loss 2.1382
# emotion_predict: val acc 0.7610 p 0.6984 r 0.4889 f1 0.5752
# max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
#
# cause_predict: val acc 0.7721 p 0.7333 r 0.4889 f1 0.5867
# max_acc 0.7610 max_p 0.6374 max_r 0.6444 max_f1 0.6409
#
# pair_predict: val acc 0.9073 p 0.4190 r 0.4889 f1 0.4513
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 7 val loss 2.0714
# emotion_predict: val acc 0.7757 p 0.7231 r 0.5222 f1 0.6065
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# cause_predict: val acc 0.7868 p 0.7424 r 0.5444 f1 0.6282
# max_acc 0.7610 max_p 0.6374 max_r 0.6444 max_f1 0.6409
#
# pair_predict: val acc 0.8778 p 0.3376 r 0.5889 f1 0.4291
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 8 val loss 2.0721
# emotion_predict: val acc 0.7757 p 0.6883 r 0.5889 f1 0.6347
# max_acc 0.7757 max_p 0.6883 max_r 0.5889 max_f1 0.6347
#
# cause_predict: val acc 0.7831 p 0.7013 r 0.6000 f1 0.6467
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8865 p 0.3546 r 0.5556 f1 0.4329
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 9 val loss 2.1225
# emotion_predict: val acc 0.7831 p 0.7067 r 0.5889 f1 0.6424
# max_acc 0.7831 max_p 0.7067 max_r 0.5889 max_f1 0.6424
#
# cause_predict: val acc 0.7684 p 0.7015 r 0.5222 f1 0.5987
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8813 p 0.3484 r 0.6000 f1 0.4408
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 10 val loss 2.2195
# emotion_predict: val acc 0.7794 p 0.6744 r 0.6444 f1 0.6591
# max_acc 0.7794 max_p 0.6744 max_r 0.6444 max_f1 0.6591
#
# cause_predict: val acc 0.7868 p 0.7353 r 0.5556 f1 0.6329
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8882 p 0.3636 r 0.5778 f1 0.4464
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 11 val loss 2.1917
# emotion_predict: val acc 0.7941 p 0.7179 r 0.6222 f1 0.6667
# max_acc 0.7941 max_p 0.7179 max_r 0.6222 max_f1 0.6667
#
# cause_predict: val acc 0.7647 p 0.6667 r 0.5778 f1 0.6190
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8744 p 0.3313 r 0.6000 f1 0.4269
# max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7610 max_p 0.6984 max_r 0.4889 max_f1 0.5752
# avg max pair: max_acc 0.9073 max_p 0.4190 max_r 0.4889 max_f1 0.4513
#
# Fold 1 Epoch 12 val loss 2.1841
# emotion_predict: val acc 0.7941 p 0.7237 r 0.6111 f1 0.6627
# max_acc 0.7941 max_p 0.7179 max_r 0.6222 max_f1 0.6667
#
# cause_predict: val acc 0.7684 p 0.6957 r 0.5333 f1 0.6038
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.9029 p 0.4141 r 0.5889 f1 0.4862
# max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# avg max cause: max_acc 0.7684 max_p 0.6957 max_r 0.5333 max_f1 0.6038
# avg max pos: max_acc 0.7941 max_p 0.7237 max_r 0.6111 max_f1 0.6627
# avg max pair: max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# Fold 1 Epoch 13 val loss 2.2636
# emotion_predict: val acc 0.7831 p 0.6867 r 0.6333 f1 0.6590
# max_acc 0.7941 max_p 0.7179 max_r 0.6222 max_f1 0.6667
#
# cause_predict: val acc 0.7610 p 0.6471 r 0.6111 f1 0.6286
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8553 p 0.2963 r 0.6222 f1 0.4014
# max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# avg max cause: max_acc 0.7684 max_p 0.6957 max_r 0.5333 max_f1 0.6038
# avg max pos: max_acc 0.7941 max_p 0.7237 max_r 0.6111 max_f1 0.6627
# avg max pair: max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# Fold 1 Epoch 14 val loss 2.2849
# emotion_predict: val acc 0.8088 p 0.7568 r 0.6222 f1 0.6829
# max_acc 0.8088 max_p 0.7568 max_r 0.6222 max_f1 0.6829
#
# cause_predict: val acc 0.7353 p 0.6364 r 0.4667 f1 0.5385
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.9081 p 0.4273 r 0.5222 f1 0.4700
# max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# avg max cause: max_acc 0.7684 max_p 0.6957 max_r 0.5333 max_f1 0.6038
# avg max pos: max_acc 0.7941 max_p 0.7237 max_r 0.6111 max_f1 0.6627
# avg max pair: max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# Fold 1 Epoch 15 val loss 2.3935
# emotion_predict: val acc 0.7978 p 0.7059 r 0.6667 f1 0.6857
# max_acc 0.7978 max_p 0.7059 max_r 0.6667 max_f1 0.6857
#
# cause_predict: val acc 0.7757 p 0.6883 r 0.5889 f1 0.6347
# max_acc 0.7831 max_p 0.7013 max_r 0.6000 max_f1 0.6467
#
# pair_predict: val acc 0.8943 p 0.3889 r 0.6222 f1 0.4786
# max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# avg max cause: max_acc 0.7684 max_p 0.6957 max_r 0.5333 max_f1 0.6038
# avg max pos: max_acc 0.7941 max_p 0.7237 max_r 0.6111 max_f1 0.6627
# avg max pair: max_acc 0.9029 max_p 0.4141 max_r 0.5889 max_f1 0.4862
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.60377358]]
# average : acc 0.7684 p 0.6957 r 0.5333 f1 0.6038
#
# emotion_predict: val f1 in 1 fold: [[0.6626506]]
# average : acc 0.7941 p 0.7237 r 0.6111 f1 0.6627
#
# pair_predict: val f1 in 1 fold: [[0.48623853]]
# average : acc 0.9029 p 0.4141 r 0.5889 f1 0.4862

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.8388
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.6003
# emotion_predict: val acc 0.3309 p 0.3309 r 1.0000 f1 0.4972
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.7610 p 0.7778 r 0.3889 f1 0.5185
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.8397 p 0.2156 r 0.4000 f1 0.2802
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 3 val loss 3.8711
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 4 val loss 3.3492
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 5 val loss 3.2021
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 6 val loss 3.1029
# emotion_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.7022 p 0.9091 r 0.1111 f1 0.1980
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 7 val loss 3.0279
# emotion_predict: val acc 0.7132 p 0.7727 r 0.1889 f1 0.3036
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.7500 p 0.7619 r 0.3556 f1 0.4848
# max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 8 val loss 2.9994
# emotion_predict: val acc 0.6838 p 0.5208 r 0.5556 f1 0.5376
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7279 p 0.5851 r 0.6111 f1 0.5978
# max_acc 0.7279 max_p 0.5851 max_r 0.6111 max_f1 0.5978
#
# pair_predict: val acc 0.9255 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 9 val loss 2.9343
# emotion_predict: val acc 0.7316 p 0.7179 r 0.3111 f1 0.4341
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7463 p 0.7838 r 0.3222 f1 0.4567
# max_acc 0.7279 max_p 0.5851 max_r 0.6111 max_f1 0.5978
#
# pair_predict: val acc 0.9272 p 0.8000 r 0.0889 f1 0.1600
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 10 val loss 2.9469
# emotion_predict: val acc 0.7206 p 0.7692 r 0.2222 f1 0.3448
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7316 p 0.8148 r 0.2444 f1 0.3761
# max_acc 0.7279 max_p 0.5851 max_r 0.6111 max_f1 0.5978
#
# pair_predict: val acc 0.9255 p 0.6250 r 0.1111 f1 0.1887
# max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# avg max cause: max_acc 0.7610 max_p 0.7778 max_r 0.3889 max_f1 0.5185
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.8397 max_p 0.2156 max_r 0.4000 max_f1 0.2802
#
# Fold 1 Epoch 11 val loss 2.9185
# emotion_predict: val acc 0.7279 p 0.6143 r 0.4778 f1 0.5375
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7610 p 0.6623 r 0.5667 f1 0.6108
# max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
#
# pair_predict: val acc 0.9125 p 0.4267 r 0.3556 f1 0.3879
# max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# avg max cause: max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# Fold 1 Epoch 12 val loss 2.8782
# emotion_predict: val acc 0.7279 p 0.8077 r 0.2333 f1 0.3621
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7426 p 0.7941 r 0.3000 f1 0.4355
# max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
#
# pair_predict: val acc 0.9272 p 0.5937 r 0.2111 f1 0.3115
# max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# avg max cause: max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# Fold 1 Epoch 13 val loss 2.8353
# emotion_predict: val acc 0.7316 p 0.8148 r 0.2444 f1 0.3761
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7574 p 0.7857 r 0.3667 f1 0.5000
# max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
#
# pair_predict: val acc 0.9289 p 0.6176 r 0.2333 f1 0.3387
# max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# avg max cause: max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
# avg max pos: max_acc 0.7279 max_p 0.6143 max_r 0.4778 max_f1 0.5375
# avg max pair: max_acc 0.9125 max_p 0.4267 max_r 0.3556 max_f1 0.3879
#
# Fold 1 Epoch 14 val loss 2.8396
# emotion_predict: val acc 0.7353 p 0.6667 r 0.4000 f1 0.5000
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7574 p 0.6667 r 0.5333 f1 0.5926
# max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
#
# pair_predict: val acc 0.9229 p 0.5082 r 0.3444 f1 0.4106
# max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# avg max cause: max_acc 0.7574 max_p 0.6667 max_r 0.5333 max_f1 0.5926
# avg max pos: max_acc 0.7353 max_p 0.6667 max_r 0.4000 max_f1 0.5000
# avg max pair: max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# Fold 1 Epoch 15 val loss 2.8405
# emotion_predict: val acc 0.7169 p 0.5915 r 0.4667 f1 0.5217
# max_acc 0.6838 max_p 0.5208 max_r 0.5556 max_f1 0.5376
#
# cause_predict: val acc 0.7647 p 0.6667 r 0.5778 f1 0.6190
# max_acc 0.7647 max_p 0.6667 max_r 0.5778 max_f1 0.6190
#
# pair_predict: val acc 0.9107 p 0.4177 r 0.3667 f1 0.3905
# max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# avg max cause: max_acc 0.7574 max_p 0.6667 max_r 0.5333 max_f1 0.5926
# avg max pos: max_acc 0.7353 max_p 0.6667 max_r 0.4000 max_f1 0.5000
# avg max pair: max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.59259259]]
# average : acc 0.7574 p 0.6667 r 0.5333 f1 0.5926
#
# emotion_predict: val f1 in 1 fold: [[0.5]]
# average : acc 0.7353 p 0.6667 r 0.4000 f1 0.5000
#
# pair_predict: val f1 in 1 fold: [[0.41059603]]
# average : acc 0.9229 p 0.5082 r 0.3444 f1 0.4106

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 4.1090
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0925
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 3 val loss 3.0814
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6728 p 0.6000 r 0.0333 f1 0.0632
# max_acc 0.6728 max_p 0.6000 max_r 0.0333 max_f1 0.0632
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 4 val loss 2.9310
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6801 p 0.7143 r 0.0556 f1 0.1031
# max_acc 0.6801 max_p 0.7143 max_r 0.0556 max_f1 0.1031
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 5 val loss 2.7822
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# cause_predict: val acc 0.6912 p 0.8000 r 0.0889 f1 0.1600
# max_acc 0.6912 max_p 0.8000 max_r 0.0889 max_f1 0.1600
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 6 val loss 2.6306
# emotion_predict: val acc 0.7426 p 0.7174 r 0.3667 f1 0.4853
# max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
#
# cause_predict: val acc 0.7500 p 0.6833 r 0.4556 f1 0.5467
# max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 7 val loss 2.6415
# emotion_predict: val acc 0.6875 p 0.8571 r 0.0667 f1 0.1237
# max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
#
# cause_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.7500 max_p 0.6833 max_r 0.4556 max_f1 0.5467
#
# pair_predict: val acc 0.9298 p 0.6957 r 0.1778 f1 0.2832
# max_acc 0.9298 max_p 0.6957 max_r 0.1778 max_f1 0.2832
#
# avg max cause: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pos: max_acc 0.6875 max_p 0.8571 max_r 0.0667 max_f1 0.1237
# avg max pair: max_acc 0.9298 max_p 0.6957 max_r 0.1778 max_f1 0.2832
#
# Fold 1 Epoch 8 val loss 2.6219
# emotion_predict: val acc 0.7243 p 0.6087 r 0.4667 f1 0.5283
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7574 p 0.6935 r 0.4778 f1 0.5658
# max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
#
# pair_predict: val acc 0.6967 p 0.1782 r 0.8000 f1 0.2915
# max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# avg max cause: max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
# avg max pos: max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
# avg max pair: max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# Fold 1 Epoch 9 val loss 2.6174
# emotion_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
#
# pair_predict: val acc 0.9272 p 0.6071 r 0.1889 f1 0.2881
# max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# avg max cause: max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
# avg max pos: max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
# avg max pair: max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# Fold 1 Epoch 10 val loss 2.6169
# emotion_predict: val acc 0.6985 p 0.8333 r 0.1111 f1 0.1961
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.6985 p 0.8333 r 0.1111 f1 0.1961
# max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
#
# pair_predict: val acc 0.9298 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# avg max cause: max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
# avg max pos: max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
# avg max pair: max_acc 0.6967 max_p 0.1782 max_r 0.8000 max_f1 0.2915
#
# Fold 1 Epoch 11 val loss 2.5268
# emotion_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7132 p 0.8333 r 0.1667 f1 0.2778
# max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
#
# pair_predict: val acc 0.9350 p 0.7778 r 0.2333 f1 0.3590
# max_acc 0.9350 max_p 0.7778 max_r 0.2333 max_f1 0.3590
#
# avg max cause: max_acc 0.7132 max_p 0.8333 max_r 0.1667 max_f1 0.2778
# avg max pos: max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
# avg max pair: max_acc 0.9350 max_p 0.7778 max_r 0.2333 max_f1 0.3590
#
# Fold 1 Epoch 12 val loss 2.5278
# emotion_predict: val acc 0.7169 p 0.7826 r 0.2000 f1 0.3186
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7721 p 0.8182 r 0.4000 f1 0.5373
# max_acc 0.7574 max_p 0.6935 max_r 0.4778 max_f1 0.5658
#
# pair_predict: val acc 0.8969 p 0.3441 r 0.3556 f1 0.3497
# max_acc 0.9350 max_p 0.7778 max_r 0.2333 max_f1 0.3590
#
# avg max cause: max_acc 0.7132 max_p 0.8333 max_r 0.1667 max_f1 0.2778
# avg max pos: max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
# avg max pair: max_acc 0.9350 max_p 0.7778 max_r 0.2333 max_f1 0.3590
#
# Fold 1 Epoch 13 val loss 2.5589
# emotion_predict: val acc 0.7279 p 0.6379 r 0.4111 f1 0.5000
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7243 p 0.5758 r 0.6333 f1 0.6032
# max_acc 0.7243 max_p 0.5758 max_r 0.6333 max_f1 0.6032
#
# pair_predict: val acc 0.8839 p 0.3308 r 0.4778 f1 0.3909
# max_acc 0.8839 max_p 0.3308 max_r 0.4778 max_f1 0.3909
#
# avg max cause: max_acc 0.7243 max_p 0.5758 max_r 0.6333 max_f1 0.6032
# avg max pos: max_acc 0.7279 max_p 0.6379 max_r 0.4111 max_f1 0.5000
# avg max pair: max_acc 0.8839 max_p 0.3308 max_r 0.4778 max_f1 0.3909
#
# Fold 1 Epoch 14 val loss 2.5015
# emotion_predict: val acc 0.7243 p 0.6027 r 0.4889 f1 0.5399
# max_acc 0.7243 max_p 0.6027 max_r 0.4889 max_f1 0.5399
#
# cause_predict: val acc 0.7206 p 0.5700 r 0.6333 f1 0.6000
# max_acc 0.7243 max_p 0.5758 max_r 0.6333 max_f1 0.6032
#
# pair_predict: val acc 0.8700 p 0.3101 r 0.5444 f1 0.3952
# max_acc 0.8700 max_p 0.3101 max_r 0.5444 max_f1 0.3952
#
# avg max cause: max_acc 0.7206 max_p 0.5700 max_r 0.6333 max_f1 0.6000
# avg max pos: max_acc 0.7243 max_p 0.6027 max_r 0.4889 max_f1 0.5399
# avg max pair: max_acc 0.8700 max_p 0.3101 max_r 0.5444 max_f1 0.3952
#
# Fold 1 Epoch 15 val loss 2.4115
# emotion_predict: val acc 0.7353 p 0.6452 r 0.4444 f1 0.5263
# max_acc 0.7243 max_p 0.6027 max_r 0.4889 max_f1 0.5399
#
# cause_predict: val acc 0.7574 p 0.6429 r 0.6000 f1 0.6207
# max_acc 0.7574 max_p 0.6429 max_r 0.6000 max_f1 0.6207
#
# pair_predict: val acc 0.8873 p 0.3333 r 0.4444 f1 0.3810
# max_acc 0.8700 max_p 0.3101 max_r 0.5444 max_f1 0.3952
#
# avg max cause: max_acc 0.7206 max_p 0.5700 max_r 0.6333 max_f1 0.6000
# avg max pos: max_acc 0.7243 max_p 0.6027 max_r 0.4889 max_f1 0.5399
# avg max pair: max_acc 0.8700 max_p 0.3101 max_r 0.5444 max_f1 0.3952
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.6]]
# average : acc 0.7206 p 0.5700 r 0.6333 f1 0.6000
#
# emotion_predict: val f1 in 1 fold: [[0.5398773]]
# average : acc 0.7243 p 0.6027 r 0.4889 f1 0.5399
#
# pair_predict: val f1 in 1 fold: [[0.39516129]]
# average : acc 0.8700 p 0.3101 r 0.5444 f1 0.3952

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.9648
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6066 p 0.3509 r 0.2222 f1 0.2721
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.4679
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3565
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.3410
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.2563
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.2056
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.1872
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.1578
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0950
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0279
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.9863
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# cause_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 0.6667 max_r 0.0222 max_f1 0.0430
# avg max pos: max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 12 val loss 2.9782
# emotion_predict: val acc 0.6875 p 0.8571 r 0.0667 f1 0.1237
# max_acc 0.6875 max_p 0.8571 max_r 0.0667 max_f1 0.1237
#
# cause_predict: val acc 0.6949 p 0.8889 r 0.0889 f1 0.1616
# max_acc 0.6066 max_p 0.3509 max_r 0.2222 max_f1 0.2721
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6728 max_p 0.6667 max_r 0.0222 max_f1 0.0430
# avg max pos: max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 13 val loss 2.9647
# emotion_predict: val acc 0.7022 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
#
# cause_predict: val acc 0.7243 p 0.8261 r 0.2111 f1 0.3363
# max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
#
# pair_predict: val acc 0.9246 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7022 max_p 0.8462 max_r 0.1222 max_f1 0.2136
# avg max pair: max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# Fold 1 Epoch 14 val loss 2.9357
# emotion_predict: val acc 0.7390 p 0.7209 r 0.3444 f1 0.4662
# max_acc 0.7390 max_p 0.7209 max_r 0.3444 max_f1 0.4662
#
# cause_predict: val acc 0.7390 p 0.6508 r 0.4556 f1 0.5359
# max_acc 0.7390 max_p 0.6508 max_r 0.4556 max_f1 0.5359
#
# pair_predict: val acc 0.9333 p 0.8095 r 0.1889 f1 0.3063
# max_acc 0.9333 max_p 0.8095 max_r 0.1889 max_f1 0.3063
#
# avg max cause: max_acc 0.7390 max_p 0.6508 max_r 0.4556 max_f1 0.5359
# avg max pos: max_acc 0.7390 max_p 0.7209 max_r 0.3444 max_f1 0.4662
# avg max pair: max_acc 0.9333 max_p 0.8095 max_r 0.1889 max_f1 0.3063
#
# Fold 1 Epoch 15 val loss 2.9778
# emotion_predict: val acc 0.7059 p 0.5595 r 0.5222 f1 0.5402
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# cause_predict: val acc 0.6985 p 0.5417 r 0.5778 f1 0.5591
# max_acc 0.6985 max_p 0.5417 max_r 0.5778 max_f1 0.5591
#
# pair_predict: val acc 0.9133 p 0.4286 r 0.3333 f1 0.3750
# max_acc 0.9133 max_p 0.4286 max_r 0.3333 max_f1 0.3750
#
# avg max cause: max_acc 0.6985 max_p 0.5417 max_r 0.5778 max_f1 0.5591
# avg max pos: max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
# avg max pair: max_acc 0.9133 max_p 0.4286 max_r 0.3333 max_f1 0.3750
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.55913978]]
# average : acc 0.6985 p 0.5417 r 0.5778 f1 0.5591
#
# emotion_predict: val f1 in 1 fold: [[0.54022988]]
# average : acc 0.7059 p 0.5595 r 0.5222 f1 0.5402
#
# pair_predict: val f1 in 1 fold: [[0.375]]
# average : acc 0.9133 p 0.4286 r 0.3333 f1 0.3750

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9592
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8907
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.8132
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7540
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.7047
# emotion_predict: val acc 0.6618 p 0.3750 r 0.0333 f1 0.0612
# max_acc 0.6618 max_p 0.3750 max_r 0.0333 max_f1 0.0612
#
# cause_predict: val acc 0.7279 p 0.7857 r 0.2444 f1 0.3729
# max_acc 0.7279 max_p 0.7857 max_r 0.2444 max_f1 0.3729
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.6055
# emotion_predict: val acc 0.7243 p 0.6923 r 0.3000 f1 0.4186
# max_acc 0.7243 max_p 0.6923 max_r 0.3000 max_f1 0.4186
#
# cause_predict: val acc 0.7463 p 0.7234 r 0.3778 f1 0.4964
# max_acc 0.7463 max_p 0.7234 max_r 0.3778 max_f1 0.4964
#
# pair_predict: val acc 0.9289 p 0.8333 r 0.1111 f1 0.1961
# max_acc 0.9289 max_p 0.8333 max_r 0.1111 max_f1 0.1961
#
# avg max cause: max_acc 0.7463 max_p 0.7234 max_r 0.3778 max_f1 0.4964
# avg max pos: max_acc 0.7243 max_p 0.6923 max_r 0.3000 max_f1 0.4186
# avg max pair: max_acc 0.9289 max_p 0.8333 max_r 0.1111 max_f1 0.1961
#
# Fold 1 Epoch 7 val loss 2.5382
# emotion_predict: val acc 0.7096 p 0.7200 r 0.2000 f1 0.3130
# max_acc 0.7243 max_p 0.6923 max_r 0.3000 max_f1 0.4186
#
# cause_predict: val acc 0.7353 p 0.8214 r 0.2556 f1 0.3898
# max_acc 0.7463 max_p 0.7234 max_r 0.3778 max_f1 0.4964
#
# pair_predict: val acc 0.9298 p 0.8462 r 0.1222 f1 0.2136
# max_acc 0.9298 max_p 0.8462 max_r 0.1222 max_f1 0.2136
#
# avg max cause: max_acc 0.7353 max_p 0.8214 max_r 0.2556 max_f1 0.3898
# avg max pos: max_acc 0.7096 max_p 0.7200 max_r 0.2000 max_f1 0.3130
# avg max pair: max_acc 0.9298 max_p 0.8462 max_r 0.1222 max_f1 0.2136
#
# Fold 1 Epoch 8 val loss 2.4499
# emotion_predict: val acc 0.7537 p 0.7347 r 0.4000 f1 0.5180
# max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
#
# cause_predict: val acc 0.7537 p 0.7091 r 0.4333 f1 0.5379
# max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
#
# pair_predict: val acc 0.9237 p 0.5172 r 0.3333 f1 0.4054
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 9 val loss 2.4694
# emotion_predict: val acc 0.7022 p 0.5570 r 0.4889 f1 0.5207
# max_acc 0.7022 max_p 0.5570 max_r 0.4889 max_f1 0.5207
#
# cause_predict: val acc 0.7426 p 0.6064 r 0.6333 f1 0.6196
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8267 p 0.2356 r 0.5444 f1 0.3289
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 10 val loss 2.3736
# emotion_predict: val acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
# max_acc 0.7022 max_p 0.5570 max_r 0.4889 max_f1 0.5207
#
# cause_predict: val acc 0.7610 p 0.6923 r 0.5000 f1 0.5806
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8865 p 0.3333 r 0.4556 f1 0.3850
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 11 val loss 2.4258
# emotion_predict: val acc 0.7390 p 0.7436 r 0.3222 f1 0.4496
# max_acc 0.7022 max_p 0.5570 max_r 0.4889 max_f1 0.5207
#
# cause_predict: val acc 0.7574 p 0.7609 r 0.3889 f1 0.5147
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.9064 p 0.3953 r 0.3778 f1 0.3864
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 12 val loss 2.3439
# emotion_predict: val acc 0.7537 p 0.7018 r 0.4444 f1 0.5442
# max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
#
# cause_predict: val acc 0.7537 p 0.6949 r 0.4556 f1 0.5503
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8813 p 0.3285 r 0.5000 f1 0.3965
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 13 val loss 2.3479
# emotion_predict: val acc 0.7096 p 0.5696 r 0.5000 f1 0.5325
# max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
#
# cause_predict: val acc 0.7537 p 0.6386 r 0.5889 f1 0.6127
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8024 p 0.2305 r 0.6556 f1 0.3410
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 14 val loss 2.3074
# emotion_predict: val acc 0.7059 p 0.5595 r 0.5222 f1 0.5402
# max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
#
# cause_predict: val acc 0.7463 p 0.6235 r 0.5889 f1 0.6057
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8206 p 0.2468 r 0.6333 f1 0.3551
# max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# avg max cause: max_acc 0.7537 max_p 0.7091 max_r 0.4333 max_f1 0.5379
# avg max pos: max_acc 0.7537 max_p 0.7347 max_r 0.4000 max_f1 0.5180
# avg max pair: max_acc 0.9237 max_p 0.5172 max_r 0.3333 max_f1 0.4054
#
# Fold 1 Epoch 15 val loss 2.2231
# emotion_predict: val acc 0.7316 p 0.6269 r 0.4667 f1 0.5350
# max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
#
# cause_predict: val acc 0.7537 p 0.6575 r 0.5333 f1 0.5890
# max_acc 0.7426 max_p 0.6064 max_r 0.6333 max_f1 0.6196
#
# pair_predict: val acc 0.8925 p 0.3672 r 0.5222 f1 0.4312
# max_acc 0.8925 max_p 0.3672 max_r 0.5222 max_f1 0.4312
#
# avg max cause: max_acc 0.7537 max_p 0.6575 max_r 0.5333 max_f1 0.5890
# avg max pos: max_acc 0.7316 max_p 0.6269 max_r 0.4667 max_f1 0.5350
# avg max pair: max_acc 0.8925 max_p 0.3672 max_r 0.5222 max_f1 0.4312
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58895705]]
# average : acc 0.7537 p 0.6575 r 0.5333 f1 0.5890
#
# emotion_predict: val f1 in 1 fold: [[0.53503185]]
# average : acc 0.7316 p 0.6269 r 0.4667 f1 0.5350
#
# pair_predict: val f1 in 1 fold: [[0.43119266]]
# average : acc 0.8925 p 0.3672 r 0.5222 f1 0.4312
