# %%
# connect to google colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# base path
DATA_PATH = './drive/MyDrive/fyp-code/codes/data/ecpe/'
MODEL_PATH = './drive/MyDrive/fyp-code/codes/model/ecpe/EC/long_summarized/'

# %%
############################################ IMPORT ##########################################################
import sys, os
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# call the zip folder with all the self defined modules
base_folder = '/content/drive/MyDrive/fyp-code/codes'

training_path = os.path.join(base_folder, "utils_ecpe.zip") 
# !unzip $training_path

from funcs import *
from prepare_data import *
# Out:
# Archive:  /content/drive/MyDrive/fyp-code/codes/utils_ecpe.zip
#   inflating: funcs.py
#   inflating: prepare_data.py

# %%
############################################ FLAGS ############################################################
# file names of the data files
LOOKUP = 'ecpe_long_summarized_max_5_clauses_annotated.csv'
DATA = 'long_summarized'
TRAIN_DATA = 'ecpe_long_summarized_max_5_clauses_annotated_train'
VAL_DATA = 'ecpe_long_summarized_max_5_clauses_annotated_val'

# fixed parameters
train_file_path = DATA_PATH + LOOKUP                                # clause keyword file
w2v_file = DATA_PATH+'w2v_200.txt'                                  # embedding file
embedding_dim = 200                                                 # dimension of word embedding
embedding_dim_pos = 30                                              # dimension of position embedding
max_sen_len = 30                                                    # max number of tokens per sentence
max_doc_len = 41                                                    # max number of tokens per document
n_class = 2                                                         # number of distinct class
training_epochs = 20                                                # number of train epochs
keep_prob1 = 0.8                                                    # word embedding training dropout keep prob
keep_prob2 = 1.0                                                    # softmax layer dropout keep prob
keep_prob3 = 1.0                                                    # softmax layer dropout keep prob
l2_reg = 0.00010                                                    # l2 regularization
cause = 1.0                                                         # lambda1
pos = 1.0                                                           # lambda2
pair = 2.5                                                          # lambda3

# hyperparameters considered for tuning (will be tuned later when the class is called)
n_hidden = None                                                     # number of hidden unit
batch_size = None                                                   # number of example per batch
learning_rate = None                                                # learning rate
diminish_factor = None                                              # give less weight to -ve examples

# %%
############################################ MODEL ############################################################
class E2E_PextE(nn.Module):
    def __init__(self, embedding_dim, embedding_dim_pos, sen_len, doc_len, keep_prob1, keep_prob2, \
                 keep_prob3, n_hidden, n_class):
        super(E2E_PextE, self).__init__()
        self.embedding_dim = embedding_dim; self.embedding_dim_pos = embedding_dim_pos 
        self.sen_len = sen_len; self.doc_len = doc_len
        self.keep_prob1 = keep_prob1; self.keep_prob2 = keep_prob2
        self.n_hidden = n_hidden; self.n_class = n_class

        self.dropout1 = nn.Dropout(p = 1 - keep_prob1)
        self.dropout2 = nn.Dropout(p = 1 - keep_prob2)
        self.dropout3 = nn.Dropout(p = 1 - keep_prob3)
        self.relu = nn.ReLU()
        self.pos_linear = nn.Linear(2*n_hidden, n_class)
        self.cause_linear = nn.Linear(2*n_hidden, n_class)
        self.pair_linear1 = nn.Linear(4*n_hidden + embedding_dim_pos, n_hidden//2)
        self.pair_linear2 = nn.Linear(n_hidden//2, n_class)
        self.word_bilstm = nn.LSTM(embedding_dim, n_hidden, batch_first = True, bidirectional = True)
        self.cause_bilstm = nn.LSTM(2*n_hidden + n_class, n_hidden, batch_first = True, bidirectional = True)
        self.pos_bilstm = nn.LSTM(2*n_hidden, n_hidden, batch_first = True, bidirectional = True)
        self.attention = Attention(n_hidden, sen_len)

    def get_clause_embedding(self, x):
        '''
        input shape: [batch_size, doc_len, sen_len, embedding_dim]
        output shape: [batch_size, doc_len, 2 * n_hidden]
        '''
        x = x.reshape(-1, self.sen_len, self.embedding_dim)
        x = self.dropout1(x)
        # x is of shape (batch_size * max_doc_len, max_sen_len, embedding_dim)
        x, hidden_states = self.word_bilstm(x.float())
        # x is of shape (batch_size * max_doc_len, max_sen_len, 2 * n_hidden)
        s = self.attention(x).reshape(-1, self.doc_len, 2 * self.n_hidden)
        # s is of shape (batch_size, max_doc_len, 2 * n_hidden)
        return s

    def get_emotion_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.pos_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_pos = F.softmax(self.pos_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_pos = pred_pos.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_pos

    def get_cause_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden + n_class]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.cause_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_cause = F.softmax(self.cause_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_cause = pred_cause.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_cause

    def get_pair_prediction(self, x1, x2, distance):
        '''
        input(s) shape: [batch_size * doc_len, 2 * n_hidden], [batch_size * doc_len, 2 * n_hidden], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos] 
        output shape: [batch_size, doc_len * doc_len, n_class]
        '''        
        x = create_pairs(x1, x2)
        # x is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden)
        x_distance = torch.cat([x, distance.float()], -1)
        # x_distance is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        x_distance = x_distance.reshape(-1, 4 * self.n_hidden + self.embedding_dim_pos)
        x_distance = self.dropout3(x_distance)
        # x is of shape (batch_size * max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        pred_pair = F.softmax(self.pair_linear2(self.relu(self.pair_linear1(x_distance))), dim = -1)
        # pred_pair is of shape (batch_size * max_doc_len * max_doc_len, n_class)
        pred_pair = pred_pair.reshape(-1, self.doc_len * self.doc_len, self.n_class)
        # pred_pair is of shape (batch_size, max_doc_len * max_doc_len, n_class)
        return pred_pair

    def forward(self, x, distance):
        '''
        input(s) shape: [batch_size, doc_len, sen_len, embedding_dim], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos]
        output(s) shape: [batch_size, doc_len, n_class], [batch_size, doc_len, n_class], 
                         [batch_size, doc_len * doc_len, n_class]
        '''
        s = self.get_clause_embedding(x)
        x_pos, pred_pos = self.get_emotion_prediction(s)
        s_pred_pos = torch.cat([s, pred_pos], 2)
        x_cause, pred_cause = self.get_cause_prediction(s_pred_pos)
        pred_pair = self.get_pair_prediction(x_pos, x_cause, distance)
        return pred_pos, pred_cause, pred_pair

# %%
def load_data_pair(input_file, word_idx, max_doc_len = 75, max_sen_len = 45):
    print('load data_file: {}'.format(input_file))
    pair_id_all, y_position, y_cause, y_pair, x, sen_len, doc_len, distance = [], [], [], [], [], [], [], []
    n_cut = 0
    inputFile = open(input_file, 'r')
    while True:
        line = inputFile.readline()
        if line == '': break
        line = line.strip().split()
        doc_id = int(line[0])
        d_len = int(line[1])
        ######################################## doc_len_condition ########################################
        if d_len >= max_doc_len :
            for i in range(d_len+1) :
                line = inputFile.readline().strip().split(',')
            continue
        ######################################## doc_len_condition ########################################

        pairs = eval('[' + inputFile.readline().strip() + ']')
        pos_list, cause_list = zip(*pairs)
        pairs = [[pos_list[i], cause_list[i]] for i in range(len(pos_list))]
        pair_id_all.extend([doc_id*10000+p[0]*100+p[1] for p in pairs])
        y_position_tmp, y_cause_tmp, y_pair_tmp, sen_len_tmp, x_tmp, distance_tmp = \
        np.zeros((max_doc_len, 2)), np.zeros((max_doc_len, 2)), np.zeros((max_doc_len * max_doc_len, 2)), \
        np.zeros((max_doc_len, )), np.zeros((max_doc_len, max_sen_len)), np.zeros((max_doc_len * max_doc_len, ))

        for i in range(d_len):
            line = inputFile.readline().strip().split(',')
            words = line[-1]
            sen_len_tmp[i] = min(len(words.split()), max_sen_len)
            for j, word in enumerate(words.split()):
                word = word.lower()
                if j >= max_sen_len:
                    n_cut += 1
                    break
                elif word not in word_idx : x_tmp[i][j] = 24166
                else : x_tmp[i][j] = int(word_idx[word])

        for i in range(d_len):
            for j in range(d_len):
                # Check whether i is an emotion clause
                if i+1 in pos_list :
                    y_position_tmp[i][0] = 0; y_position_tmp[i][1] = 1
                else :
                    y_position_tmp[i][0] = 1; y_position_tmp[i][1] = 0
                # Check whether j is a cause clause
                if j+1 in cause_list :
                    y_cause_tmp[j][0] = 0; y_cause_tmp[j][1] = 1
                else :
                    y_cause_tmp[j][0] = 1; y_cause_tmp[j][1] = 0
                # Check whether i, j clauses are emotion cause pairs
                pair_id_curr = doc_id*10000+(i+1)*100+(j+1)
                if pair_id_curr in pair_id_all :
                    y_pair_tmp[i*max_doc_len+j][0] = 0; y_pair_tmp[i*max_doc_len+j][1] = 1
                else :
                    y_pair_tmp[i*max_doc_len+j][0] = 1; y_pair_tmp[i*max_doc_len+j][1] = 0
                # Find the distance between the clauses, and use the same embedding beyond 10 clauses
                distance_tmp[i*max_doc_len+j] = min(max(j-i+100, 90), 110)

        y_position.append(y_position_tmp)
        y_cause.append(y_cause_tmp)
        y_pair.append(y_pair_tmp)
        x.append(x_tmp)
        sen_len.append(sen_len_tmp)
        doc_len.append(d_len)
        distance.append(distance_tmp)

    y_position, y_cause, y_pair, x, sen_len, doc_len, distance = map(torch.tensor, \
    [y_position, y_cause, y_pair, x, sen_len, doc_len, distance])

    for var in ['y_position', 'y_cause', 'y_pair', 'x', 'sen_len', 'doc_len', 'distance']:
        print('{}.shape {}'.format( var, eval(var).shape ))
    print('n_cut {}'.format(n_cut))
    print('load data done!\n')
    return y_position, y_cause, y_pair, x, sen_len, doc_len, distance

# %%
############################################ TRAIN #####################################################
def train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, n_hidden, batch_size, learning_rate, diminish_factor):
    word_idx_rev, word_id_mapping, word_embedding, pos_embedding = load_w2v(
        embedding_dim, embedding_dim_pos, train_file_path, w2v_file)
    word_embedding = torch.from_numpy(word_embedding)
    # Train distance embeddings
    pos_embedding = torch.autograd.Variable(torch.from_numpy(pos_embedding))
    pos_embedding.requires_grad_(True)
    #torch.save(word_embedding, MODEL_PATH+DATA+'_'+'word_embedding'+'.pth')
    torch.save(word_embedding, f'{MODEL_PATH}{DATA}_word_embedding_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    #torch.save(word_id_mapping, MODEL_PATH+DATA+'_'+'word_id_mapping'+'.pth')
    torch.save(word_id_mapping, f'{MODEL_PATH}{DATA}_word_id_mapping_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    acc_cause_list, p_cause_list, r_cause_list, f1_cause_list = [], [], [], []
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list = [], [], [], []
    acc_pair_list, p_pair_list, r_pair_list, f1_pair_list = [], [], [], []
    #################################### LOOP OVER FOLDS ####################################
    # do 5 fold cross validation
    for fold in range(1, 2):
        print('############# fold {} begin ###############'.format(fold))
        ############################# RE-INITIALIZE MODEL PARAMETERS #############################
        for layer in Model.parameters():
            nn.init.uniform_(layer.data, -0.10, 0.10)
        #################################### TRAIN/TEST DATA ####################################
        train_file_name = '{}_{}.txt'.format(TRAIN_DATA,fold)
        val_file_name = '{}_{}.txt'.format(VAL_DATA,fold)
        tr_y_position, tr_y_cause, tr_y_pair, tr_x, tr_sen_len, tr_doc_len, tr_distance = load_data_pair(
                        DATA_PATH+train_file_name, word_id_mapping, max_doc_len, max_sen_len)
        val_y_position, val_y_cause, val_y_pair, val_x, val_sen_len, val_doc_len, val_distance = \
            load_data_pair(DATA_PATH+val_file_name, word_id_mapping, max_doc_len, max_sen_len)
        max_f1_cause, max_f1_pos, max_f1_pair, max_f1_avg = [-1.] * 4
        #################################### LOOP OVER EPOCHS ####################################
        for epoch in range(1, training_epochs + 1):
            step = 1
            #################################### GET BATCH DATA ####################################
            for train, _ in get_batch_data_pair(
                tr_x, tr_sen_len, tr_doc_len, tr_y_position, tr_y_cause, tr_y_pair, tr_distance, batch_size):
                tr_x_batch, tr_sen_len_batch, tr_doc_len_batch, tr_true_y_pos, tr_true_y_cause, \
                tr_true_y_pair, tr_distance_batch = train
                Model.train()
                tr_pred_y_pos, tr_pred_y_cause, tr_pred_y_pair = Model(embedding_lookup(word_embedding, \
                tr_x_batch), embedding_lookup(pos_embedding, tr_distance_batch))
                ############################## LOSS FUNCTION AND OPTIMIZATION ##############################
                loss = pos_cause_criterion(tr_true_y_pos, tr_pred_y_pos, tr_doc_len_batch)*pos + \
                pos_cause_criterion(tr_true_y_cause, tr_pred_y_cause, tr_doc_len_batch)*cause + \
                pair_criterion(tr_true_y_pair, tr_pred_y_pair, tr_doc_len_batch)*pair
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                #################################### PRINT AFTER EPOCHS ####################################
                if step % 25 == 0:
                    # print(Model.pair_linear.weight.shape); print(Model.pair_linear.weight.grad)
                    print('Fold {}, Epoch {}, step {}: train loss {:.4f} '.format(fold, epoch, step, loss))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_pos, tr_true_y_pos, tr_doc_len_batch)
                    print('emotion_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_cause, tr_true_y_cause, tr_doc_len_batch)
                    print('cause_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_pair(tr_pred_y_pair, tr_true_y_pair, tr_doc_len_batch)
                    print('pair_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1)) 
                step += 1
            #################################### TEST ON 1 FOLD ####################################
            with torch.no_grad():
                Model.eval()
                val_pred_y_pos, val_pred_y_cause, val_pred_y_pair = Model(embedding_lookup(word_embedding, \
                val_x), embedding_lookup(pos_embedding, val_distance))

                loss = pos_cause_criterion(val_y_position, val_pred_y_pos, val_doc_len)*pos + \
                pos_cause_criterion(val_y_cause, val_pred_y_cause, val_doc_len)*cause + \
                pair_criterion(val_y_pair, val_pred_y_pair, val_doc_len)*pair
                print('Fold {} Epoch {} val loss {:.4f}'.format(fold, epoch, loss))
                acc, p, r, f1 = acc_prf_aux(val_pred_y_pos, val_y_position, val_doc_len)
                result_avg_pos = [acc, p, r, f1]
                if f1 > max_f1_pos:
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos = acc, p, r, f1
                print('emotion_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos))

                acc, p, r, f1 = acc_prf_aux(val_pred_y_cause, val_y_cause, val_doc_len)
                result_avg_cause = [acc, p, r, f1]
                if f1 > max_f1_cause:
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause = acc, p, r, f1
                print('cause_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause))

                acc, p, r, f1 = acc_prf_pair(val_pred_y_pair, val_y_pair, val_doc_len)
                result_avg_pair = [acc, p, r, f1]
                if f1 > max_f1_pair:
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair = acc, p, r, f1
                print('pair_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair))

            #################################### STORE BETTER PAIR F1 ####################################
            if result_avg_pair[-1] > max_f1_avg:
                #torch.save(pos_embedding, MODEL_PATH+DATA+"_"+"pos_embedding_fold_{}.pth".format(fold))
                torch.save(pos_embedding, f'{MODEL_PATH}{DATA}_pos_embedding_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                #torch.save(Model.state_dict(), MODEL_PATH+DATA+"_"+"E2E-EC_fold_{}.pth".format(fold))
                torch.save(Model.state_dict(), f'{MODEL_PATH}{DATA}_E2E-EC_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                
                max_f1_avg = result_avg_pair[-1]
                result_avg_cause_max = result_avg_cause
                result_avg_pos_max = result_avg_pos
                result_avg_pair_max = result_avg_pair

            print('avg max cause: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_cause_max[0], result_avg_cause_max[1], result_avg_cause_max[2], result_avg_cause_max[3]))
            print('avg max pos: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_pos_max[0], result_avg_pos_max[1], result_avg_pos_max[2], result_avg_pos_max[3]))
            print('avg max pair: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                result_avg_pair_max[0], result_avg_pair_max[1], result_avg_pair_max[2], result_avg_pair_max[3]))

        print('############# fold {} end ###############'.format(fold))
        acc_cause_list.append(result_avg_cause_max[0])
        p_cause_list.append(result_avg_cause_max[1])
        r_cause_list.append(result_avg_cause_max[2])
        f1_cause_list.append(result_avg_cause_max[3])
        acc_pos_list.append(result_avg_pos_max[0])
        p_pos_list.append(result_avg_pos_max[1])
        r_pos_list.append(result_avg_pos_max[2])
        f1_pos_list.append(result_avg_pos_max[3])
        acc_pair_list.append(result_avg_pair_max[0])
        p_pair_list.append(result_avg_pair_max[1])
        r_pair_list.append(result_avg_pair_max[2])
        f1_pair_list.append(result_avg_pair_max[3])

    #################################### FINAL TEST RESULTS ON 10 FOLDS ####################################
    all_results = [acc_cause_list, p_cause_list, r_cause_list, f1_cause_list, \
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list, acc_pair_list, p_pair_list, r_pair_list, f1_pair_list,]
    acc_cause, p_cause, r_cause, f1_cause, acc_pos, p_pos, r_pos, f1_pos, acc_pair, p_pair, r_pair, f1_pair = \
        map(lambda x: np.array(x).mean(), all_results)
    print('\ncause_predict: val f1 in 1 fold: {}'.format(np.array(f1_cause_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_cause, p_cause, r_cause, f1_cause))
    print('emotion_predict: val f1 in 1 fold: {}'.format(np.array(f1_pos_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pos, p_pos, r_pos, f1_pos))
    print('pair_predict: val f1 in 1 fold: {}'.format(np.array(f1_pair_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pair, p_pair, r_pair, f1_pair))

# %% [markdown]
# ## Calling the class for the varying hyperparamters

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.4651
# emotion_predict: val acc 0.6700 p 0.4800 r 0.1818 f1 0.2637
# max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
# avg max pos: max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.1601
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
#
# cause_predict: val acc 0.7044 p 1.0000 r 0.0909 f1 0.1667
# max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
# avg max pos: max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0748
# emotion_predict: val acc 0.6798 p 0.5385 r 0.1061 f1 0.1772
# max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
#
# cause_predict: val acc 0.6946 p 0.5500 r 0.3333 f1 0.4151
# max_acc 0.6946 max_p 0.5500 max_r 0.3333 max_f1 0.4151
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
# avg max pos: max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.9638
# emotion_predict: val acc 0.6749 p 0.5000 r 0.2424 f1 0.3265
# max_acc 0.6749 max_p 0.5000 max_r 0.2424 max_f1 0.3265
#
# cause_predict: val acc 0.7192 p 0.6364 r 0.3182 f1 0.4242
# max_acc 0.7192 max_p 0.6364 max_r 0.3182 max_f1 0.4242
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
# avg max pos: max_acc 0.6700 max_p 0.4800 max_r 0.1818 max_f1 0.2637
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.8210
# emotion_predict: val acc 0.7192 p 0.6216 r 0.3485 f1 0.4466
# max_acc 0.7192 max_p 0.6216 max_r 0.3485 max_f1 0.4466
#
# cause_predict: val acc 0.7143 p 0.5833 r 0.4242 f1 0.4912
# max_acc 0.7143 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# pair_predict: val acc 0.9139 p 1.0000 r 0.0303 f1 0.0588
# max_acc 0.9139 max_p 1.0000 max_r 0.0303 max_f1 0.0588
#
# avg max cause: max_acc 0.7143 max_p 0.5833 max_r 0.4242 max_f1 0.4912
# avg max pos: max_acc 0.7192 max_p 0.6216 max_r 0.3485 max_f1 0.4466
# avg max pair: max_acc 0.9139 max_p 1.0000 max_r 0.0303 max_f1 0.0588
#
# Fold 1 Epoch 6 val loss 2.5723
# emotion_predict: val acc 0.7931 p 0.6818 r 0.6818 f1 0.6818
# max_acc 0.7931 max_p 0.6818 max_r 0.6818 max_f1 0.6818
#
# cause_predict: val acc 0.7241 p 0.5926 r 0.4848 f1 0.5333
# max_acc 0.7241 max_p 0.5926 max_r 0.4848 max_f1 0.5333
#
# pair_predict: val acc 0.9071 p 0.4737 r 0.4091 f1 0.4390
# max_acc 0.9071 max_p 0.4737 max_r 0.4091 max_f1 0.4390
#
# avg max cause: max_acc 0.7241 max_p 0.5926 max_r 0.4848 max_f1 0.5333
# avg max pos: max_acc 0.7931 max_p 0.6818 max_r 0.6818 max_f1 0.6818
# avg max pair: max_acc 0.9071 max_p 0.4737 max_r 0.4091 max_f1 0.4390
#
# Fold 1 Epoch 7 val loss 2.3791
# emotion_predict: val acc 0.8177 p 0.8085 r 0.5758 f1 0.6726
# max_acc 0.7931 max_p 0.6818 max_r 0.6818 max_f1 0.6818
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
#
# pair_predict: val acc 0.8937 p 0.4156 r 0.4848 f1 0.4476
# max_acc 0.8937 max_p 0.4156 max_r 0.4848 max_f1 0.4476
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.8177 max_p 0.8085 max_r 0.5758 max_f1 0.6726
# avg max pair: max_acc 0.8937 max_p 0.4156 max_r 0.4848 max_f1 0.4476
#
# Fold 1 Epoch 8 val loss 2.3791
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.8923 p 0.4146 r 0.5152 f1 0.4595
# max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# Fold 1 Epoch 9 val loss 2.3896
# emotion_predict: val acc 0.8276 p 0.8163 r 0.6061 f1 0.6957
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7241 p 0.5862 r 0.5152 f1 0.5484
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9004 p 0.4394 r 0.4394 f1 0.4394
# max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# Fold 1 Epoch 10 val loss 2.5114
# emotion_predict: val acc 0.8030 p 0.6857 r 0.7273 f1 0.7059
# max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
#
# cause_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9085 p 0.4828 r 0.4242 f1 0.4516
# max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# avg max cause: max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
# avg max pos: max_acc 0.8177 max_p 0.7377 max_r 0.6818 max_f1 0.7087
# avg max pair: max_acc 0.8923 max_p 0.4146 max_r 0.5152 max_f1 0.4595
#
# Fold 1 Epoch 11 val loss 2.3640
# emotion_predict: val acc 0.8473 p 0.8182 r 0.6818 f1 0.7438
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7438 p 0.6667 r 0.4242 f1 0.5185
# max_acc 0.7340 max_p 0.6000 max_r 0.5455 max_f1 0.5714
#
# pair_predict: val acc 0.9179 p 0.5410 r 0.5000 f1 0.5197
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 12 val loss 2.5144
# emotion_predict: val acc 0.8276 p 0.7385 r 0.7273 f1 0.7328
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7291 p 0.5821 r 0.5909 f1 0.5865
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.9071 p 0.4776 r 0.4848 f1 0.4812
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 13 val loss 2.4937
# emotion_predict: val acc 0.8177 p 0.7231 r 0.7121 f1 0.7176
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.8977 p 0.4432 r 0.5909 f1 0.5065
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 14 val loss 2.8599
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7241 p 0.5735 r 0.5909 f1 0.5821
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.8991 p 0.4384 r 0.4848 f1 0.4604
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 15 val loss 3.0183
# emotion_predict: val acc 0.7980 p 0.6812 r 0.7121 f1 0.6963
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7291 p 0.6038 r 0.4848 f1 0.5378
# max_acc 0.7291 max_p 0.5821 max_r 0.5909 max_f1 0.5865
#
# pair_predict: val acc 0.9017 p 0.4545 r 0.5303 f1 0.4895
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 16 val loss 3.1232
# emotion_predict: val acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7438 p 0.6094 r 0.5909 f1 0.6000
# max_acc 0.7438 max_p 0.6094 max_r 0.5909 max_f1 0.6000
#
# pair_predict: val acc 0.9058 p 0.4730 r 0.5303 f1 0.5000
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 17 val loss 3.3518
# emotion_predict: val acc 0.7833 p 0.6719 r 0.6515 f1 0.6615
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7586 p 0.6491 r 0.5606 f1 0.6016
# max_acc 0.7586 max_p 0.6491 max_r 0.5606 max_f1 0.6016
#
# pair_predict: val acc 0.9085 p 0.4865 r 0.5455 f1 0.5143
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 18 val loss 3.7823
# emotion_predict: val acc 0.8276 p 0.7541 r 0.6970 f1 0.7244
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7488 p 0.6087 r 0.6364 f1 0.6222
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.9085 p 0.4861 r 0.5303 f1 0.5072
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 19 val loss 4.2291
# emotion_predict: val acc 0.8177 p 0.7544 r 0.6515 f1 0.6992
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7094 p 0.5522 r 0.5606 f1 0.5564
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.9017 p 0.4521 r 0.5000 f1 0.4748
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# Fold 1 Epoch 20 val loss 4.7447
# emotion_predict: val acc 0.8128 p 0.7187 r 0.6970 f1 0.7077
# max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7488 max_p 0.6087 max_r 0.6364 max_f1 0.6222
#
# pair_predict: val acc 0.9085 p 0.4839 r 0.4545 f1 0.4687
# max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.8473 max_p 0.8182 max_r 0.6818 max_f1 0.7438
# avg max pair: max_acc 0.9179 max_p 0.5410 max_r 0.5000 max_f1 0.5197
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.51851852]]
# average : acc 0.7438 p 0.6667 r 0.4242 f1 0.5185
#
# emotion_predict: val f1 in 1 fold: [[0.74380165]]
# average : acc 0.8473 p 0.8182 r 0.6818 f1 0.7438
#
# pair_predict: val f1 in 1 fold: [[0.51968504]]
# average : acc 0.9179 p 0.5410 r 0.5000 f1 0.5197

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.6434
# emotion_predict: val acc 0.6847 p 0.6000 r 0.0909 f1 0.1579
# max_acc 0.6847 max_p 0.6000 max_r 0.0909 max_f1 0.1579
#
# cause_predict: val acc 0.7192 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.7192 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7192 max_p 0.9091 max_r 0.1515 max_f1 0.2597
# avg max pos: max_acc 0.6847 max_p 0.6000 max_r 0.0909 max_f1 0.1579
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.5133
# emotion_predict: val acc 0.6798 p 0.5057 r 0.6667 f1 0.5752
# max_acc 0.6798 max_p 0.5057 max_r 0.6667 max_f1 0.5752
#
# cause_predict: val acc 0.7044 p 0.5417 r 0.5909 f1 0.5652
# max_acc 0.7044 max_p 0.5417 max_r 0.5909 max_f1 0.5652
#
# pair_predict: val acc 0.9233 p 0.7368 r 0.2121 f1 0.3294
# max_acc 0.9233 max_p 0.7368 max_r 0.2121 max_f1 0.3294
#
# avg max cause: max_acc 0.7044 max_p 0.5417 max_r 0.5909 max_f1 0.5652
# avg max pos: max_acc 0.6798 max_p 0.5057 max_r 0.6667 max_f1 0.5752
# avg max pair: max_acc 0.9233 max_p 0.7368 max_r 0.2121 max_f1 0.3294
#
# Fold 1 Epoch 3 val loss 2.1064
# emotion_predict: val acc 0.7980 p 0.7273 r 0.6061 f1 0.6612
# max_acc 0.7980 max_p 0.7273 max_r 0.6061 max_f1 0.6612
#
# cause_predict: val acc 0.7438 p 0.6061 r 0.6061 f1 0.6061
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8156 p 0.2739 r 0.6515 f1 0.3857
# max_acc 0.8156 max_p 0.2739 max_r 0.6515 max_f1 0.3857
#
# avg max cause: max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
# avg max pos: max_acc 0.7980 max_p 0.7273 max_r 0.6061 max_f1 0.6612
# avg max pair: max_acc 0.8156 max_p 0.2739 max_r 0.6515 max_f1 0.3857
#
# Fold 1 Epoch 4 val loss 2.0856
# emotion_predict: val acc 0.8227 p 0.7586 r 0.6667 f1 0.7097
# max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
#
# cause_predict: val acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8614 p 0.3543 r 0.6818 f1 0.4663
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 5 val loss 2.1299
# emotion_predict: val acc 0.7833 p 0.6833 r 0.6212 f1 0.6508
# max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
#
# cause_predict: val acc 0.7291 p 0.6279 r 0.4091 f1 0.4954
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8412 p 0.2903 r 0.5455 f1 0.3789
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 6 val loss 2.0506
# emotion_predict: val acc 0.8128 p 0.7500 r 0.6364 f1 0.6885
# max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
#
# cause_predict: val acc 0.7192 p 0.6047 r 0.3939 f1 0.4771
# max_acc 0.7438 max_p 0.6061 max_r 0.6061 max_f1 0.6061
#
# pair_predict: val acc 0.8439 p 0.3239 r 0.6970 f1 0.4423
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 7 val loss 2.0139
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7340 p 0.5811 r 0.6515 f1 0.6143
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8425 p 0.3311 r 0.7576 f1 0.4608
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 8 val loss 2.1090
# emotion_predict: val acc 0.8079 p 0.7368 r 0.6364 f1 0.6829
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7635 p 0.6800 r 0.5152 f1 0.5862
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8560 p 0.3306 r 0.6061 f1 0.4278
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 9 val loss 2.3009
# emotion_predict: val acc 0.8177 p 0.7231 r 0.7121 f1 0.7176
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7192 p 0.5634 r 0.6061 f1 0.5839
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8345 p 0.3087 r 0.6970 f1 0.4279
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 10 val loss 2.4949
# emotion_predict: val acc 0.7882 p 0.6620 r 0.7121 f1 0.6861
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7340 p 0.5909 r 0.5909 f1 0.5909
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8358 p 0.2941 r 0.6061 f1 0.3960
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 11 val loss 2.3586
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8614 p 0.3419 r 0.6061 f1 0.4372
# max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
# avg max pair: max_acc 0.8614 max_p 0.3543 max_r 0.6818 max_f1 0.4663
#
# Fold 1 Epoch 12 val loss 2.7096
# emotion_predict: val acc 0.8276 p 0.7460 r 0.7121 f1 0.7287
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.7340 p 0.5937 r 0.5758 f1 0.5846
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8991 p 0.4483 r 0.5909 f1 0.5098
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 13 val loss 2.6856
# emotion_predict: val acc 0.8374 p 0.7619 r 0.7273 f1 0.7442
# max_acc 0.8374 max_p 0.7619 max_r 0.7273 max_f1 0.7442
#
# cause_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8775 p 0.3711 r 0.5455 f1 0.4417
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 14 val loss 3.1219
# emotion_predict: val acc 0.8276 p 0.7123 r 0.7879 f1 0.7482
# max_acc 0.8276 max_p 0.7123 max_r 0.7879 max_f1 0.7482
#
# cause_predict: val acc 0.6847 p 0.5161 r 0.4848 f1 0.5000
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8587 p 0.3361 r 0.6061 f1 0.4324
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 15 val loss 3.2456
# emotion_predict: val acc 0.8424 p 0.7576 r 0.7576 f1 0.7576
# max_acc 0.8424 max_p 0.7576 max_r 0.7576 max_f1 0.7576
#
# cause_predict: val acc 0.7143 p 0.5526 r 0.6364 f1 0.5915
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8789 p 0.3800 r 0.5758 f1 0.4578
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 16 val loss 3.6060
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8424 max_p 0.7576 max_r 0.7576 max_f1 0.7576
#
# cause_predict: val acc 0.7044 p 0.5500 r 0.5000 f1 0.5238
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8802 p 0.3883 r 0.6061 f1 0.4734
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 17 val loss 3.9031
# emotion_predict: val acc 0.8424 p 0.7500 r 0.7727 f1 0.7612
# max_acc 0.8424 max_p 0.7500 max_r 0.7727 max_f1 0.7612
#
# cause_predict: val acc 0.6995 p 0.5439 r 0.4697 f1 0.5041
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8816 p 0.3721 r 0.4848 f1 0.4211
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 18 val loss 4.1901
# emotion_predict: val acc 0.8128 p 0.7187 r 0.6970 f1 0.7077
# max_acc 0.8424 max_p 0.7500 max_r 0.7727 max_f1 0.7612
#
# cause_predict: val acc 0.7143 p 0.5571 r 0.5909 f1 0.5735
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8883 p 0.4045 r 0.5455 f1 0.4645
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 19 val loss 4.2859
# emotion_predict: val acc 0.8079 p 0.6800 r 0.7727 f1 0.7234
# max_acc 0.8424 max_p 0.7500 max_r 0.7727 max_f1 0.7612
#
# cause_predict: val acc 0.6897 p 0.5211 r 0.5606 f1 0.5401
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8843 p 0.3864 r 0.5152 f1 0.4416
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# Fold 1 Epoch 20 val loss 4.8005
# emotion_predict: val acc 0.8374 p 0.7463 r 0.7576 f1 0.7519
# max_acc 0.8424 max_p 0.7500 max_r 0.7727 max_f1 0.7612
#
# cause_predict: val acc 0.6798 p 0.5068 r 0.5606 f1 0.5324
# max_acc 0.7340 max_p 0.5811 max_r 0.6515 max_f1 0.6143
#
# pair_predict: val acc 0.8883 p 0.3924 r 0.4697 f1 0.4276
# max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# avg max cause: max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8991 max_p 0.4483 max_r 0.5909 max_f1 0.5098
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58461538]]
# average : acc 0.7340 p 0.5937 r 0.5758 f1 0.5846
#
# emotion_predict: val f1 in 1 fold: [[0.72868217]]
# average : acc 0.8276 p 0.7460 r 0.7121 f1 0.7287
#
# pair_predict: val f1 in 1 fold: [[0.50980392]]
# average : acc 0.8991 p 0.4483 r 0.5909 f1 0.5098

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3098
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2088
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.1701
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.0973
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.0546
# emotion_predict: val acc 0.7241 p 0.6250 r 0.3788 f1 0.4717
# max_acc 0.7241 max_p 0.6250 max_r 0.3788 max_f1 0.4717
#
# cause_predict: val acc 0.7241 p 0.8571 r 0.1818 f1 0.3000
# max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.9945
# emotion_predict: val acc 0.7389 p 0.7241 r 0.3182 f1 0.4421
# max_acc 0.7241 max_p 0.6250 max_r 0.3788 max_f1 0.4717
#
# cause_predict: val acc 0.7192 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.7241 max_p 0.8571 max_r 0.1818 max_f1 0.3000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.9259
# emotion_predict: val acc 0.7192 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.7241 max_p 0.6250 max_r 0.3788 max_f1 0.4717
#
# cause_predict: val acc 0.7192 p 0.6286 r 0.3333 f1 0.4356
# max_acc 0.7192 max_p 0.6286 max_r 0.3333 max_f1 0.4356
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.8437
# emotion_predict: val acc 0.7438 p 0.6750 r 0.4091 f1 0.5094
# max_acc 0.7438 max_p 0.6750 max_r 0.4091 max_f1 0.5094
#
# cause_predict: val acc 0.7192 p 0.6098 r 0.3788 f1 0.4673
# max_acc 0.7192 max_p 0.6098 max_r 0.3788 max_f1 0.4673
#
# pair_predict: val acc 0.9233 p 0.9091 r 0.1515 f1 0.2597
# max_acc 0.9233 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# avg max cause: max_acc 0.7192 max_p 0.6098 max_r 0.3788 max_f1 0.4673
# avg max pos: max_acc 0.7438 max_p 0.6750 max_r 0.4091 max_f1 0.5094
# avg max pair: max_acc 0.9233 max_p 0.9091 max_r 0.1515 max_f1 0.2597
#
# Fold 1 Epoch 9 val loss 2.7729
# emotion_predict: val acc 0.7291 p 0.6279 r 0.4091 f1 0.4954
# max_acc 0.7438 max_p 0.6750 max_r 0.4091 max_f1 0.5094
#
# cause_predict: val acc 0.7192 p 0.5692 r 0.5606 f1 0.5649
# max_acc 0.7192 max_p 0.5692 max_r 0.5606 max_f1 0.5649
#
# pair_predict: val acc 0.9152 p 0.5484 r 0.2576 f1 0.3505
# max_acc 0.9152 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# avg max cause: max_acc 0.7192 max_p 0.5692 max_r 0.5606 max_f1 0.5649
# avg max pos: max_acc 0.7291 max_p 0.6279 max_r 0.4091 max_f1 0.4954
# avg max pair: max_acc 0.9152 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# Fold 1 Epoch 10 val loss 2.7244
# emotion_predict: val acc 0.7537 p 0.6818 r 0.4545 f1 0.5455
# max_acc 0.7537 max_p 0.6818 max_r 0.4545 max_f1 0.5455
#
# cause_predict: val acc 0.7192 p 0.5714 r 0.5455 f1 0.5581
# max_acc 0.7192 max_p 0.5692 max_r 0.5606 max_f1 0.5649
#
# pair_predict: val acc 0.9139 p 0.5238 r 0.3333 f1 0.4074
# max_acc 0.9139 max_p 0.5238 max_r 0.3333 max_f1 0.4074
#
# avg max cause: max_acc 0.7192 max_p 0.5714 max_r 0.5455 max_f1 0.5581
# avg max pos: max_acc 0.7537 max_p 0.6818 max_r 0.4545 max_f1 0.5455
# avg max pair: max_acc 0.9139 max_p 0.5238 max_r 0.3333 max_f1 0.4074
#
# Fold 1 Epoch 11 val loss 2.6874
# emotion_predict: val acc 0.7241 p 0.5806 r 0.5455 f1 0.5625
# max_acc 0.7241 max_p 0.5806 max_r 0.5455 max_f1 0.5625
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
#
# pair_predict: val acc 0.9139 p 0.5192 r 0.4091 f1 0.4576
# max_acc 0.9139 max_p 0.5192 max_r 0.4091 max_f1 0.4576
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.7241 max_p 0.5806 max_r 0.5455 max_f1 0.5625
# avg max pair: max_acc 0.9139 max_p 0.5192 max_r 0.4091 max_f1 0.4576
#
# Fold 1 Epoch 12 val loss 2.6577
# emotion_predict: val acc 0.7685 p 0.7111 r 0.4848 f1 0.5766
# max_acc 0.7685 max_p 0.7111 max_r 0.4848 max_f1 0.5766
#
# cause_predict: val acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
# max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
#
# pair_predict: val acc 0.9192 p 0.5652 r 0.3939 f1 0.4643
# max_acc 0.9192 max_p 0.5652 max_r 0.3939 max_f1 0.4643
#
# avg max cause: max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
# avg max pos: max_acc 0.7685 max_p 0.7111 max_r 0.4848 max_f1 0.5766
# avg max pair: max_acc 0.9192 max_p 0.5652 max_r 0.3939 max_f1 0.4643
#
# Fold 1 Epoch 13 val loss 2.6005
# emotion_predict: val acc 0.7734 p 0.6613 r 0.6212 f1 0.6406
# max_acc 0.7734 max_p 0.6613 max_r 0.6212 max_f1 0.6406
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
#
# pair_predict: val acc 0.9098 p 0.4915 r 0.4394 f1 0.4640
# max_acc 0.9192 max_p 0.5652 max_r 0.3939 max_f1 0.4643
#
# avg max cause: max_acc 0.7192 max_p 0.5818 max_r 0.4848 max_f1 0.5289
# avg max pos: max_acc 0.7685 max_p 0.7111 max_r 0.4848 max_f1 0.5766
# avg max pair: max_acc 0.9192 max_p 0.5652 max_r 0.3939 max_f1 0.4643
#
# Fold 1 Epoch 14 val loss 2.4752
# emotion_predict: val acc 0.7931 p 0.7000 r 0.6364 f1 0.6667
# max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.4545 f1 0.4762
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 15 val loss 2.4687
# emotion_predict: val acc 0.8177 p 0.7544 r 0.6515 f1 0.6992
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.9071 p 0.4769 r 0.4697 f1 0.4733
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 16 val loss 2.5650
# emotion_predict: val acc 0.8030 p 0.7241 r 0.6364 f1 0.6774
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.9031 p 0.4559 r 0.4697 f1 0.4627
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 17 val loss 2.5190
# emotion_predict: val acc 0.8227 p 0.7586 r 0.6667 f1 0.7097
# max_acc 0.8227 max_p 0.7586 max_r 0.6667 max_f1 0.7097
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.9071 p 0.4754 r 0.4394 f1 0.4567
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 18 val loss 2.4976
# emotion_predict: val acc 0.8424 p 0.7656 r 0.7424 f1 0.7538
# max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
#
# cause_predict: val acc 0.7291 p 0.5846 r 0.5758 f1 0.5802
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.8937 p 0.4217 r 0.5303 f1 0.4698
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 19 val loss 2.5592
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
#
# cause_predict: val acc 0.7094 p 0.5507 r 0.5758 f1 0.5630
# max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
#
# pair_predict: val acc 0.8896 p 0.4091 r 0.5455 f1 0.4675
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# Fold 1 Epoch 20 val loss 2.5028
# emotion_predict: val acc 0.8227 p 0.7206 r 0.7424 f1 0.7313
# max_acc 0.8424 max_p 0.7656 max_r 0.7424 max_f1 0.7538
#
# cause_predict: val acc 0.7044 p 0.5366 r 0.6667 f1 0.5946
# max_acc 0.7044 max_p 0.5366 max_r 0.6667 max_f1 0.5946
#
# pair_predict: val acc 0.8802 p 0.3861 r 0.5909 f1 0.4671
# max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7931 max_p 0.7000 max_r 0.6364 max_f1 0.6667
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4545 max_f1 0.4762
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58267716]]
# average : acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
#
# emotion_predict: val f1 in 1 fold: [[0.66666667]]
# average : acc 0.7931 p 0.7000 r 0.6364 f1 0.6667
#
# pair_predict: val f1 in 1 fold: [[0.47619048]]
# average : acc 0.9112 p 0.5000 r 0.4545 f1 0.4762

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7980
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7411
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.6582
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.6024
# emotion_predict: val acc 0.6847 p 0.5238 r 0.3333 f1 0.4074
# max_acc 0.6847 max_p 0.5238 max_r 0.3333 max_f1 0.4074
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.8937 p 0.3860 r 0.3333 f1 0.3577
# max_acc 0.8937 max_p 0.3860 max_r 0.3333 max_f1 0.3577
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6847 max_p 0.5238 max_r 0.3333 max_f1 0.4074
# avg max pair: max_acc 0.8937 max_p 0.3860 max_r 0.3333 max_f1 0.3577
#
# Fold 1 Epoch 5 val loss 2.5279
# emotion_predict: val acc 0.7488 p 0.8947 r 0.2576 f1 0.4000
# max_acc 0.6847 max_p 0.5238 max_r 0.3333 max_f1 0.4074
#
# cause_predict: val acc 0.7438 p 0.8182 r 0.2727 f1 0.4091
# max_acc 0.7438 max_p 0.8182 max_r 0.2727 max_f1 0.4091
#
# pair_predict: val acc 0.8937 p 0.3934 r 0.3636 f1 0.3780
# max_acc 0.8937 max_p 0.3934 max_r 0.3636 max_f1 0.3780
#
# avg max cause: max_acc 0.7438 max_p 0.8182 max_r 0.2727 max_f1 0.4091
# avg max pos: max_acc 0.7488 max_p 0.8947 max_r 0.2576 max_f1 0.4000
# avg max pair: max_acc 0.8937 max_p 0.3934 max_r 0.3636 max_f1 0.3780
#
# Fold 1 Epoch 6 val loss 2.3978
# emotion_predict: val acc 0.7192 p 0.6957 r 0.2424 f1 0.3596
# max_acc 0.6847 max_p 0.5238 max_r 0.3333 max_f1 0.4074
#
# cause_predict: val acc 0.7241 p 0.6786 r 0.2879 f1 0.4043
# max_acc 0.7438 max_p 0.8182 max_r 0.2727 max_f1 0.4091
#
# pair_predict: val acc 0.8802 p 0.3506 r 0.4091 f1 0.3776
# max_acc 0.8937 max_p 0.3934 max_r 0.3636 max_f1 0.3780
#
# avg max cause: max_acc 0.7438 max_p 0.8182 max_r 0.2727 max_f1 0.4091
# avg max pos: max_acc 0.7488 max_p 0.8947 max_r 0.2576 max_f1 0.4000
# avg max pair: max_acc 0.8937 max_p 0.3934 max_r 0.3636 max_f1 0.3780
#
# Fold 1 Epoch 7 val loss 2.3377
# emotion_predict: val acc 0.7340 p 0.6500 r 0.3939 f1 0.4906
# max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
#
# cause_predict: val acc 0.7192 p 0.5763 r 0.5152 f1 0.5440
# max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
#
# pair_predict: val acc 0.8439 p 0.2951 r 0.5455 f1 0.3830
# max_acc 0.8439 max_p 0.2951 max_r 0.5455 max_f1 0.3830
#
# avg max cause: max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
# avg max pos: max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
# avg max pair: max_acc 0.8439 max_p 0.2951 max_r 0.5455 max_f1 0.3830
#
# Fold 1 Epoch 8 val loss 2.3061
# emotion_predict: val acc 0.7389 p 0.6275 r 0.4848 f1 0.5470
# max_acc 0.7389 max_p 0.6275 max_r 0.4848 max_f1 0.5470
#
# cause_predict: val acc 0.7192 p 0.5849 r 0.4697 f1 0.5210
# max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
#
# pair_predict: val acc 0.8170 p 0.2500 r 0.5303 f1 0.3398
# max_acc 0.8439 max_p 0.2951 max_r 0.5455 max_f1 0.3830
#
# avg max cause: max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
# avg max pos: max_acc 0.7340 max_p 0.6500 max_r 0.3939 max_f1 0.4906
# avg max pair: max_acc 0.8439 max_p 0.2951 max_r 0.5455 max_f1 0.3830
#
# Fold 1 Epoch 9 val loss 2.3063
# emotion_predict: val acc 0.7537 p 0.6538 r 0.5152 f1 0.5763
# max_acc 0.7537 max_p 0.6538 max_r 0.5152 max_f1 0.5763
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8721 p 0.3371 r 0.4545 f1 0.3871
# max_acc 0.8721 max_p 0.3371 max_r 0.4545 max_f1 0.3871
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.7537 max_p 0.6538 max_r 0.5152 max_f1 0.5763
# avg max pair: max_acc 0.8721 max_p 0.3371 max_r 0.4545 max_f1 0.3871
#
# Fold 1 Epoch 10 val loss 2.2310
# emotion_predict: val acc 0.7586 p 0.6441 r 0.5758 f1 0.6080
# max_acc 0.7586 max_p 0.6441 max_r 0.5758 max_f1 0.6080
#
# cause_predict: val acc 0.7192 p 0.5738 r 0.5303 f1 0.5512
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8318 p 0.2815 r 0.5758 f1 0.3781
# max_acc 0.8721 max_p 0.3371 max_r 0.4545 max_f1 0.3871
#
# avg max cause: max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
# avg max pos: max_acc 0.7537 max_p 0.6538 max_r 0.5152 max_f1 0.5763
# avg max pair: max_acc 0.8721 max_p 0.3371 max_r 0.4545 max_f1 0.3871
#
# Fold 1 Epoch 11 val loss 2.1745
# emotion_predict: val acc 0.7734 p 0.6923 r 0.5455 f1 0.6102
# max_acc 0.7734 max_p 0.6923 max_r 0.5455 max_f1 0.6102
#
# cause_predict: val acc 0.7291 p 0.6038 r 0.4848 f1 0.5378
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8452 p 0.3040 r 0.5758 f1 0.3979
# max_acc 0.8452 max_p 0.3040 max_r 0.5758 max_f1 0.3979
#
# avg max cause: max_acc 0.7291 max_p 0.6038 max_r 0.4848 max_f1 0.5378
# avg max pos: max_acc 0.7734 max_p 0.6923 max_r 0.5455 max_f1 0.6102
# avg max pair: max_acc 0.8452 max_p 0.3040 max_r 0.5758 max_f1 0.3979
#
# Fold 1 Epoch 12 val loss 2.1644
# emotion_predict: val acc 0.7882 p 0.7018 r 0.6061 f1 0.6504
# max_acc 0.7882 max_p 0.7018 max_r 0.6061 max_f1 0.6504
#
# cause_predict: val acc 0.7192 p 0.5763 r 0.5152 f1 0.5440
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8641 p 0.3364 r 0.5455 f1 0.4162
# max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# avg max cause: max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
# avg max pos: max_acc 0.7882 max_p 0.7018 max_r 0.6061 max_f1 0.6504
# avg max pair: max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# Fold 1 Epoch 13 val loss 2.1114
# emotion_predict: val acc 0.7980 p 0.6923 r 0.6818 f1 0.6870
# max_acc 0.7980 max_p 0.6923 max_r 0.6818 max_f1 0.6870
#
# cause_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8506 p 0.3171 r 0.5909 f1 0.4127
# max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# avg max cause: max_acc 0.7192 max_p 0.5763 max_r 0.5152 max_f1 0.5440
# avg max pos: max_acc 0.7882 max_p 0.7018 max_r 0.6061 max_f1 0.6504
# avg max pair: max_acc 0.8641 max_p 0.3364 max_r 0.5455 max_f1 0.4162
#
# Fold 1 Epoch 14 val loss 2.1814
# emotion_predict: val acc 0.7783 p 0.6780 r 0.6061 f1 0.6400
# max_acc 0.7980 max_p 0.6923 max_r 0.6818 max_f1 0.6870
#
# cause_predict: val acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
# max_acc 0.7389 max_p 0.6182 max_r 0.5152 max_f1 0.5620
#
# pair_predict: val acc 0.8520 p 0.3226 r 0.6061 f1 0.4211
# max_acc 0.8520 max_p 0.3226 max_r 0.6061 max_f1 0.4211
#
# avg max cause: max_acc 0.7291 max_p 0.5932 max_r 0.5303 max_f1 0.5600
# avg max pos: max_acc 0.7783 max_p 0.6780 max_r 0.6061 max_f1 0.6400
# avg max pair: max_acc 0.8520 max_p 0.3226 max_r 0.6061 max_f1 0.4211
#
# Fold 1 Epoch 15 val loss 2.1441
# emotion_predict: val acc 0.7783 p 0.6721 r 0.6212 f1 0.6457
# max_acc 0.7980 max_p 0.6923 max_r 0.6818 max_f1 0.6870
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
#
# pair_predict: val acc 0.8573 p 0.3333 r 0.6061 f1 0.4301
# max_acc 0.8573 max_p 0.3333 max_r 0.6061 max_f1 0.4301
#
# avg max cause: max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
# avg max pos: max_acc 0.7783 max_p 0.6721 max_r 0.6212 max_f1 0.6457
# avg max pair: max_acc 0.8573 max_p 0.3333 max_r 0.6061 max_f1 0.4301
#
# Fold 1 Epoch 16 val loss 2.2021
# emotion_predict: val acc 0.8276 p 0.7460 r 0.7121 f1 0.7287
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.7537 p 0.6212 r 0.6212 f1 0.6212
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8398 p 0.3147 r 0.6818 f1 0.4306
# max_acc 0.8398 max_p 0.3147 max_r 0.6818 max_f1 0.4306
#
# avg max cause: max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
# avg max pos: max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
# avg max pair: max_acc 0.8398 max_p 0.3147 max_r 0.6818 max_f1 0.4306
#
# Fold 1 Epoch 17 val loss 2.3561
# emotion_predict: val acc 0.7882 p 0.6716 r 0.6818 f1 0.6767
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.7241 p 0.5833 r 0.5303 f1 0.5556
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8546 p 0.3333 r 0.6364 f1 0.4375
# max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# avg max cause: max_acc 0.7241 max_p 0.5833 max_r 0.5303 max_f1 0.5556
# avg max pos: max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
# avg max pair: max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# Fold 1 Epoch 18 val loss 2.3103
# emotion_predict: val acc 0.7931 p 0.6818 r 0.6818 f1 0.6818
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.7094 p 0.5493 r 0.5909 f1 0.5693
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8345 p 0.3061 r 0.6818 f1 0.4225
# max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# avg max cause: max_acc 0.7241 max_p 0.5833 max_r 0.5303 max_f1 0.5556
# avg max pos: max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
# avg max pair: max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# Fold 1 Epoch 19 val loss 2.5209
# emotion_predict: val acc 0.7833 p 0.6719 r 0.6515 f1 0.6615
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.7291 p 0.5965 r 0.5152 f1 0.5528
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8627 p 0.3302 r 0.5303 f1 0.4070
# max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# avg max cause: max_acc 0.7241 max_p 0.5833 max_r 0.5303 max_f1 0.5556
# avg max pos: max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
# avg max pair: max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# Fold 1 Epoch 20 val loss 2.7341
# emotion_predict: val acc 0.7980 p 0.6984 r 0.6667 f1 0.6822
# max_acc 0.8276 max_p 0.7460 max_r 0.7121 max_f1 0.7287
#
# cause_predict: val acc 0.6897 p 0.5217 r 0.5455 f1 0.5333
# max_acc 0.7537 max_p 0.6212 max_r 0.6212 max_f1 0.6212
#
# pair_predict: val acc 0.8668 p 0.3398 r 0.5303 f1 0.4142
# max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# avg max cause: max_acc 0.7241 max_p 0.5833 max_r 0.5303 max_f1 0.5556
# avg max pos: max_acc 0.7882 max_p 0.6716 max_r 0.6818 max_f1 0.6767
# avg max pair: max_acc 0.8546 max_p 0.3333 max_r 0.6364 max_f1 0.4375
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.55555556]]
# average : acc 0.7241 p 0.5833 r 0.5303 f1 0.5556
#
# emotion_predict: val f1 in 1 fold: [[0.67669173]]
# average : acc 0.7882 p 0.6716 r 0.6818 f1 0.6767
#
# pair_predict: val f1 in 1 fold: [[0.4375]]
# average : acc 0.8546 p 0.3333 r 0.6364 f1 0.4375

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 4.1472
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.5276
# emotion_predict: val acc 0.6650 p 0.4706 r 0.2424 f1 0.3200
# max_acc 0.6650 max_p 0.4706 max_r 0.2424 max_f1 0.3200
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3449
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6650 max_p 0.4706 max_r 0.2424 max_f1 0.3200
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1774
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6650 max_p 0.4706 max_r 0.2424 max_f1 0.3200
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.1681
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6650 max_p 0.4706 max_r 0.2424 max_f1 0.3200
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.0941
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6650 max_p 0.4706 max_r 0.2424 max_f1 0.3200
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.1046
# emotion_predict: val acc 0.6700 p 0.4921 r 0.4697 f1 0.4806
# max_acc 0.6700 max_p 0.4921 max_r 0.4697 max_f1 0.4806
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.0550
# emotion_predict: val acc 0.6946 p 0.5357 r 0.4545 f1 0.4918
# max_acc 0.6946 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# cause_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.6798 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0048
# emotion_predict: val acc 0.7291 p 1.0000 r 0.1667 f1 0.2857
# max_acc 0.6946 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# cause_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.6798 max_p 1.0000 max_r 0.0152 max_f1 0.0299
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.9888
# emotion_predict: val acc 0.7389 p 1.0000 r 0.1970 f1 0.3291
# max_acc 0.6946 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# cause_predict: val acc 0.7241 p 0.8125 r 0.1970 f1 0.3171
# max_acc 0.7241 max_p 0.8125 max_r 0.1970 max_f1 0.3171
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.9340
# emotion_predict: val acc 0.7586 p 0.7931 r 0.3485 f1 0.4842
# max_acc 0.6946 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# cause_predict: val acc 0.7340 p 0.6304 r 0.4394 f1 0.5179
# max_acc 0.7340 max_p 0.6304 max_r 0.4394 max_f1 0.5179
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.8886
# emotion_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# cause_predict: val acc 0.7241 p 0.5694 r 0.6212 f1 0.5942
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 2.7322
# emotion_predict: val acc 0.7833 p 0.7115 r 0.5606 f1 0.6271
# max_acc 0.7833 max_p 0.7115 max_r 0.5606 max_f1 0.6271
#
# cause_predict: val acc 0.7488 p 0.6829 r 0.4242 f1 0.5234
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 2.6490
# emotion_predict: val acc 0.7833 p 0.7115 r 0.5606 f1 0.6271
# max_acc 0.7833 max_p 0.7115 max_r 0.5606 max_f1 0.6271
#
# cause_predict: val acc 0.7438 p 0.6667 r 0.4242 f1 0.5185
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 2.5627
# emotion_predict: val acc 0.7783 p 0.6567 r 0.6667 f1 0.6617
# max_acc 0.7783 max_p 0.6567 max_r 0.6667 max_f1 0.6617
#
# cause_predict: val acc 0.7537 p 0.6429 r 0.5455 f1 0.5902
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 16 val loss 2.4904
# emotion_predict: val acc 0.7783 p 0.6667 r 0.6364 f1 0.6512
# max_acc 0.7783 max_p 0.6567 max_r 0.6667 max_f1 0.6617
#
# cause_predict: val acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 17 val loss 2.4577
# emotion_predict: val acc 0.8177 p 0.7843 r 0.6061 f1 0.6838
# max_acc 0.8177 max_p 0.7843 max_r 0.6061 max_f1 0.6838
#
# cause_predict: val acc 0.7537 p 0.7105 r 0.4091 f1 0.5192
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9233 p 0.8000 r 0.1818 f1 0.2963
# max_acc 0.9233 max_p 0.8000 max_r 0.1818 max_f1 0.2963
#
# avg max cause: max_acc 0.7537 max_p 0.7105 max_r 0.4091 max_f1 0.5192
# avg max pos: max_acc 0.8177 max_p 0.7843 max_r 0.6061 max_f1 0.6838
# avg max pair: max_acc 0.9233 max_p 0.8000 max_r 0.1818 max_f1 0.2963
#
# Fold 1 Epoch 18 val loss 2.3848
# emotion_predict: val acc 0.8325 p 0.7500 r 0.7273 f1 0.7385
# max_acc 0.8325 max_p 0.7500 max_r 0.7273 max_f1 0.7385
#
# cause_predict: val acc 0.7488 p 0.6829 r 0.4242 f1 0.5234
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9058 p 0.4687 r 0.4545 f1 0.4615
# max_acc 0.9058 max_p 0.4687 max_r 0.4545 max_f1 0.4615
#
# avg max cause: max_acc 0.7488 max_p 0.6829 max_r 0.4242 max_f1 0.5234
# avg max pos: max_acc 0.8325 max_p 0.7500 max_r 0.7273 max_f1 0.7385
# avg max pair: max_acc 0.9058 max_p 0.4687 max_r 0.4545 max_f1 0.4615
#
# Fold 1 Epoch 19 val loss 2.4041
# emotion_predict: val acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
# max_acc 0.8325 max_p 0.7500 max_r 0.7273 max_f1 0.7385
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.9004 p 0.4474 r 0.5152 f1 0.4789
# max_acc 0.9004 max_p 0.4474 max_r 0.5152 max_f1 0.4789
#
# avg max cause: max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
# avg max pos: max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
# avg max pair: max_acc 0.9004 max_p 0.4474 max_r 0.5152 max_f1 0.4789
#
# Fold 1 Epoch 20 val loss 2.4272
# emotion_predict: val acc 0.8079 p 0.7213 r 0.6667 f1 0.6929
# max_acc 0.8325 max_p 0.7500 max_r 0.7273 max_f1 0.7385
#
# cause_predict: val acc 0.7438 p 0.6250 r 0.5303 f1 0.5738
# max_acc 0.7241 max_p 0.5694 max_r 0.6212 max_f1 0.5942
#
# pair_predict: val acc 0.8937 p 0.4177 r 0.5000 f1 0.4552
# max_acc 0.9004 max_p 0.4474 max_r 0.5152 max_f1 0.4789
#
# avg max cause: max_acc 0.7438 max_p 0.6296 max_r 0.5152 max_f1 0.5667
# avg max pos: max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
# avg max pair: max_acc 0.9004 max_p 0.4474 max_r 0.5152 max_f1 0.4789
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.56666667]]
# average : acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
#
# emotion_predict: val f1 in 1 fold: [[0.6984127]]
# average : acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
#
# pair_predict: val f1 in 1 fold: [[0.47887324]]
# average : acc 0.9004 p 0.4474 r 0.5152 f1 0.4789

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7867
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7006
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.6041
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6995 p 1.0000 r 0.0758 f1 0.1408
# max_acc 0.6995 max_p 1.0000 max_r 0.0758 max_f1 0.1408
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.5637
# emotion_predict: val acc 0.7044 p 1.0000 r 0.0909 f1 0.1667
# max_acc 0.7044 max_p 1.0000 max_r 0.0909 max_f1 0.1667
#
# cause_predict: val acc 0.7241 p 0.6136 r 0.4091 f1 0.4909
# max_acc 0.7241 max_p 0.6136 max_r 0.4091 max_f1 0.4909
#
# pair_predict: val acc 0.9219 p 0.7857 r 0.1667 f1 0.2750
# max_acc 0.9219 max_p 0.7857 max_r 0.1667 max_f1 0.2750
#
# avg max cause: max_acc 0.7241 max_p 0.6136 max_r 0.4091 max_f1 0.4909
# avg max pos: max_acc 0.7044 max_p 1.0000 max_r 0.0909 max_f1 0.1667
# avg max pair: max_acc 0.9219 max_p 0.7857 max_r 0.1667 max_f1 0.2750
#
# Fold 1 Epoch 5 val loss 2.5024
# emotion_predict: val acc 0.7241 p 0.5735 r 0.5909 f1 0.5821
# max_acc 0.7241 max_p 0.5735 max_r 0.5909 max_f1 0.5821
#
# cause_predict: val acc 0.7192 p 0.5652 r 0.5909 f1 0.5778
# max_acc 0.7192 max_p 0.5652 max_r 0.5909 max_f1 0.5778
#
# pair_predict: val acc 0.8668 p 0.3146 r 0.4242 f1 0.3613
# max_acc 0.8668 max_p 0.3146 max_r 0.4242 max_f1 0.3613
#
# avg max cause: max_acc 0.7192 max_p 0.5652 max_r 0.5909 max_f1 0.5778
# avg max pos: max_acc 0.7241 max_p 0.5735 max_r 0.5909 max_f1 0.5821
# avg max pair: max_acc 0.8668 max_p 0.3146 max_r 0.4242 max_f1 0.3613
#
# Fold 1 Epoch 6 val loss 2.3759
# emotion_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7241 max_p 0.5735 max_r 0.5909 max_f1 0.5821
#
# cause_predict: val acc 0.7438 p 0.6250 r 0.5303 f1 0.5738
# max_acc 0.7192 max_p 0.5652 max_r 0.5909 max_f1 0.5778
#
# pair_predict: val acc 0.8587 p 0.3030 r 0.4545 f1 0.3636
# max_acc 0.8587 max_p 0.3030 max_r 0.4545 max_f1 0.3636
#
# avg max cause: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pos: max_acc 0.7488 max_p 0.6471 max_r 0.5000 max_f1 0.5641
# avg max pair: max_acc 0.8587 max_p 0.3030 max_r 0.4545 max_f1 0.3636
#
# Fold 1 Epoch 7 val loss 2.2812
# emotion_predict: val acc 0.7685 p 0.7568 r 0.4242 f1 0.5437
# max_acc 0.7241 max_p 0.5735 max_r 0.5909 max_f1 0.5821
#
# cause_predict: val acc 0.7488 p 0.6190 r 0.5909 f1 0.6047
# max_acc 0.7488 max_p 0.6190 max_r 0.5909 max_f1 0.6047
#
# pair_predict: val acc 0.8856 p 0.3882 r 0.5000 f1 0.4371
# max_acc 0.8856 max_p 0.3882 max_r 0.5000 max_f1 0.4371
#
# avg max cause: max_acc 0.7488 max_p 0.6190 max_r 0.5909 max_f1 0.6047
# avg max pos: max_acc 0.7685 max_p 0.7568 max_r 0.4242 max_f1 0.5437
# avg max pair: max_acc 0.8856 max_p 0.3882 max_r 0.5000 max_f1 0.4371
#
# Fold 1 Epoch 8 val loss 2.1425
# emotion_predict: val acc 0.8128 p 0.7800 r 0.5909 f1 0.6724
# max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
#
# cause_predict: val acc 0.7783 p 0.6909 r 0.5758 f1 0.6281
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.9058 p 0.4697 r 0.4697 f1 0.4697
# max_acc 0.9058 max_p 0.4697 max_r 0.4697 max_f1 0.4697
#
# avg max cause: max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9058 max_p 0.4697 max_r 0.4697 max_f1 0.4697
#
# Fold 1 Epoch 9 val loss 2.1484
# emotion_predict: val acc 0.7980 p 0.6812 r 0.7121 f1 0.6963
# max_acc 0.7980 max_p 0.6812 max_r 0.7121 max_f1 0.6963
#
# cause_predict: val acc 0.7537 p 0.6333 r 0.5758 f1 0.6032
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8048 p 0.2635 r 0.6667 f1 0.3777
# max_acc 0.9058 max_p 0.4697 max_r 0.4697 max_f1 0.4697
#
# avg max cause: max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
# avg max pos: max_acc 0.8128 max_p 0.7800 max_r 0.5909 max_f1 0.6724
# avg max pair: max_acc 0.9058 max_p 0.4697 max_r 0.4697 max_f1 0.4697
#
# Fold 1 Epoch 10 val loss 2.0710
# emotion_predict: val acc 0.8325 p 0.7857 r 0.6667 f1 0.7213
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8762 p 0.3796 r 0.6212 f1 0.4713
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 11 val loss 2.0724
# emotion_predict: val acc 0.8177 p 0.7458 r 0.6667 f1 0.7040
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8735 p 0.3654 r 0.5758 f1 0.4471
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 12 val loss 2.0153
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7340 p 0.5937 r 0.5758 f1 0.5846
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8170 p 0.2785 r 0.6667 f1 0.3929
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 13 val loss 2.0374
# emotion_predict: val acc 0.8128 p 0.7258 r 0.6818 f1 0.7031
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7438 p 0.6296 r 0.5152 f1 0.5667
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8358 p 0.2941 r 0.6061 f1 0.3960
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 14 val loss 2.1521
# emotion_predict: val acc 0.8079 p 0.7015 r 0.7121 f1 0.7068
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7241 p 0.5833 r 0.5303 f1 0.5556
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8398 p 0.3121 r 0.6667 f1 0.4251
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 15 val loss 2.1726
# emotion_predict: val acc 0.8227 p 0.7500 r 0.6818 f1 0.7143
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7241 p 0.5758 r 0.5758 f1 0.5758
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8493 p 0.3231 r 0.6364 f1 0.4286
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 16 val loss 2.1497
# emotion_predict: val acc 0.8030 p 0.6912 r 0.7121 f1 0.7015
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7438 p 0.6591 r 0.4394 f1 0.5273
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8331 p 0.3014 r 0.6667 f1 0.4151
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 17 val loss 2.1484
# emotion_predict: val acc 0.8325 p 0.7759 r 0.6818 f1 0.7258
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7438 p 0.6094 r 0.5909 f1 0.6000
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8587 p 0.3511 r 0.6970 f1 0.4670
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 18 val loss 2.2988
# emotion_predict: val acc 0.8177 p 0.7377 r 0.6818 f1 0.7087
# max_acc 0.8325 max_p 0.7759 max_r 0.6818 max_f1 0.7258
#
# cause_predict: val acc 0.7340 p 0.5833 r 0.6364 f1 0.6087
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8668 p 0.3613 r 0.6515 f1 0.4649
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 19 val loss 2.3512
# emotion_predict: val acc 0.8276 p 0.7385 r 0.7273 f1 0.7328
# max_acc 0.8276 max_p 0.7385 max_r 0.7273 max_f1 0.7328
#
# cause_predict: val acc 0.7291 p 0.5965 r 0.5152 f1 0.5528
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8614 p 0.3520 r 0.6667 f1 0.4607
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# Fold 1 Epoch 20 val loss 2.7082
# emotion_predict: val acc 0.8276 p 0.7313 r 0.7424 f1 0.7368
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7340 p 0.5882 r 0.6061 f1 0.5970
# max_acc 0.7783 max_p 0.6909 max_r 0.5758 max_f1 0.6281
#
# pair_predict: val acc 0.8425 p 0.3053 r 0.6061 f1 0.4061
# max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# avg max cause: max_acc 0.7291 max_p 0.6000 max_r 0.5000 max_f1 0.5455
# avg max pos: max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
# avg max pair: max_acc 0.8762 max_p 0.3796 max_r 0.6212 max_f1 0.4713
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.54545454]]
# average : acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
#
# emotion_predict: val f1 in 1 fold: [[0.72131147]]
# average : acc 0.8325 p 0.7857 r 0.6667 f1 0.7213
#
# pair_predict: val f1 in 1 fold: [[0.47126437]]
# average : acc 0.8762 p 0.3796 r 0.6212 f1 0.4713

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.8902
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.4294
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3035
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.3043
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.1913
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.2322
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.2213
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.1411
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0922
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0928
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 3.0646
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 3.0366
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.0456
# emotion_predict: val acc 0.7340 p 0.8000 r 0.2424 f1 0.3721
# max_acc 0.7340 max_p 0.8000 max_r 0.2424 max_f1 0.3721
#
# cause_predict: val acc 0.7340 p 0.8750 r 0.2121 f1 0.3415
# max_acc 0.7340 max_p 0.8750 max_r 0.2121 max_f1 0.3415
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 3.0239
# emotion_predict: val acc 0.7389 p 0.7826 r 0.2727 f1 0.4045
# max_acc 0.7389 max_p 0.7826 max_r 0.2727 max_f1 0.4045
#
# cause_predict: val acc 0.7340 p 0.8333 r 0.2273 f1 0.3571
# max_acc 0.7340 max_p 0.8333 max_r 0.2273 max_f1 0.3571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 2.9836
# emotion_predict: val acc 0.7340 p 0.8750 r 0.2121 f1 0.3415
# max_acc 0.7389 max_p 0.7826 max_r 0.2727 max_f1 0.4045
#
# cause_predict: val acc 0.7340 p 0.9286 r 0.1970 f1 0.3250
# max_acc 0.7340 max_p 0.8333 max_r 0.2273 max_f1 0.3571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 16 val loss 2.9625
# emotion_predict: val acc 0.7389 p 0.8824 r 0.2273 f1 0.3614
# max_acc 0.7389 max_p 0.7826 max_r 0.2727 max_f1 0.4045
#
# cause_predict: val acc 0.7340 p 0.9286 r 0.1970 f1 0.3250
# max_acc 0.7340 max_p 0.8333 max_r 0.2273 max_f1 0.3571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 17 val loss 2.9123
# emotion_predict: val acc 0.7537 p 0.8333 r 0.3030 f1 0.4444
# max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
#
# cause_predict: val acc 0.7143 p 0.6818 r 0.2273 f1 0.3409
# max_acc 0.7340 max_p 0.8333 max_r 0.2273 max_f1 0.3571
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 18 val loss 2.8695
# emotion_predict: val acc 0.7389 p 0.6667 r 0.3939 f1 0.4952
# max_acc 0.7389 max_p 0.6667 max_r 0.3939 max_f1 0.4952
#
# cause_predict: val acc 0.7340 p 0.6579 r 0.3788 f1 0.4808
# max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
#
# pair_predict: val acc 0.9260 p 0.9231 r 0.1818 f1 0.3038
# max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# avg max cause: max_acc 0.7340 max_p 0.6579 max_r 0.3788 max_f1 0.4808
# avg max pos: max_acc 0.7389 max_p 0.6667 max_r 0.3939 max_f1 0.4952
# avg max pair: max_acc 0.9260 max_p 0.9231 max_r 0.1818 max_f1 0.3038
#
# Fold 1 Epoch 19 val loss 2.8040
# emotion_predict: val acc 0.7488 p 0.7027 r 0.3939 f1 0.5049
# max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
#
# cause_predict: val acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
# max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
#
# pair_predict: val acc 0.9260 p 0.8667 r 0.1970 f1 0.3210
# max_acc 0.9260 max_p 0.8667 max_r 0.1970 max_f1 0.3210
#
# avg max cause: max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
# avg max pos: max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
# avg max pair: max_acc 0.9260 max_p 0.8667 max_r 0.1970 max_f1 0.3210
#
# Fold 1 Epoch 20 val loss 2.7525
# emotion_predict: val acc 0.7438 p 0.7059 r 0.3636 f1 0.4800
# max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
#
# cause_predict: val acc 0.7340 p 0.6304 r 0.4394 f1 0.5179
# max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
#
# pair_predict: val acc 0.9219 p 0.7222 r 0.1970 f1 0.3095
# max_acc 0.9260 max_p 0.8667 max_r 0.1970 max_f1 0.3210
#
# avg max cause: max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
# avg max pos: max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
# avg max pair: max_acc 0.9260 max_p 0.8667 max_r 0.1970 max_f1 0.3210
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.52173913]]
# average : acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
#
# emotion_predict: val f1 in 1 fold: [[0.50485437]]
# average : acc 0.7488 p 0.7027 r 0.3939 f1 0.5049
#
# pair_predict: val f1 in 1 fold: [[0.32098765]]
# average : acc 0.9260 p 0.8667 r 0.1970 f1 0.3210

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9083
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8086
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7773
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7519
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.7466
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.6967
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.6497
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.6168
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.5791
# emotion_predict: val acc 0.7192 p 0.7368 r 0.2121 f1 0.3294
# max_acc 0.7192 max_p 0.7368 max_r 0.2121 max_f1 0.3294
#
# cause_predict: val acc 0.7044 p 0.8750 r 0.1061 f1 0.1892
# max_acc 0.7044 max_p 0.8750 max_r 0.1061 max_f1 0.1892
#
# pair_predict: val acc 0.9233 p 0.7647 r 0.1970 f1 0.3133
# max_acc 0.9233 max_p 0.7647 max_r 0.1970 max_f1 0.3133
#
# avg max cause: max_acc 0.7044 max_p 0.8750 max_r 0.1061 max_f1 0.1892
# avg max pos: max_acc 0.7192 max_p 0.7368 max_r 0.2121 max_f1 0.3294
# avg max pair: max_acc 0.9233 max_p 0.7647 max_r 0.1970 max_f1 0.3133
#
# Fold 1 Epoch 10 val loss 2.5376
# emotion_predict: val acc 0.7143 p 0.5870 r 0.4091 f1 0.4821
# max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
#
# cause_predict: val acc 0.7143 p 0.6250 r 0.3030 f1 0.4082
# max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
#
# pair_predict: val acc 0.9058 p 0.4600 r 0.3485 f1 0.3966
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 11 val loss 2.4961
# emotion_predict: val acc 0.7291 p 0.6571 r 0.3485 f1 0.4554
# max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
#
# cause_predict: val acc 0.7192 p 0.6552 r 0.2879 f1 0.4000
# max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
#
# pair_predict: val acc 0.9152 p 0.5405 r 0.3030 f1 0.3883
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 12 val loss 2.4474
# emotion_predict: val acc 0.7291 p 0.6222 r 0.4242 f1 0.5045
# max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
#
# cause_predict: val acc 0.7192 p 0.5918 r 0.4394 f1 0.5043
# max_acc 0.7192 max_p 0.5918 max_r 0.4394 max_f1 0.5043
#
# pair_predict: val acc 0.8560 p 0.3010 r 0.4697 f1 0.3669
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 13 val loss 2.4071
# emotion_predict: val acc 0.7291 p 0.6410 r 0.3788 f1 0.4762
# max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
#
# cause_predict: val acc 0.7291 p 0.6078 r 0.4697 f1 0.5299
# max_acc 0.7291 max_p 0.6078 max_r 0.4697 max_f1 0.5299
#
# pair_predict: val acc 0.8358 p 0.2778 r 0.5303 f1 0.3646
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 14 val loss 2.3715
# emotion_predict: val acc 0.7488 p 0.7586 r 0.3333 f1 0.4632
# max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
#
# cause_predict: val acc 0.7143 p 0.5870 r 0.4091 f1 0.4821
# max_acc 0.7291 max_p 0.6078 max_r 0.4697 max_f1 0.5299
#
# pair_predict: val acc 0.8721 p 0.3253 r 0.4091 f1 0.3624
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 15 val loss 2.3667
# emotion_predict: val acc 0.7192 p 0.5882 r 0.4545 f1 0.5128
# max_acc 0.7192 max_p 0.5882 max_r 0.4545 max_f1 0.5128
#
# cause_predict: val acc 0.7044 p 0.5441 r 0.5606 f1 0.5522
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.8318 p 0.2677 r 0.5152 f1 0.3523
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 16 val loss 2.3402
# emotion_predict: val acc 0.7340 p 0.6250 r 0.4545 f1 0.5263
# max_acc 0.7340 max_p 0.6250 max_r 0.4545 max_f1 0.5263
#
# cause_predict: val acc 0.7094 p 0.5538 r 0.5455 f1 0.5496
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.8371 p 0.2689 r 0.4848 f1 0.3459
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 17 val loss 2.3078
# emotion_predict: val acc 0.7488 p 0.6829 r 0.4242 f1 0.5234
# max_acc 0.7340 max_p 0.6250 max_r 0.4545 max_f1 0.5263
#
# cause_predict: val acc 0.7192 p 0.5849 r 0.4697 f1 0.5210
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.8412 p 0.2719 r 0.4697 f1 0.3444
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 18 val loss 2.2857
# emotion_predict: val acc 0.7438 p 0.6591 r 0.4394 f1 0.5273
# max_acc 0.7438 max_p 0.6591 max_r 0.4394 max_f1 0.5273
#
# cause_predict: val acc 0.7241 p 0.5893 r 0.5000 f1 0.5410
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.8318 p 0.2713 r 0.5303 f1 0.3590
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 19 val loss 2.2868
# emotion_predict: val acc 0.7586 p 0.6735 r 0.5000 f1 0.5739
# max_acc 0.7586 max_p 0.6735 max_r 0.5000 max_f1 0.5739
#
# cause_predict: val acc 0.7340 p 0.6111 r 0.5000 f1 0.5500
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.8493 p 0.2909 r 0.4848 f1 0.3636
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# Fold 1 Epoch 20 val loss 2.2818
# emotion_predict: val acc 0.7635 p 0.6607 r 0.5606 f1 0.6066
# max_acc 0.7635 max_p 0.6607 max_r 0.5606 max_f1 0.6066
#
# cause_predict: val acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
# max_acc 0.7291 max_p 0.5932 max_r 0.5303 max_f1 0.5600
#
# pair_predict: val acc 0.8533 p 0.3028 r 0.5000 f1 0.3771
# max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# avg max cause: max_acc 0.7143 max_p 0.6250 max_r 0.3030 max_f1 0.4082
# avg max pos: max_acc 0.7143 max_p 0.5870 max_r 0.4091 max_f1 0.4821
# avg max pair: max_acc 0.9058 max_p 0.4600 max_r 0.3485 max_f1 0.3966
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.40816326]]
# average : acc 0.7143 p 0.6250 r 0.3030 f1 0.4082
#
# emotion_predict: val f1 in 1 fold: [[0.48214286]]
# average : acc 0.7143 p 0.5870 r 0.4091 f1 0.4821
#
# pair_predict: val f1 in 1 fold: [[0.39655172]]
# average : acc 0.9058 p 0.4600 r 0.3485 f1 0.3966

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.1978
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.7143 p 0.9000 r 0.1364 f1 0.2368
# max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.9352
# emotion_predict: val acc 0.6749 p 0.5000 r 0.2121 f1 0.2979
# max_acc 0.6749 max_p 0.5000 max_r 0.2121 max_f1 0.2979
#
# cause_predict: val acc 0.7389 p 0.8095 r 0.2576 f1 0.3908
# max_acc 0.7389 max_p 0.8095 max_r 0.2576 max_f1 0.3908
#
# pair_predict: val acc 0.9166 p 0.7500 r 0.0909 f1 0.1622
# max_acc 0.9166 max_p 0.7500 max_r 0.0909 max_f1 0.1622
#
# avg max cause: max_acc 0.7389 max_p 0.8095 max_r 0.2576 max_f1 0.3908
# avg max pos: max_acc 0.6749 max_p 0.5000 max_r 0.2121 max_f1 0.2979
# avg max pair: max_acc 0.9166 max_p 0.7500 max_r 0.0909 max_f1 0.1622
#
# Fold 1 Epoch 3 val loss 2.8238
# emotion_predict: val acc 0.7291 p 0.7200 r 0.2727 f1 0.3956
# max_acc 0.7291 max_p 0.7200 max_r 0.2727 max_f1 0.3956
#
# cause_predict: val acc 0.7192 p 0.5957 r 0.4242 f1 0.4956
# max_acc 0.7192 max_p 0.5957 max_r 0.4242 max_f1 0.4956
#
# pair_predict: val acc 0.9206 p 0.6842 r 0.1970 f1 0.3059
# max_acc 0.9206 max_p 0.6842 max_r 0.1970 max_f1 0.3059
#
# avg max cause: max_acc 0.7192 max_p 0.5957 max_r 0.4242 max_f1 0.4956
# avg max pos: max_acc 0.7291 max_p 0.7200 max_r 0.2727 max_f1 0.3956
# avg max pair: max_acc 0.9206 max_p 0.6842 max_r 0.1970 max_f1 0.3059
#
# Fold 1 Epoch 4 val loss 2.7224
# emotion_predict: val acc 0.7291 p 0.8667 r 0.1970 f1 0.3210
# max_acc 0.7291 max_p 0.7200 max_r 0.2727 max_f1 0.3956
#
# cause_predict: val acc 0.7438 p 0.7692 r 0.3030 f1 0.4348
# max_acc 0.7192 max_p 0.5957 max_r 0.4242 max_f1 0.4956
#
# pair_predict: val acc 0.9233 p 0.6452 r 0.3030 f1 0.4124
# max_acc 0.9233 max_p 0.6452 max_r 0.3030 max_f1 0.4124
#
# avg max cause: max_acc 0.7438 max_p 0.7692 max_r 0.3030 max_f1 0.4348
# avg max pos: max_acc 0.7291 max_p 0.8667 max_r 0.1970 max_f1 0.3210
# avg max pair: max_acc 0.9233 max_p 0.6452 max_r 0.3030 max_f1 0.4124
#
# Fold 1 Epoch 5 val loss 2.7105
# emotion_predict: val acc 0.6798 p 0.5075 r 0.5152 f1 0.5113
# max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
#
# cause_predict: val acc 0.7192 p 0.5672 r 0.5758 f1 0.5714
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9192 p 0.5714 r 0.3636 f1 0.4444
# max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# avg max cause: max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# Fold 1 Epoch 6 val loss 2.7187
# emotion_predict: val acc 0.7241 p 0.6786 r 0.2879 f1 0.4043
# max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
#
# cause_predict: val acc 0.7537 p 0.6818 r 0.4545 f1 0.5455
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9058 p 0.4600 r 0.3485 f1 0.3966
# max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# avg max cause: max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# Fold 1 Epoch 7 val loss 2.7197
# emotion_predict: val acc 0.7291 p 0.5873 r 0.5606 f1 0.5736
# max_acc 0.7291 max_p 0.5873 max_r 0.5606 max_f1 0.5736
#
# cause_predict: val acc 0.7192 p 0.5714 r 0.5455 f1 0.5581
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9139 p 0.5294 r 0.2727 f1 0.3600
# max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# avg max cause: max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# Fold 1 Epoch 8 val loss 2.8686
# emotion_predict: val acc 0.7241 p 0.6136 r 0.4091 f1 0.4909
# max_acc 0.7291 max_p 0.5873 max_r 0.5606 max_f1 0.5736
#
# cause_predict: val acc 0.7094 p 0.5745 r 0.4091 f1 0.4779
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9098 p 0.4872 r 0.2879 f1 0.3619
# max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# avg max cause: max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# Fold 1 Epoch 9 val loss 2.6045
# emotion_predict: val acc 0.7586 p 0.6604 r 0.5303 f1 0.5882
# max_acc 0.7586 max_p 0.6604 max_r 0.5303 max_f1 0.5882
#
# cause_predict: val acc 0.7340 p 0.6071 r 0.5152 f1 0.5574
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9139 p 0.5208 r 0.3788 f1 0.4386
# max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# avg max cause: max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
# avg max pos: max_acc 0.6798 max_p 0.5075 max_r 0.5152 max_f1 0.5113
# avg max pair: max_acc 0.9192 max_p 0.5714 max_r 0.3636 max_f1 0.4444
#
# Fold 1 Epoch 10 val loss 2.5665
# emotion_predict: val acc 0.7635 p 0.6957 r 0.4848 f1 0.5714
# max_acc 0.7586 max_p 0.6604 max_r 0.5303 max_f1 0.5882
#
# cause_predict: val acc 0.7438 p 0.6522 r 0.4545 f1 0.5357
# max_acc 0.7192 max_p 0.5672 max_r 0.5758 max_f1 0.5714
#
# pair_predict: val acc 0.9058 p 0.4706 r 0.4848 f1 0.4776
# max_acc 0.9058 max_p 0.4706 max_r 0.4848 max_f1 0.4776
#
# avg max cause: max_acc 0.7438 max_p 0.6522 max_r 0.4545 max_f1 0.5357
# avg max pos: max_acc 0.7635 max_p 0.6957 max_r 0.4848 max_f1 0.5714
# avg max pair: max_acc 0.9058 max_p 0.4706 max_r 0.4848 max_f1 0.4776
#
# Fold 1 Epoch 11 val loss 2.7225
# emotion_predict: val acc 0.7635 p 0.6500 r 0.5909 f1 0.6190
# max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
#
# cause_predict: val acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9219 p 0.5833 r 0.4242 f1 0.4912
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 12 val loss 2.6876
# emotion_predict: val acc 0.7438 p 0.6167 r 0.5606 f1 0.5873
# max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
#
# cause_predict: val acc 0.7537 p 0.6667 r 0.4848 f1 0.5614
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8923 p 0.4028 r 0.4394 f1 0.4203
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 13 val loss 2.7339
# emotion_predict: val acc 0.8128 p 0.7333 r 0.6667 f1 0.6984
# max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
#
# cause_predict: val acc 0.7241 p 0.5735 r 0.5909 f1 0.5821
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9058 p 0.4687 r 0.4545 f1 0.4615
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 14 val loss 2.6101
# emotion_predict: val acc 0.7635 p 0.6324 r 0.6515 f1 0.6418
# max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
#
# cause_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.9206 p 0.5814 r 0.3788 f1 0.4587
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 15 val loss 2.8968
# emotion_predict: val acc 0.7980 p 0.7049 r 0.6515 f1 0.6772
# max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
#
# cause_predict: val acc 0.6946 p 0.5312 r 0.5152 f1 0.5231
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8869 p 0.3902 r 0.4848 f1 0.4324
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 16 val loss 2.7224
# emotion_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
#
# cause_predict: val acc 0.7094 p 0.5660 r 0.4545 f1 0.5042
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8923 p 0.4054 r 0.4545 f1 0.4286
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 17 val loss 3.0020
# emotion_predict: val acc 0.7438 p 0.5897 r 0.6970 f1 0.6389
# max_acc 0.8128 max_p 0.7333 max_r 0.6667 max_f1 0.6984
#
# cause_predict: val acc 0.7044 p 0.5417 r 0.5909 f1 0.5652
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8694 p 0.3434 r 0.5152 f1 0.4121
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 18 val loss 2.8426
# emotion_predict: val acc 0.8227 p 0.7206 r 0.7424 f1 0.7313
# max_acc 0.8227 max_p 0.7206 max_r 0.7424 max_f1 0.7313
#
# cause_predict: val acc 0.7143 p 0.5541 r 0.6212 f1 0.5857
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8708 p 0.3558 r 0.5606 f1 0.4353
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 19 val loss 2.8189
# emotion_predict: val acc 0.8079 p 0.7288 r 0.6515 f1 0.6880
# max_acc 0.8227 max_p 0.7206 max_r 0.7424 max_f1 0.7313
#
# cause_predict: val acc 0.7488 p 0.6190 r 0.5909 f1 0.6047
# max_acc 0.7488 max_p 0.6190 max_r 0.5909 max_f1 0.6047
#
# pair_predict: val acc 0.9071 p 0.4783 r 0.5000 f1 0.4889
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# Fold 1 Epoch 20 val loss 3.1627
# emotion_predict: val acc 0.7635 p 0.6324 r 0.6515 f1 0.6418
# max_acc 0.8227 max_p 0.7206 max_r 0.7424 max_f1 0.7313
#
# cause_predict: val acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
# max_acc 0.7488 max_p 0.6190 max_r 0.5909 max_f1 0.6047
#
# pair_predict: val acc 0.8856 p 0.3908 r 0.5152 f1 0.4444
# max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# avg max cause: max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
# avg max pos: max_acc 0.7635 max_p 0.6500 max_r 0.5909 max_f1 0.6190
# avg max pair: max_acc 0.9219 max_p 0.5833 max_r 0.4242 max_f1 0.4912
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.59541985]]
# average : acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
#
# emotion_predict: val f1 in 1 fold: [[0.61904762]]
# average : acc 0.7635 p 0.6500 r 0.5909 f1 0.6190
#
# pair_predict: val f1 in 1 fold: [[0.49122807]]
# average : acc 0.9219 p 0.5833 r 0.4242 f1 0.4912

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7999
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.6317
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9031 p 0.4286 r 0.2727 f1 0.3333
# max_acc 0.9031 max_p 0.4286 max_r 0.2727 max_f1 0.3333
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9031 max_p 0.4286 max_r 0.2727 max_f1 0.3333
#
# Fold 1 Epoch 3 val loss 2.5047
# emotion_predict: val acc 0.6847 p 0.5152 r 0.5152 f1 0.5152
# max_acc 0.6847 max_p 0.5152 max_r 0.5152 max_f1 0.5152
#
# cause_predict: val acc 0.6946 p 0.5250 r 0.6364 f1 0.5753
# max_acc 0.6946 max_p 0.5250 max_r 0.6364 max_f1 0.5753
#
# pair_predict: val acc 0.7497 p 0.2115 r 0.6667 f1 0.3212
# max_acc 0.9031 max_p 0.4286 max_r 0.2727 max_f1 0.3333
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9031 max_p 0.4286 max_r 0.2727 max_f1 0.3333
#
# Fold 1 Epoch 4 val loss 2.2217
# emotion_predict: val acc 0.7980 p 0.8049 r 0.5000 f1 0.6168
# max_acc 0.7980 max_p 0.8049 max_r 0.5000 max_f1 0.6168
#
# cause_predict: val acc 0.7438 p 0.6667 r 0.4242 f1 0.5185
# max_acc 0.6946 max_p 0.5250 max_r 0.6364 max_f1 0.5753
#
# pair_predict: val acc 0.9192 p 0.5750 r 0.3485 f1 0.4340
# max_acc 0.9192 max_p 0.5750 max_r 0.3485 max_f1 0.4340
#
# avg max cause: max_acc 0.7438 max_p 0.6667 max_r 0.4242 max_f1 0.5185
# avg max pos: max_acc 0.7980 max_p 0.8049 max_r 0.5000 max_f1 0.6168
# avg max pair: max_acc 0.9192 max_p 0.5750 max_r 0.3485 max_f1 0.4340
#
# Fold 1 Epoch 5 val loss 2.0805
# emotion_predict: val acc 0.7931 p 0.7500 r 0.5455 f1 0.6316
# max_acc 0.7931 max_p 0.7500 max_r 0.5455 max_f1 0.6316
#
# cause_predict: val acc 0.7488 p 0.7027 r 0.3939 f1 0.5049
# max_acc 0.6946 max_p 0.5250 max_r 0.6364 max_f1 0.5753
#
# pair_predict: val acc 0.9058 p 0.4687 r 0.4545 f1 0.4615
# max_acc 0.9058 max_p 0.4687 max_r 0.4545 max_f1 0.4615
#
# avg max cause: max_acc 0.7488 max_p 0.7027 max_r 0.3939 max_f1 0.5049
# avg max pos: max_acc 0.7931 max_p 0.7500 max_r 0.5455 max_f1 0.6316
# avg max pair: max_acc 0.9058 max_p 0.4687 max_r 0.4545 max_f1 0.4615
#
# Fold 1 Epoch 6 val loss 2.0543
# emotion_predict: val acc 0.7980 p 0.7358 r 0.5909 f1 0.6555
# max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
#
# cause_predict: val acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
# max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
#
# pair_predict: val acc 0.8991 p 0.4444 r 0.5455 f1 0.4898
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 7 val loss 2.0004
# emotion_predict: val acc 0.8079 p 0.7213 r 0.6667 f1 0.6929
# max_acc 0.8079 max_p 0.7213 max_r 0.6667 max_f1 0.6929
#
# cause_predict: val acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
# max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
#
# pair_predict: val acc 0.8560 p 0.3360 r 0.6364 f1 0.4398
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 8 val loss 2.1355
# emotion_predict: val acc 0.7783 p 0.6479 r 0.6970 f1 0.6715
# max_acc 0.8079 max_p 0.7213 max_r 0.6667 max_f1 0.6929
#
# cause_predict: val acc 0.7291 p 0.5797 r 0.6061 f1 0.5926
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8304 p 0.2945 r 0.6515 f1 0.4057
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 9 val loss 2.1092
# emotion_predict: val acc 0.8276 p 0.7313 r 0.7424 f1 0.7368
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7143 p 0.5541 r 0.6212 f1 0.5857
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8358 p 0.3158 r 0.7273 f1 0.4404
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 10 val loss 2.3072
# emotion_predict: val acc 0.7882 p 0.6825 r 0.6515 f1 0.6667
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7044 p 0.5536 r 0.4697 f1 0.5082
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8573 p 0.3361 r 0.6212 f1 0.4362
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 11 val loss 2.3509
# emotion_predict: val acc 0.8030 p 0.7241 r 0.6364 f1 0.6774
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7192 p 0.5672 r 0.5758 f1 0.5714
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8721 p 0.3645 r 0.5909 f1 0.4509
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 12 val loss 2.5472
# emotion_predict: val acc 0.7833 p 0.6618 r 0.6818 f1 0.6716
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.6995 p 0.5532 r 0.3939 f1 0.4602
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8869 p 0.3977 r 0.5303 f1 0.4545
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 13 val loss 2.7990
# emotion_predict: val acc 0.7783 p 0.6842 r 0.5909 f1 0.6341
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7340 p 0.5909 r 0.5909 f1 0.5909
# max_acc 0.7291 max_p 0.5797 max_r 0.6061 max_f1 0.5926
#
# pair_predict: val acc 0.8843 p 0.3810 r 0.4848 f1 0.4267
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 14 val loss 2.8506
# emotion_predict: val acc 0.7783 p 0.6479 r 0.6970 f1 0.6715
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8425 p 0.3023 r 0.5909 f1 0.4000
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 15 val loss 2.9367
# emotion_predict: val acc 0.7783 p 0.6780 r 0.6061 f1 0.6400
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7340 p 0.5909 r 0.5909 f1 0.5909
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8816 p 0.3804 r 0.5303 f1 0.4430
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 16 val loss 3.2154
# emotion_predict: val acc 0.8030 p 0.6970 r 0.6970 f1 0.6970
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7389 p 0.6102 r 0.5455 f1 0.5760
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8843 p 0.3913 r 0.5455 f1 0.4557
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 17 val loss 4.5111
# emotion_predict: val acc 0.7833 p 0.6964 r 0.5909 f1 0.6393
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.6897 p 0.5195 r 0.6061 f1 0.5594
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8748 p 0.3608 r 0.5303 f1 0.4294
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 18 val loss 3.7324
# emotion_predict: val acc 0.7635 p 0.6216 r 0.6970 f1 0.6571
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8748 p 0.3412 r 0.4394 f1 0.3841
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 19 val loss 3.7358
# emotion_predict: val acc 0.7931 p 0.7143 r 0.6061 f1 0.6557
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.7143 p 0.5588 r 0.5758 f1 0.5672
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8843 p 0.3810 r 0.4848 f1 0.4267
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# Fold 1 Epoch 20 val loss 4.5219
# emotion_predict: val acc 0.7882 p 0.7018 r 0.6061 f1 0.6504
# max_acc 0.8276 max_p 0.7313 max_r 0.7424 max_f1 0.7368
#
# cause_predict: val acc 0.6897 p 0.5238 r 0.5000 f1 0.5116
# max_acc 0.7537 max_p 0.6379 max_r 0.5606 max_f1 0.5968
#
# pair_predict: val acc 0.8883 p 0.3692 r 0.3636 f1 0.3664
# max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# avg max cause: max_acc 0.7635 max_p 0.6875 max_r 0.5000 max_f1 0.5789
# avg max pos: max_acc 0.7980 max_p 0.7358 max_r 0.5909 max_f1 0.6555
# avg max pair: max_acc 0.8991 max_p 0.4444 max_r 0.5455 max_f1 0.4898
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.57894737]]
# average : acc 0.7635 p 0.6875 r 0.5000 f1 0.5789
#
# emotion_predict: val f1 in 1 fold: [[0.65546218]]
# average : acc 0.7980 p 0.7358 r 0.5909 f1 0.6555
#
# pair_predict: val f1 in 1 fold: [[0.48979592]]
# average : acc 0.8991 p 0.4444 r 0.5455 f1 0.4898

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.1681
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0414
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0059
# emotion_predict: val acc 0.6946 p 0.5286 r 0.5606 f1 0.5441
# max_acc 0.6946 max_p 0.5286 max_r 0.5606 max_f1 0.5441
#
# cause_predict: val acc 0.7192 p 0.5584 r 0.6515 f1 0.6014
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9233 p 0.7647 r 0.1970 f1 0.3133
# max_acc 0.9233 max_p 0.7647 max_r 0.1970 max_f1 0.3133
#
# avg max cause: max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
# avg max pos: max_acc 0.6946 max_p 0.5286 max_r 0.5606 max_f1 0.5441
# avg max pair: max_acc 0.9233 max_p 0.7647 max_r 0.1970 max_f1 0.3133
#
# Fold 1 Epoch 4 val loss 2.7430
# emotion_predict: val acc 0.7488 p 0.7419 r 0.3485 f1 0.4742
# max_acc 0.6946 max_p 0.5286 max_r 0.5606 max_f1 0.5441
#
# cause_predict: val acc 0.7291 p 0.6486 r 0.3636 f1 0.4660
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9166 p 0.5667 r 0.2576 f1 0.3542
# max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# avg max cause: max_acc 0.7291 max_p 0.6486 max_r 0.3636 max_f1 0.4660
# avg max pos: max_acc 0.7488 max_p 0.7419 max_r 0.3485 max_f1 0.4742
# avg max pair: max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# Fold 1 Epoch 5 val loss 2.7804
# emotion_predict: val acc 0.7438 p 0.6944 r 0.3788 f1 0.4902
# max_acc 0.6946 max_p 0.5286 max_r 0.5606 max_f1 0.5441
#
# cause_predict: val acc 0.7291 p 0.6222 r 0.4242 f1 0.5045
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9233 p 0.6800 r 0.2576 f1 0.3736
# max_acc 0.9233 max_p 0.6800 max_r 0.2576 max_f1 0.3736
#
# avg max cause: max_acc 0.7291 max_p 0.6222 max_r 0.4242 max_f1 0.5045
# avg max pos: max_acc 0.7438 max_p 0.6944 max_r 0.3788 max_f1 0.4902
# avg max pair: max_acc 0.9233 max_p 0.6800 max_r 0.2576 max_f1 0.3736
#
# Fold 1 Epoch 6 val loss 2.6094
# emotion_predict: val acc 0.7635 p 0.6667 r 0.5455 f1 0.6000
# max_acc 0.7635 max_p 0.6667 max_r 0.5455 max_f1 0.6000
#
# cause_predict: val acc 0.7488 p 0.6230 r 0.5758 f1 0.5984
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.8991 p 0.4308 r 0.4242 f1 0.4275
# max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# avg max cause: max_acc 0.7488 max_p 0.6230 max_r 0.5758 max_f1 0.5984
# avg max pos: max_acc 0.7635 max_p 0.6667 max_r 0.5455 max_f1 0.6000
# avg max pair: max_acc 0.8991 max_p 0.4308 max_r 0.4242 max_f1 0.4275
#
# Fold 1 Epoch 7 val loss 2.4962
# emotion_predict: val acc 0.8128 p 0.7593 r 0.6212 f1 0.6833
# max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
#
# cause_predict: val acc 0.7488 p 0.6316 r 0.5455 f1 0.5854
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9192 p 0.5577 r 0.4394 f1 0.4915
# max_acc 0.9192 max_p 0.5577 max_r 0.4394 max_f1 0.4915
#
# avg max cause: max_acc 0.7488 max_p 0.6316 max_r 0.5455 max_f1 0.5854
# avg max pos: max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
# avg max pair: max_acc 0.9192 max_p 0.5577 max_r 0.4394 max_f1 0.4915
#
# Fold 1 Epoch 8 val loss 2.5114
# emotion_predict: val acc 0.8177 p 0.7959 r 0.5909 f1 0.6783
# max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
#
# cause_predict: val acc 0.7241 p 0.5962 r 0.4697 f1 0.5254
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9260 p 0.6170 r 0.4394 f1 0.5133
# max_acc 0.9260 max_p 0.6170 max_r 0.4394 max_f1 0.5133
#
# avg max cause: max_acc 0.7241 max_p 0.5962 max_r 0.4697 max_f1 0.5254
# avg max pos: max_acc 0.8177 max_p 0.7959 max_r 0.5909 max_f1 0.6783
# avg max pair: max_acc 0.9260 max_p 0.6170 max_r 0.4394 max_f1 0.5133
#
# Fold 1 Epoch 9 val loss 2.4741
# emotion_predict: val acc 0.8030 p 0.7321 r 0.6212 f1 0.6721
# max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
#
# cause_predict: val acc 0.7241 p 0.5862 r 0.5152 f1 0.5484
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.5303 f1 0.5147
# max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# avg max cause: max_acc 0.7241 max_p 0.5862 max_r 0.5152 max_f1 0.5484
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# Fold 1 Epoch 10 val loss 2.3900
# emotion_predict: val acc 0.8177 p 0.7544 r 0.6515 f1 0.6992
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7340 p 0.6000 r 0.5455 f1 0.5714
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9071 p 0.4783 r 0.5000 f1 0.4889
# max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# avg max cause: max_acc 0.7241 max_p 0.5862 max_r 0.5152 max_f1 0.5484
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# Fold 1 Epoch 11 val loss 2.5269
# emotion_predict: val acc 0.7833 p 0.6897 r 0.6061 f1 0.6452
# max_acc 0.8177 max_p 0.7544 max_r 0.6515 max_f1 0.6992
#
# cause_predict: val acc 0.7044 p 0.5455 r 0.5455 f1 0.5455
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.8937 p 0.4177 r 0.5000 f1 0.4552
# max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# avg max cause: max_acc 0.7241 max_p 0.5862 max_r 0.5152 max_f1 0.5484
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# Fold 1 Epoch 12 val loss 2.2759
# emotion_predict: val acc 0.8276 p 0.7719 r 0.6667 f1 0.7154
# max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
#
# cause_predict: val acc 0.7488 p 0.6271 r 0.5606 f1 0.5920
# max_acc 0.7192 max_p 0.5584 max_r 0.6515 max_f1 0.6014
#
# pair_predict: val acc 0.9017 p 0.4533 r 0.5152 f1 0.4823
# max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# avg max cause: max_acc 0.7241 max_p 0.5862 max_r 0.5152 max_f1 0.5484
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# Fold 1 Epoch 13 val loss 2.4758
# emotion_predict: val acc 0.7931 p 0.6935 r 0.6515 f1 0.6719
# max_acc 0.8276 max_p 0.7719 max_r 0.6667 max_f1 0.7154
#
# cause_predict: val acc 0.7389 p 0.5942 r 0.6212 f1 0.6074
# max_acc 0.7389 max_p 0.5942 max_r 0.6212 max_f1 0.6074
#
# pair_predict: val acc 0.8937 p 0.4301 r 0.6061 f1 0.5031
# max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# avg max cause: max_acc 0.7241 max_p 0.5862 max_r 0.5152 max_f1 0.5484
# avg max pos: max_acc 0.8030 max_p 0.7321 max_r 0.6212 max_f1 0.6721
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.5303 max_f1 0.5147
#
# Fold 1 Epoch 14 val loss 2.4514
# emotion_predict: val acc 0.8424 p 0.7742 r 0.7273 f1 0.7500
# max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
#
# cause_predict: val acc 0.7143 p 0.5541 r 0.6212 f1 0.5857
# max_acc 0.7389 max_p 0.5942 max_r 0.6212 max_f1 0.6074
#
# pair_predict: val acc 0.9004 p 0.4592 r 0.6818 f1 0.5488
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 15 val loss 2.3987
# emotion_predict: val acc 0.8030 p 0.6970 r 0.6970 f1 0.6970
# max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
#
# cause_predict: val acc 0.7586 p 0.6197 r 0.6667 f1 0.6423
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.8910 p 0.4227 r 0.6212 f1 0.5031
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 16 val loss 2.6949
# emotion_predict: val acc 0.8227 p 0.7344 r 0.7121 f1 0.7231
# max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
#
# cause_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.8964 p 0.4353 r 0.5606 f1 0.4901
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 17 val loss 2.4747
# emotion_predict: val acc 0.8473 p 0.7869 r 0.7273 f1 0.7559
# max_acc 0.8473 max_p 0.7869 max_r 0.7273 max_f1 0.7559
#
# cause_predict: val acc 0.7635 p 0.6406 r 0.6212 f1 0.6308
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.9139 p 0.5147 r 0.5303 f1 0.5224
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 18 val loss 2.9313
# emotion_predict: val acc 0.8030 p 0.7097 r 0.6667 f1 0.6875
# max_acc 0.8473 max_p 0.7869 max_r 0.7273 max_f1 0.7559
#
# cause_predict: val acc 0.7537 p 0.6379 r 0.5606 f1 0.5968
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.9125 p 0.5082 r 0.4697 f1 0.4882
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 19 val loss 3.1825
# emotion_predict: val acc 0.8374 p 0.7895 r 0.6818 f1 0.7317
# max_acc 0.8473 max_p 0.7869 max_r 0.7273 max_f1 0.7559
#
# cause_predict: val acc 0.7340 p 0.5909 r 0.5909 f1 0.5909
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.5152 f1 0.5075
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# Fold 1 Epoch 20 val loss 3.5895
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8473 max_p 0.7869 max_r 0.7273 max_f1 0.7559
#
# cause_predict: val acc 0.7094 p 0.5507 r 0.5758 f1 0.5630
# max_acc 0.7586 max_p 0.6197 max_r 0.6667 max_f1 0.6423
#
# pair_predict: val acc 0.8964 p 0.4368 r 0.5758 f1 0.4967
# max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# avg max cause: max_acc 0.7143 max_p 0.5541 max_r 0.6212 max_f1 0.5857
# avg max pos: max_acc 0.8424 max_p 0.7742 max_r 0.7273 max_f1 0.7500
# avg max pair: max_acc 0.9004 max_p 0.4592 max_r 0.6818 max_f1 0.5488
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58571429]]
# average : acc 0.7143 p 0.5541 r 0.6212 f1 0.5857
#
# emotion_predict: val f1 in 1 fold: [[0.75]]
# average : acc 0.8424 p 0.7742 r 0.7273 f1 0.7500
#
# pair_predict: val f1 in 1 fold: [[0.54878049]]
# average : acc 0.9004 p 0.4592 r 0.6818 f1 0.5488

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7426
# emotion_predict: val acc 0.6650 p 0.4545 r 0.1515 f1 0.2273
# max_acc 0.6650 max_p 0.4545 max_r 0.1515 max_f1 0.2273
#
# cause_predict: val acc 0.7044 p 0.6364 r 0.2121 f1 0.3182
# max_acc 0.7044 max_p 0.6364 max_r 0.2121 max_f1 0.3182
#
# pair_predict: val acc 0.9139 p 0.7500 r 0.0455 f1 0.0857
# max_acc 0.9139 max_p 0.7500 max_r 0.0455 max_f1 0.0857
#
# avg max cause: max_acc 0.7044 max_p 0.6364 max_r 0.2121 max_f1 0.3182
# avg max pos: max_acc 0.6650 max_p 0.4545 max_r 0.1515 max_f1 0.2273
# avg max pair: max_acc 0.9139 max_p 0.7500 max_r 0.0455 max_f1 0.0857
#
# Fold 1 Epoch 2 val loss 2.5153
# emotion_predict: val acc 0.6995 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.6650 max_p 0.4545 max_r 0.1515 max_f1 0.2273
#
# cause_predict: val acc 0.6995 p 1.0000 r 0.0758 f1 0.1408
# max_acc 0.7044 max_p 0.6364 max_r 0.2121 max_f1 0.3182
#
# pair_predict: val acc 0.8183 p 0.2406 r 0.4848 f1 0.3216
# max_acc 0.8183 max_p 0.2406 max_r 0.4848 max_f1 0.3216
#
# avg max cause: max_acc 0.6995 max_p 1.0000 max_r 0.0758 max_f1 0.1408
# avg max pos: max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
# avg max pair: max_acc 0.8183 max_p 0.2406 max_r 0.4848 max_f1 0.3216
#
# Fold 1 Epoch 3 val loss 2.3359
# emotion_predict: val acc 0.7044 p 0.5652 r 0.3939 f1 0.4643
# max_acc 0.7044 max_p 0.5652 max_r 0.3939 max_f1 0.4643
#
# cause_predict: val acc 0.7044 p 0.5484 r 0.5152 f1 0.5312
# max_acc 0.7044 max_p 0.5484 max_r 0.5152 max_f1 0.5312
#
# pair_predict: val acc 0.8614 p 0.3131 r 0.4697 f1 0.3758
# max_acc 0.8614 max_p 0.3131 max_r 0.4697 max_f1 0.3758
#
# avg max cause: max_acc 0.7044 max_p 0.5484 max_r 0.5152 max_f1 0.5312
# avg max pos: max_acc 0.7044 max_p 0.5652 max_r 0.3939 max_f1 0.4643
# avg max pair: max_acc 0.8614 max_p 0.3131 max_r 0.4697 max_f1 0.3758
#
# Fold 1 Epoch 4 val loss 2.2688
# emotion_predict: val acc 0.7635 p 0.7045 r 0.4697 f1 0.5636
# max_acc 0.7635 max_p 0.7045 max_r 0.4697 max_f1 0.5636
#
# cause_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7488 max_p 0.6471 max_r 0.5000 max_f1 0.5641
#
# pair_predict: val acc 0.8318 p 0.2815 r 0.5758 f1 0.3781
# max_acc 0.8318 max_p 0.2815 max_r 0.5758 max_f1 0.3781
#
# avg max cause: max_acc 0.7488 max_p 0.6471 max_r 0.5000 max_f1 0.5641
# avg max pos: max_acc 0.7635 max_p 0.7045 max_r 0.4697 max_f1 0.5636
# avg max pair: max_acc 0.8318 max_p 0.2815 max_r 0.5758 max_f1 0.3781
#
# Fold 1 Epoch 5 val loss 2.0616
# emotion_predict: val acc 0.7931 p 0.7727 r 0.5152 f1 0.6182
# max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
#
# cause_predict: val acc 0.7635 p 0.6800 r 0.5152 f1 0.5862
# max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
#
# pair_predict: val acc 0.8977 p 0.4375 r 0.5303 f1 0.4795
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 6 val loss 2.0786
# emotion_predict: val acc 0.8128 p 0.7593 r 0.6212 f1 0.6833
# max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
#
# cause_predict: val acc 0.7241 p 0.5862 r 0.5152 f1 0.5484
# max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
#
# pair_predict: val acc 0.8681 p 0.3491 r 0.5606 f1 0.4302
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 7 val loss 2.0648
# emotion_predict: val acc 0.7783 p 0.7059 r 0.5455 f1 0.6154
# max_acc 0.8128 max_p 0.7593 max_r 0.6212 max_f1 0.6833
#
# cause_predict: val acc 0.7488 p 0.6364 r 0.5303 f1 0.5785
# max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
#
# pair_predict: val acc 0.8937 p 0.4156 r 0.4848 f1 0.4476
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 8 val loss 2.1072
# emotion_predict: val acc 0.8128 p 0.7414 r 0.6515 f1 0.6935
# max_acc 0.8128 max_p 0.7414 max_r 0.6515 max_f1 0.6935
#
# cause_predict: val acc 0.7389 p 0.6102 r 0.5455 f1 0.5760
# max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
#
# pair_predict: val acc 0.8654 p 0.3482 r 0.5909 f1 0.4382
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 9 val loss 2.1347
# emotion_predict: val acc 0.7931 p 0.6875 r 0.6667 f1 0.6769
# max_acc 0.8128 max_p 0.7414 max_r 0.6515 max_f1 0.6935
#
# cause_predict: val acc 0.7389 p 0.6000 r 0.5909 f1 0.5954
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8533 p 0.3280 r 0.6212 f1 0.4293
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 10 val loss 2.1820
# emotion_predict: val acc 0.7931 p 0.6818 r 0.6818 f1 0.6818
# max_acc 0.8128 max_p 0.7414 max_r 0.6515 max_f1 0.6935
#
# cause_predict: val acc 0.7291 p 0.5873 r 0.5606 f1 0.5736
# max_acc 0.7389 max_p 0.6000 max_r 0.5909 max_f1 0.5954
#
# pair_predict: val acc 0.8398 p 0.3121 r 0.6667 f1 0.4251
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 11 val loss 2.2938
# emotion_predict: val acc 0.8128 p 0.7121 r 0.7121 f1 0.7121
# max_acc 0.8128 max_p 0.7121 max_r 0.7121 max_f1 0.7121
#
# cause_predict: val acc 0.7389 p 0.5970 r 0.6061 f1 0.6015
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8345 p 0.3007 r 0.6515 f1 0.4115
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 12 val loss 2.2464
# emotion_predict: val acc 0.8079 p 0.6957 r 0.7273 f1 0.7111
# max_acc 0.8128 max_p 0.7121 max_r 0.7121 max_f1 0.7121
#
# cause_predict: val acc 0.7291 p 0.6000 r 0.5000 f1 0.5455
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8371 p 0.3154 r 0.7121 f1 0.4372
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 13 val loss 2.5589
# emotion_predict: val acc 0.8227 p 0.7273 r 0.7273 f1 0.7273
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7438 p 0.6207 r 0.5455 f1 0.5806
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8694 p 0.3551 r 0.5758 f1 0.4393
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 14 val loss 2.5462
# emotion_predict: val acc 0.7931 p 0.7000 r 0.6364 f1 0.6667
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7488 p 0.6316 r 0.5455 f1 0.5854
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8560 p 0.3248 r 0.5758 f1 0.4153
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 15 val loss 2.6695
# emotion_predict: val acc 0.7980 p 0.6761 r 0.7273 f1 0.7007
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7192 p 0.5738 r 0.5303 f1 0.5512
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8694 p 0.3524 r 0.5606 f1 0.4327
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 16 val loss 3.0720
# emotion_predict: val acc 0.8227 p 0.7586 r 0.6667 f1 0.7097
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8762 p 0.3673 r 0.5455 f1 0.4390
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 17 val loss 3.4523
# emotion_predict: val acc 0.7980 p 0.6761 r 0.7273 f1 0.7007
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8802 p 0.3814 r 0.5606 f1 0.4540
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 18 val loss 3.5574
# emotion_predict: val acc 0.7931 p 0.6875 r 0.6667 f1 0.6769
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7192 p 0.5849 r 0.4697 f1 0.5210
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8762 p 0.3700 r 0.5606 f1 0.4458
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 19 val loss 3.8631
# emotion_predict: val acc 0.7931 p 0.7222 r 0.5909 f1 0.6500
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7340 p 0.6071 r 0.5152 f1 0.5574
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8977 p 0.4375 r 0.5303 f1 0.4795
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# Fold 1 Epoch 20 val loss 4.0900
# emotion_predict: val acc 0.7734 p 0.6351 r 0.7121 f1 0.6714
# max_acc 0.8227 max_p 0.7273 max_r 0.7273 max_f1 0.7273
#
# cause_predict: val acc 0.7241 p 0.5962 r 0.4697 f1 0.5254
# max_acc 0.7389 max_p 0.5970 max_r 0.6061 max_f1 0.6015
#
# pair_predict: val acc 0.8896 p 0.3974 r 0.4697 f1 0.4306
# max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# avg max cause: max_acc 0.7635 max_p 0.6800 max_r 0.5152 max_f1 0.5862
# avg max pos: max_acc 0.7931 max_p 0.7727 max_r 0.5152 max_f1 0.6182
# avg max pair: max_acc 0.8977 max_p 0.4375 max_r 0.5303 max_f1 0.4795
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.5862069]]
# average : acc 0.7635 p 0.6800 r 0.5152 f1 0.5862
#
# emotion_predict: val f1 in 1 fold: [[0.61818182]]
# average : acc 0.7931 p 0.7727 r 0.5152 f1 0.6182
#
# pair_predict: val f1 in 1 fold: [[0.47945205]]
# average : acc 0.8977 p 0.4375 r 0.5303 f1 0.4795

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.9724
# emotion_predict: val acc 0.6355 p 0.3571 r 0.1515 f1 0.2128
# max_acc 0.6355 max_p 0.3571 max_r 0.1515 max_f1 0.2128
#
# cause_predict: val acc 0.7143 p 0.9000 r 0.1364 f1 0.2368
# max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6355 max_p 0.3571 max_r 0.1515 max_f1 0.2128
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.1496
# emotion_predict: val acc 0.6946 p 0.7000 r 0.1061 f1 0.1842
# max_acc 0.6355 max_p 0.3571 max_r 0.1515 max_f1 0.2128
#
# cause_predict: val acc 0.7143 p 0.9000 r 0.1364 f1 0.2368
# max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6355 max_p 0.3571 max_r 0.1515 max_f1 0.2128
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0728
# emotion_predict: val acc 0.6995 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.6355 max_p 0.3571 max_r 0.1515 max_f1 0.2128
#
# cause_predict: val acc 0.7241 p 0.9167 r 0.1667 f1 0.2821
# max_acc 0.7241 max_p 0.9167 max_r 0.1667 max_f1 0.2821
#
# pair_predict: val acc 0.9179 p 1.0000 r 0.0758 f1 0.1408
# max_acc 0.9179 max_p 1.0000 max_r 0.0758 max_f1 0.1408
#
# avg max cause: max_acc 0.7241 max_p 0.9167 max_r 0.1667 max_f1 0.2821
# avg max pos: max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
# avg max pair: max_acc 0.9179 max_p 1.0000 max_r 0.0758 max_f1 0.1408
#
# Fold 1 Epoch 4 val loss 3.0791
# emotion_predict: val acc 0.6897 p 0.5484 r 0.2576 f1 0.3505
# max_acc 0.6897 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# cause_predict: val acc 0.6798 p 0.5106 r 0.3636 f1 0.4248
# max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
#
# pair_predict: val acc 0.8977 p 0.3529 r 0.1818 f1 0.2400
# max_acc 0.8977 max_p 0.3529 max_r 0.1818 max_f1 0.2400
#
# avg max cause: max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
# avg max pos: max_acc 0.6897 max_p 0.5484 max_r 0.2576 max_f1 0.3505
# avg max pair: max_acc 0.8977 max_p 0.3529 max_r 0.1818 max_f1 0.2400
#
# Fold 1 Epoch 5 val loss 2.9633
# emotion_predict: val acc 0.6847 p 0.5357 r 0.2273 f1 0.3191
# max_acc 0.6897 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# cause_predict: val acc 0.7340 p 0.8750 r 0.2121 f1 0.3415
# max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
#
# pair_predict: val acc 0.9098 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.8977 max_p 0.3529 max_r 0.1818 max_f1 0.2400
#
# avg max cause: max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
# avg max pos: max_acc 0.6897 max_p 0.5484 max_r 0.2576 max_f1 0.3505
# avg max pair: max_acc 0.8977 max_p 0.3529 max_r 0.1818 max_f1 0.2400
#
# Fold 1 Epoch 6 val loss 2.8707
# emotion_predict: val acc 0.6798 p 0.5106 r 0.3636 f1 0.4248
# max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
#
# cause_predict: val acc 0.7291 p 0.6122 r 0.4545 f1 0.5217
# max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
#
# pair_predict: val acc 0.9139 p 0.5357 r 0.2273 f1 0.3191
# max_acc 0.9139 max_p 0.5357 max_r 0.2273 max_f1 0.3191
#
# avg max cause: max_acc 0.7291 max_p 0.6122 max_r 0.4545 max_f1 0.5217
# avg max pos: max_acc 0.6798 max_p 0.5106 max_r 0.3636 max_f1 0.4248
# avg max pair: max_acc 0.9139 max_p 0.5357 max_r 0.2273 max_f1 0.3191
#
# Fold 1 Epoch 7 val loss 2.7821
# emotion_predict: val acc 0.6995 p 0.5472 r 0.4394 f1 0.4874
# max_acc 0.6995 max_p 0.5472 max_r 0.4394 max_f1 0.4874
#
# cause_predict: val acc 0.7685 p 0.6792 r 0.5455 f1 0.6050
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.8977 p 0.4107 r 0.3485 f1 0.3770
# max_acc 0.8977 max_p 0.4107 max_r 0.3485 max_f1 0.3770
#
# avg max cause: max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
# avg max pos: max_acc 0.6995 max_p 0.5472 max_r 0.4394 max_f1 0.4874
# avg max pair: max_acc 0.8977 max_p 0.4107 max_r 0.3485 max_f1 0.3770
#
# Fold 1 Epoch 8 val loss 2.7249
# emotion_predict: val acc 0.7537 p 0.7000 r 0.4242 f1 0.5283
# max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
#
# cause_predict: val acc 0.7734 p 0.7000 r 0.5303 f1 0.6034
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9166 p 0.5500 r 0.3333 f1 0.4151
# max_acc 0.9166 max_p 0.5500 max_r 0.3333 max_f1 0.4151
#
# avg max cause: max_acc 0.7734 max_p 0.7000 max_r 0.5303 max_f1 0.6034
# avg max pos: max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
# avg max pair: max_acc 0.9166 max_p 0.5500 max_r 0.3333 max_f1 0.4151
#
# Fold 1 Epoch 9 val loss 2.7327
# emotion_predict: val acc 0.7389 p 0.7097 r 0.3333 f1 0.4536
# max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
#
# cause_predict: val acc 0.7143 p 0.5625 r 0.5455 f1 0.5538
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9179 p 0.5758 r 0.2879 f1 0.3838
# max_acc 0.9166 max_p 0.5500 max_r 0.3333 max_f1 0.4151
#
# avg max cause: max_acc 0.7734 max_p 0.7000 max_r 0.5303 max_f1 0.6034
# avg max pos: max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
# avg max pair: max_acc 0.9166 max_p 0.5500 max_r 0.3333 max_f1 0.4151
#
# Fold 1 Epoch 10 val loss 2.6804
# emotion_predict: val acc 0.7537 p 0.6905 r 0.4394 f1 0.5370
# max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
#
# cause_predict: val acc 0.7389 p 0.6140 r 0.5303 f1 0.5691
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9166 p 0.5435 r 0.3788 f1 0.4464
# max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
# avg max pair: max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# Fold 1 Epoch 11 val loss 2.6776
# emotion_predict: val acc 0.7192 p 0.5789 r 0.5000 f1 0.5366
# max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
#
# cause_predict: val acc 0.7488 p 0.6415 r 0.5152 f1 0.5714
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9139 p 0.5227 r 0.3485 f1 0.4182
# max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
# avg max pair: max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# Fold 1 Epoch 12 val loss 2.6943
# emotion_predict: val acc 0.7143 p 0.5667 r 0.5152 f1 0.5397
# max_acc 0.7143 max_p 0.5667 max_r 0.5152 max_f1 0.5397
#
# cause_predict: val acc 0.7143 p 0.5690 r 0.5000 f1 0.5323
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9219 p 0.6053 r 0.3485 f1 0.4423
# max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# avg max cause: max_acc 0.7389 max_p 0.6140 max_r 0.5303 max_f1 0.5691
# avg max pos: max_acc 0.7537 max_p 0.6905 max_r 0.4394 max_f1 0.5370
# avg max pair: max_acc 0.9166 max_p 0.5435 max_r 0.3788 max_f1 0.4464
#
# Fold 1 Epoch 13 val loss 2.6695
# emotion_predict: val acc 0.7586 p 0.7179 r 0.4242 f1 0.5333
# max_acc 0.7143 max_p 0.5667 max_r 0.5152 max_f1 0.5397
#
# cause_predict: val acc 0.7291 p 0.6341 r 0.3939 f1 0.4860
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9246 p 0.6389 r 0.3485 f1 0.4510
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 14 val loss 2.7096
# emotion_predict: val acc 0.7635 p 0.7143 r 0.4545 f1 0.5556
# max_acc 0.7635 max_p 0.7143 max_r 0.4545 max_f1 0.5556
#
# cause_predict: val acc 0.7438 p 0.6842 r 0.3939 f1 0.5000
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9219 p 0.6111 r 0.3333 f1 0.4314
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 15 val loss 2.6163
# emotion_predict: val acc 0.7488 p 0.6471 r 0.5000 f1 0.5641
# max_acc 0.7488 max_p 0.6471 max_r 0.5000 max_f1 0.5641
#
# cause_predict: val acc 0.6946 p 0.5323 r 0.5000 f1 0.5156
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9152 p 0.5349 r 0.3485 f1 0.4220
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 16 val loss 2.5983
# emotion_predict: val acc 0.7537 p 0.6739 r 0.4697 f1 0.5536
# max_acc 0.7488 max_p 0.6471 max_r 0.5000 max_f1 0.5641
#
# cause_predict: val acc 0.7389 p 0.6182 r 0.5152 f1 0.5620
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.3636 f1 0.4211
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 17 val loss 2.6355
# emotion_predict: val acc 0.7340 p 0.5937 r 0.5758 f1 0.5846
# max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
#
# cause_predict: val acc 0.7192 p 0.5882 r 0.4545 f1 0.5128
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9192 p 0.5714 r 0.3636 f1 0.4444
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 18 val loss 2.5855
# emotion_predict: val acc 0.7734 p 0.6852 r 0.5606 f1 0.6167
# max_acc 0.7734 max_p 0.6852 max_r 0.5606 max_f1 0.6167
#
# cause_predict: val acc 0.7340 p 0.6034 r 0.5303 f1 0.5645
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9071 p 0.4746 r 0.4242 f1 0.4480
# max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# avg max cause: max_acc 0.7291 max_p 0.6341 max_r 0.3939 max_f1 0.4860
# avg max pos: max_acc 0.7586 max_p 0.7179 max_r 0.4242 max_f1 0.5333
# avg max pair: max_acc 0.9246 max_p 0.6389 max_r 0.3485 max_f1 0.4510
#
# Fold 1 Epoch 19 val loss 2.5539
# emotion_predict: val acc 0.7980 p 0.7551 r 0.5606 f1 0.6435
# max_acc 0.7980 max_p 0.7551 max_r 0.5606 max_f1 0.6435
#
# cause_predict: val acc 0.7389 p 0.6066 r 0.5606 f1 0.5827
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9044 p 0.4638 r 0.4848 f1 0.4741
# max_acc 0.9044 max_p 0.4638 max_r 0.4848 max_f1 0.4741
#
# avg max cause: max_acc 0.7389 max_p 0.6066 max_r 0.5606 max_f1 0.5827
# avg max pos: max_acc 0.7980 max_p 0.7551 max_r 0.5606 max_f1 0.6435
# avg max pair: max_acc 0.9044 max_p 0.4638 max_r 0.4848 max_f1 0.4741
#
# Fold 1 Epoch 20 val loss 2.6361
# emotion_predict: val acc 0.8030 p 0.7407 r 0.6061 f1 0.6667
# max_acc 0.8030 max_p 0.7407 max_r 0.6061 max_f1 0.6667
#
# cause_predict: val acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
# max_acc 0.7685 max_p 0.6792 max_r 0.5455 max_f1 0.6050
#
# pair_predict: val acc 0.9166 p 0.5357 r 0.4545 f1 0.4918
# max_acc 0.9166 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# avg max cause: max_acc 0.7291 max_p 0.5932 max_r 0.5303 max_f1 0.5600
# avg max pos: max_acc 0.8030 max_p 0.7407 max_r 0.6061 max_f1 0.6667
# avg max pair: max_acc 0.9166 max_p 0.5357 max_r 0.4545 max_f1 0.4918
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.56]]
# average : acc 0.7291 p 0.5932 r 0.5303 f1 0.5600
#
# emotion_predict: val f1 in 1 fold: [[0.66666667]]
# average : acc 0.8030 p 0.7407 r 0.6061 f1 0.6667
#
# pair_predict: val f1 in 1 fold: [[0.49180328]]
# average : acc 0.9166 p 0.5357 r 0.4545 f1 0.4918

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3943
# emotion_predict: val acc 0.3399 p 0.3211 r 0.9242 f1 0.4766
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.3842 p 0.3388 r 0.9394 f1 0.4980
# max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
#
# pair_predict: val acc 0.0996 p 0.0898 r 1.0000 f1 0.1648
# max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# avg max cause: max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
# avg max pos: max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
# avg max pair: max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# Fold 1 Epoch 2 val loss 2.8065
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.6798 p 1.0000 r 0.0152 f1 0.0299
# max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# avg max cause: max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
# avg max pos: max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
# avg max pair: max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# Fold 1 Epoch 3 val loss 2.7617
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# avg max cause: max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
# avg max pos: max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
# avg max pair: max_acc 0.0996 max_p 0.0898 max_r 1.0000 max_f1 0.1648
#
# Fold 1 Epoch 4 val loss 2.6617
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
#
# pair_predict: val acc 0.9098 p 0.4762 r 0.1515 f1 0.2299
# max_acc 0.9098 max_p 0.4762 max_r 0.1515 max_f1 0.2299
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9098 max_p 0.4762 max_r 0.1515 max_f1 0.2299
#
# Fold 1 Epoch 5 val loss 2.5298
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.7143 p 0.9000 r 0.1364 f1 0.2368
# max_acc 0.3842 max_p 0.3388 max_r 0.9394 max_f1 0.4980
#
# pair_predict: val acc 0.9004 p 0.4167 r 0.3030 f1 0.3509
# max_acc 0.9004 max_p 0.4167 max_r 0.3030 max_f1 0.3509
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9004 max_p 0.4167 max_r 0.3030 max_f1 0.3509
#
# Fold 1 Epoch 6 val loss 2.7548
# emotion_predict: val acc 0.6650 p 0.4821 r 0.4091 f1 0.4426
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.6601 p 0.4805 r 0.5606 f1 0.5175
# max_acc 0.6601 max_p 0.4805 max_r 0.5606 max_f1 0.5175
#
# pair_predict: val acc 0.5976 p 0.1563 r 0.8030 f1 0.2617
# max_acc 0.9004 max_p 0.4167 max_r 0.3030 max_f1 0.3509
#
# avg max cause: max_acc 0.7143 max_p 0.9000 max_r 0.1364 max_f1 0.2368
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9004 max_p 0.4167 max_r 0.3030 max_f1 0.3509
#
# Fold 1 Epoch 7 val loss 2.6120
# emotion_predict: val acc 0.7044 p 0.5652 r 0.3939 f1 0.4643
# max_acc 0.3399 max_p 0.3211 max_r 0.9242 max_f1 0.4766
#
# cause_predict: val acc 0.7340 p 0.7143 r 0.3030 f1 0.4255
# max_acc 0.6601 max_p 0.4805 max_r 0.5606 max_f1 0.5175
#
# pair_predict: val acc 0.9166 p 0.5667 r 0.2576 f1 0.3542
# max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# avg max cause: max_acc 0.7340 max_p 0.7143 max_r 0.3030 max_f1 0.4255
# avg max pos: max_acc 0.7044 max_p 0.5652 max_r 0.3939 max_f1 0.4643
# avg max pair: max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# Fold 1 Epoch 8 val loss 2.5815
# emotion_predict: val acc 0.7094 p 0.5614 r 0.4848 f1 0.5203
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7389 p 0.6667 r 0.3939 f1 0.4952
# max_acc 0.6601 max_p 0.4805 max_r 0.5606 max_f1 0.5175
#
# pair_predict: val acc 0.7120 p 0.1864 r 0.6667 f1 0.2914
# max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# avg max cause: max_acc 0.7340 max_p 0.7143 max_r 0.3030 max_f1 0.4255
# avg max pos: max_acc 0.7044 max_p 0.5652 max_r 0.3939 max_f1 0.4643
# avg max pair: max_acc 0.9166 max_p 0.5667 max_r 0.2576 max_f1 0.3542
#
# Fold 1 Epoch 9 val loss 2.4237
# emotion_predict: val acc 0.6946 p 0.6000 r 0.1818 f1 0.2791
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7340 p 0.7308 r 0.2879 f1 0.4130
# max_acc 0.6601 max_p 0.4805 max_r 0.5606 max_f1 0.5175
#
# pair_predict: val acc 0.8977 p 0.4167 r 0.3788 f1 0.3968
# max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# avg max cause: max_acc 0.7340 max_p 0.7308 max_r 0.2879 max_f1 0.4130
# avg max pos: max_acc 0.6946 max_p 0.6000 max_r 0.1818 max_f1 0.2791
# avg max pair: max_acc 0.8977 max_p 0.4167 max_r 0.3788 max_f1 0.3968
#
# Fold 1 Epoch 10 val loss 2.3911
# emotion_predict: val acc 0.6995 p 0.6316 r 0.1818 f1 0.2824
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7537 p 0.8333 r 0.3030 f1 0.4444
# max_acc 0.6601 max_p 0.4805 max_r 0.5606 max_f1 0.5175
#
# pair_predict: val acc 0.9031 p 0.4464 r 0.3788 f1 0.4098
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 11 val loss 2.3499
# emotion_predict: val acc 0.7241 p 0.6190 r 0.3939 f1 0.4815
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7389 p 0.6327 r 0.4697 f1 0.5391
# max_acc 0.7389 max_p 0.6327 max_r 0.4697 max_f1 0.5391
#
# pair_predict: val acc 0.8641 p 0.3333 r 0.5303 f1 0.4094
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 12 val loss 2.3017
# emotion_predict: val acc 0.7488 p 0.7027 r 0.3939 f1 0.5049
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7291 p 0.6038 r 0.4848 f1 0.5378
# max_acc 0.7389 max_p 0.6327 max_r 0.4697 max_f1 0.5391
#
# pair_predict: val acc 0.8614 p 0.3238 r 0.5152 f1 0.3977
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 13 val loss 2.3131
# emotion_predict: val acc 0.7340 p 0.6364 r 0.4242 f1 0.5091
# max_acc 0.7094 max_p 0.5614 max_r 0.4848 max_f1 0.5203
#
# cause_predict: val acc 0.7340 p 0.6071 r 0.5152 f1 0.5574
# max_acc 0.7340 max_p 0.6071 max_r 0.5152 max_f1 0.5574
#
# pair_predict: val acc 0.8439 p 0.2807 r 0.4848 f1 0.3556
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 14 val loss 2.3086
# emotion_predict: val acc 0.7488 p 0.6596 r 0.4697 f1 0.5487
# max_acc 0.7488 max_p 0.6596 max_r 0.4697 max_f1 0.5487
#
# cause_predict: val acc 0.7241 p 0.5781 r 0.5606 f1 0.5692
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8291 p 0.2636 r 0.5152 f1 0.3487
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 15 val loss 2.2931
# emotion_predict: val acc 0.7241 p 0.6389 r 0.3485 f1 0.4510
# max_acc 0.7488 max_p 0.6596 max_r 0.4697 max_f1 0.5487
#
# cause_predict: val acc 0.7291 p 0.5902 r 0.5455 f1 0.5669
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8546 p 0.2981 r 0.4697 f1 0.3647
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 16 val loss 2.2906
# emotion_predict: val acc 0.7241 p 0.6042 r 0.4394 f1 0.5088
# max_acc 0.7488 max_p 0.6596 max_r 0.4697 max_f1 0.5487
#
# cause_predict: val acc 0.7291 p 0.6038 r 0.4848 f1 0.5378
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8412 p 0.2759 r 0.4848 f1 0.3516
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 17 val loss 2.2703
# emotion_predict: val acc 0.7488 p 0.6415 r 0.5152 f1 0.5714
# max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
#
# cause_predict: val acc 0.7438 p 0.6458 r 0.4697 f1 0.5439
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8883 p 0.3836 r 0.4242 f1 0.4029
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 18 val loss 2.2737
# emotion_predict: val acc 0.7192 p 0.5714 r 0.5455 f1 0.5581
# max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
#
# cause_predict: val acc 0.7291 p 0.6078 r 0.4697 f1 0.5299
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8829 p 0.3704 r 0.4545 f1 0.4082
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 19 val loss 2.3128
# emotion_predict: val acc 0.6946 p 0.5278 r 0.5758 f1 0.5507
# max_acc 0.7488 max_p 0.6415 max_r 0.5152 max_f1 0.5714
#
# cause_predict: val acc 0.7192 p 0.5818 r 0.4848 f1 0.5289
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8681 p 0.3298 r 0.4697 f1 0.3875
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# Fold 1 Epoch 20 val loss 2.2048
# emotion_predict: val acc 0.7635 p 0.6731 r 0.5303 f1 0.5932
# max_acc 0.7635 max_p 0.6731 max_r 0.5303 max_f1 0.5932
#
# cause_predict: val acc 0.7389 p 0.6327 r 0.4697 f1 0.5391
# max_acc 0.7241 max_p 0.5781 max_r 0.5606 max_f1 0.5692
#
# pair_predict: val acc 0.8681 p 0.3367 r 0.5000 f1 0.4024
# max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# avg max cause: max_acc 0.7537 max_p 0.8333 max_r 0.3030 max_f1 0.4444
# avg max pos: max_acc 0.6995 max_p 0.6316 max_r 0.1818 max_f1 0.2824
# avg max pair: max_acc 0.9031 max_p 0.4464 max_r 0.3788 max_f1 0.4098
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.44444444]]
# average : acc 0.7537 p 0.8333 r 0.3030 f1 0.4444
#
# emotion_predict: val f1 in 1 fold: [[0.28235294]]
# average : acc 0.6995 p 0.6316 r 0.1818 f1 0.2824
#
# pair_predict: val f1 in 1 fold: [[0.40983607]]
# average : acc 0.9031 p 0.4464 r 0.3788 f1 0.4098

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 3.2851
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.2841
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.1911
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1499
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.7192 p 1.0000 r 0.1364 f1 0.2400
# max_acc 0.7192 max_p 1.0000 max_r 0.1364 max_f1 0.2400
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.0659
# emotion_predict: val acc 0.6897 p 0.6667 r 0.0909 f1 0.1600
# max_acc 0.6897 max_p 0.6667 max_r 0.0909 max_f1 0.1600
#
# cause_predict: val acc 0.7241 p 0.7778 r 0.2121 f1 0.3333
# max_acc 0.7241 max_p 0.7778 max_r 0.2121 max_f1 0.3333
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.0191
# emotion_predict: val acc 0.6700 p 0.4706 r 0.1212 f1 0.1928
# max_acc 0.6700 max_p 0.4706 max_r 0.1212 max_f1 0.1928
#
# cause_predict: val acc 0.7143 p 0.6667 r 0.2424 f1 0.3556
# max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.0214
# emotion_predict: val acc 0.6897 p 0.5319 r 0.3788 f1 0.4425
# max_acc 0.6897 max_p 0.5319 max_r 0.3788 max_f1 0.4425
#
# cause_predict: val acc 0.6798 p 0.5079 r 0.4848 f1 0.4961
# max_acc 0.6798 max_p 0.5079 max_r 0.4848 max_f1 0.4961
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.9626
# emotion_predict: val acc 0.6897 p 0.5333 r 0.3636 f1 0.4324
# max_acc 0.6897 max_p 0.5319 max_r 0.3788 max_f1 0.4425
#
# cause_predict: val acc 0.7094 p 0.5686 r 0.4394 f1 0.4957
# max_acc 0.6798 max_p 0.5079 max_r 0.4848 max_f1 0.4961
#
# pair_predict: val acc 0.9192 p 0.8750 r 0.1061 f1 0.1892
# max_acc 0.9192 max_p 0.8750 max_r 0.1061 max_f1 0.1892
#
# avg max cause: max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
# avg max pos: max_acc 0.6897 max_p 0.5333 max_r 0.3636 max_f1 0.4324
# avg max pair: max_acc 0.9192 max_p 0.8750 max_r 0.1061 max_f1 0.1892
#
# Fold 1 Epoch 9 val loss 2.9287
# emotion_predict: val acc 0.6995 p 0.5610 r 0.3485 f1 0.4299
# max_acc 0.6897 max_p 0.5319 max_r 0.3788 max_f1 0.4425
#
# cause_predict: val acc 0.6995 p 0.5556 r 0.3788 f1 0.4505
# max_acc 0.6798 max_p 0.5079 max_r 0.4848 max_f1 0.4961
#
# pair_predict: val acc 0.9152 p 0.5484 r 0.2576 f1 0.3505
# max_acc 0.9152 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# avg max cause: max_acc 0.6995 max_p 0.5556 max_r 0.3788 max_f1 0.4505
# avg max pos: max_acc 0.6995 max_p 0.5610 max_r 0.3485 max_f1 0.4299
# avg max pair: max_acc 0.9152 max_p 0.5484 max_r 0.2576 max_f1 0.3505
#
# Fold 1 Epoch 10 val loss 2.8565
# emotion_predict: val acc 0.7044 p 0.5600 r 0.4242 f1 0.4828
# max_acc 0.7044 max_p 0.5600 max_r 0.4242 max_f1 0.4828
#
# cause_predict: val acc 0.7044 p 0.5577 r 0.4394 f1 0.4915
# max_acc 0.6798 max_p 0.5079 max_r 0.4848 max_f1 0.4961
#
# pair_predict: val acc 0.9085 p 0.4762 r 0.3030 f1 0.3704
# max_acc 0.9085 max_p 0.4762 max_r 0.3030 max_f1 0.3704
#
# avg max cause: max_acc 0.7044 max_p 0.5577 max_r 0.4394 max_f1 0.4915
# avg max pos: max_acc 0.7044 max_p 0.5600 max_r 0.4242 max_f1 0.4828
# avg max pair: max_acc 0.9085 max_p 0.4762 max_r 0.3030 max_f1 0.3704
#
# Fold 1 Epoch 11 val loss 2.7609
# emotion_predict: val acc 0.7143 p 0.5714 r 0.4848 f1 0.5246
# max_acc 0.7143 max_p 0.5714 max_r 0.4848 max_f1 0.5246
#
# cause_predict: val acc 0.7044 p 0.5441 r 0.5606 f1 0.5522
# max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
#
# pair_predict: val acc 0.9206 p 0.6129 r 0.2879 f1 0.3918
# max_acc 0.9206 max_p 0.6129 max_r 0.2879 max_f1 0.3918
#
# avg max cause: max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
# avg max pos: max_acc 0.7143 max_p 0.5714 max_r 0.4848 max_f1 0.5246
# avg max pair: max_acc 0.9206 max_p 0.6129 max_r 0.2879 max_f1 0.3918
#
# Fold 1 Epoch 12 val loss 2.6703
# emotion_predict: val acc 0.7340 p 0.6250 r 0.4545 f1 0.5263
# max_acc 0.7340 max_p 0.6250 max_r 0.4545 max_f1 0.5263
#
# cause_predict: val acc 0.7143 p 0.5571 r 0.5909 f1 0.5735
# max_acc 0.7143 max_p 0.5571 max_r 0.5909 max_f1 0.5735
#
# pair_predict: val acc 0.9166 p 0.5625 r 0.2727 f1 0.3673
# max_acc 0.9206 max_p 0.6129 max_r 0.2879 max_f1 0.3918
#
# avg max cause: max_acc 0.7044 max_p 0.5441 max_r 0.5606 max_f1 0.5522
# avg max pos: max_acc 0.7143 max_p 0.5714 max_r 0.4848 max_f1 0.5246
# avg max pair: max_acc 0.9206 max_p 0.6129 max_r 0.2879 max_f1 0.3918
#
# Fold 1 Epoch 13 val loss 2.5885
# emotion_predict: val acc 0.7833 p 0.7292 r 0.5303 f1 0.6140
# max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
#
# cause_predict: val acc 0.7340 p 0.5909 r 0.5909 f1 0.5909
# max_acc 0.7340 max_p 0.5909 max_r 0.5909 max_f1 0.5909
#
# pair_predict: val acc 0.9139 p 0.5192 r 0.4091 f1 0.4576
# max_acc 0.9139 max_p 0.5192 max_r 0.4091 max_f1 0.4576
#
# avg max cause: max_acc 0.7340 max_p 0.5909 max_r 0.5909 max_f1 0.5909
# avg max pos: max_acc 0.7833 max_p 0.7292 max_r 0.5303 max_f1 0.6140
# avg max pair: max_acc 0.9139 max_p 0.5192 max_r 0.4091 max_f1 0.4576
#
# Fold 1 Epoch 14 val loss 2.5140
# emotion_predict: val acc 0.8079 p 0.8000 r 0.5455 f1 0.6486
# max_acc 0.8079 max_p 0.8000 max_r 0.5455 max_f1 0.6486
#
# cause_predict: val acc 0.7537 p 0.7000 r 0.4242 f1 0.5283
# max_acc 0.7340 max_p 0.5909 max_r 0.5909 max_f1 0.5909
#
# pair_predict: val acc 0.9233 p 0.6098 r 0.3788 f1 0.4673
# max_acc 0.9233 max_p 0.6098 max_r 0.3788 max_f1 0.4673
#
# avg max cause: max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
# avg max pos: max_acc 0.8079 max_p 0.8000 max_r 0.5455 max_f1 0.6486
# avg max pair: max_acc 0.9233 max_p 0.6098 max_r 0.3788 max_f1 0.4673
#
# Fold 1 Epoch 15 val loss 2.4623
# emotion_predict: val acc 0.8276 p 0.7925 r 0.6364 f1 0.7059
# max_acc 0.8276 max_p 0.7925 max_r 0.6364 max_f1 0.7059
#
# cause_predict: val acc 0.7340 p 0.6250 r 0.4545 f1 0.5263
# max_acc 0.7340 max_p 0.5909 max_r 0.5909 max_f1 0.5909
#
# pair_predict: val acc 0.9058 p 0.4677 r 0.4394 f1 0.4531
# max_acc 0.9233 max_p 0.6098 max_r 0.3788 max_f1 0.4673
#
# avg max cause: max_acc 0.7537 max_p 0.7000 max_r 0.4242 max_f1 0.5283
# avg max pos: max_acc 0.8079 max_p 0.8000 max_r 0.5455 max_f1 0.6486
# avg max pair: max_acc 0.9233 max_p 0.6098 max_r 0.3788 max_f1 0.4673
#
# Fold 1 Epoch 16 val loss 2.4150
# emotion_predict: val acc 0.8325 p 0.8077 r 0.6364 f1 0.7119
# max_acc 0.8325 max_p 0.8077 max_r 0.6364 max_f1 0.7119
#
# cause_predict: val acc 0.7488 p 0.6316 r 0.5455 f1 0.5854
# max_acc 0.7340 max_p 0.5909 max_r 0.5909 max_f1 0.5909
#
# pair_predict: val acc 0.9139 p 0.5172 r 0.4545 f1 0.4839
# max_acc 0.9139 max_p 0.5172 max_r 0.4545 max_f1 0.4839
#
# avg max cause: max_acc 0.7488 max_p 0.6316 max_r 0.5455 max_f1 0.5854
# avg max pos: max_acc 0.8325 max_p 0.8077 max_r 0.6364 max_f1 0.7119
# avg max pair: max_acc 0.9139 max_p 0.5172 max_r 0.4545 max_f1 0.4839
#
# Fold 1 Epoch 17 val loss 2.4321
# emotion_predict: val acc 0.8325 p 0.7857 r 0.6667 f1 0.7213
# max_acc 0.8325 max_p 0.7857 max_r 0.6667 max_f1 0.7213
#
# cause_predict: val acc 0.7488 p 0.6154 r 0.6061 f1 0.6107
# max_acc 0.7488 max_p 0.6154 max_r 0.6061 max_f1 0.6107
#
# pair_predict: val acc 0.8937 p 0.4133 r 0.4697 f1 0.4397
# max_acc 0.9139 max_p 0.5172 max_r 0.4545 max_f1 0.4839
#
# avg max cause: max_acc 0.7488 max_p 0.6316 max_r 0.5455 max_f1 0.5854
# avg max pos: max_acc 0.8325 max_p 0.8077 max_r 0.6364 max_f1 0.7119
# avg max pair: max_acc 0.9139 max_p 0.5172 max_r 0.4545 max_f1 0.4839
#
# Fold 1 Epoch 18 val loss 2.3810
# emotion_predict: val acc 0.8424 p 0.8400 r 0.6364 f1 0.7241
# max_acc 0.8424 max_p 0.8400 max_r 0.6364 max_f1 0.7241
#
# cause_predict: val acc 0.7291 p 0.5902 r 0.5455 f1 0.5669
# max_acc 0.7488 max_p 0.6154 max_r 0.6061 max_f1 0.6107
#
# pair_predict: val acc 0.9112 p 0.5000 r 0.4848 f1 0.4923
# max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# avg max cause: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pos: max_acc 0.8424 max_p 0.8400 max_r 0.6364 max_f1 0.7241
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# Fold 1 Epoch 19 val loss 2.3983
# emotion_predict: val acc 0.8374 p 0.8000 r 0.6667 f1 0.7273
# max_acc 0.8374 max_p 0.8000 max_r 0.6667 max_f1 0.7273
#
# cause_predict: val acc 0.7488 p 0.6364 r 0.5303 f1 0.5785
# max_acc 0.7488 max_p 0.6154 max_r 0.6061 max_f1 0.6107
#
# pair_predict: val acc 0.9031 p 0.4583 r 0.5000 f1 0.4783
# max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# avg max cause: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pos: max_acc 0.8424 max_p 0.8400 max_r 0.6364 max_f1 0.7241
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# Fold 1 Epoch 20 val loss 2.4981
# emotion_predict: val acc 0.7833 p 0.6667 r 0.6667 f1 0.6667
# max_acc 0.8374 max_p 0.8000 max_r 0.6667 max_f1 0.7273
#
# cause_predict: val acc 0.7192 p 0.5652 r 0.5909 f1 0.5778
# max_acc 0.7488 max_p 0.6154 max_r 0.6061 max_f1 0.6107
#
# pair_predict: val acc 0.8883 p 0.3976 r 0.5000 f1 0.4430
# max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# avg max cause: max_acc 0.7291 max_p 0.5902 max_r 0.5455 max_f1 0.5669
# avg max pos: max_acc 0.8424 max_p 0.8400 max_r 0.6364 max_f1 0.7241
# avg max pair: max_acc 0.9112 max_p 0.5000 max_r 0.4848 max_f1 0.4923
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.56692913]]
# average : acc 0.7291 p 0.5902 r 0.5455 f1 0.5669
#
# emotion_predict: val f1 in 1 fold: [[0.72413793]]
# average : acc 0.8424 p 0.8400 r 0.6364 f1 0.7241
#
# pair_predict: val f1 in 1 fold: [[0.49230769]]
# average : acc 0.9112 p 0.5000 r 0.4848 f1 0.4923

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextE(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextE(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 2083 hit_words: 1588
# embedding.shape: (2085, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_train_1.txt
# y_position.shape torch.Size([321, 41, 2])
# y_cause.shape torch.Size([321, 41, 2])
# y_pair.shape torch.Size([321, 1681, 2])
# x.shape torch.Size([321, 41, 30])
# sen_len.shape torch.Size([321, 41])
# doc_len.shape torch.Size([321])
# distance.shape torch.Size([321, 1681])
# n_cut 58
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_long_summarized_max_5_clauses_annotated_val_1.txt
# y_position.shape torch.Size([68, 41, 2])
# y_cause.shape torch.Size([68, 41, 2])
# y_pair.shape torch.Size([68, 1681, 2])
# x.shape torch.Size([68, 41, 30])
# sen_len.shape torch.Size([68, 41])
# doc_len.shape torch.Size([68])
# distance.shape torch.Size([68, 1681])
# n_cut 10
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7899
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.7110
# emotion_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6749 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9112 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6749 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9112 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7089
# emotion_predict: val acc 0.6946 p 0.8333 r 0.0758 f1 0.1389
# max_acc 0.6946 max_p 0.8333 max_r 0.0758 max_f1 0.1389
#
# cause_predict: val acc 0.7143 p 0.6667 r 0.2424 f1 0.3556
# max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
#
# pair_predict: val acc 0.9152 p 0.6364 r 0.1061 f1 0.1818
# max_acc 0.9152 max_p 0.6364 max_r 0.1061 max_f1 0.1818
#
# avg max cause: max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
# avg max pos: max_acc 0.6946 max_p 0.8333 max_r 0.0758 max_f1 0.1389
# avg max pair: max_acc 0.9152 max_p 0.6364 max_r 0.1061 max_f1 0.1818
#
# Fold 1 Epoch 4 val loss 2.6022
# emotion_predict: val acc 0.6995 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
#
# cause_predict: val acc 0.7241 p 0.8571 r 0.1818 f1 0.3000
# max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
#
# pair_predict: val acc 0.9179 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.9152 max_p 0.6364 max_r 0.1061 max_f1 0.1818
#
# avg max cause: max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
# avg max pos: max_acc 0.6946 max_p 0.8333 max_r 0.0758 max_f1 0.1389
# avg max pair: max_acc 0.9152 max_p 0.6364 max_r 0.1061 max_f1 0.1818
#
# Fold 1 Epoch 5 val loss 2.5619
# emotion_predict: val acc 0.6995 p 0.8571 r 0.0909 f1 0.1644
# max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
#
# cause_predict: val acc 0.7291 p 0.7895 r 0.2273 f1 0.3529
# max_acc 0.7143 max_p 0.6667 max_r 0.2424 max_f1 0.3556
#
# pair_predict: val acc 0.9125 p 0.5333 r 0.1212 f1 0.1975
# max_acc 0.9125 max_p 0.5333 max_r 0.1212 max_f1 0.1975
#
# avg max cause: max_acc 0.7291 max_p 0.7895 max_r 0.2273 max_f1 0.3529
# avg max pos: max_acc 0.6995 max_p 0.8571 max_r 0.0909 max_f1 0.1644
# avg max pair: max_acc 0.9125 max_p 0.5333 max_r 0.1212 max_f1 0.1975
#
# Fold 1 Epoch 6 val loss 2.5468
# emotion_predict: val acc 0.6995 p 0.5556 r 0.3788 f1 0.4505
# max_acc 0.6995 max_p 0.5556 max_r 0.3788 max_f1 0.4505
#
# cause_predict: val acc 0.6897 p 0.5254 r 0.4697 f1 0.4960
# max_acc 0.6897 max_p 0.5254 max_r 0.4697 max_f1 0.4960
#
# pair_predict: val acc 0.8022 p 0.2207 r 0.4848 f1 0.3033
# max_acc 0.8022 max_p 0.2207 max_r 0.4848 max_f1 0.3033
#
# avg max cause: max_acc 0.6897 max_p 0.5254 max_r 0.4697 max_f1 0.4960
# avg max pos: max_acc 0.6995 max_p 0.5556 max_r 0.3788 max_f1 0.4505
# avg max pair: max_acc 0.8022 max_p 0.2207 max_r 0.4848 max_f1 0.3033
#
# Fold 1 Epoch 7 val loss 2.4629
# emotion_predict: val acc 0.7044 p 0.5682 r 0.3788 f1 0.4545
# max_acc 0.7044 max_p 0.5682 max_r 0.3788 max_f1 0.4545
#
# cause_predict: val acc 0.6995 p 0.5490 r 0.4242 f1 0.4786
# max_acc 0.6897 max_p 0.5254 max_r 0.4697 max_f1 0.4960
#
# pair_predict: val acc 0.8398 p 0.2735 r 0.4848 f1 0.3497
# max_acc 0.8398 max_p 0.2735 max_r 0.4848 max_f1 0.3497
#
# avg max cause: max_acc 0.6995 max_p 0.5490 max_r 0.4242 max_f1 0.4786
# avg max pos: max_acc 0.7044 max_p 0.5682 max_r 0.3788 max_f1 0.4545
# avg max pair: max_acc 0.8398 max_p 0.2735 max_r 0.4848 max_f1 0.3497
#
# Fold 1 Epoch 8 val loss 2.3907
# emotion_predict: val acc 0.7094 p 0.5686 r 0.4394 f1 0.4957
# max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
#
# cause_predict: val acc 0.7044 p 0.5682 r 0.3788 f1 0.4545
# max_acc 0.6897 max_p 0.5254 max_r 0.4697 max_f1 0.4960
#
# pair_predict: val acc 0.8493 p 0.2909 r 0.4848 f1 0.3636
# max_acc 0.8493 max_p 0.2909 max_r 0.4848 max_f1 0.3636
#
# avg max cause: max_acc 0.7044 max_p 0.5682 max_r 0.3788 max_f1 0.4545
# avg max pos: max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
# avg max pair: max_acc 0.8493 max_p 0.2909 max_r 0.4848 max_f1 0.3636
#
# Fold 1 Epoch 9 val loss 2.3114
# emotion_predict: val acc 0.7340 p 0.5937 r 0.5758 f1 0.5846
# max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
#
# cause_predict: val acc 0.7241 p 0.5658 r 0.6515 f1 0.6056
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8183 p 0.2621 r 0.5758 f1 0.3602
# max_acc 0.8493 max_p 0.2909 max_r 0.4848 max_f1 0.3636
#
# avg max cause: max_acc 0.7044 max_p 0.5682 max_r 0.3788 max_f1 0.4545
# avg max pos: max_acc 0.7094 max_p 0.5686 max_r 0.4394 max_f1 0.4957
# avg max pair: max_acc 0.8493 max_p 0.2909 max_r 0.4848 max_f1 0.3636
#
# Fold 1 Epoch 10 val loss 2.2150
# emotion_predict: val acc 0.7734 p 0.7500 r 0.4545 f1 0.5660
# max_acc 0.7340 max_p 0.5937 max_r 0.5758 max_f1 0.5846
#
# cause_predict: val acc 0.7340 p 0.6154 r 0.4848 f1 0.5424
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8735 p 0.3478 r 0.4848 f1 0.4051
# max_acc 0.8735 max_p 0.3478 max_r 0.4848 max_f1 0.4051
#
# avg max cause: max_acc 0.7340 max_p 0.6154 max_r 0.4848 max_f1 0.5424
# avg max pos: max_acc 0.7734 max_p 0.7500 max_r 0.4545 max_f1 0.5660
# avg max pair: max_acc 0.8735 max_p 0.3478 max_r 0.4848 max_f1 0.4051
#
# Fold 1 Epoch 11 val loss 2.1440
# emotion_predict: val acc 0.7833 p 0.7391 r 0.5152 f1 0.6071
# max_acc 0.7833 max_p 0.7391 max_r 0.5152 max_f1 0.6071
#
# cause_predict: val acc 0.7586 p 0.6889 r 0.4697 f1 0.5586
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8358 p 0.2910 r 0.5909 f1 0.3900
# max_acc 0.8735 max_p 0.3478 max_r 0.4848 max_f1 0.4051
#
# avg max cause: max_acc 0.7340 max_p 0.6154 max_r 0.4848 max_f1 0.5424
# avg max pos: max_acc 0.7734 max_p 0.7500 max_r 0.4545 max_f1 0.5660
# avg max pair: max_acc 0.8735 max_p 0.3478 max_r 0.4848 max_f1 0.4051
#
# Fold 1 Epoch 12 val loss 2.0769
# emotion_predict: val acc 0.8079 p 0.7872 r 0.5606 f1 0.6549
# max_acc 0.8079 max_p 0.7872 max_r 0.5606 max_f1 0.6549
#
# cause_predict: val acc 0.7586 p 0.6977 r 0.4545 f1 0.5505
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8802 p 0.3736 r 0.5152 f1 0.4331
# max_acc 0.8802 max_p 0.3736 max_r 0.5152 max_f1 0.4331
#
# avg max cause: max_acc 0.7586 max_p 0.6977 max_r 0.4545 max_f1 0.5505
# avg max pos: max_acc 0.8079 max_p 0.7872 max_r 0.5606 max_f1 0.6549
# avg max pair: max_acc 0.8802 max_p 0.3736 max_r 0.5152 max_f1 0.4331
#
# Fold 1 Epoch 13 val loss 2.0292
# emotion_predict: val acc 0.8276 p 0.8163 r 0.6061 f1 0.6957
# max_acc 0.8276 max_p 0.8163 max_r 0.6061 max_f1 0.6957
#
# cause_predict: val acc 0.7488 p 0.6271 r 0.5606 f1 0.5920
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8681 p 0.3491 r 0.5606 f1 0.4302
# max_acc 0.8802 max_p 0.3736 max_r 0.5152 max_f1 0.4331
#
# avg max cause: max_acc 0.7586 max_p 0.6977 max_r 0.4545 max_f1 0.5505
# avg max pos: max_acc 0.8079 max_p 0.7872 max_r 0.5606 max_f1 0.6549
# avg max pair: max_acc 0.8802 max_p 0.3736 max_r 0.5152 max_f1 0.4331
#
# Fold 1 Epoch 14 val loss 2.0304
# emotion_predict: val acc 0.8128 p 0.7692 r 0.6061 f1 0.6780
# max_acc 0.8276 max_p 0.8163 max_r 0.6061 max_f1 0.6957
#
# cause_predict: val acc 0.7438 p 0.6250 r 0.5303 f1 0.5738
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8614 p 0.3419 r 0.6061 f1 0.4372
# max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# avg max cause: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pos: max_acc 0.8128 max_p 0.7692 max_r 0.6061 max_f1 0.6780
# avg max pair: max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# Fold 1 Epoch 15 val loss 2.0632
# emotion_predict: val acc 0.8276 p 0.7627 r 0.6818 f1 0.7200
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8493 p 0.3145 r 0.5909 f1 0.4105
# max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# avg max cause: max_acc 0.7438 max_p 0.6250 max_r 0.5303 max_f1 0.5738
# avg max pos: max_acc 0.8128 max_p 0.7692 max_r 0.6061 max_f1 0.6780
# avg max pair: max_acc 0.8614 max_p 0.3419 max_r 0.6061 max_f1 0.4372
#
# Fold 1 Epoch 16 val loss 2.0746
# emotion_predict: val acc 0.8030 p 0.7167 r 0.6515 f1 0.6825
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7340 p 0.6111 r 0.5000 f1 0.5500
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8614 p 0.3471 r 0.6364 f1 0.4492
# max_acc 0.8614 max_p 0.3471 max_r 0.6364 max_f1 0.4492
#
# avg max cause: max_acc 0.7340 max_p 0.6111 max_r 0.5000 max_f1 0.5500
# avg max pos: max_acc 0.8030 max_p 0.7167 max_r 0.6515 max_f1 0.6825
# avg max pair: max_acc 0.8614 max_p 0.3471 max_r 0.6364 max_f1 0.4492
#
# Fold 1 Epoch 17 val loss 2.0395
# emotion_predict: val acc 0.8177 p 0.7736 r 0.6212 f1 0.6891
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8856 p 0.3933 r 0.5303 f1 0.4516
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7389 max_p 0.6226 max_r 0.5000 max_f1 0.5546
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 18 val loss 2.0198
# emotion_predict: val acc 0.8177 p 0.7843 r 0.6061 f1 0.6838
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7537 p 0.6333 r 0.5758 f1 0.6032
# max_acc 0.7241 max_p 0.5658 max_r 0.6515 max_f1 0.6056
#
# pair_predict: val acc 0.8412 p 0.3060 r 0.6212 f1 0.4100
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7389 max_p 0.6226 max_r 0.5000 max_f1 0.5546
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 19 val loss 2.0048
# emotion_predict: val acc 0.8177 p 0.7636 r 0.6364 f1 0.6942
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7734 p 0.6724 r 0.5909 f1 0.6290
# max_acc 0.7734 max_p 0.6724 max_r 0.5909 max_f1 0.6290
#
# pair_predict: val acc 0.8520 p 0.3226 r 0.6061 f1 0.4211
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7389 max_p 0.6226 max_r 0.5000 max_f1 0.5546
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# Fold 1 Epoch 20 val loss 2.0673
# emotion_predict: val acc 0.8030 p 0.7167 r 0.6515 f1 0.6825
# max_acc 0.8276 max_p 0.7627 max_r 0.6818 max_f1 0.7200
#
# cause_predict: val acc 0.7734 p 0.6923 r 0.5455 f1 0.6102
# max_acc 0.7734 max_p 0.6724 max_r 0.5909 max_f1 0.6290
#
# pair_predict: val acc 0.8950 p 0.4211 r 0.4848 f1 0.4507
# max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# avg max cause: max_acc 0.7389 max_p 0.6226 max_r 0.5000 max_f1 0.5546
# avg max pos: max_acc 0.8177 max_p 0.7736 max_r 0.6212 max_f1 0.6891
# avg max pair: max_acc 0.8856 max_p 0.3933 max_r 0.5303 max_f1 0.4516
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.55462185]]
# average : acc 0.7389 p 0.6226 r 0.5000 f1 0.5546
#
# emotion_predict: val f1 in 1 fold: [[0.68907563]]
# average : acc 0.8177 p 0.7736 r 0.6212 f1 0.6891
#
# pair_predict: val f1 in 1 fold: [[0.4516129]]
# average : acc 0.8856 p 0.3933 r 0.5303 f1 0.4516
