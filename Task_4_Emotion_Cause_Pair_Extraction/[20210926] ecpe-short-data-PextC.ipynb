# %%
# connect to google colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# base path
DATA_PATH = './drive/MyDrive/fyp-code/codes/data/ecpe/'
MODEL_PATH = './drive/MyDrive/fyp-code/codes/model/ecpe/CE/short/'

# %%
############################################ IMPORT ##########################################################
import sys, os
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# call the zip folder with all the self defined modules
base_folder = '/content/drive/MyDrive/fyp-code/codes'

training_path = os.path.join(base_folder, "utils_ecpe.zip") 
# !unzip $training_path

from funcs import *
from prepare_data import *
# Out:
# Archive:  /content/drive/MyDrive/fyp-code/codes/utils_ecpe.zip
#   inflating: funcs.py
#   inflating: prepare_data.py

# %%
############################################ FLAGS ############################################################
# file names of the data files
LOOKUP = 'ecpe_short_annotated.csv'
DATA = 'short'
TRAIN_DATA = 'ecpe_short_annotated_train'
VAL_DATA = 'ecpe_short_annotated_val'

# fixed parameters
train_file_path = DATA_PATH + LOOKUP                                # clause keyword file
w2v_file = DATA_PATH+'w2v_200.txt'                                  # embedding file
embedding_dim = 200                                                 # dimension of word embedding
embedding_dim_pos = 30                                              # dimension of position embedding
max_sen_len = 30                                                    # max number of tokens per sentence
max_doc_len = 41                                                    # max number of tokens per document
n_class = 2                                                         # number of distinct class
training_epochs = 15                                                # number of train epochs
keep_prob1 = 0.8                                                    # word embedding training dropout keep prob
keep_prob2 = 1.0                                                    # softmax layer dropout keep prob
keep_prob3 = 1.0                                                    # softmax layer dropout keep prob
l2_reg = 0.00010                                                    # l2 regularization
cause = 1.0                                                         # lambda1
pos = 1.0                                                           # lambda2
pair = 2.5                                                          # lambda3

# hyperparameters considered for tuning (will be tuned later when the class is called)
n_hidden = None                                                     # number of hidden unit
batch_size = None                                                   # number of example per batch
learning_rate = None                                                # learning rate
diminish_factor = None                                              # give less weight to -ve examples

# %%
############################################ MODEL ############################################################
class E2E_PextC(nn.Module):
    def __init__(self, embedding_dim, embedding_dim_pos, sen_len, doc_len, keep_prob1, keep_prob2, \
                 keep_prob3, n_hidden, n_class):
        super(E2E_PextC, self).__init__()
        self.embedding_dim = embedding_dim; self.embedding_dim_pos = embedding_dim_pos 
        self.sen_len = sen_len; self.doc_len = doc_len
        self.keep_prob1 = keep_prob1; self.keep_prob2 = keep_prob2
        self.n_hidden = n_hidden; self.n_class = n_class

        self.dropout1 = nn.Dropout(p = 1 - keep_prob1)
        self.dropout2 = nn.Dropout(p = 1 - keep_prob2)
        self.dropout3 = nn.Dropout(p = 1 - keep_prob3)
        self.relu = nn.ReLU()
        self.pos_linear = nn.Linear(2*n_hidden, n_class)
        self.cause_linear = nn.Linear(2*n_hidden, n_class)
        self.pair_linear1 = nn.Linear(4*n_hidden + embedding_dim_pos, n_hidden//2)
        self.pair_linear2 = nn.Linear(n_hidden//2, n_class)
        self.word_bilstm = nn.LSTM(embedding_dim, n_hidden, batch_first = True, bidirectional = True)
        self.cause_bilstm = nn.LSTM(2*n_hidden, n_hidden, batch_first = True, bidirectional = True)
        self.pos_bilstm = nn.LSTM(2*n_hidden + n_class, n_hidden, batch_first = True, bidirectional = True)
        self.attention = Attention(n_hidden, sen_len)

    def get_clause_embedding(self, x):
        '''
        input shape: [batch_size, doc_len, sen_len, embedding_dim]
        output shape: [batch_size, doc_len, 2 * n_hidden]
        '''
        x = x.reshape(-1, self.sen_len, self.embedding_dim)
        x = self.dropout1(x)
        # x is of shape (batch_size * max_doc_len, max_sen_len, embedding_dim)
        x, hidden_states = self.word_bilstm(x.float())
        # x is of shape (batch_size * max_doc_len, max_sen_len, 2 * n_hidden)
        s = self.attention(x).reshape(-1, self.doc_len, 2 * self.n_hidden)
        # s is of shape (batch_size, max_doc_len, 2 * n_hidden)
        return s

    def get_emotion_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden + n_class]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.pos_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_pos = F.softmax(self.pos_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_pos = pred_pos.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_pos

    def get_cause_prediction(self, x):
        '''
        input shape: [batch_size, doc_len, 2 * n_hidden]
        output(s) shape: [batch_size, doc_len, 2 * n_hidden], [batch_size, doc_len, n_class]
        '''
        x_context, hidden_states = self.cause_bilstm(x.float())
        # x_context is of shape (batch_size, max_doc_len, 2 * n_hidden)
        x = x_context.reshape(-1, 2 * self.n_hidden)
        x = self.dropout2(x)
        # x is of shape (batch_size * max_doc_len, 2 * n_hidden)
        pred_cause = F.softmax(self.cause_linear(x), dim = -1)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        pred_cause = pred_cause.reshape(-1, self.doc_len, self.n_class)
        # pred_pos is of shape (batch_size * max_doc_len, n_class)
        return x_context, pred_cause

    def get_pair_prediction(self, x1, x2, distance):
        '''
        input(s) shape: [batch_size * doc_len, 2 * n_hidden], [batch_size * doc_len, 2 * n_hidden], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos] 
        output shape: [batch_size, doc_len * doc_len, n_class]
        '''        
        x = create_pairs(x1, x2)
        # x is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden)
        x_distance = torch.cat([x, distance.float()], -1)
        # x_distance is of shape (batch_size, max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        x_distance = x_distance.reshape(-1, 4 * self.n_hidden + self.embedding_dim_pos)
        x_distance = self.dropout3(x_distance)
        # x is of shape (batch_size * max_doc_len * max_doc_len, 4 * n_hidden + embedding_dim_pos)
        pred_pair = F.softmax(self.pair_linear2(self.relu(self.pair_linear1(x_distance))), dim = -1)
        # pred_pair is of shape (batch_size * max_doc_len * max_doc_len, n_class)
        pred_pair = pred_pair.reshape(-1, self.doc_len * self.doc_len, self.n_class)
        # pred_pair is of shape (batch_size, max_doc_len * max_doc_len, n_class)
        return pred_pair

    def forward(self, x, distance):
        '''
        input(s) shape: [batch_size, doc_len, sen_len, embedding_dim], 
                        [batch_size, doc_len * doc_len, embedding_dim_pos]
        output(s) shape: [batch_size, doc_len, n_class], [batch_size, doc_len, n_class], 
                         [batch_size, doc_len * doc_len, n_class]
        '''
        s = self.get_clause_embedding(x)
        x_cause, pred_cause = self.get_cause_prediction(s)
        s_pred_cause = torch.cat([s, pred_cause], 2)
        x_pos, pred_pos = self.get_emotion_prediction(s_pred_cause)
        pred_pair = self.get_pair_prediction(x_pos, x_cause, distance)
        return pred_pos, pred_cause, pred_pair

# %%
def load_data_pair(input_file, word_idx, max_doc_len = 75, max_sen_len = 45):
    print('load data_file: {}'.format(input_file))
    pair_id_all, y_position, y_cause, y_pair, x, sen_len, doc_len, distance = [], [], [], [], [], [], [], []
    n_cut = 0
    inputFile = open(input_file, 'r')
    while True:
        line = inputFile.readline()
        if line == '': break
        line = line.strip().split()
        doc_id = int(line[0])
        d_len = int(line[1])
        ######################################## doc_len_condition ########################################
        if d_len >= max_doc_len :
            for i in range(d_len+1) :
                line = inputFile.readline().strip().split(',')
            continue
        ######################################## doc_len_condition ########################################

        pairs = eval('[' + inputFile.readline().strip() + ']')
        pos_list, cause_list = zip(*pairs)
        pairs = [[pos_list[i], cause_list[i]] for i in range(len(pos_list))]
        pair_id_all.extend([doc_id*10000+p[0]*100+p[1] for p in pairs])
        y_position_tmp, y_cause_tmp, y_pair_tmp, sen_len_tmp, x_tmp, distance_tmp = \
        np.zeros((max_doc_len, 2)), np.zeros((max_doc_len, 2)), np.zeros((max_doc_len * max_doc_len, 2)), \
        np.zeros((max_doc_len, )), np.zeros((max_doc_len, max_sen_len)), np.zeros((max_doc_len * max_doc_len, ))

        for i in range(d_len):
            line = inputFile.readline().strip().split(',')
            words = line[-1]
            sen_len_tmp[i] = min(len(words.split()), max_sen_len)
            for j, word in enumerate(words.split()):
                word = word.lower()
                if j >= max_sen_len:
                    n_cut += 1
                    break
                elif word not in word_idx : x_tmp[i][j] = 24166
                else : x_tmp[i][j] = int(word_idx[word])

        for i in range(d_len):
            for j in range(d_len):
                # Check whether i is an emotion clause
                if i+1 in pos_list :
                    y_position_tmp[i][0] = 0; y_position_tmp[i][1] = 1
                else :
                    y_position_tmp[i][0] = 1; y_position_tmp[i][1] = 0
                # Check whether j is a cause clause
                if j+1 in cause_list :
                    y_cause_tmp[j][0] = 0; y_cause_tmp[j][1] = 1
                else :
                    y_cause_tmp[j][0] = 1; y_cause_tmp[j][1] = 0
                # Check whether i, j clauses are emotion cause pairs
                pair_id_curr = doc_id*10000+(i+1)*100+(j+1)
                if pair_id_curr in pair_id_all :
                    y_pair_tmp[i*max_doc_len+j][0] = 0; y_pair_tmp[i*max_doc_len+j][1] = 1
                else :
                    y_pair_tmp[i*max_doc_len+j][0] = 1; y_pair_tmp[i*max_doc_len+j][1] = 0
                # Find the distance between the clauses, and use the same embedding beyond 10 clauses
                distance_tmp[i*max_doc_len+j] = min(max(j-i+100, 90), 110)

        y_position.append(y_position_tmp)
        y_cause.append(y_cause_tmp)
        y_pair.append(y_pair_tmp)
        x.append(x_tmp)
        sen_len.append(sen_len_tmp)
        doc_len.append(d_len)
        distance.append(distance_tmp)

    y_position, y_cause, y_pair, x, sen_len, doc_len, distance = map(torch.tensor, \
    [y_position, y_cause, y_pair, x, sen_len, doc_len, distance])

    for var in ['y_position', 'y_cause', 'y_pair', 'x', 'sen_len', 'doc_len', 'distance']:
        print('{}.shape {}'.format( var, eval(var).shape ))
    print('n_cut {}'.format(n_cut))
    print('load data done!\n')
    return y_position, y_cause, y_pair, x, sen_len, doc_len, distance

# %%
############################################ TRAIN #####################################################
def train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, n_hidden, batch_size, learning_rate, diminish_factor):
    word_idx_rev, word_id_mapping, word_embedding, pos_embedding = load_w2v(
        embedding_dim, embedding_dim_pos, train_file_path, w2v_file)
    word_embedding = torch.from_numpy(word_embedding)
    # Train distance embeddings
    pos_embedding = torch.autograd.Variable(torch.from_numpy(pos_embedding))
    pos_embedding.requires_grad_(True)
    #torch.save(word_embedding, MODEL_PATH+DATA+'_'+'word_embedding'+'.pth')
    torch.save(word_embedding, f'{MODEL_PATH}{DATA}_word_embedding_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    #torch.save(word_id_mapping, MODEL_PATH+DATA+'_'+'word_id_mapping'+'.pth')
    torch.save(word_id_mapping, f'{MODEL_PATH}{DATA}_word_id_mapping_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
    acc_cause_list, p_cause_list, r_cause_list, f1_cause_list = [], [], [], []
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list = [], [], [], []
    acc_pair_list, p_pair_list, r_pair_list, f1_pair_list = [], [], [], []
    #################################### LOOP OVER FOLDS ####################################
    # do 5 fold cross validation
    for fold in range(1, 2):
        print('############# fold {} begin ###############'.format(fold))
        ############################# RE-INITIALIZE MODEL PARAMETERS #############################
        for layer in Model.parameters():
            nn.init.uniform_(layer.data, -0.10, 0.10)
        #################################### TRAIN/TEST DATA ####################################
        train_file_name = '{}_{}.txt'.format(TRAIN_DATA,fold)
        val_file_name = '{}_{}.txt'.format(VAL_DATA,fold)
        tr_y_position, tr_y_cause, tr_y_pair, tr_x, tr_sen_len, tr_doc_len, tr_distance = load_data_pair(
                        DATA_PATH+train_file_name, word_id_mapping, max_doc_len, max_sen_len)
        val_y_position, val_y_cause, val_y_pair, val_x, val_sen_len, val_doc_len, val_distance = \
            load_data_pair(DATA_PATH+val_file_name, word_id_mapping, max_doc_len, max_sen_len)
        max_f1_cause, max_f1_pos, max_f1_pair, max_f1_avg = [-1.] * 4
        #################################### LOOP OVER EPOCHS ####################################
        for epoch in range(1, training_epochs + 1):
            step = 1
            #################################### GET BATCH DATA ####################################
            for train, _ in get_batch_data_pair(
                tr_x, tr_sen_len, tr_doc_len, tr_y_position, tr_y_cause, tr_y_pair, tr_distance, batch_size):
                tr_x_batch, tr_sen_len_batch, tr_doc_len_batch, tr_true_y_pos, tr_true_y_cause, \
                tr_true_y_pair, tr_distance_batch = train
                Model.train()
                tr_pred_y_pos, tr_pred_y_cause, tr_pred_y_pair = Model(embedding_lookup(word_embedding, \
                tr_x_batch), embedding_lookup(pos_embedding, tr_distance_batch))
                ############################## LOSS FUNCTION AND OPTIMIZATION ##############################
                loss = pos_cause_criterion(tr_true_y_pos, tr_pred_y_pos, tr_doc_len_batch)*pos + \
                pos_cause_criterion(tr_true_y_cause, tr_pred_y_cause, tr_doc_len_batch)*cause + \
                pair_criterion(tr_true_y_pair, tr_pred_y_pair, tr_doc_len_batch)*pair
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                #################################### PRINT AFTER EPOCHS ####################################
                if step % 25 == 0:
                    # print(Model.pair_linear.weight.shape); print(Model.pair_linear.weight.grad)
                    print('Fold {}, Epoch {}, step {}: train loss {:.4f} '.format(fold, epoch, step, loss))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_pos, tr_true_y_pos, tr_doc_len_batch)
                    print('emotion_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_aux(tr_pred_y_cause, tr_true_y_cause, tr_doc_len_batch)
                    print('cause_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1))
                    acc, p, r, f1 = acc_prf_pair(tr_pred_y_pair, tr_true_y_pair, tr_doc_len_batch)
                    print('pair_predict: train acc {:.4f} p {:.4f} r {:.4f} f1 score {:.4f}'.format(
                            acc, p, r, f1)) 
                step += 1
            #################################### TEST ON 1 FOLD ####################################
            with torch.no_grad():
                Model.eval()
                val_pred_y_pos, val_pred_y_cause, val_pred_y_pair = Model(embedding_lookup(word_embedding, \
                val_x), embedding_lookup(pos_embedding, val_distance))

                loss = pos_cause_criterion(val_y_position, val_pred_y_pos, val_doc_len)*pos + \
                pos_cause_criterion(val_y_cause, val_pred_y_cause, val_doc_len)*cause + \
                pair_criterion(val_y_pair, val_pred_y_pair, val_doc_len)*pair
                print('Fold {} Epoch {} val loss {:.4f}'.format(fold, epoch, loss))
                acc, p, r, f1 = acc_prf_aux(val_pred_y_pos, val_y_position, val_doc_len)
                result_avg_pos = [acc, p, r, f1]
                if f1 > max_f1_pos:
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos = acc, p, r, f1
                print('emotion_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pos, max_p_pos, max_r_pos, max_f1_pos))

                acc, p, r, f1 = acc_prf_aux(val_pred_y_cause, val_y_cause, val_doc_len)
                result_avg_cause = [acc, p, r, f1]
                if f1 > max_f1_cause:
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause = acc, p, r, f1
                print('cause_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_cause, max_p_cause, max_r_cause, max_f1_cause))

                acc, p, r, f1 = acc_prf_pair(val_pred_y_pair, val_y_pair, val_doc_len)
                result_avg_pair = [acc, p, r, f1]
                if f1 > max_f1_pair:
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair = acc, p, r, f1
                print('pair_predict: val acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}'.format(acc, p, r, f1))
                print('max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                    max_acc_pair, max_p_pair, max_r_pair, max_f1_pair))

            #################################### STORE BETTER PAIR F1 ####################################
            if result_avg_pair[-1] > max_f1_avg:
                #torch.save(pos_embedding, MODEL_PATH+DATA+"_"+"pos_embedding_fold_{}.pth".format(fold))
                torch.save(pos_embedding, f'{MODEL_PATH}{DATA}_pos_embedding_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                #torch.save(Model.state_dict(), MODEL_PATH+DATA+"_"+"E2E-EC_fold_{}.pth".format(fold))
                torch.save(Model.state_dict(), f'{MODEL_PATH}{DATA}_E2E-EC_fold-{fold}_nhid-{n_hidden}_bs-{batch_size}_lr-{learning_rate}_dimf-{diminish_factor}.pth')
                
                max_f1_avg = result_avg_pair[-1]
                result_avg_cause_max = result_avg_cause
                result_avg_pos_max = result_avg_pos
                result_avg_pair_max = result_avg_pair

            print('avg max cause: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_cause_max[0], result_avg_cause_max[1], result_avg_cause_max[2], result_avg_cause_max[3]))
            print('avg max pos: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}'.format(
                result_avg_pos_max[0], result_avg_pos_max[1], result_avg_pos_max[2], result_avg_pos_max[3]))
            print('avg max pair: max_acc {:.4f} max_p {:.4f} max_r {:.4f} max_f1 {:.4f}\n'.format(
                result_avg_pair_max[0], result_avg_pair_max[1], result_avg_pair_max[2], result_avg_pair_max[3]))

        print('############# fold {} end ###############'.format(fold))
        acc_cause_list.append(result_avg_cause_max[0])
        p_cause_list.append(result_avg_cause_max[1])
        r_cause_list.append(result_avg_cause_max[2])
        f1_cause_list.append(result_avg_cause_max[3])
        acc_pos_list.append(result_avg_pos_max[0])
        p_pos_list.append(result_avg_pos_max[1])
        r_pos_list.append(result_avg_pos_max[2])
        f1_pos_list.append(result_avg_pos_max[3])
        acc_pair_list.append(result_avg_pair_max[0])
        p_pair_list.append(result_avg_pair_max[1])
        r_pair_list.append(result_avg_pair_max[2])
        f1_pair_list.append(result_avg_pair_max[3])

    #################################### FINAL TEST RESULTS ON 10 FOLDS ####################################
    all_results = [acc_cause_list, p_cause_list, r_cause_list, f1_cause_list, \
    acc_pos_list, p_pos_list, r_pos_list, f1_pos_list, acc_pair_list, p_pair_list, r_pair_list, f1_pair_list,]
    acc_cause, p_cause, r_cause, f1_cause, acc_pos, p_pos, r_pos, f1_pos, acc_pair, p_pair, r_pair, f1_pair = \
        map(lambda x: np.array(x).mean(), all_results)
    print('\ncause_predict: val f1 in 1 fold: {}'.format(np.array(f1_cause_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_cause, p_cause, r_cause, f1_cause))
    print('emotion_predict: val f1 in 1 fold: {}'.format(np.array(f1_pos_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pos, p_pos, r_pos, f1_pos))
    print('pair_predict: val f1 in 1 fold: {}'.format(np.array(f1_pair_list).reshape(-1,1)))
    print('average : acc {:.4f} p {:.4f} r {:.4f} f1 {:.4f}\n'.format(acc_pair, p_pair, r_pair, f1_pair))

# %% [markdown]
# ## Calling the class for the varying hyperparameters

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3107
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.9993
# emotion_predict: val acc 0.7059 p 0.8125 r 0.1444 f1 0.2453
# max_acc 0.7059 max_p 0.8125 max_r 0.1444 max_f1 0.2453
#
# cause_predict: val acc 0.7132 p 0.8333 r 0.1667 f1 0.2778
# max_acc 0.7132 max_p 0.8333 max_r 0.1667 max_f1 0.2778
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0557
# emotion_predict: val acc 0.7096 p 0.8235 r 0.1556 f1 0.2617
# max_acc 0.7096 max_p 0.8235 max_r 0.1556 max_f1 0.2617
#
# cause_predict: val acc 0.7096 p 0.7619 r 0.1778 f1 0.2883
# max_acc 0.7096 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.7096 max_p 0.7619 max_r 0.1778 max_f1 0.2883
# avg max pos: max_acc 0.7096 max_p 0.8235 max_r 0.1556 max_f1 0.2617
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 4 val loss 2.9896
# emotion_predict: val acc 0.7463 p 0.7143 r 0.3889 f1 0.5036
# max_acc 0.7463 max_p 0.7143 max_r 0.3889 max_f1 0.5036
#
# cause_predict: val acc 0.7610 p 0.7193 r 0.4556 f1 0.5578
# max_acc 0.7610 max_p 0.7193 max_r 0.4556 max_f1 0.5578
#
# pair_predict: val acc 0.9350 p 0.8571 r 0.2000 f1 0.3243
# max_acc 0.9350 max_p 0.8571 max_r 0.2000 max_f1 0.3243
#
# avg max cause: max_acc 0.7610 max_p 0.7193 max_r 0.4556 max_f1 0.5578
# avg max pos: max_acc 0.7463 max_p 0.7143 max_r 0.3889 max_f1 0.5036
# avg max pair: max_acc 0.9350 max_p 0.8571 max_r 0.2000 max_f1 0.3243
#
# Fold 1 Epoch 5 val loss 2.8499
# emotion_predict: val acc 0.7537 p 0.7255 r 0.4111 f1 0.5248
# max_acc 0.7537 max_p 0.7255 max_r 0.4111 max_f1 0.5248
#
# cause_predict: val acc 0.7574 p 0.7069 r 0.4556 f1 0.5541
# max_acc 0.7610 max_p 0.7193 max_r 0.4556 max_f1 0.5578
#
# pair_predict: val acc 0.9367 p 0.8696 r 0.2222 f1 0.3540
# max_acc 0.9367 max_p 0.8696 max_r 0.2222 max_f1 0.3540
#
# avg max cause: max_acc 0.7574 max_p 0.7069 max_r 0.4556 max_f1 0.5541
# avg max pos: max_acc 0.7537 max_p 0.7255 max_r 0.4111 max_f1 0.5248
# avg max pair: max_acc 0.9367 max_p 0.8696 max_r 0.2222 max_f1 0.3540
#
# Fold 1 Epoch 6 val loss 2.7550
# emotion_predict: val acc 0.7059 p 0.5676 r 0.4667 f1 0.5122
# max_acc 0.7537 max_p 0.7255 max_r 0.4111 max_f1 0.5248
#
# cause_predict: val acc 0.7537 p 0.6575 r 0.5333 f1 0.5890
# max_acc 0.7537 max_p 0.6575 max_r 0.5333 max_f1 0.5890
#
# pair_predict: val acc 0.9307 p 0.6087 r 0.3111 f1 0.4118
# max_acc 0.9307 max_p 0.6087 max_r 0.3111 max_f1 0.4118
#
# avg max cause: max_acc 0.7537 max_p 0.6575 max_r 0.5333 max_f1 0.5890
# avg max pos: max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
# avg max pair: max_acc 0.9307 max_p 0.6087 max_r 0.3111 max_f1 0.4118
#
# Fold 1 Epoch 7 val loss 2.6400
# emotion_predict: val acc 0.7279 p 0.6212 r 0.4556 f1 0.5256
# max_acc 0.7279 max_p 0.6212 max_r 0.4556 max_f1 0.5256
#
# cause_predict: val acc 0.7684 p 0.7015 r 0.5222 f1 0.5987
# max_acc 0.7684 max_p 0.7015 max_r 0.5222 max_f1 0.5987
#
# pair_predict: val acc 0.9159 p 0.4507 r 0.3556 f1 0.3975
# max_acc 0.9307 max_p 0.6087 max_r 0.3111 max_f1 0.4118
#
# avg max cause: max_acc 0.7537 max_p 0.6575 max_r 0.5333 max_f1 0.5890
# avg max pos: max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
# avg max pair: max_acc 0.9307 max_p 0.6087 max_r 0.3111 max_f1 0.4118
#
# Fold 1 Epoch 8 val loss 2.4981
# emotion_predict: val acc 0.7537 p 0.6949 r 0.4556 f1 0.5503
# max_acc 0.7537 max_p 0.6949 max_r 0.4556 max_f1 0.5503
#
# cause_predict: val acc 0.7831 p 0.7460 r 0.5222 f1 0.6144
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.3667 f1 0.4231
# max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# avg max cause: max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
# avg max pos: max_acc 0.7537 max_p 0.6949 max_r 0.4556 max_f1 0.5503
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# Fold 1 Epoch 9 val loss 2.5347
# emotion_predict: val acc 0.7794 p 0.6630 r 0.6778 f1 0.6703
# max_acc 0.7794 max_p 0.6630 max_r 0.6778 max_f1 0.6703
#
# cause_predict: val acc 0.7610 p 0.6623 r 0.5667 f1 0.6108
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9203 p 0.4872 r 0.4222 f1 0.4524
# max_acc 0.9203 max_p 0.4872 max_r 0.4222 max_f1 0.4524
#
# avg max cause: max_acc 0.7610 max_p 0.6623 max_r 0.5667 max_f1 0.6108
# avg max pos: max_acc 0.7794 max_p 0.6630 max_r 0.6778 max_f1 0.6703
# avg max pair: max_acc 0.9203 max_p 0.4872 max_r 0.4222 max_f1 0.4524
#
# Fold 1 Epoch 10 val loss 2.4796
# emotion_predict: val acc 0.7941 p 0.7429 r 0.5778 f1 0.6500
# max_acc 0.7794 max_p 0.6630 max_r 0.6778 max_f1 0.6703
#
# cause_predict: val acc 0.7537 p 0.6885 r 0.4667 f1 0.5563
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9359 p 0.6538 r 0.3778 f1 0.4789
# max_acc 0.9359 max_p 0.6538 max_r 0.3778 max_f1 0.4789
#
# avg max cause: max_acc 0.7537 max_p 0.6885 max_r 0.4667 max_f1 0.5563
# avg max pos: max_acc 0.7941 max_p 0.7429 max_r 0.5778 max_f1 0.6500
# avg max pair: max_acc 0.9359 max_p 0.6538 max_r 0.3778 max_f1 0.4789
#
# Fold 1 Epoch 11 val loss 2.4320
# emotion_predict: val acc 0.8015 p 0.7500 r 0.6000 f1 0.6667
# max_acc 0.7794 max_p 0.6630 max_r 0.6778 max_f1 0.6703
#
# cause_predict: val acc 0.7757 p 0.7164 r 0.5333 f1 0.6115
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9246 p 0.5181 r 0.4778 f1 0.4971
# max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# avg max cause: max_acc 0.7757 max_p 0.7164 max_r 0.5333 max_f1 0.6115
# avg max pos: max_acc 0.8015 max_p 0.7500 max_r 0.6000 max_f1 0.6667
# avg max pair: max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# Fold 1 Epoch 12 val loss 2.4670
# emotion_predict: val acc 0.7978 p 0.7273 r 0.6222 f1 0.6707
# max_acc 0.7978 max_p 0.7273 max_r 0.6222 max_f1 0.6707
#
# cause_predict: val acc 0.7684 p 0.7213 r 0.4889 f1 0.5828
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9272 p 0.5417 r 0.4333 f1 0.4815
# max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# avg max cause: max_acc 0.7757 max_p 0.7164 max_r 0.5333 max_f1 0.6115
# avg max pos: max_acc 0.8015 max_p 0.7500 max_r 0.6000 max_f1 0.6667
# avg max pair: max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# Fold 1 Epoch 13 val loss 2.5785
# emotion_predict: val acc 0.7794 p 0.6667 r 0.6667 f1 0.6667
# max_acc 0.7978 max_p 0.7273 max_r 0.6222 max_f1 0.6707
#
# cause_predict: val acc 0.7574 p 0.6538 r 0.5667 f1 0.6071
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9272 p 0.5405 r 0.4444 f1 0.4878
# max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# avg max cause: max_acc 0.7757 max_p 0.7164 max_r 0.5333 max_f1 0.6115
# avg max pos: max_acc 0.8015 max_p 0.7500 max_r 0.6000 max_f1 0.6667
# avg max pair: max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# Fold 1 Epoch 14 val loss 2.8552
# emotion_predict: val acc 0.7684 p 0.6627 r 0.6111 f1 0.6358
# max_acc 0.7978 max_p 0.7273 max_r 0.6222 max_f1 0.6707
#
# cause_predict: val acc 0.7647 p 0.7097 r 0.4889 f1 0.5789
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9012 p 0.3947 r 0.5000 f1 0.4412
# max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# avg max cause: max_acc 0.7757 max_p 0.7164 max_r 0.5333 max_f1 0.6115
# avg max pos: max_acc 0.8015 max_p 0.7500 max_r 0.6000 max_f1 0.6667
# avg max pair: max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# Fold 1 Epoch 15 val loss 2.7973
# emotion_predict: val acc 0.7647 p 0.6711 r 0.5667 f1 0.6145
# max_acc 0.7978 max_p 0.7273 max_r 0.6222 max_f1 0.6707
#
# cause_predict: val acc 0.7684 p 0.7143 r 0.5000 f1 0.5882
# max_acc 0.7831 max_p 0.7460 max_r 0.5222 max_f1 0.6144
#
# pair_predict: val acc 0.9272 p 0.5405 r 0.4444 f1 0.4878
# max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# avg max cause: max_acc 0.7757 max_p 0.7164 max_r 0.5333 max_f1 0.6115
# avg max pos: max_acc 0.8015 max_p 0.7500 max_r 0.6000 max_f1 0.6667
# avg max pair: max_acc 0.9246 max_p 0.5181 max_r 0.4778 max_f1 0.4971
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.61146497]]
# average : acc 0.7757 p 0.7164 r 0.5333 f1 0.6115
#
# emotion_predict: val f1 in 1 fold: [[0.66666667]]
# average : acc 0.8015 p 0.7500 r 0.6000 f1 0.6667
#
# pair_predict: val f1 in 1 fold: [[0.49710983]]
# average : acc 0.9246 p 0.5181 r 0.4778 f1 0.4971

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.9184
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.5627
# emotion_predict: val acc 0.7132 p 0.7727 r 0.1889 f1 0.3036
# max_acc 0.7132 max_p 0.7727 max_r 0.1889 max_f1 0.3036
#
# cause_predict: val acc 0.7096 p 0.8235 r 0.1556 f1 0.2617
# max_acc 0.7096 max_p 0.8235 max_r 0.1556 max_f1 0.2617
#
# pair_predict: val acc 0.9272 p 0.8750 r 0.0778 f1 0.1429
# max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# avg max cause: max_acc 0.7096 max_p 0.8235 max_r 0.1556 max_f1 0.2617
# avg max pos: max_acc 0.7132 max_p 0.7727 max_r 0.1889 max_f1 0.3036
# avg max pair: max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# Fold 1 Epoch 3 val loss 2.4379
# emotion_predict: val acc 0.7169 p 0.5942 r 0.4556 f1 0.5157
# max_acc 0.7169 max_p 0.5942 max_r 0.4556 max_f1 0.5157
#
# cause_predict: val acc 0.7574 p 0.6500 r 0.5778 f1 0.6118
# max_acc 0.7574 max_p 0.6500 max_r 0.5778 max_f1 0.6118
#
# pair_predict: val acc 0.9012 p 0.3776 r 0.4111 f1 0.3936
# max_acc 0.9012 max_p 0.3776 max_r 0.4111 max_f1 0.3936
#
# avg max cause: max_acc 0.7574 max_p 0.6500 max_r 0.5778 max_f1 0.6118
# avg max pos: max_acc 0.7169 max_p 0.5942 max_r 0.4556 max_f1 0.5157
# avg max pair: max_acc 0.9012 max_p 0.3776 max_r 0.4111 max_f1 0.3936
#
# Fold 1 Epoch 4 val loss 2.3191
# emotion_predict: val acc 0.7426 p 0.6667 r 0.4444 f1 0.5333
# max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
#
# cause_predict: val acc 0.7721 p 0.7059 r 0.5333 f1 0.6076
# max_acc 0.7574 max_p 0.6500 max_r 0.5778 max_f1 0.6118
#
# pair_predict: val acc 0.9116 p 0.4302 r 0.4111 f1 0.4205
# max_acc 0.9116 max_p 0.4302 max_r 0.4111 max_f1 0.4205
#
# avg max cause: max_acc 0.7721 max_p 0.7059 max_r 0.5333 max_f1 0.6076
# avg max pos: max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
# avg max pair: max_acc 0.9116 max_p 0.4302 max_r 0.4111 max_f1 0.4205
#
# Fold 1 Epoch 5 val loss 2.2289
# emotion_predict: val acc 0.7316 p 0.6000 r 0.5667 f1 0.5829
# max_acc 0.7316 max_p 0.6000 max_r 0.5667 max_f1 0.5829
#
# cause_predict: val acc 0.7721 p 0.6892 r 0.5667 f1 0.6220
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8172 p 0.2490 r 0.6667 f1 0.3625
# max_acc 0.9116 max_p 0.4302 max_r 0.4111 max_f1 0.4205
#
# avg max cause: max_acc 0.7721 max_p 0.7059 max_r 0.5333 max_f1 0.6076
# avg max pos: max_acc 0.7426 max_p 0.6667 max_r 0.4444 max_f1 0.5333
# avg max pair: max_acc 0.9116 max_p 0.4302 max_r 0.4111 max_f1 0.4205
#
# Fold 1 Epoch 6 val loss 2.1840
# emotion_predict: val acc 0.8088 p 0.8065 r 0.5556 f1 0.6579
# max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
#
# cause_predict: val acc 0.7684 p 0.7368 r 0.4667 f1 0.5714
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.9229 p 0.5065 r 0.4333 f1 0.4671
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 7 val loss 2.1354
# emotion_predict: val acc 0.8051 p 0.7229 r 0.6667 f1 0.6936
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7647 p 0.6857 r 0.5333 f1 0.6000
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8718 p 0.3274 r 0.6111 f1 0.4264
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 8 val loss 2.2636
# emotion_predict: val acc 0.7574 p 0.6395 r 0.6111 f1 0.6250
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7721 p 0.7059 r 0.5333 f1 0.6076
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8839 p 0.3553 r 0.6000 f1 0.4463
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 9 val loss 2.1721
# emotion_predict: val acc 0.7757 p 0.6790 r 0.6111 f1 0.6433
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8821 p 0.3487 r 0.5889 f1 0.4380
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 10 val loss 2.3358
# emotion_predict: val acc 0.7831 p 0.6914 r 0.6222 f1 0.6550
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7426 p 0.6220 r 0.5667 f1 0.5930
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8960 p 0.3810 r 0.5333 f1 0.4444
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 11 val loss 2.4795
# emotion_predict: val acc 0.7831 p 0.6914 r 0.6222 f1 0.6550
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7500 p 0.6410 r 0.5556 f1 0.5952
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8692 p 0.3237 r 0.6222 f1 0.4259
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 12 val loss 2.4001
# emotion_predict: val acc 0.7904 p 0.6941 r 0.6556 f1 0.6743
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7721 p 0.7187 r 0.5111 f1 0.5974
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8718 p 0.3274 r 0.6111 f1 0.4264
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 13 val loss 2.8353
# emotion_predict: val acc 0.7647 p 0.6585 r 0.6000 f1 0.6279
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7243 p 0.5926 r 0.5333 f1 0.5614
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8969 p 0.3802 r 0.5111 f1 0.4360
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 14 val loss 2.8304
# emotion_predict: val acc 0.7721 p 0.6628 r 0.6333 f1 0.6477
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7169 p 0.5802 r 0.5222 f1 0.5497
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8821 p 0.3333 r 0.5111 f1 0.4035
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# Fold 1 Epoch 15 val loss 3.1644
# emotion_predict: val acc 0.7537 p 0.6264 r 0.6333 f1 0.6298
# max_acc 0.8051 max_p 0.7229 max_r 0.6667 max_f1 0.6936
#
# cause_predict: val acc 0.7206 p 0.5972 r 0.4778 f1 0.5309
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# pair_predict: val acc 0.8744 p 0.3179 r 0.5333 f1 0.3983
# max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# avg max cause: max_acc 0.7684 max_p 0.7368 max_r 0.4667 max_f1 0.5714
# avg max pos: max_acc 0.8088 max_p 0.8065 max_r 0.5556 max_f1 0.6579
# avg max pair: max_acc 0.9229 max_p 0.5065 max_r 0.4333 max_f1 0.4671
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.57142857]]
# average : acc 0.7684 p 0.7368 r 0.4667 f1 0.5714
#
# emotion_predict: val f1 in 1 fold: [[0.65789474]]
# average : acc 0.8088 p 0.8065 r 0.5556 f1 0.6579
#
# pair_predict: val f1 in 1 fold: [[0.46706587]]
# average : acc 0.9229 p 0.5065 r 0.4333 f1 0.4671

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.9559
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.3556
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.2404
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1901
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6912 p 0.5789 r 0.2444 f1 0.3437
# max_acc 0.6912 max_p 0.5789 max_r 0.2444 max_f1 0.3437
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.0379
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6912 max_p 0.5789 max_r 0.2444 max_f1 0.3437
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.9626
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.7316 p 0.7931 r 0.2556 f1 0.3866
# max_acc 0.7316 max_p 0.7931 max_r 0.2556 max_f1 0.3866
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.9150
# emotion_predict: val acc 0.7279 p 0.6081 r 0.5000 f1 0.5488
# max_acc 0.7279 max_p 0.6081 max_r 0.5000 max_f1 0.5488
#
# cause_predict: val acc 0.7206 p 0.5761 r 0.5889 f1 0.5824
# max_acc 0.7206 max_p 0.5761 max_r 0.5889 max_f1 0.5824
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.8494
# emotion_predict: val acc 0.7353 p 0.6500 r 0.4333 f1 0.5200
# max_acc 0.7279 max_p 0.6081 max_r 0.5000 max_f1 0.5488
#
# cause_predict: val acc 0.7537 p 0.6494 r 0.5556 f1 0.5988
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.7815
# emotion_predict: val acc 0.7353 p 0.6500 r 0.4333 f1 0.5200
# max_acc 0.7279 max_p 0.6081 max_r 0.5000 max_f1 0.5488
#
# cause_predict: val acc 0.7610 p 0.6761 r 0.5333 f1 0.5963
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.7042
# emotion_predict: val acc 0.7353 p 0.6500 r 0.4333 f1 0.5200
# max_acc 0.7279 max_p 0.6081 max_r 0.5000 max_f1 0.5488
#
# cause_predict: val acc 0.7721 p 0.7258 r 0.5000 f1 0.5921
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# pair_predict: val acc 0.9376 p 0.8214 r 0.2556 f1 0.3898
# max_acc 0.9376 max_p 0.8214 max_r 0.2556 max_f1 0.3898
#
# avg max cause: max_acc 0.7721 max_p 0.7258 max_r 0.5000 max_f1 0.5921
# avg max pos: max_acc 0.7353 max_p 0.6500 max_r 0.4333 max_f1 0.5200
# avg max pair: max_acc 0.9376 max_p 0.8214 max_r 0.2556 max_f1 0.3898
#
# Fold 1 Epoch 11 val loss 2.6419
# emotion_predict: val acc 0.7390 p 0.6418 r 0.4778 f1 0.5478
# max_acc 0.7279 max_p 0.6081 max_r 0.5000 max_f1 0.5488
#
# cause_predict: val acc 0.7831 p 0.7313 r 0.5444 f1 0.6242
# max_acc 0.7831 max_p 0.7313 max_r 0.5444 max_f1 0.6242
#
# pair_predict: val acc 0.9324 p 0.6304 r 0.3222 f1 0.4265
# max_acc 0.9324 max_p 0.6304 max_r 0.3222 max_f1 0.4265
#
# avg max cause: max_acc 0.7831 max_p 0.7313 max_r 0.5444 max_f1 0.6242
# avg max pos: max_acc 0.7390 max_p 0.6418 max_r 0.4778 max_f1 0.5478
# avg max pair: max_acc 0.9324 max_p 0.6304 max_r 0.3222 max_f1 0.4265
#
# Fold 1 Epoch 12 val loss 2.5978
# emotion_predict: val acc 0.7426 p 0.6316 r 0.5333 f1 0.5783
# max_acc 0.7426 max_p 0.6316 max_r 0.5333 max_f1 0.5783
#
# cause_predict: val acc 0.7757 p 0.6933 r 0.5778 f1 0.6303
# max_acc 0.7757 max_p 0.6933 max_r 0.5778 max_f1 0.6303
#
# pair_predict: val acc 0.9289 p 0.5741 r 0.3444 f1 0.4306
# max_acc 0.9289 max_p 0.5741 max_r 0.3444 max_f1 0.4306
#
# avg max cause: max_acc 0.7757 max_p 0.6933 max_r 0.5778 max_f1 0.6303
# avg max pos: max_acc 0.7426 max_p 0.6316 max_r 0.5333 max_f1 0.5783
# avg max pair: max_acc 0.9289 max_p 0.5741 max_r 0.3444 max_f1 0.4306
#
# Fold 1 Epoch 13 val loss 2.5572
# emotion_predict: val acc 0.7463 p 0.6364 r 0.5444 f1 0.5868
# max_acc 0.7463 max_p 0.6364 max_r 0.5444 max_f1 0.5868
#
# cause_predict: val acc 0.7941 p 0.7297 r 0.6000 f1 0.6585
# max_acc 0.7941 max_p 0.7297 max_r 0.6000 max_f1 0.6585
#
# pair_predict: val acc 0.9289 p 0.5645 r 0.3889 f1 0.4605
# max_acc 0.9289 max_p 0.5645 max_r 0.3889 max_f1 0.4605
#
# avg max cause: max_acc 0.7941 max_p 0.7297 max_r 0.6000 max_f1 0.6585
# avg max pos: max_acc 0.7463 max_p 0.6364 max_r 0.5444 max_f1 0.5868
# avg max pair: max_acc 0.9289 max_p 0.5645 max_r 0.3889 max_f1 0.4605
#
# Fold 1 Epoch 14 val loss 2.5221
# emotion_predict: val acc 0.7610 p 0.6543 r 0.5889 f1 0.6199
# max_acc 0.7610 max_p 0.6543 max_r 0.5889 max_f1 0.6199
#
# cause_predict: val acc 0.7868 p 0.7222 r 0.5778 f1 0.6420
# max_acc 0.7941 max_p 0.7297 max_r 0.6000 max_f1 0.6585
#
# pair_predict: val acc 0.9255 p 0.5278 r 0.4222 f1 0.4691
# max_acc 0.9255 max_p 0.5278 max_r 0.4222 max_f1 0.4691
#
# avg max cause: max_acc 0.7868 max_p 0.7222 max_r 0.5778 max_f1 0.6420
# avg max pos: max_acc 0.7610 max_p 0.6543 max_r 0.5889 max_f1 0.6199
# avg max pair: max_acc 0.9255 max_p 0.5278 max_r 0.4222 max_f1 0.4691
#
# Fold 1 Epoch 15 val loss 2.5067
# emotion_predict: val acc 0.7426 p 0.6087 r 0.6222 f1 0.6154
# max_acc 0.7610 max_p 0.6543 max_r 0.5889 max_f1 0.6199
#
# cause_predict: val acc 0.7721 p 0.6842 r 0.5778 f1 0.6265
# max_acc 0.7941 max_p 0.7297 max_r 0.6000 max_f1 0.6585
#
# pair_predict: val acc 0.9151 p 0.4565 r 0.4667 f1 0.4615
# max_acc 0.9255 max_p 0.5278 max_r 0.4222 max_f1 0.4691
#
# avg max cause: max_acc 0.7868 max_p 0.7222 max_r 0.5778 max_f1 0.6420
# avg max pos: max_acc 0.7610 max_p 0.6543 max_r 0.5889 max_f1 0.6199
# avg max pair: max_acc 0.9255 max_p 0.5278 max_r 0.4222 max_f1 0.4691
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.64197531]]
# average : acc 0.7868 p 0.7222 r 0.5778 f1 0.6420
#
# emotion_predict: val f1 in 1 fold: [[0.61988304]]
# average : acc 0.7610 p 0.6543 r 0.5889 f1 0.6199
#
# pair_predict: val f1 in 1 fold: [[0.4691358]]
# average : acc 0.9255 p 0.5278 r 0.4222 f1 0.4691

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.0342
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8513
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.7501
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.5000 r 0.0111 f1 0.0217
# max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.6149
# emotion_predict: val acc 0.6765 p 0.6250 r 0.0556 f1 0.1020
# max_acc 0.6765 max_p 0.6250 max_r 0.0556 max_f1 0.1020
#
# cause_predict: val acc 0.7316 p 0.6735 r 0.3667 f1 0.4748
# max_acc 0.7316 max_p 0.6735 max_r 0.3667 max_f1 0.4748
#
# pair_predict: val acc 0.9237 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.9237 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# avg max cause: max_acc 0.7316 max_p 0.6735 max_r 0.3667 max_f1 0.4748
# avg max pos: max_acc 0.6765 max_p 0.6250 max_r 0.0556 max_f1 0.1020
# avg max pair: max_acc 0.9237 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# Fold 1 Epoch 5 val loss 2.4582
# emotion_predict: val acc 0.7279 p 0.7353 r 0.2778 f1 0.4032
# max_acc 0.7279 max_p 0.7353 max_r 0.2778 max_f1 0.4032
#
# cause_predict: val acc 0.7426 p 0.7083 r 0.3778 f1 0.4928
# max_acc 0.7426 max_p 0.7083 max_r 0.3778 max_f1 0.4928
#
# pair_predict: val acc 0.9185 p 0.4706 r 0.3556 f1 0.4051
# max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# avg max cause: max_acc 0.7426 max_p 0.7083 max_r 0.3778 max_f1 0.4928
# avg max pos: max_acc 0.7279 max_p 0.7353 max_r 0.2778 max_f1 0.4032
# avg max pair: max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# Fold 1 Epoch 6 val loss 2.3987
# emotion_predict: val acc 0.7316 p 0.6133 r 0.5111 f1 0.5576
# max_acc 0.7316 max_p 0.6133 max_r 0.5111 max_f1 0.5576
#
# cause_predict: val acc 0.7500 p 0.6341 r 0.5778 f1 0.6047
# max_acc 0.7500 max_p 0.6341 max_r 0.5778 max_f1 0.6047
#
# pair_predict: val acc 0.8769 p 0.3194 r 0.5111 f1 0.3932
# max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# avg max cause: max_acc 0.7426 max_p 0.7083 max_r 0.3778 max_f1 0.4928
# avg max pos: max_acc 0.7279 max_p 0.7353 max_r 0.2778 max_f1 0.4032
# avg max pair: max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# Fold 1 Epoch 7 val loss 2.3305
# emotion_predict: val acc 0.7390 p 0.6667 r 0.4222 f1 0.5170
# max_acc 0.7316 max_p 0.6133 max_r 0.5111 max_f1 0.5576
#
# cause_predict: val acc 0.7721 p 0.7000 r 0.5444 f1 0.6125
# max_acc 0.7721 max_p 0.7000 max_r 0.5444 max_f1 0.6125
#
# pair_predict: val acc 0.8865 p 0.3435 r 0.5000 f1 0.4072
# max_acc 0.8865 max_p 0.3435 max_r 0.5000 max_f1 0.4072
#
# avg max cause: max_acc 0.7721 max_p 0.7000 max_r 0.5444 max_f1 0.6125
# avg max pos: max_acc 0.7390 max_p 0.6667 max_r 0.4222 max_f1 0.5170
# avg max pair: max_acc 0.8865 max_p 0.3435 max_r 0.5000 max_f1 0.4072
#
# Fold 1 Epoch 8 val loss 2.2453
# emotion_predict: val acc 0.7537 p 0.7091 r 0.4333 f1 0.5379
# max_acc 0.7316 max_p 0.6133 max_r 0.5111 max_f1 0.5576
#
# cause_predict: val acc 0.7757 p 0.7164 r 0.5333 f1 0.6115
# max_acc 0.7721 max_p 0.7000 max_r 0.5444 max_f1 0.6125
#
# pair_predict: val acc 0.8588 p 0.2914 r 0.5667 f1 0.3849
# max_acc 0.8865 max_p 0.3435 max_r 0.5000 max_f1 0.4072
#
# avg max cause: max_acc 0.7721 max_p 0.7000 max_r 0.5444 max_f1 0.6125
# avg max pos: max_acc 0.7390 max_p 0.6667 max_r 0.4222 max_f1 0.5170
# avg max pair: max_acc 0.8865 max_p 0.3435 max_r 0.5000 max_f1 0.4072
#
# Fold 1 Epoch 9 val loss 2.2004
# emotion_predict: val acc 0.7647 p 0.7167 r 0.4778 f1 0.5733
# max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
#
# cause_predict: val acc 0.7721 p 0.7414 r 0.4778 f1 0.5811
# max_acc 0.7721 max_p 0.7000 max_r 0.5444 max_f1 0.6125
#
# pair_predict: val acc 0.9047 p 0.4091 r 0.5000 f1 0.4500
# max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# avg max cause: max_acc 0.7721 max_p 0.7414 max_r 0.4778 max_f1 0.5811
# avg max pos: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pair: max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# Fold 1 Epoch 10 val loss 2.1803
# emotion_predict: val acc 0.7316 p 0.6104 r 0.5222 f1 0.5629
# max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
#
# cause_predict: val acc 0.7684 p 0.6709 r 0.5889 f1 0.6272
# max_acc 0.7684 max_p 0.6709 max_r 0.5889 max_f1 0.6272
#
# pair_predict: val acc 0.8769 p 0.3289 r 0.5556 f1 0.4132
# max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# avg max cause: max_acc 0.7721 max_p 0.7414 max_r 0.4778 max_f1 0.5811
# avg max pos: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pair: max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# Fold 1 Epoch 11 val loss 2.1648
# emotion_predict: val acc 0.7684 p 0.7547 r 0.4444 f1 0.5594
# max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
#
# cause_predict: val acc 0.7868 p 0.7581 r 0.5222 f1 0.6184
# max_acc 0.7684 max_p 0.6709 max_r 0.5889 max_f1 0.6272
#
# pair_predict: val acc 0.8899 p 0.3520 r 0.4889 f1 0.4093
# max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# avg max cause: max_acc 0.7721 max_p 0.7414 max_r 0.4778 max_f1 0.5811
# avg max pos: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pair: max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# Fold 1 Epoch 12 val loss 2.1832
# emotion_predict: val acc 0.7500 p 0.6250 r 0.6111 f1 0.6180
# max_acc 0.7500 max_p 0.6250 max_r 0.6111 max_f1 0.6180
#
# cause_predict: val acc 0.7721 p 0.6944 r 0.5556 f1 0.6173
# max_acc 0.7684 max_p 0.6709 max_r 0.5889 max_f1 0.6272
#
# pair_predict: val acc 0.8527 p 0.2849 r 0.5889 f1 0.3841
# max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# avg max cause: max_acc 0.7721 max_p 0.7414 max_r 0.4778 max_f1 0.5811
# avg max pos: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pair: max_acc 0.9047 max_p 0.4091 max_r 0.5000 max_f1 0.4500
#
# Fold 1 Epoch 13 val loss 2.1859
# emotion_predict: val acc 0.7537 p 0.6322 r 0.6111 f1 0.6215
# max_acc 0.7537 max_p 0.6322 max_r 0.6111 max_f1 0.6215
#
# cause_predict: val acc 0.7868 p 0.7353 r 0.5556 f1 0.6329
# max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
#
# pair_predict: val acc 0.9047 p 0.4153 r 0.5444 f1 0.4712
# max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# avg max cause: max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
# avg max pos: max_acc 0.7537 max_p 0.6322 max_r 0.6111 max_f1 0.6215
# avg max pair: max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# Fold 1 Epoch 14 val loss 2.1402
# emotion_predict: val acc 0.7647 p 0.6548 r 0.6111 f1 0.6322
# max_acc 0.7647 max_p 0.6548 max_r 0.6111 max_f1 0.6322
#
# cause_predict: val acc 0.7757 p 0.7042 r 0.5556 f1 0.6211
# max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
#
# pair_predict: val acc 0.8692 p 0.3152 r 0.5778 f1 0.4078
# max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# avg max cause: max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
# avg max pos: max_acc 0.7537 max_p 0.6322 max_r 0.6111 max_f1 0.6215
# avg max pair: max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# Fold 1 Epoch 15 val loss 2.1295
# emotion_predict: val acc 0.7978 p 0.7465 r 0.5889 f1 0.6584
# max_acc 0.7978 max_p 0.7465 max_r 0.5889 max_f1 0.6584
#
# cause_predict: val acc 0.7757 p 0.7164 r 0.5333 f1 0.6115
# max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
#
# pair_predict: val acc 0.8865 p 0.3525 r 0.5444 f1 0.4279
# max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# avg max cause: max_acc 0.7868 max_p 0.7353 max_r 0.5556 max_f1 0.6329
# avg max pos: max_acc 0.7537 max_p 0.6322 max_r 0.6111 max_f1 0.6215
# avg max pair: max_acc 0.9047 max_p 0.4153 max_r 0.5444 max_f1 0.4712
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.63291139]]
# average : acc 0.7868 p 0.7353 r 0.5556 f1 0.6329
#
# emotion_predict: val f1 in 1 fold: [[0.62146893]]
# average : acc 0.7537 p 0.6322 r 0.6111 f1 0.6215
#
# pair_predict: val f1 in 1 fold: [[0.47115385]]
# average : acc 0.9047 p 0.4153 r 0.5444 f1 0.4712

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.6291
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.3502
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3810
# emotion_predict: val acc 0.6912 p 0.6250 r 0.1667 f1 0.2632
# max_acc 0.6912 max_p 0.6250 max_r 0.1667 max_f1 0.2632
#
# cause_predict: val acc 0.7059 p 0.5595 r 0.5222 f1 0.5402
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.6205
# emotion_predict: val acc 0.7243 p 0.7419 r 0.2556 f1 0.3802
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.7206 p 0.7500 r 0.2333 f1 0.3559
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.5774
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.4255
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.2261
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.0892
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0712
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0555
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.7243 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# cause_predict: val acc 0.6838 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.9628
# emotion_predict: val acc 0.7316 p 0.7742 r 0.2667 f1 0.3967
# max_acc 0.7316 max_p 0.7742 max_r 0.2667 max_f1 0.3967
#
# cause_predict: val acc 0.7537 p 0.8108 r 0.3333 f1 0.4724
# max_acc 0.7059 max_p 0.5595 max_r 0.5222 max_f1 0.5402
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.9463
# emotion_predict: val acc 0.6949 p 0.5422 r 0.5000 f1 0.5202
# max_acc 0.6949 max_p 0.5422 max_r 0.5000 max_f1 0.5202
#
# cause_predict: val acc 0.7316 p 0.5876 r 0.6333 f1 0.6096
# max_acc 0.7316 max_p 0.5876 max_r 0.6333 max_f1 0.6096
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.0747
# emotion_predict: val acc 0.6360 p 0.4634 r 0.6333 f1 0.5352
# max_acc 0.6360 max_p 0.4634 max_r 0.6333 max_f1 0.5352
#
# cause_predict: val acc 0.6654 p 0.4966 r 0.8000 f1 0.6128
# max_acc 0.6654 max_p 0.4966 max_r 0.8000 max_f1 0.6128
#
# pair_predict: val acc 0.9246 p 0.7143 r 0.0556 f1 0.1031
# max_acc 0.9246 max_p 0.7143 max_r 0.0556 max_f1 0.1031
#
# avg max cause: max_acc 0.6654 max_p 0.4966 max_r 0.8000 max_f1 0.6128
# avg max pos: max_acc 0.6360 max_p 0.4634 max_r 0.6333 max_f1 0.5352
# avg max pair: max_acc 0.9246 max_p 0.7143 max_r 0.0556 max_f1 0.1031
#
# Fold 1 Epoch 14 val loss 2.9301
# emotion_predict: val acc 0.6912 p 0.5349 r 0.5111 f1 0.5227
# max_acc 0.6360 max_p 0.4634 max_r 0.6333 max_f1 0.5352
#
# cause_predict: val acc 0.7316 p 0.5876 r 0.6333 f1 0.6096
# max_acc 0.6654 max_p 0.4966 max_r 0.8000 max_f1 0.6128
#
# pair_predict: val acc 0.9272 p 0.8750 r 0.0778 f1 0.1429
# max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# avg max cause: max_acc 0.7316 max_p 0.5876 max_r 0.6333 max_f1 0.6096
# avg max pos: max_acc 0.6912 max_p 0.5349 max_r 0.5111 max_f1 0.5227
# avg max pair: max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# Fold 1 Epoch 15 val loss 2.8865
# emotion_predict: val acc 0.7353 p 0.6607 r 0.4111 f1 0.5068
# max_acc 0.6360 max_p 0.4634 max_r 0.6333 max_f1 0.5352
#
# cause_predict: val acc 0.7537 p 0.6667 r 0.5111 f1 0.5786
# max_acc 0.6654 max_p 0.4966 max_r 0.8000 max_f1 0.6128
#
# pair_predict: val acc 0.9272 p 0.8750 r 0.0778 f1 0.1429
# max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# avg max cause: max_acc 0.7316 max_p 0.5876 max_r 0.6333 max_f1 0.6096
# avg max pos: max_acc 0.6912 max_p 0.5349 max_r 0.5111 max_f1 0.5227
# avg max pair: max_acc 0.9272 max_p 0.8750 max_r 0.0778 max_f1 0.1429
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.60962567]]
# average : acc 0.7316 p 0.5876 r 0.6333 f1 0.6096
#
# emotion_predict: val f1 in 1 fold: [[0.52272727]]
# average : acc 0.6912 p 0.5349 r 0.5111 f1 0.5227
#
# pair_predict: val f1 in 1 fold: [[0.14285714]]
# average : acc 0.9272 p 0.8750 r 0.0778 f1 0.1429

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.0528
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.0532
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.9144
# emotion_predict: val acc 0.7059 p 0.5676 r 0.4667 f1 0.5122
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.7096 p 0.6897 r 0.2222 f1 0.3361
# max_acc 0.7096 max_p 0.6897 max_r 0.2222 max_f1 0.3361
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.8873
# emotion_predict: val acc 0.7243 p 0.7586 r 0.2444 f1 0.3697
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.7426 p 0.7500 r 0.3333 f1 0.4615
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.7644
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.6875 p 0.7778 r 0.0778 f1 0.1414
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6875 max_p 0.7778 max_r 0.0778 max_f1 0.1414
# avg max pos: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 6 val loss 2.6540
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6875 max_p 0.7778 max_r 0.0778 max_f1 0.1414
# avg max pos: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 7 val loss 2.6316
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# avg max cause: max_acc 0.6875 max_p 0.7778 max_r 0.0778 max_f1 0.1414
# avg max pos: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pair: max_acc 0.9229 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# Fold 1 Epoch 8 val loss 2.6196
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.6838 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9246 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# avg max cause: max_acc 0.6838 max_p 0.8333 max_r 0.0556 max_f1 0.1042
# avg max pos: max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
# avg max pair: max_acc 0.9246 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# Fold 1 Epoch 9 val loss 2.5377
# emotion_predict: val acc 0.7243 p 0.8000 r 0.2222 f1 0.3478
# max_acc 0.7059 max_p 0.5676 max_r 0.4667 max_f1 0.5122
#
# cause_predict: val acc 0.7426 p 0.8333 r 0.2778 f1 0.4167
# max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
#
# pair_predict: val acc 0.9350 p 0.7419 r 0.2556 f1 0.3802
# max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# avg max cause: max_acc 0.7426 max_p 0.8333 max_r 0.2778 max_f1 0.4167
# avg max pos: max_acc 0.7243 max_p 0.8000 max_r 0.2222 max_f1 0.3478
# avg max pair: max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# Fold 1 Epoch 10 val loss 2.5777
# emotion_predict: val acc 0.7022 p 0.5529 r 0.5222 f1 0.5371
# max_acc 0.7022 max_p 0.5529 max_r 0.5222 max_f1 0.5371
#
# cause_predict: val acc 0.7279 p 0.5816 r 0.6333 f1 0.6064
# max_acc 0.7279 max_p 0.5816 max_r 0.6333 max_f1 0.6064
#
# pair_predict: val acc 0.8761 p 0.3008 r 0.4444 f1 0.3587
# max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# avg max cause: max_acc 0.7426 max_p 0.8333 max_r 0.2778 max_f1 0.4167
# avg max pos: max_acc 0.7243 max_p 0.8000 max_r 0.2222 max_f1 0.3478
# avg max pair: max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# Fold 1 Epoch 11 val loss 2.5321
# emotion_predict: val acc 0.7169 p 0.5844 r 0.5000 f1 0.5389
# max_acc 0.7169 max_p 0.5844 max_r 0.5000 max_f1 0.5389
#
# cause_predict: val acc 0.7500 p 0.6310 r 0.5889 f1 0.6092
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# pair_predict: val acc 0.8839 p 0.3226 r 0.4444 f1 0.3738
# max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# avg max cause: max_acc 0.7426 max_p 0.8333 max_r 0.2778 max_f1 0.4167
# avg max pos: max_acc 0.7243 max_p 0.8000 max_r 0.2222 max_f1 0.3478
# avg max pair: max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# Fold 1 Epoch 12 val loss 2.4776
# emotion_predict: val acc 0.7426 p 0.6852 r 0.4111 f1 0.5139
# max_acc 0.7169 max_p 0.5844 max_r 0.5000 max_f1 0.5389
#
# cause_predict: val acc 0.7610 p 0.7119 r 0.4667 f1 0.5638
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# pair_predict: val acc 0.9038 p 0.3820 r 0.3778 f1 0.3799
# max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# avg max cause: max_acc 0.7426 max_p 0.8333 max_r 0.2778 max_f1 0.4167
# avg max pos: max_acc 0.7243 max_p 0.8000 max_r 0.2222 max_f1 0.3478
# avg max pair: max_acc 0.9350 max_p 0.7419 max_r 0.2556 max_f1 0.3802
#
# Fold 1 Epoch 13 val loss 2.4592
# emotion_predict: val acc 0.7390 p 0.7209 r 0.3444 f1 0.4662
# max_acc 0.7169 max_p 0.5844 max_r 0.5000 max_f1 0.5389
#
# cause_predict: val acc 0.7647 p 0.7826 r 0.4000 f1 0.5294
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# pair_predict: val acc 0.9116 p 0.4231 r 0.3667 f1 0.3929
# max_acc 0.9116 max_p 0.4231 max_r 0.3667 max_f1 0.3929
#
# avg max cause: max_acc 0.7647 max_p 0.7826 max_r 0.4000 max_f1 0.5294
# avg max pos: max_acc 0.7390 max_p 0.7209 max_r 0.3444 max_f1 0.4662
# avg max pair: max_acc 0.9116 max_p 0.4231 max_r 0.3667 max_f1 0.3929
#
# Fold 1 Epoch 14 val loss 2.4215
# emotion_predict: val acc 0.7390 p 0.7317 r 0.3333 f1 0.4580
# max_acc 0.7169 max_p 0.5844 max_r 0.5000 max_f1 0.5389
#
# cause_predict: val acc 0.7757 p 0.7959 r 0.4333 f1 0.5612
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# pair_predict: val acc 0.9073 p 0.4023 r 0.3889 f1 0.3955
# max_acc 0.9073 max_p 0.4023 max_r 0.3889 max_f1 0.3955
#
# avg max cause: max_acc 0.7757 max_p 0.7959 max_r 0.4333 max_f1 0.5612
# avg max pos: max_acc 0.7390 max_p 0.7317 max_r 0.3333 max_f1 0.4580
# avg max pair: max_acc 0.9073 max_p 0.4023 max_r 0.3889 max_f1 0.3955
#
# Fold 1 Epoch 15 val loss 2.3724
# emotion_predict: val acc 0.7500 p 0.7292 r 0.3889 f1 0.5072
# max_acc 0.7169 max_p 0.5844 max_r 0.5000 max_f1 0.5389
#
# cause_predict: val acc 0.7574 p 0.6935 r 0.4778 f1 0.5658
# max_acc 0.7500 max_p 0.6310 max_r 0.5889 max_f1 0.6092
#
# pair_predict: val acc 0.8847 p 0.3223 r 0.4333 f1 0.3697
# max_acc 0.9073 max_p 0.4023 max_r 0.3889 max_f1 0.3955
#
# avg max cause: max_acc 0.7757 max_p 0.7959 max_r 0.4333 max_f1 0.5612
# avg max pos: max_acc 0.7390 max_p 0.7317 max_r 0.3333 max_f1 0.4580
# avg max pair: max_acc 0.9073 max_p 0.4023 max_r 0.3889 max_f1 0.3955
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.56115108]]
# average : acc 0.7757 p 0.7959 r 0.4333 f1 0.5612
#
# emotion_predict: val f1 in 1 fold: [[0.45801527]]
# average : acc 0.7390 p 0.7317 r 0.3333 f1 0.4580
#
# pair_predict: val f1 in 1 fold: [[0.39548023]]
# average : acc 0.9073 p 0.4023 r 0.3889 f1 0.3955

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 4.3671
# emotion_predict: val acc 0.3309 p 0.3309 r 1.0000 f1 0.4972
# max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.1642
# emotion_predict: val acc 0.5882 p 0.4345 r 0.8111 f1 0.5659
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.9588
# emotion_predict: val acc 0.6250 p 0.3000 r 0.1000 f1 0.1500
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.7298
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.5009
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.3517
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.3222
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.2888
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.2395
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.2022
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 3.1985
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 3.2099
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.1700
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 3.0903
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 3.0195
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.5882 max_p 0.4345 max_r 0.8111 max_f1 0.5659
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.3309 max_p 0.3309 max_r 1.0000 max_f1 0.4972
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# emotion_predict: val f1 in 1 fold: [[0.49723757]]
# average : acc 0.3309 p 0.3309 r 1.0000 f1 0.4972
#
# pair_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.9220 p 0.0000 r 0.0000 f1 0.0000

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 128
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=256, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=256, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=542, out_features=64, bias=True)
#   (pair_linear2): Linear(in_features=64, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 128, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(258, 128, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=256, out_features=256, bias=True)
#     (linear2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.2366
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.1528
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.0852
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.0228
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.9687
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.9247
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.8896
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.8545
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.8164
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.7832
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 2.7640
# emotion_predict: val acc 0.6728 p 0.6000 r 0.0333 f1 0.0632
# max_acc 0.6728 max_p 0.6000 max_r 0.0333 max_f1 0.0632
#
# cause_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 2.7691
# emotion_predict: val acc 0.7169 p 0.6970 r 0.2556 f1 0.3740
# max_acc 0.7169 max_p 0.6970 max_r 0.2556 max_f1 0.3740
#
# cause_predict: val acc 0.7206 p 0.7692 r 0.2222 f1 0.3448
# max_acc 0.7206 max_p 0.7692 max_r 0.2222 max_f1 0.3448
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 2.7459
# emotion_predict: val acc 0.7169 p 0.6275 r 0.3556 f1 0.4539
# max_acc 0.7169 max_p 0.6275 max_r 0.3556 max_f1 0.4539
#
# cause_predict: val acc 0.7353 p 0.6875 r 0.3667 f1 0.4783
# max_acc 0.7353 max_p 0.6875 max_r 0.3667 max_f1 0.4783
#
# pair_predict: val acc 0.9272 p 0.7500 r 0.1000 f1 0.1765
# max_acc 0.9272 max_p 0.7500 max_r 0.1000 max_f1 0.1765
#
# avg max cause: max_acc 0.7353 max_p 0.6875 max_r 0.3667 max_f1 0.4783
# avg max pos: max_acc 0.7169 max_p 0.6275 max_r 0.3556 max_f1 0.4539
# avg max pair: max_acc 0.9272 max_p 0.7500 max_r 0.1000 max_f1 0.1765
#
# Fold 1 Epoch 14 val loss 2.6762
# emotion_predict: val acc 0.7279 p 0.6739 r 0.3444 f1 0.4559
# max_acc 0.7279 max_p 0.6739 max_r 0.3444 max_f1 0.4559
#
# cause_predict: val acc 0.7353 p 0.7045 r 0.3444 f1 0.4627
# max_acc 0.7353 max_p 0.6875 max_r 0.3667 max_f1 0.4783
#
# pair_predict: val acc 0.9272 p 0.6667 r 0.1333 f1 0.2222
# max_acc 0.9272 max_p 0.6667 max_r 0.1333 max_f1 0.2222
#
# avg max cause: max_acc 0.7353 max_p 0.7045 max_r 0.3444 max_f1 0.4627
# avg max pos: max_acc 0.7279 max_p 0.6739 max_r 0.3444 max_f1 0.4559
# avg max pair: max_acc 0.9272 max_p 0.6667 max_r 0.1333 max_f1 0.2222
#
# Fold 1 Epoch 15 val loss 2.5903
# emotion_predict: val acc 0.7206 p 0.7187 r 0.2556 f1 0.3770
# max_acc 0.7279 max_p 0.6739 max_r 0.3444 max_f1 0.4559
#
# cause_predict: val acc 0.7353 p 0.8000 r 0.2667 f1 0.4000
# max_acc 0.7353 max_p 0.6875 max_r 0.3667 max_f1 0.4783
#
# pair_predict: val acc 0.9272 p 0.6875 r 0.1222 f1 0.2075
# max_acc 0.9272 max_p 0.6667 max_r 0.1333 max_f1 0.2222
#
# avg max cause: max_acc 0.7353 max_p 0.7045 max_r 0.3444 max_f1 0.4627
# avg max pos: max_acc 0.7279 max_p 0.6739 max_r 0.3444 max_f1 0.4559
# avg max pair: max_acc 0.9272 max_p 0.6667 max_r 0.1333 max_f1 0.2222
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.46268657]]
# average : acc 0.7353 p 0.7045 r 0.3444 f1 0.4627
#
# emotion_predict: val f1 in 1 fold: [[0.45588235]]
# average : acc 0.7279 p 0.6739 r 0.3444 f1 0.4559
#
# pair_predict: val f1 in 1 fold: [[0.22222222]]
# average : acc 0.9272 p 0.6667 r 0.1333 f1 0.2222

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.4827
# emotion_predict: val acc 0.6691 p 0.5000 r 0.0111 f1 0.0217
# max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
#
# cause_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pos: max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.9405
# emotion_predict: val acc 0.6691 p 0.5000 r 0.5556 f1 0.5263
# max_acc 0.6691 max_p 0.5000 max_r 0.5556 max_f1 0.5263
#
# cause_predict: val acc 0.7353 p 0.6000 r 0.6000 f1 0.6000
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pos: max_acc 0.6691 max_p 0.5000 max_r 0.0111 max_f1 0.0217
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.8264
# emotion_predict: val acc 0.7390 p 0.7879 r 0.2889 f1 0.4228
# max_acc 0.6691 max_p 0.5000 max_r 0.5556 max_f1 0.5263
#
# cause_predict: val acc 0.7610 p 0.7907 r 0.3778 f1 0.5113
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9229 p 0.5088 r 0.3222 f1 0.3946
# max_acc 0.9229 max_p 0.5088 max_r 0.3222 max_f1 0.3946
#
# avg max cause: max_acc 0.7610 max_p 0.7907 max_r 0.3778 max_f1 0.5113
# avg max pos: max_acc 0.7390 max_p 0.7879 max_r 0.2889 max_f1 0.4228
# avg max pair: max_acc 0.9229 max_p 0.5088 max_r 0.3222 max_f1 0.3946
#
# Fold 1 Epoch 4 val loss 2.7936
# emotion_predict: val acc 0.7279 p 0.7667 r 0.2556 f1 0.3833
# max_acc 0.6691 max_p 0.5000 max_r 0.5556 max_f1 0.5263
#
# cause_predict: val acc 0.7684 p 0.8000 r 0.4000 f1 0.5333
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9333 p 0.6970 r 0.2556 f1 0.3740
# max_acc 0.9229 max_p 0.5088 max_r 0.3222 max_f1 0.3946
#
# avg max cause: max_acc 0.7610 max_p 0.7907 max_r 0.3778 max_f1 0.5113
# avg max pos: max_acc 0.7390 max_p 0.7879 max_r 0.2889 max_f1 0.4228
# avg max pair: max_acc 0.9229 max_p 0.5088 max_r 0.3222 max_f1 0.3946
#
# Fold 1 Epoch 5 val loss 2.7178
# emotion_predict: val acc 0.6912 p 0.5341 r 0.5222 f1 0.5281
# max_acc 0.6912 max_p 0.5341 max_r 0.5222 max_f1 0.5281
#
# cause_predict: val acc 0.7353 p 0.6071 r 0.5667 f1 0.5862
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9185 p 0.4706 r 0.3556 f1 0.4051
# max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# avg max cause: max_acc 0.7353 max_p 0.6071 max_r 0.5667 max_f1 0.5862
# avg max pos: max_acc 0.6912 max_p 0.5341 max_r 0.5222 max_f1 0.5281
# avg max pair: max_acc 0.9185 max_p 0.4706 max_r 0.3556 max_f1 0.4051
#
# Fold 1 Epoch 6 val loss 2.6472
# emotion_predict: val acc 0.7279 p 0.6290 r 0.4333 f1 0.5132
# max_acc 0.6912 max_p 0.5341 max_r 0.5222 max_f1 0.5281
#
# cause_predict: val acc 0.7647 p 0.7167 r 0.4778 f1 0.5733
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9133 p 0.4375 r 0.3889 f1 0.4118
# max_acc 0.9133 max_p 0.4375 max_r 0.3889 max_f1 0.4118
#
# avg max cause: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pos: max_acc 0.7279 max_p 0.6290 max_r 0.4333 max_f1 0.5132
# avg max pair: max_acc 0.9133 max_p 0.4375 max_r 0.3889 max_f1 0.4118
#
# Fold 1 Epoch 7 val loss 2.6640
# emotion_predict: val acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
# max_acc 0.6912 max_p 0.5341 max_r 0.5222 max_f1 0.5281
#
# cause_predict: val acc 0.7684 p 0.7288 r 0.4778 f1 0.5772
# max_acc 0.7353 max_p 0.6000 max_r 0.6000 max_f1 0.6000
#
# pair_predict: val acc 0.9237 p 0.5172 r 0.3333 f1 0.4054
# max_acc 0.9133 max_p 0.4375 max_r 0.3889 max_f1 0.4118
#
# avg max cause: max_acc 0.7647 max_p 0.7167 max_r 0.4778 max_f1 0.5733
# avg max pos: max_acc 0.7279 max_p 0.6290 max_r 0.4333 max_f1 0.5132
# avg max pair: max_acc 0.9133 max_p 0.4375 max_r 0.3889 max_f1 0.4118
#
# Fold 1 Epoch 8 val loss 2.6773
# emotion_predict: val acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
# max_acc 0.6912 max_p 0.5341 max_r 0.5222 max_f1 0.5281
#
# cause_predict: val acc 0.7757 p 0.7231 r 0.5222 f1 0.6065
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9237 p 0.5167 r 0.3444 f1 0.4133
# max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# avg max cause: max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
# avg max pos: max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
# avg max pair: max_acc 0.9237 max_p 0.5167 max_r 0.3444 max_f1 0.4133
#
# Fold 1 Epoch 9 val loss 2.7037
# emotion_predict: val acc 0.7463 p 0.6842 r 0.4333 f1 0.5306
# max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
#
# cause_predict: val acc 0.7684 p 0.7015 r 0.5222 f1 0.5987
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.3667 f1 0.4231
# max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# avg max cause: max_acc 0.7684 max_p 0.7015 max_r 0.5222 max_f1 0.5987
# avg max pos: max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# Fold 1 Epoch 10 val loss 2.6665
# emotion_predict: val acc 0.7132 p 0.5857 r 0.4556 f1 0.5125
# max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
#
# cause_predict: val acc 0.7721 p 0.7333 r 0.4889 f1 0.5867
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9116 p 0.4302 r 0.4111 f1 0.4205
# max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# avg max cause: max_acc 0.7684 max_p 0.7015 max_r 0.5222 max_f1 0.5987
# avg max pos: max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3667 max_f1 0.4231
#
# Fold 1 Epoch 11 val loss 2.7359
# emotion_predict: val acc 0.7426 p 0.6852 r 0.4111 f1 0.5139
# max_acc 0.7463 max_p 0.6842 max_r 0.4333 max_f1 0.5306
#
# cause_predict: val acc 0.7721 p 0.7258 r 0.5000 f1 0.5921
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9307 p 0.5962 r 0.3444 f1 0.4366
# max_acc 0.9307 max_p 0.5962 max_r 0.3444 max_f1 0.4366
#
# avg max cause: max_acc 0.7721 max_p 0.7258 max_r 0.5000 max_f1 0.5921
# avg max pos: max_acc 0.7426 max_p 0.6852 max_r 0.4111 max_f1 0.5139
# avg max pair: max_acc 0.9307 max_p 0.5962 max_r 0.3444 max_f1 0.4366
#
# Fold 1 Epoch 12 val loss 2.6651
# emotion_predict: val acc 0.7647 p 0.7097 r 0.4889 f1 0.5789
# max_acc 0.7647 max_p 0.7097 max_r 0.4889 max_f1 0.5789
#
# cause_predict: val acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.3889 f1 0.4375
# max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.7647 max_p 0.7097 max_r 0.4889 max_f1 0.5789
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# Fold 1 Epoch 13 val loss 2.9322
# emotion_predict: val acc 0.7537 p 0.6494 r 0.5556 f1 0.5988
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# cause_predict: val acc 0.7316 p 0.5955 r 0.5889 f1 0.5922
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9151 p 0.4412 r 0.3333 f1 0.3797
# max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.7647 max_p 0.7097 max_r 0.4889 max_f1 0.5789
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# Fold 1 Epoch 14 val loss 2.6960
# emotion_predict: val acc 0.7316 p 0.6441 r 0.4222 f1 0.5101
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# cause_predict: val acc 0.7610 p 0.7193 r 0.4556 f1 0.5578
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9333 p 0.6585 r 0.3000 f1 0.4122
# max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.7647 max_p 0.7097 max_r 0.4889 max_f1 0.5789
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# Fold 1 Epoch 15 val loss 2.7885
# emotion_predict: val acc 0.7426 p 0.6613 r 0.4556 f1 0.5395
# max_acc 0.7537 max_p 0.6494 max_r 0.5556 max_f1 0.5988
#
# cause_predict: val acc 0.7574 p 0.7727 r 0.3778 f1 0.5075
# max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
#
# pair_predict: val acc 0.9350 p 0.7143 r 0.2778 f1 0.4000
# max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# avg max cause: max_acc 0.7574 max_p 0.6714 max_r 0.5222 max_f1 0.5875
# avg max pos: max_acc 0.7647 max_p 0.7097 max_r 0.4889 max_f1 0.5789
# avg max pair: max_acc 0.9220 max_p 0.5000 max_r 0.3889 max_f1 0.4375
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.5875]]
# average : acc 0.7574 p 0.6714 r 0.5222 f1 0.5875
#
# emotion_predict: val f1 in 1 fold: [[0.57894737]]
# average : acc 0.7647 p 0.7097 r 0.4889 f1 0.5789
#
# pair_predict: val f1 in 1 fold: [[0.4375]]
# average : acc 0.9220 p 0.5000 r 0.3889 f1 0.4375

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.0387
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.6248
# emotion_predict: val acc 0.7206 p 0.7187 r 0.2556 f1 0.3770
# max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
#
# cause_predict: val acc 0.7243 p 0.8261 r 0.2111 f1 0.3363
# max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
#
# pair_predict: val acc 0.9159 p 0.4478 r 0.3333 f1 0.3822
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 3 val loss 2.8340
# emotion_predict: val acc 0.7059 p 0.7500 r 0.1667 f1 0.2727
# max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
#
# cause_predict: val acc 0.7096 p 0.8235 r 0.1556 f1 0.2617
# max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
#
# pair_predict: val acc 0.9324 p 0.8000 r 0.1778 f1 0.2909
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 4 val loss 2.6651
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
#
# cause_predict: val acc 0.6875 p 0.7778 r 0.0778 f1 0.1414
# max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
#
# pair_predict: val acc 0.8934 p 0.2911 r 0.2556 f1 0.2722
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 5 val loss 2.6851
# emotion_predict: val acc 0.7022 p 0.6552 r 0.2111 f1 0.3193
# max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
#
# cause_predict: val acc 0.7463 p 0.8387 r 0.2889 f1 0.4298
# max_acc 0.7463 max_p 0.8387 max_r 0.2889 max_f1 0.4298
#
# pair_predict: val acc 0.8873 p 0.2959 r 0.3222 f1 0.3085
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 6 val loss 2.4132
# emotion_predict: val acc 0.7206 p 0.6061 r 0.4444 f1 0.5128
# max_acc 0.7206 max_p 0.6061 max_r 0.4444 max_f1 0.5128
#
# cause_predict: val acc 0.7574 p 0.6622 r 0.5444 f1 0.5976
# max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
#
# pair_predict: val acc 0.8813 p 0.3150 r 0.4444 f1 0.3687
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 7 val loss 2.4046
# emotion_predict: val acc 0.7279 p 0.6600 r 0.3667 f1 0.4714
# max_acc 0.7206 max_p 0.6061 max_r 0.4444 max_f1 0.5128
#
# cause_predict: val acc 0.7647 p 0.6970 r 0.5111 f1 0.5897
# max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
#
# pair_predict: val acc 0.8847 p 0.3252 r 0.4444 f1 0.3756
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 8 val loss 2.3867
# emotion_predict: val acc 0.7279 p 0.7105 r 0.3000 f1 0.4219
# max_acc 0.7206 max_p 0.6061 max_r 0.4444 max_f1 0.5128
#
# cause_predict: val acc 0.7721 p 0.8043 r 0.4111 f1 0.5441
# max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
#
# pair_predict: val acc 0.8830 p 0.3171 r 0.4333 f1 0.3662
# max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# avg max cause: max_acc 0.7243 max_p 0.8261 max_r 0.2111 max_f1 0.3363
# avg max pos: max_acc 0.7206 max_p 0.7187 max_r 0.2556 max_f1 0.3770
# avg max pair: max_acc 0.9159 max_p 0.4478 max_r 0.3333 max_f1 0.3822
#
# Fold 1 Epoch 9 val loss 2.3497
# emotion_predict: val acc 0.7390 p 0.6727 r 0.4111 f1 0.5103
# max_acc 0.7206 max_p 0.6061 max_r 0.4444 max_f1 0.5128
#
# cause_predict: val acc 0.7721 p 0.7333 r 0.4889 f1 0.5867
# max_acc 0.7574 max_p 0.6622 max_r 0.5444 max_f1 0.5976
#
# pair_predict: val acc 0.8787 p 0.3214 r 0.5000 f1 0.3913
# max_acc 0.8787 max_p 0.3214 max_r 0.5000 max_f1 0.3913
#
# avg max cause: max_acc 0.7721 max_p 0.7333 max_r 0.4889 max_f1 0.5867
# avg max pos: max_acc 0.7390 max_p 0.6727 max_r 0.4111 max_f1 0.5103
# avg max pair: max_acc 0.8787 max_p 0.3214 max_r 0.5000 max_f1 0.3913
#
# Fold 1 Epoch 10 val loss 2.2690
# emotion_predict: val acc 0.7243 p 0.6087 r 0.4667 f1 0.5283
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7757 p 0.7101 r 0.5444 f1 0.6164
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.8986 p 0.3714 r 0.4333 f1 0.4000
# max_acc 0.8986 max_p 0.3714 max_r 0.4333 max_f1 0.4000
#
# avg max cause: max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
# avg max pos: max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
# avg max pair: max_acc 0.8986 max_p 0.3714 max_r 0.4333 max_f1 0.4000
#
# Fold 1 Epoch 11 val loss 2.3024
# emotion_predict: val acc 0.7353 p 0.6552 r 0.4222 f1 0.5135
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7794 p 0.7500 r 0.5000 f1 0.6000
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.8856 p 0.3433 r 0.5111 f1 0.4107
# max_acc 0.8856 max_p 0.3433 max_r 0.5111 max_f1 0.4107
#
# avg max cause: max_acc 0.7794 max_p 0.7500 max_r 0.5000 max_f1 0.6000
# avg max pos: max_acc 0.7353 max_p 0.6552 max_r 0.4222 max_f1 0.5135
# avg max pair: max_acc 0.8856 max_p 0.3433 max_r 0.5111 max_f1 0.4107
#
# Fold 1 Epoch 12 val loss 2.4186
# emotion_predict: val acc 0.7390 p 0.6863 r 0.3889 f1 0.4965
# max_acc 0.7243 max_p 0.6087 max_r 0.4667 max_f1 0.5283
#
# cause_predict: val acc 0.7684 p 0.7143 r 0.5000 f1 0.5882
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.9012 p 0.3723 r 0.3889 f1 0.3804
# max_acc 0.8856 max_p 0.3433 max_r 0.5111 max_f1 0.4107
#
# avg max cause: max_acc 0.7794 max_p 0.7500 max_r 0.5000 max_f1 0.6000
# avg max pos: max_acc 0.7353 max_p 0.6552 max_r 0.4222 max_f1 0.5135
# avg max pair: max_acc 0.8856 max_p 0.3433 max_r 0.5111 max_f1 0.4107
#
# Fold 1 Epoch 13 val loss 2.3702
# emotion_predict: val acc 0.7463 p 0.6479 r 0.5111 f1 0.5714
# max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
#
# cause_predict: val acc 0.7757 p 0.7231 r 0.5222 f1 0.6065
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.8943 p 0.3788 r 0.5556 f1 0.4505
# max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# avg max cause: max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
# avg max pos: max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
# avg max pair: max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# Fold 1 Epoch 14 val loss 2.4990
# emotion_predict: val acc 0.7279 p 0.6026 r 0.5222 f1 0.5595
# max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
#
# cause_predict: val acc 0.7426 p 0.6250 r 0.5556 f1 0.5882
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.8908 p 0.3636 r 0.5333 f1 0.4324
# max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# avg max cause: max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
# avg max pos: max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
# avg max pair: max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# Fold 1 Epoch 15 val loss 2.2720
# emotion_predict: val acc 0.7537 p 0.7255 r 0.4111 f1 0.5248
# max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
#
# cause_predict: val acc 0.7868 p 0.7759 r 0.5000 f1 0.6081
# max_acc 0.7757 max_p 0.7101 max_r 0.5444 max_f1 0.6164
#
# pair_predict: val acc 0.9185 p 0.4730 r 0.3889 f1 0.4268
# max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# avg max cause: max_acc 0.7757 max_p 0.7231 max_r 0.5222 max_f1 0.6065
# avg max pos: max_acc 0.7463 max_p 0.6479 max_r 0.5111 max_f1 0.5714
# avg max pair: max_acc 0.8943 max_p 0.3788 max_r 0.5556 max_f1 0.4505
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.60645161]]
# average : acc 0.7757 p 0.7231 r 0.5222 f1 0.6065
#
# emotion_predict: val f1 in 1 fold: [[0.57142857]]
# average : acc 0.7463 p 0.6479 r 0.5111 f1 0.5714
#
# pair_predict: val f1 in 1 fold: [[0.45045045]]
# average : acc 0.8943 p 0.3788 r 0.5556 f1 0.4505

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.3319
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.1973
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6801 max_p 0.8000 max_r 0.0444 max_f1 0.0842
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.9082
# emotion_predict: val acc 0.7096 p 0.7619 r 0.1778 f1 0.2883
# max_acc 0.7096 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# cause_predict: val acc 0.7500 p 0.7391 r 0.3778 f1 0.5000
# max_acc 0.7500 max_p 0.7391 max_r 0.3778 max_f1 0.5000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7887
# emotion_predict: val acc 0.7500 p 0.6719 r 0.4778 f1 0.5584
# max_acc 0.7500 max_p 0.6719 max_r 0.4778 max_f1 0.5584
#
# cause_predict: val acc 0.7463 p 0.6522 r 0.5000 f1 0.5660
# max_acc 0.7463 max_p 0.6522 max_r 0.5000 max_f1 0.5660
#
# pair_predict: val acc 0.9229 p 0.5082 r 0.3444 f1 0.4106
# max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# avg max cause: max_acc 0.7463 max_p 0.6522 max_r 0.5000 max_f1 0.5660
# avg max pos: max_acc 0.7500 max_p 0.6719 max_r 0.4778 max_f1 0.5584
# avg max pair: max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# Fold 1 Epoch 5 val loss 2.7120
# emotion_predict: val acc 0.7206 p 0.5946 r 0.4889 f1 0.5366
# max_acc 0.7500 max_p 0.6719 max_r 0.4778 max_f1 0.5584
#
# cause_predict: val acc 0.7610 p 0.6712 r 0.5444 f1 0.6012
# max_acc 0.7610 max_p 0.6712 max_r 0.5444 max_f1 0.6012
#
# pair_predict: val acc 0.9125 p 0.4267 r 0.3556 f1 0.3879
# max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# avg max cause: max_acc 0.7463 max_p 0.6522 max_r 0.5000 max_f1 0.5660
# avg max pos: max_acc 0.7500 max_p 0.6719 max_r 0.4778 max_f1 0.5584
# avg max pair: max_acc 0.9229 max_p 0.5082 max_r 0.3444 max_f1 0.4106
#
# Fold 1 Epoch 6 val loss 2.6119
# emotion_predict: val acc 0.7537 p 0.6949 r 0.4556 f1 0.5503
# max_acc 0.7500 max_p 0.6719 max_r 0.4778 max_f1 0.5584
#
# cause_predict: val acc 0.7574 p 0.6818 r 0.5000 f1 0.5769
# max_acc 0.7610 max_p 0.6712 max_r 0.5444 max_f1 0.6012
#
# pair_predict: val acc 0.9255 p 0.5357 r 0.3333 f1 0.4110
# max_acc 0.9255 max_p 0.5357 max_r 0.3333 max_f1 0.4110
#
# avg max cause: max_acc 0.7574 max_p 0.6818 max_r 0.5000 max_f1 0.5769
# avg max pos: max_acc 0.7537 max_p 0.6949 max_r 0.4556 max_f1 0.5503
# avg max pair: max_acc 0.9255 max_p 0.5357 max_r 0.3333 max_f1 0.4110
#
# Fold 1 Epoch 7 val loss 2.5160
# emotion_predict: val acc 0.7647 p 0.6912 r 0.5222 f1 0.5949
# max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
#
# cause_predict: val acc 0.7647 p 0.6585 r 0.6000 f1 0.6279
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.9263 p 0.5397 r 0.3778 f1 0.4444
# max_acc 0.9263 max_p 0.5397 max_r 0.3778 max_f1 0.4444
#
# avg max cause: max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
# avg max pos: max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
# avg max pair: max_acc 0.9263 max_p 0.5397 max_r 0.3778 max_f1 0.4444
#
# Fold 1 Epoch 8 val loss 2.4532
# emotion_predict: val acc 0.7647 p 0.7031 r 0.5000 f1 0.5844
# max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
#
# cause_predict: val acc 0.7978 p 0.7778 r 0.5444 f1 0.6405
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.4000 f1 0.4444
# max_acc 0.9263 max_p 0.5397 max_r 0.3778 max_f1 0.4444
#
# avg max cause: max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
# avg max pos: max_acc 0.7647 max_p 0.6912 max_r 0.5222 max_f1 0.5949
# avg max pair: max_acc 0.9263 max_p 0.5397 max_r 0.3778 max_f1 0.4444
#
# Fold 1 Epoch 9 val loss 2.4096
# emotion_predict: val acc 0.7978 p 0.7692 r 0.5556 f1 0.6452
# max_acc 0.7978 max_p 0.7692 max_r 0.5556 max_f1 0.6452
#
# cause_predict: val acc 0.7721 p 0.7692 r 0.4444 f1 0.5634
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9315 p 0.5902 r 0.4000 f1 0.4768
# max_acc 0.9315 max_p 0.5902 max_r 0.4000 max_f1 0.4768
#
# avg max cause: max_acc 0.7721 max_p 0.7692 max_r 0.4444 max_f1 0.5634
# avg max pos: max_acc 0.7978 max_p 0.7692 max_r 0.5556 max_f1 0.6452
# avg max pair: max_acc 0.9315 max_p 0.5902 max_r 0.4000 max_f1 0.4768
#
# Fold 1 Epoch 10 val loss 2.4672
# emotion_predict: val acc 0.7647 p 0.6444 r 0.6444 f1 0.6444
# max_acc 0.7978 max_p 0.7692 max_r 0.5556 max_f1 0.6452
#
# cause_predict: val acc 0.7537 p 0.6264 r 0.6333 f1 0.6298
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9211 p 0.4944 r 0.4889 f1 0.4916
# max_acc 0.9211 max_p 0.4944 max_r 0.4889 max_f1 0.4916
#
# avg max cause: max_acc 0.7537 max_p 0.6264 max_r 0.6333 max_f1 0.6298
# avg max pos: max_acc 0.7647 max_p 0.6444 max_r 0.6444 max_f1 0.6444
# avg max pair: max_acc 0.9211 max_p 0.4944 max_r 0.4889 max_f1 0.4916
#
# Fold 1 Epoch 11 val loss 2.4444
# emotion_predict: val acc 0.8125 p 0.7746 r 0.6111 f1 0.6832
# max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
#
# cause_predict: val acc 0.7610 p 0.6866 r 0.5111 f1 0.5860
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9281 p 0.5443 r 0.4778 f1 0.5089
# max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# avg max cause: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pos: max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
# avg max pair: max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# Fold 1 Epoch 12 val loss 2.4449
# emotion_predict: val acc 0.7831 p 0.6703 r 0.6778 f1 0.6740
# max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
#
# cause_predict: val acc 0.7831 p 0.7313 r 0.5444 f1 0.6242
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9159 p 0.4660 r 0.5333 f1 0.4974
# max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# avg max cause: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pos: max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
# avg max pair: max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# Fold 1 Epoch 13 val loss 2.5313
# emotion_predict: val acc 0.8088 p 0.7568 r 0.6222 f1 0.6829
# max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
#
# cause_predict: val acc 0.7684 p 0.6753 r 0.5778 f1 0.6228
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9246 p 0.5200 r 0.4333 f1 0.4727
# max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# avg max cause: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pos: max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
# avg max pair: max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# Fold 1 Epoch 14 val loss 2.4927
# emotion_predict: val acc 0.8235 p 0.7561 r 0.6889 f1 0.7209
# max_acc 0.8235 max_p 0.7561 max_r 0.6889 max_f1 0.7209
#
# cause_predict: val acc 0.7684 p 0.6753 r 0.5778 f1 0.6228
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9159 p 0.4660 r 0.5333 f1 0.4974
# max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# avg max cause: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pos: max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
# avg max pair: max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# Fold 1 Epoch 15 val loss 2.5598
# emotion_predict: val acc 0.7941 p 0.6977 r 0.6667 f1 0.6818
# max_acc 0.8235 max_p 0.7561 max_r 0.6889 max_f1 0.7209
#
# cause_predict: val acc 0.7721 p 0.7258 r 0.5000 f1 0.5921
# max_acc 0.7978 max_p 0.7778 max_r 0.5444 max_f1 0.6405
#
# pair_predict: val acc 0.9211 p 0.4943 r 0.4778 f1 0.4859
# max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# avg max cause: max_acc 0.7610 max_p 0.6866 max_r 0.5111 max_f1 0.5860
# avg max pos: max_acc 0.8125 max_p 0.7746 max_r 0.6111 max_f1 0.6832
# avg max pair: max_acc 0.9281 max_p 0.5443 max_r 0.4778 max_f1 0.5089
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.58598726]]
# average : acc 0.7610 p 0.6866 r 0.5111 f1 0.5860
#
# emotion_predict: val f1 in 1 fold: [[0.68322981]]
# average : acc 0.8125 p 0.7746 r 0.6111 f1 0.6832
#
# pair_predict: val f1 in 1 fold: [[0.50887574]]
# average : acc 0.9281 p 0.5443 r 0.4778 f1 0.5089

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([64, 41, 30, 200]), distance: torch.Size([64, 1681, 30]), y_pos: torch.Size([64, 41, 2]), y_cause: torch.Size([64, 41, 2]), y_pair: torch.Size([64, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 2.7857
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.5470
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.6985 p 0.7000 r 0.1556 f1 0.2545
# max_acc 0.6985 max_p 0.7000 max_r 0.1556 max_f1 0.2545
#
# pair_predict: val acc 0.9263 p 0.7778 r 0.0778 f1 0.1414
# max_acc 0.9263 max_p 0.7778 max_r 0.0778 max_f1 0.1414
#
# avg max cause: max_acc 0.6985 max_p 0.7000 max_r 0.1556 max_f1 0.2545
# avg max pos: max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
# avg max pair: max_acc 0.9263 max_p 0.7778 max_r 0.0778 max_f1 0.1414
#
# Fold 1 Epoch 3 val loss 2.3810
# emotion_predict: val acc 0.7390 p 0.6792 r 0.4000 f1 0.5035
# max_acc 0.7390 max_p 0.6792 max_r 0.4000 max_f1 0.5035
#
# cause_predict: val acc 0.7500 p 0.6528 r 0.5222 f1 0.5802
# max_acc 0.7500 max_p 0.6528 max_r 0.5222 max_f1 0.5802
#
# pair_predict: val acc 0.8562 p 0.2765 r 0.5222 f1 0.3615
# max_acc 0.8562 max_p 0.2765 max_r 0.5222 max_f1 0.3615
#
# avg max cause: max_acc 0.7500 max_p 0.6528 max_r 0.5222 max_f1 0.5802
# avg max pos: max_acc 0.7390 max_p 0.6792 max_r 0.4000 max_f1 0.5035
# avg max pair: max_acc 0.8562 max_p 0.2765 max_r 0.5222 max_f1 0.3615
#
# Fold 1 Epoch 4 val loss 2.3527
# emotion_predict: val acc 0.7537 p 0.7447 r 0.3889 f1 0.5109
# max_acc 0.7537 max_p 0.7447 max_r 0.3889 max_f1 0.5109
#
# cause_predict: val acc 0.7537 p 0.6825 r 0.4778 f1 0.5621
# max_acc 0.7500 max_p 0.6528 max_r 0.5222 max_f1 0.5802
#
# pair_predict: val acc 0.9021 p 0.3925 r 0.4667 f1 0.4264
# max_acc 0.9021 max_p 0.3925 max_r 0.4667 max_f1 0.4264
#
# avg max cause: max_acc 0.7537 max_p 0.6825 max_r 0.4778 max_f1 0.5621
# avg max pos: max_acc 0.7537 max_p 0.7447 max_r 0.3889 max_f1 0.5109
# avg max pair: max_acc 0.9021 max_p 0.3925 max_r 0.4667 max_f1 0.4264
#
# Fold 1 Epoch 5 val loss 2.2199
# emotion_predict: val acc 0.7206 p 0.5875 r 0.5222 f1 0.5529
# max_acc 0.7206 max_p 0.5875 max_r 0.5222 max_f1 0.5529
#
# cause_predict: val acc 0.7684 p 0.6753 r 0.5778 f1 0.6228
# max_acc 0.7684 max_p 0.6753 max_r 0.5778 max_f1 0.6228
#
# pair_predict: val acc 0.8510 p 0.2908 r 0.6333 f1 0.3986
# max_acc 0.9021 max_p 0.3925 max_r 0.4667 max_f1 0.4264
#
# avg max cause: max_acc 0.7537 max_p 0.6825 max_r 0.4778 max_f1 0.5621
# avg max pos: max_acc 0.7537 max_p 0.7447 max_r 0.3889 max_f1 0.5109
# avg max pair: max_acc 0.9021 max_p 0.3925 max_r 0.4667 max_f1 0.4264
#
# Fold 1 Epoch 6 val loss 2.1788
# emotion_predict: val acc 0.7463 p 0.6981 r 0.4111 f1 0.5175
# max_acc 0.7206 max_p 0.5875 max_r 0.5222 max_f1 0.5529
#
# cause_predict: val acc 0.7721 p 0.7917 r 0.4222 f1 0.5507
# max_acc 0.7684 max_p 0.6753 max_r 0.5778 max_f1 0.6228
#
# pair_predict: val acc 0.9133 p 0.4490 r 0.4889 f1 0.4681
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 7 val loss 2.1560
# emotion_predict: val acc 0.7721 p 0.6892 r 0.5667 f1 0.6220
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# cause_predict: val acc 0.7684 p 0.6800 r 0.5667 f1 0.6182
# max_acc 0.7684 max_p 0.6753 max_r 0.5778 max_f1 0.6228
#
# pair_predict: val acc 0.8917 p 0.3684 r 0.5444 f1 0.4395
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 8 val loss 2.1033
# emotion_predict: val acc 0.7831 p 0.7719 r 0.4889 f1 0.5986
# max_acc 0.7721 max_p 0.6892 max_r 0.5667 max_f1 0.6220
#
# cause_predict: val acc 0.7831 p 0.7541 r 0.5111 f1 0.6093
# max_acc 0.7684 max_p 0.6753 max_r 0.5778 max_f1 0.6228
#
# pair_predict: val acc 0.8969 p 0.3876 r 0.5556 f1 0.4566
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 9 val loss 2.0916
# emotion_predict: val acc 0.7721 p 0.6628 r 0.6333 f1 0.6477
# max_acc 0.7721 max_p 0.6628 max_r 0.6333 max_f1 0.6477
#
# cause_predict: val acc 0.7647 p 0.6585 r 0.6000 f1 0.6279
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.8692 p 0.3174 r 0.5889 f1 0.4125
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 10 val loss 2.1571
# emotion_predict: val acc 0.7757 p 0.6835 r 0.6000 f1 0.6391
# max_acc 0.7721 max_p 0.6628 max_r 0.6333 max_f1 0.6477
#
# cause_predict: val acc 0.7721 p 0.6842 r 0.5778 f1 0.6265
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.8830 p 0.3427 r 0.5444 f1 0.4206
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 11 val loss 2.1482
# emotion_predict: val acc 0.7941 p 0.7297 r 0.6000 f1 0.6585
# max_acc 0.7941 max_p 0.7297 max_r 0.6000 max_f1 0.6585
#
# cause_predict: val acc 0.7684 p 0.6800 r 0.5667 f1 0.6182
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.8761 p 0.3354 r 0.6000 f1 0.4303
# max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# avg max cause: max_acc 0.7721 max_p 0.7917 max_r 0.4222 max_f1 0.5507
# avg max pos: max_acc 0.7463 max_p 0.6981 max_r 0.4111 max_f1 0.5175
# avg max pair: max_acc 0.9133 max_p 0.4490 max_r 0.4889 max_f1 0.4681
#
# Fold 1 Epoch 12 val loss 2.2353
# emotion_predict: val acc 0.7941 p 0.7125 r 0.6333 f1 0.6706
# max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
#
# cause_predict: val acc 0.7684 p 0.6849 r 0.5556 f1 0.6135
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.9151 p 0.4608 r 0.5222 f1 0.4896
# max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# avg max cause: max_acc 0.7684 max_p 0.6849 max_r 0.5556 max_f1 0.6135
# avg max pos: max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
# avg max pair: max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# Fold 1 Epoch 13 val loss 2.2505
# emotion_predict: val acc 0.7794 p 0.6923 r 0.6000 f1 0.6429
# max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
#
# cause_predict: val acc 0.7574 p 0.6622 r 0.5444 f1 0.5976
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.8778 p 0.3416 r 0.6111 f1 0.4382
# max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# avg max cause: max_acc 0.7684 max_p 0.6849 max_r 0.5556 max_f1 0.6135
# avg max pos: max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
# avg max pair: max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# Fold 1 Epoch 14 val loss 2.3119
# emotion_predict: val acc 0.8051 p 0.7534 r 0.6111 f1 0.6748
# max_acc 0.8051 max_p 0.7534 max_r 0.6111 max_f1 0.6748
#
# cause_predict: val acc 0.7684 p 0.7015 r 0.5222 f1 0.5987
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.9107 p 0.4381 r 0.5111 f1 0.4718
# max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# avg max cause: max_acc 0.7684 max_p 0.6849 max_r 0.5556 max_f1 0.6135
# avg max pos: max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
# avg max pair: max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# Fold 1 Epoch 15 val loss 2.4186
# emotion_predict: val acc 0.7684 p 0.6517 r 0.6444 f1 0.6480
# max_acc 0.8051 max_p 0.7534 max_r 0.6111 max_f1 0.6748
#
# cause_predict: val acc 0.7574 p 0.6463 r 0.5889 f1 0.6163
# max_acc 0.7647 max_p 0.6585 max_r 0.6000 max_f1 0.6279
#
# pair_predict: val acc 0.8839 p 0.3533 r 0.5889 f1 0.4417
# max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# avg max cause: max_acc 0.7684 max_p 0.6849 max_r 0.5556 max_f1 0.6135
# avg max pos: max_acc 0.7941 max_p 0.7125 max_r 0.6333 max_f1 0.6706
# avg max pair: max_acc 0.9151 max_p 0.4608 max_r 0.5222 max_f1 0.4896
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.61349693]]
# average : acc 0.7684 p 0.6849 r 0.5556 f1 0.6135
#
# emotion_predict: val f1 in 1 fold: [[0.67058823]]
# average : acc 0.7941 p 0.7125 r 0.6333 f1 0.6706
#
# pair_predict: val f1 in 1 fold: [[0.48958333]]
# average : acc 0.9151 p 0.4608 r 0.5222 f1 0.4896

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.6871
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 4.1253
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.5846 p 0.4286 r 0.7667 f1 0.5498
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.5762
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.1360
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.1802
# emotion_predict: val acc 0.6875 p 0.7778 r 0.0778 f1 0.1414
# max_acc 0.6875 max_p 0.7778 max_r 0.0778 max_f1 0.1414
#
# cause_predict: val acc 0.6949 p 0.8182 r 0.1000 f1 0.1782
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.5397
# emotion_predict: val acc 0.5294 p 0.3967 r 0.8111 f1 0.5328
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.4522 p 0.3723 r 0.9556 f1 0.5358
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 3.2341
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6949 p 0.8889 r 0.0889 f1 0.1616
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 3.1874
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 3.0649
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 3.0988
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 11 val loss 3.1843
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 12 val loss 3.1737
# emotion_predict: val acc 0.6912 p 0.8750 r 0.0778 f1 0.1429
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 13 val loss 3.0998
# emotion_predict: val acc 0.7279 p 0.8333 r 0.2222 f1 0.3509
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 14 val loss 3.0423
# emotion_predict: val acc 0.7353 p 0.7812 r 0.2778 f1 0.4098
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6875 p 0.8571 r 0.0667 f1 0.1237
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 15 val loss 3.0321
# emotion_predict: val acc 0.7169 p 0.8095 r 0.1889 f1 0.3063
# max_acc 0.5294 max_p 0.3967 max_r 0.8111 max_f1 0.5328
#
# cause_predict: val acc 0.6838 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.5846 max_p 0.4286 max_r 0.7667 max_f1 0.5498
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# emotion_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# pair_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.9220 p 0.0000 r 0.0000 f1 0.0000

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.005
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 4.0824
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.3440
# emotion_predict: val acc 0.6213 p 0.4480 r 0.6222 f1 0.5209
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6801 p 0.5116 r 0.7333 f1 0.6027
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.0780 p 0.0780 r 1.0000 f1 0.1447
# max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# avg max cause: max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
# avg max pos: max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
# avg max pair: max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# Fold 1 Epoch 3 val loss 3.0696
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# avg max cause: max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
# avg max pos: max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
# avg max pair: max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# Fold 1 Epoch 4 val loss 2.9173
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9229 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# avg max cause: max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
# avg max pos: max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
# avg max pair: max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# Fold 1 Epoch 5 val loss 2.7946
# emotion_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# avg max cause: max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
# avg max pos: max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
# avg max pair: max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# Fold 1 Epoch 6 val loss 2.7131
# emotion_predict: val acc 0.6801 p 0.8000 r 0.0444 f1 0.0842
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 0.6667 r 0.0222 f1 0.0430
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# avg max cause: max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
# avg max pos: max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
# avg max pair: max_acc 0.0780 max_p 0.0780 max_r 1.0000 max_f1 0.1447
#
# Fold 1 Epoch 7 val loss 2.5491
# emotion_predict: val acc 0.7279 p 0.7000 r 0.3111 f1 0.4308
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.7353 p 0.8462 r 0.2444 f1 0.3793
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9333 p 0.8824 r 0.1667 f1 0.2804
# max_acc 0.9333 max_p 0.8824 max_r 0.1667 max_f1 0.2804
#
# avg max cause: max_acc 0.7353 max_p 0.8462 max_r 0.2444 max_f1 0.3793
# avg max pos: max_acc 0.7279 max_p 0.7000 max_r 0.3111 max_f1 0.4308
# avg max pair: max_acc 0.9333 max_p 0.8824 max_r 0.1667 max_f1 0.2804
#
# Fold 1 Epoch 8 val loss 3.9514
# emotion_predict: val acc 0.4007 p 0.3498 r 0.9444 f1 0.5105
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.4118 p 0.3589 r 0.9889 f1 0.5266
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.2028 p 0.0875 r 0.9778 f1 0.1606
# max_acc 0.9333 max_p 0.8824 max_r 0.1667 max_f1 0.2804
#
# avg max cause: max_acc 0.7353 max_p 0.8462 max_r 0.2444 max_f1 0.3793
# avg max pos: max_acc 0.7279 max_p 0.7000 max_r 0.3111 max_f1 0.4308
# avg max pair: max_acc 0.9333 max_p 0.8824 max_r 0.1667 max_f1 0.2804
#
# Fold 1 Epoch 9 val loss 2.5569
# emotion_predict: val acc 0.6985 p 0.9000 r 0.1000 f1 0.1800
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.7243 p 0.8571 r 0.2000 f1 0.3243
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9315 p 0.7619 r 0.1778 f1 0.2883
# max_acc 0.9315 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# avg max cause: max_acc 0.7243 max_p 0.8571 max_r 0.2000 max_f1 0.3243
# avg max pos: max_acc 0.6985 max_p 0.9000 max_r 0.1000 max_f1 0.1800
# avg max pair: max_acc 0.9315 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# Fold 1 Epoch 10 val loss 2.6715
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9315 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# avg max cause: max_acc 0.7243 max_p 0.8571 max_r 0.2000 max_f1 0.3243
# avg max pos: max_acc 0.6985 max_p 0.9000 max_r 0.1000 max_f1 0.1800
# avg max pair: max_acc 0.9315 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# Fold 1 Epoch 11 val loss 2.6094
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.9003 p 0.3333 r 0.2778 f1 0.3030
# max_acc 0.9003 max_p 0.3333 max_r 0.2778 max_f1 0.3030
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9003 max_p 0.3333 max_r 0.2778 max_f1 0.3030
#
# Fold 1 Epoch 12 val loss 2.6120
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.8977 p 0.3372 r 0.3222 f1 0.3295
# max_acc 0.8977 max_p 0.3372 max_r 0.3222 max_f1 0.3295
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8977 max_p 0.3372 max_r 0.3222 max_f1 0.3295
#
# Fold 1 Epoch 13 val loss 2.6458
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.8986 p 0.3483 r 0.3444 f1 0.3464
# max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# Fold 1 Epoch 14 val loss 2.6405
# emotion_predict: val acc 0.7426 p 0.8846 r 0.2556 f1 0.3966
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.7059 p 0.9167 r 0.1222 f1 0.2157
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.8986 p 0.3483 r 0.3444 f1 0.3464
# max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# Fold 1 Epoch 15 val loss 2.6103
# emotion_predict: val acc 0.7022 p 0.9091 r 0.1111 f1 0.1980
# max_acc 0.6213 max_p 0.4480 max_r 0.6222 max_f1 0.5209
#
# cause_predict: val acc 0.7279 p 0.9444 r 0.1889 f1 0.3148
# max_acc 0.6801 max_p 0.5116 max_r 0.7333 max_f1 0.6027
#
# pair_predict: val acc 0.8986 p 0.3483 r 0.3444 f1 0.3464
# max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# avg max cause: max_acc 0.6728 max_p 1.0000 max_r 0.0111 max_f1 0.0220
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.8986 max_p 0.3483 max_r 0.3444 max_f1 0.3464
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.02197802]]
# average : acc 0.6728 p 1.0000 r 0.0111 f1 0.0220
#
# emotion_predict: val f1 in 1 fold: [[0.]]
# average : acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
#
# pair_predict: val f1 in 1 fold: [[0.34636871]]
# average : acc 0.8986 p 0.3483 r 0.3444 f1 0.3464

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.400

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.6128
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 3.3644
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 3.3036
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 3.2124
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 3.2288
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 3.1301
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 7 val loss 2.9875
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6654 p 0.3333 r 0.0111 f1 0.0215
# max_acc 0.6654 max_p 0.3333 max_r 0.0111 max_f1 0.0215
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 8 val loss 2.9142
# emotion_predict: val acc 0.6765 p 1.0000 r 0.0222 f1 0.0435
# max_acc 0.6765 max_p 1.0000 max_r 0.0222 max_f1 0.0435
#
# cause_predict: val acc 0.7096 p 0.7619 r 0.1778 f1 0.2883
# max_acc 0.7096 max_p 0.7619 max_r 0.1778 max_f1 0.2883
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 9 val loss 2.8575
# emotion_predict: val acc 0.7426 p 0.7632 r 0.3222 f1 0.4531
# max_acc 0.7426 max_p 0.7632 max_r 0.3222 max_f1 0.4531
#
# cause_predict: val acc 0.7610 p 0.7551 r 0.4111 f1 0.5324
# max_acc 0.7610 max_p 0.7551 max_r 0.4111 max_f1 0.5324
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 10 val loss 2.8141
# emotion_predict: val acc 0.7022 p 0.5529 r 0.5222 f1 0.5371
# max_acc 0.7022 max_p 0.5529 max_r 0.5222 max_f1 0.5371
#
# cause_predict: val acc 0.7243 p 0.5904 r 0.5444 f1 0.5665
# max_acc 0.7243 max_p 0.5904 max_r 0.5444 max_f1 0.5665
#
# pair_predict: val acc 0.9341 p 0.6944 r 0.2778 f1 0.3968
# max_acc 0.9341 max_p 0.6944 max_r 0.2778 max_f1 0.3968
#
# avg max cause: max_acc 0.7243 max_p 0.5904 max_r 0.5444 max_f1 0.5665
# avg max pos: max_acc 0.7022 max_p 0.5529 max_r 0.5222 max_f1 0.5371
# avg max pair: max_acc 0.9341 max_p 0.6944 max_r 0.2778 max_f1 0.3968
#
# Fold 1 Epoch 11 val loss 2.8182
# emotion_predict: val acc 0.6985 p 0.5408 r 0.5889 f1 0.5638
# max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
#
# cause_predict: val acc 0.7279 p 0.5833 r 0.6222 f1 0.6022
# max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
#
# pair_predict: val acc 0.9211 p 0.4928 r 0.3778 f1 0.4277
# max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# avg max cause: max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
# avg max pos: max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
# avg max pair: max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# Fold 1 Epoch 12 val loss 2.7791
# emotion_predict: val acc 0.7022 p 0.5529 r 0.5222 f1 0.5371
# max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
#
# cause_predict: val acc 0.7426 p 0.6190 r 0.5778 f1 0.5977
# max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
#
# pair_predict: val acc 0.9142 p 0.4416 r 0.3778 f1 0.4072
# max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# avg max cause: max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
# avg max pos: max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
# avg max pair: max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# Fold 1 Epoch 13 val loss 2.7473
# emotion_predict: val acc 0.7390 p 0.6557 r 0.4444 f1 0.5298
# max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
#
# cause_predict: val acc 0.7537 p 0.6667 r 0.5111 f1 0.5786
# max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
#
# pair_predict: val acc 0.9220 p 0.5000 r 0.3444 f1 0.4079
# max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# avg max cause: max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
# avg max pos: max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
# avg max pair: max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# Fold 1 Epoch 14 val loss 2.7220
# emotion_predict: val acc 0.7574 p 0.7308 r 0.4222 f1 0.5352
# max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
#
# cause_predict: val acc 0.7500 p 0.6833 r 0.4556 f1 0.5467
# max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
#
# pair_predict: val acc 0.9263 p 0.5439 r 0.3444 f1 0.4218
# max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# avg max cause: max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
# avg max pos: max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
# avg max pair: max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# Fold 1 Epoch 15 val loss 2.6598
# emotion_predict: val acc 0.7647 p 0.7407 r 0.4444 f1 0.5556
# max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
#
# cause_predict: val acc 0.7500 p 0.6719 r 0.4778 f1 0.5584
# max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
#
# pair_predict: val acc 0.9177 p 0.4627 r 0.3444 f1 0.3949
# max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# avg max cause: max_acc 0.7279 max_p 0.5833 max_r 0.6222 max_f1 0.6022
# avg max pos: max_acc 0.6985 max_p 0.5408 max_r 0.5889 max_f1 0.5638
# avg max pair: max_acc 0.9211 max_p 0.4928 max_r 0.3778 max_f1 0.4277
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.60215054]]
# average : acc 0.7279 p 0.5833 r 0.6222 f1 0.6022
#
# emotion_predict: val f1 in 1 fold: [[0.56382979]]
# average : acc 0.6985 p 0.5408 r 0.5889 f1 0.5638
#
# pair_predict: val f1 in 1 fold: [[0.42767296]]
# average : acc 0.9211 p 0.4928 r 0.3778 f1 0.4277

# %%
# HYPERPARAMETERS TO BE TUNED
N_HIDDEN = 256
BATCH_SIZE = 128
LEARNING_RATE = 0.001
DIMINISH_FACTOR = 0.200

# MAIN MODEL
Model = E2E_PextC(embedding_dim, embedding_dim_pos, max_sen_len, max_doc_len, \
keep_prob1, keep_prob2, keep_prob3, N_HIDDEN, n_class)
Model.to(device)
print(Model)
x = torch.rand([BATCH_SIZE, max_doc_len, max_sen_len, embedding_dim]).to(device)
distance = torch.rand([BATCH_SIZE, max_doc_len * max_doc_len, embedding_dim_pos]).to(device)
pred_pos, pred_cause, pred_pair = Model(x, distance)
print("Random i/o shapes x: {}, distance: {}, y_pos: {}, y_cause: {}, y_pair: {}".format(
    x.shape, distance.shape, pred_pos.shape, pred_cause.shape, pred_pair.shape))
pos_cause_criterion = ce_loss_aux(); pair_criterion = ce_loss_pair(DIMINISH_FACTOR)
optimizer = optim.Adam(Model.parameters(), lr=LEARNING_RATE, weight_decay=l2_reg)
train_and_eval(Model, pos_cause_criterion, pair_criterion, optimizer, N_HIDDEN, BATCH_SIZE, LEARNING_RATE, DIMINISH_FACTOR)
# Out:
# E2E_PextC(
#   (dropout1): Dropout(p=0.19999999999999996, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (dropout3): Dropout(p=0.0, inplace=False)
#   (relu): ReLU()
#   (pos_linear): Linear(in_features=512, out_features=2, bias=True)
#   (cause_linear): Linear(in_features=512, out_features=2, bias=True)
#   (pair_linear1): Linear(in_features=1054, out_features=128, bias=True)
#   (pair_linear2): Linear(in_features=128, out_features=2, bias=True)
#   (word_bilstm): LSTM(200, 256, batch_first=True, bidirectional=True)
#   (cause_bilstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#   (pos_bilstm): LSTM(514, 256, batch_first=True, bidirectional=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=512, out_features=512, bias=True)
#     (linear2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# Random i/o shapes x: torch.Size([128, 41, 30, 200]), distance: torch.Size([128, 1681, 30]), y_pos: torch.Size([128, 41, 2]), y_cause: torch.Size([128, 41, 2]), y_pair: torch.Size([128, 1681, 2])
#
# load embedding...
# w2v_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/w2v_200.txt
# all_words: 1479 hit_words: 1122
# embedding.shape: (1481, 200) embedding_pos.shape: (201, 30)
# load embedding done!
#
# ############# fold 1 begin ###############
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_train_1.txt
# y_position.shape torch.Size([207, 41, 2])
# y_cause.shape torch.Size([207, 41, 2])
# y_pair.shape torch.Size([207, 1681, 2])
# x.shape torch.Size([207, 41, 30])
# sen_len.shape torch.Size([207, 41])
# doc_len.shape torch.Size([207])
# distance.shape torch.Size([207, 1681])
# n_cut 0
# load data done!
#
# load data_file: ./drive/MyDrive/fyp-code/codes/data/ecpe/ecpe_short_annotated_val_1.txt
# y_position.shape torch.Size([90, 41, 2])
# y_cause.shape torch.Size([90, 41, 2])
# y_pair.shape torch.Size([90, 1681, 2])
# x.shape torch.Size([90, 41, 30])
# sen_len.shape torch.Size([90, 41])
# doc_len.shape torch.Size([90])
# distance.shape torch.Size([90, 1681])
# n_cut 1
# load data done!
#
# Fold 1 Epoch 1 val loss 3.0043
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 2 val loss 2.8745
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 3 val loss 2.8337
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 4 val loss 2.7790
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 5 val loss 2.7129
# emotion_predict: val acc 0.6691 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# cause_predict: val acc 0.6838 p 0.8333 r 0.0556 f1 0.1042
# max_acc 0.6838 max_p 0.8333 max_r 0.0556 max_f1 0.1042
#
# pair_predict: val acc 0.9220 p 0.0000 r 0.0000 f1 0.0000
# max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# avg max cause: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pos: max_acc 0.6691 max_p 0.0000 max_r 0.0000 max_f1 0.0000
# avg max pair: max_acc 0.9220 max_p 0.0000 max_r 0.0000 max_f1 0.0000
#
# Fold 1 Epoch 6 val loss 2.6770
# emotion_predict: val acc 0.6765 p 0.7500 r 0.0333 f1 0.0638
# max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
#
# cause_predict: val acc 0.7426 p 0.6471 r 0.4889 f1 0.5570
# max_acc 0.7426 max_p 0.6471 max_r 0.4889 max_f1 0.5570
#
# pair_predict: val acc 0.9324 p 0.7727 r 0.1889 f1 0.3036
# max_acc 0.9324 max_p 0.7727 max_r 0.1889 max_f1 0.3036
#
# avg max cause: max_acc 0.7426 max_p 0.6471 max_r 0.4889 max_f1 0.5570
# avg max pos: max_acc 0.6765 max_p 0.7500 max_r 0.0333 max_f1 0.0638
# avg max pair: max_acc 0.9324 max_p 0.7727 max_r 0.1889 max_f1 0.3036
#
# Fold 1 Epoch 7 val loss 2.6048
# emotion_predict: val acc 0.7500 p 0.7292 r 0.3889 f1 0.5072
# max_acc 0.7500 max_p 0.7292 max_r 0.3889 max_f1 0.5072
#
# cause_predict: val acc 0.7426 p 0.6282 r 0.5444 f1 0.5833
# max_acc 0.7426 max_p 0.6282 max_r 0.5444 max_f1 0.5833
#
# pair_predict: val acc 0.9203 p 0.4828 r 0.3111 f1 0.3784
# max_acc 0.9203 max_p 0.4828 max_r 0.3111 max_f1 0.3784
#
# avg max cause: max_acc 0.7426 max_p 0.6282 max_r 0.5444 max_f1 0.5833
# avg max pos: max_acc 0.7500 max_p 0.7292 max_r 0.3889 max_f1 0.5072
# avg max pair: max_acc 0.9203 max_p 0.4828 max_r 0.3111 max_f1 0.3784
#
# Fold 1 Epoch 8 val loss 2.4890
# emotion_predict: val acc 0.7426 p 0.7500 r 0.3333 f1 0.4615
# max_acc 0.7500 max_p 0.7292 max_r 0.3889 max_f1 0.5072
#
# cause_predict: val acc 0.7426 p 0.7174 r 0.3667 f1 0.4853
# max_acc 0.7426 max_p 0.6282 max_r 0.5444 max_f1 0.5833
#
# pair_predict: val acc 0.9289 p 0.5952 r 0.2778 f1 0.3788
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 9 val loss 2.4454
# emotion_predict: val acc 0.7500 p 0.6964 r 0.4333 f1 0.5342
# max_acc 0.7500 max_p 0.6964 max_r 0.4333 max_f1 0.5342
#
# cause_predict: val acc 0.7426 p 0.7000 r 0.3889 f1 0.5000
# max_acc 0.7426 max_p 0.6282 max_r 0.5444 max_f1 0.5833
#
# pair_predict: val acc 0.9168 p 0.4531 r 0.3222 f1 0.3766
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 10 val loss 2.4398
# emotion_predict: val acc 0.6912 p 0.5357 r 0.5000 f1 0.5172
# max_acc 0.7500 max_p 0.6964 max_r 0.4333 max_f1 0.5342
#
# cause_predict: val acc 0.7500 p 0.6447 r 0.5444 f1 0.5904
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8492 p 0.2614 r 0.5111 f1 0.3459
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 11 val loss 2.4091
# emotion_predict: val acc 0.7353 p 0.6364 r 0.4667 f1 0.5385
# max_acc 0.7353 max_p 0.6364 max_r 0.4667 max_f1 0.5385
#
# cause_predict: val acc 0.7500 p 0.6774 r 0.4667 f1 0.5526
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8718 p 0.2899 r 0.4444 f1 0.3509
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 12 val loss 2.3920
# emotion_predict: val acc 0.7353 p 0.6406 r 0.4556 f1 0.5325
# max_acc 0.7353 max_p 0.6364 max_r 0.4667 max_f1 0.5385
#
# cause_predict: val acc 0.7500 p 0.6774 r 0.4667 f1 0.5526
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8579 p 0.2824 r 0.5333 f1 0.3692
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 13 val loss 2.3749
# emotion_predict: val acc 0.7353 p 0.6406 r 0.4556 f1 0.5325
# max_acc 0.7353 max_p 0.6364 max_r 0.4667 max_f1 0.5385
#
# cause_predict: val acc 0.7574 p 0.6765 r 0.5111 f1 0.5823
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8293 p 0.2512 r 0.6000 f1 0.3541
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 14 val loss 2.3379
# emotion_predict: val acc 0.7537 p 0.7255 r 0.4111 f1 0.5248
# max_acc 0.7353 max_p 0.6364 max_r 0.4667 max_f1 0.5385
#
# cause_predict: val acc 0.7610 p 0.7049 r 0.4778 f1 0.5695
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8769 p 0.3116 r 0.4778 f1 0.3772
# max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# avg max cause: max_acc 0.7426 max_p 0.7174 max_r 0.3667 max_f1 0.4853
# avg max pos: max_acc 0.7426 max_p 0.7500 max_r 0.3333 max_f1 0.4615
# avg max pair: max_acc 0.9289 max_p 0.5952 max_r 0.2778 max_f1 0.3788
#
# Fold 1 Epoch 15 val loss 2.2952
# emotion_predict: val acc 0.7537 p 0.7018 r 0.4444 f1 0.5442
# max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
#
# cause_predict: val acc 0.7574 p 0.6818 r 0.5000 f1 0.5769
# max_acc 0.7500 max_p 0.6447 max_r 0.5444 max_f1 0.5904
#
# pair_predict: val acc 0.8761 p 0.3121 r 0.4889 f1 0.3810
# max_acc 0.8761 max_p 0.3121 max_r 0.4889 max_f1 0.3810
#
# avg max cause: max_acc 0.7574 max_p 0.6818 max_r 0.5000 max_f1 0.5769
# avg max pos: max_acc 0.7537 max_p 0.7018 max_r 0.4444 max_f1 0.5442
# avg max pair: max_acc 0.8761 max_p 0.3121 max_r 0.4889 max_f1 0.3810
#
# ############# fold 1 end ###############
#
# cause_predict: val f1 in 1 fold: [[0.57692308]]
# average : acc 0.7574 p 0.6818 r 0.5000 f1 0.5769
#
# emotion_predict: val f1 in 1 fold: [[0.54421769]]
# average : acc 0.7537 p 0.7018 r 0.4444 f1 0.5442
#
# pair_predict: val f1 in 1 fold: [[0.38095238]]
# average : acc 0.8761 p 0.3121 r 0.4889 f1 0.3810
